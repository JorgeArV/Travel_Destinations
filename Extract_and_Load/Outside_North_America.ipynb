# %%
import pandas as pd
import os

# %%
df1 = pd.read_csv(os.path.join("../Resources/Melbourne.csv"))
df1.insert(0,'city','Melbourne, AU')
df1.head(3)
# Out:
#             city     id                         listing_url       scrape_id  \
# 0  Melbourne, AU   9835   https://www.airbnb.com/rooms/9835  20210208234751
# 1  Melbourne, AU  10803  https://www.airbnb.com/rooms/10803  20210208234751
# 2  Melbourne, AU  12936  https://www.airbnb.com/rooms/12936  20210208234751
#
#   last_scraped                                           name  \
# 0   2021-02-12                         Beautiful Room & House
# 1   2021-02-09  Room in Cool Deco Apartment in Brunswick East
# 2   2021-02-09         St Kilda 1BR+BEACHSIDE+BALCONY+WIFI+AC
#
#                                          description  \
# 0  <b>The space</b><br />House: Clean, New, Moder...
# 1  A large air conditioned room with queen spring...
# 2  RIGHT IN THE HEART OF ST KILDA! It doesn't get...
#
#                                neighborhood_overview  \
# 0       Very safe! Family oriented. Older age group.
# 1  This hip area is a crossroads between two grea...
# ...

# %%
df2 = pd.read_csv(os.path.join("../Resources/Rio De Janeiro.csv"))
df2.insert(0,'city','Rio de Janeiro, BR')
df2.head(3)
# Out:
#                  city     id                         listing_url  \
# 0  Rio de Janeiro, BR  17878  https://www.airbnb.com/rooms/17878
# 1  Rio de Janeiro, BR  24480  https://www.airbnb.com/rooms/24480
# 2  Rio de Janeiro, BR  25026  https://www.airbnb.com/rooms/25026
#
#         scrape_id last_scraped  \
# 0  20210222161029   2021-02-23
# 1  20210222161029   2021-02-23
# 2  20210222161029   2021-02-23
#
#                                                 name  \
# 0  Very Nice 2Br in Copacabana w. balcony, fast WiFi
# 1                   Nice and cozy near Ipanema Beach
# 2          Beautiful Modern Decorated Studio in Copa
#
#                                          description  \
# 0  Discounts for long term stays. <br />- Large b...
# 1  My studio is located in the best  of Ipanema. ...
# 2  Our apartment is a little gem, everyone loves ...
#
#                                neighborhood_overview  \
# 0  This is the one of the bests spots in Rio. Bec...
# ...

# %%
df3 = pd.read_csv(os.path.join("../Resources/Mexico City.csv"))
df3.insert(0,'city','Mexico City, ME')
df3.head(3)
# Out:
#               city     id                         listing_url       scrape_id  \
# 0  Mexico City, ME  35797  https://www.airbnb.com/rooms/35797  20210223160913
# 1  Mexico City, ME  44616  https://www.airbnb.com/rooms/44616  20210223160913
# 2  Mexico City, ME  56074  https://www.airbnb.com/rooms/56074  20210223160913
#
#   last_scraped                                  name  \
# 0   2021-02-23                           Villa Dante
# 1   2021-02-24                     CONDESA HAUS  B&B
# 2   2021-02-24  Great space in historical San Rafael
#
#                                          description  \
# 0  Dentro de Villa un estudio de arte con futon, ...
# 1  A new concept of hosting in mexico through a b...
# 2  This great apartment is located in one of the ...
#
#                                neighborhood_overview  \
# 0  Centro comercial Santa Fe, parque interlomas y...
# 1                                                NaN
# 2  Very traditional neighborhood with all service...
#
# ...

# %%
df4 = pd.read_csv(os.path.join("../Resources/Cape Town.csv"))
df4.insert(0,'city','Cape Town, RSA')
df4.head(3)
# Out:
#              city     id                         listing_url       scrape_id  \
# 0  Cape Town, RSA   3191   https://www.airbnb.com/rooms/3191  20210223161002
# 1  Cape Town, RSA  15007  https://www.airbnb.com/rooms/15007  20210223161002
# 2  Cape Town, RSA  15068  https://www.airbnb.com/rooms/15068  20210223161002
#
#   last_scraped                     name  \
# 0   2021-02-24  Malleson Garden Cottage
# 1   2021-02-24         Blaauwberg House
# 2   2021-02-24               Grande Bay
#
#                                          description  \
# 0  This is a lovely, separate, self-catering cott...
# 1  Welcome to our self-catering beach-front famil...
# 2  Modern spacious apartment.  Three bedrooms two...
#
#                                neighborhood_overview  \
# 0  Mowbray is on the Southern Suburbs line, 6km (...
# 1  Bloubergstrand is a lovely, cosy suburb near C...
# 2  Close to Eden on The Bay and lots of restauran...
#
# ...

# %%
df5 = pd.read_csv(os.path.join("../Resources/Porto.csv"))
df5.insert(0,'city','Porto, PT')
df5.head(3)
# Out:
#         city     id                         listing_url       scrape_id  \
# 0  Porto, PT  41339  https://www.airbnb.com/rooms/41339  20210213040005
# 1  Porto, PT  42462  https://www.airbnb.com/rooms/42462  20210213040005
# 2  Porto, PT  55111  https://www.airbnb.com/rooms/55111  20210213040005
#
#   last_scraped                                               name  \
# 0   2021-02-14                       Porto city flat near the sea
# 1   2021-02-14                  Large Penthouse in Vila Nova Gaia
# 2   2021-02-13  Fontielas Houses |Floor1 in House with shared ...
#
#                                          description  \
# 0  Here you'll find all you need for your holiday...
# 1  The Afurada Harbour can be reached within 10 m...
# 2  First Floor in House with shared Swimingpool a...
#
#                                neighborhood_overview  \
# 0  In the surrounds you have Serralves Museum and...
# 1                                                NaN
# ...

# %%
df6 = pd.read_csv(os.path.join("../Resources/Buenos Aires.csv"))
df6.insert(0,'city','Buenos Aires, AR')
df6.head(3)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (67) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                city     id                         listing_url  \
# 0  Buenos Aires, AR   6283   https://www.airbnb.com/rooms/6283
# 1  Buenos Aires, AR  11508  https://www.airbnb.com/rooms/11508
# 2  Buenos Aires, AR  12463  https://www.airbnb.com/rooms/12463
#
#         scrape_id last_scraped                                 name  \
# 0  20210223160926   2021-02-24                          Casa Al Sur
# 1  20210223160926   2021-02-24   Amazing Luxurious Apt-Palermo Soho
# 2  20210223160926   2021-02-24  Room in Recoleta - awesome location
#
#                                          description  \
# 0  <b>The space</b><br />This stunning studio apa...
# 1  <b>The space</b><br />LUXURIOUS NEW APT: 1 BDR...
# ...

# %%
df7 = pd.read_csv(os.path.join("../Resources/Santiago.csv"))
df7.insert(0,'city','Santiago, CH')
df7.head(3)
# Out:
#            city     id                         listing_url       scrape_id  \
# 0  Santiago, CH  14576  https://www.airbnb.com/rooms/14576  20210223160940
# 1  Santiago, CH  30950  https://www.airbnb.com/rooms/30950  20210223160940
# 2  Santiago, CH  47936  https://www.airbnb.com/rooms/47936  20210223160940
#
#   last_scraped                             name  \
# 0   2021-02-23           Dp Valen Castillo 1600
# 1   2021-02-24  Apartment Providencia, Santiago
# 2   2021-02-23               My Flat in English
#
#                                          description  \
# 0  <b>The space</b><br />Nice Flat in 11th floor ...
# 1  Located in the heart of Providencia, near by r...
# 2  <b>The space</b><br />Nice and comfortable! <b...
#
#                                neighborhood_overview  \
# 0                                                NaN
# 1  Quiet and typical beatiful neighborghood, a lo...
# 2                                                NaN
#
# ...

# %%
# compile the list of dataframes to merge
data_frames = [df1, df2, df3, df4, df5, df6, df7]

# %%
Final_df = pd.concat(data_frames)

# %%
Final_df
# Out:
#                 city        id                            listing_url  \
# 0      Melbourne, AU      9835      https://www.airbnb.com/rooms/9835
# 1      Melbourne, AU     10803     https://www.airbnb.com/rooms/10803
# 2      Melbourne, AU     12936     https://www.airbnb.com/rooms/12936
# 3      Melbourne, AU     38271     https://www.airbnb.com/rooms/38271
# 4      Melbourne, AU     41836     https://www.airbnb.com/rooms/41836
# ...              ...       ...                                    ...
# 11676   Santiago, CH  48282407  https://www.airbnb.com/rooms/48282407
# 11677   Santiago, CH  48282455  https://www.airbnb.com/rooms/48282455
# 11678   Santiago, CH  48282944  https://www.airbnb.com/rooms/48282944
# 11679   Santiago, CH  48286053  https://www.airbnb.com/rooms/48286053
# 11680   Santiago, CH  48287530  https://www.airbnb.com/rooms/48287530
#
#             scrape_id last_scraped  \
# 0      20210208234751   2021-02-12
# 1      20210208234751   2021-02-09
# ...

# %%
# MONICA
#City	Host Name	Neighbourhood	Latitude	Longitude	Property Type	Room 
#Type	Price	Minimum Nights	Availability 365	Reviews Scores Rating

# %%
Final_df.columns
# Out:
# Index(['city', 'id', 'listing_url', 'scrape_id', 'last_scraped', 'name',
#        'description', 'neighborhood_overview', 'picture_url', 'host_id',
#        'host_url', 'host_name', 'host_since', 'host_location', 'host_about',
#        'host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'host_thumbnail_url', 'host_picture_url',
#        'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
#        'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'latitude',
#        'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price',
#        'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
# ...

# %%
other_cities = Final_df[['city', 'host_name', 'neighbourhood_cleansed', 'latitude', 'longitude', 'property_type','room_type', 'price',
       'minimum_nights', 'availability_365','review_scores_rating']]

# %%
other_cities.head()
# Out:
#             city     host_name neighbourhood_cleansed  latitude  longitude  \
# 0  Melbourne, AU         Manju             Manningham -37.77268  145.09213
# 1  Melbourne, AU       Lindsay               Moreland -37.76651  144.98074
# 2  Melbourne, AU  The A2C Team           Port Phillip -37.85999  144.97662
# 3  Melbourne, AU   Daryl & Dee                  Casey -38.05725  145.33936
# 4  Melbourne, AU         Diana                Darebin -37.69729  145.00082
#
#                property_type        room_type   price  minimum_nights  \
# 0      Private room in house     Private room  $60.00               1
# 1  Private room in apartment     Private room  $28.00               4
# 2           Entire apartment  Entire home/apt  $95.00               3
# 3           Entire apartment  Entire home/apt  $99.00               1
# 4      Private room in house     Private room  $40.00               7
#
#    availability_365  review_scores_rating
# 0                 1                  90.0
# ...

# %%
other_cities['city'].unique()
# Out:
# array(['Melbourne, AU', 'Rio de Janeiro, BR', 'Mexico City, ME',
#        'Cape Town, RSA', 'Porto, PT', 'Buenos Aires, AR', 'Santiago, CH'],
#       dtype=object)

# %%
other_cities.rename(columns = {
    'city': 'City',
    'host_name':'Host Name',
    'neighbourhood_cleansed': 'Neighbourhood',
    'latitude': 'Latitude',
    'longitude': 'Longitude',
    'property_type': 'Property Type',
    'room_type': 'Room Type',
    'price': 'Price',
    'minimum_nights': 'Minimum Nights',
    'availability_365': 'Availability 365',
    'review_scores_rating': 'Reviews Scores Rating'}, inplace = True)
other_cities.head()
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4125: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#             City     Host Name Neighbourhood  Latitude  Longitude  \
# 0  Melbourne, AU         Manju    Manningham -37.77268  145.09213
# 1  Melbourne, AU       Lindsay      Moreland -37.76651  144.98074
# 2  Melbourne, AU  The A2C Team  Port Phillip -37.85999  144.97662
# 3  Melbourne, AU   Daryl & Dee         Casey -38.05725  145.33936
# 4  Melbourne, AU         Diana       Darebin -37.69729  145.00082
#
#                Property Type        Room Type   Price  Minimum Nights  \
# 0      Private room in house     Private room  $60.00               1
# 1  Private room in apartment     Private room  $28.00               4
# ...

# %%
# Converting df to csv
other_cities.to_csv("other_cities.csv", index=False)
