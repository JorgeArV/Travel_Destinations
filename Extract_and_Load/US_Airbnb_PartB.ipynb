# %%
import pandas as pd

# %%
NewYork = pd.read_csv('../Resources/New York.csv')

# %%
NewYork.rename(columns = {
    'host_name':'Host Name',
    'neighbourhood_cleansed': 'Neighbourhood',
    'latitude': 'Latitude',
    'longitude': 'Longitude',
    'property_type': 'Property Type',
    'room_type': 'Room Type',
    'price': 'Price',
    'minimum_nights': 'Minimum Nights',
    'availability_365': 'Availability 365',
    'review_scores_rating': 'Reviews Scores Rating'}, inplace = True)
NewYork.head()
# Out:
#      id                        listing_url       scrape_id last_scraped  \
# 0  2595  https://www.airbnb.com/rooms/2595  20210204180331   2021-02-05
# 1  3831  https://www.airbnb.com/rooms/3831  20210204180331   2021-02-05
# 2  5121  https://www.airbnb.com/rooms/5121  20210204180331   2021-02-05
# 3  5178  https://www.airbnb.com/rooms/5178  20210204180331   2021-02-05
# 4  5203  https://www.airbnb.com/rooms/5203  20210204180331   2021-02-06
#
#                                                 name  \
# 0                              Skylit Midtown Castle
# 1  Whole flr w/private bdrm, bath & kitchen(pls r...
# 2                                    BlissArtsSpace!
# 3                   Large Furnished Room Near B'way
# 4                 Cozy Clean Guest Room - Family Apt
#
#                                          description  \
# 0  Beautiful, spacious skylit studio in the heart...
# 1  Enjoy 500 s.f. top floor in 1899 brownstone, w...
# ...

# %%
NewYork["City"] = "New York City,NY"

# %%
NewYork = NewYork[['City','Host Name','Neighbourhood','Latitude','Longitude','Property Type','Room Type','Price','Minimum Nights','Availability 365','Reviews Scores Rating']]
NewYork.head()
# Out:
#                City    Host Name       Neighbourhood  Latitude  Longitude  \
# 0  New York City,NY     Jennifer             Midtown  40.75362  -73.98377
# 1  New York City,NY  LisaRoxanne        Clinton Hill  40.68514  -73.95976
# 2  New York City,NY        Garon  Bedford-Stuyvesant  40.68688  -73.95596
# 3  New York City,NY     Shunichi             Midtown  40.76468  -73.98315
# 4  New York City,NY    MaryEllen     Upper West Side  40.80178  -73.96723
#
#                Property Type        Room Type    Price  Minimum Nights  \
# 0           Entire apartment  Entire home/apt  $100.00              30
# 1         Entire guest suite  Entire home/apt   $73.00               1
# 2  Private room in apartment     Private room   $60.00              30
# 3  Private room in apartment     Private room   $79.00               2
# 4  Private room in apartment     Private room   $75.00               2
#
#    Availability 365  Reviews Scores Rating
# 0               365                   94.0
# ...

# %%
Oakland = pd.read_csv('../Resources/Oakland.csv')

# %%
Oakland.rename(columns = {
    'host_name':'Host Name',
    'neighbourhood_cleansed': 'Neighbourhood',
    'latitude': 'Latitude',
    'longitude': 'Longitude',
    'property_type': 'Property Type',
    'room_type': 'Room Type',
    'price': 'Price',
    'minimum_nights': 'Minimum Nights',
    'availability_365': 'Availability 365',
    'review_scores_rating': 'Reviews Scores Rating'}, inplace = True)
Oakland.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0   3083   https://www.airbnb.com/rooms/3083  20210220182033   2021-02-21
# 1   3264   https://www.airbnb.com/rooms/3264  20210220182033   2021-02-21
# 2   5739   https://www.airbnb.com/rooms/5739  20210220182033   2021-02-21
# 3  23637  https://www.airbnb.com/rooms/23637  20210220182033   2021-02-21
# 4  24916  https://www.airbnb.com/rooms/24916  20210220182033   2021-02-21
#
#                                                name  \
# 0                    Room #2 @ B-Love's Guest House
# 1                  Garden Suite - Heart of Temescal
# 2                                        Mod Studio
# 3  Share my Charming Home!  (1 person or 1 couple )
# 4               Rockridge Studio w/garden and Patio
#
#                                          description  \
# 0  B-Love's Guest House is spacious with 4 bedroo...
# 1  This is a nice sweet room, with single bed (Ca...
# ...

# %%
Oakland["City"] = "Oakland,CA"

# %%
Oakland = Oakland[['City','Host Name','Neighbourhood','Latitude','Longitude','Property Type','Room Type','Price','Minimum Nights','Availability 365','Reviews Scores Rating']]
Oakland.head()
# Out:
#          City    Host Name       Neighbourhood  Latitude  Longitude  \
# 0  Oakland,CA     Jennifer             Midtown  40.75362  -73.98377
# 1  Oakland,CA  LisaRoxanne        Clinton Hill  40.68514  -73.95976
# 2  Oakland,CA        Garon  Bedford-Stuyvesant  40.68688  -73.95596
# 3  Oakland,CA     Shunichi             Midtown  40.76468  -73.98315
# 4  Oakland,CA    MaryEllen     Upper West Side  40.80178  -73.96723
#
#                Property Type        Room Type    Price  Minimum Nights  \
# 0           Entire apartment  Entire home/apt  $100.00              30
# 1         Entire guest suite  Entire home/apt   $73.00               1
# 2  Private room in apartment     Private room   $60.00              30
# 3  Private room in apartment     Private room   $79.00               2
# 4  Private room in apartment     Private room   $75.00               2
#
#    Availability 365  Reviews Scores Rating
# 0               365                   94.0
# ...

# %%
PacificGrove = pd.read_csv('../Resources/Pacific Grove.csv')

# %%
PacificGrove.rename(columns = {
    'host_name':'Host Name',
    'neighbourhood_cleansed': 'Neighbourhood',
    'latitude': 'Latitude',
    'longitude': 'Longitude',
    'property_type': 'Property Type',
    'room_type': 'Room Type',
    'price': 'Price',
    'minimum_nights': 'Minimum Nights',
    'availability_365': 'Availability 365',
    'review_scores_rating': 'Reviews Scores Rating'}, inplace = True)
PacificGrove.head()
# Out:
#         id                           listing_url       scrape_id last_scraped  \
# 0    22772    https://www.airbnb.com/rooms/22772  20210227173938   2021-02-27
# 1    41014    https://www.airbnb.com/rooms/41014  20210227173938   2021-02-28
# 2    44515    https://www.airbnb.com/rooms/44515  20210227173938   2021-03-01
# 3  1031734  https://www.airbnb.com/rooms/1031734  20210227173938   2021-02-28
# 4  1721177  https://www.airbnb.com/rooms/1721177  20210227173938   2021-02-28
#
#                                                 name  \
# 0             Stay-Awhile  at Lovers Pt. Pacific Grv
# 1                  Ocean front 6-bedroom masterpiece
# 2  Pet-Friendly* Cottage Near Beach for 30+ day s...
# 3                 Top Rated,Ocean View,Spa,Fireplace
# 4                 Ocean View Townhome at Lover's Pt.
#
#                                          description  \
# 0  <b>The space</b><br />Very charming and artist...
# 1  In May 2015, Trip Advisor chose Pacific Grove ...
# ...

# %%
PacificGrove["City"] = "Pacific Grove,CA"

# %%
PacificGrove = PacificGrove[['City','Host Name','Neighbourhood','Latitude','Longitude','Property Type','Room Type','Price','Minimum Nights','Availability 365','Reviews Scores Rating']]
PacificGrove.head()
# Out:
#                City      Host Name  Neighbourhood  Latitude  Longitude  \
# 0  Pacific Grove,CA           Amie  Pacific Grove  36.62258 -121.91680
# 1  Pacific Grove,CA        Kirstie  Pacific Grove  36.63242 -121.93791
# 2  Pacific Grove,CA  Erika & Blake  Pacific Grove  36.62475 -121.93491
# 3  Pacific Grove,CA            Dan  Pacific Grove  36.60324 -121.92723
# 4  Pacific Grove,CA           Barb  Pacific Grove  36.62367 -121.91559
#
#        Property Type        Room Type      Price  Minimum Nights  \
# 0       Entire house  Entire home/apt    $170.00              29
# 1       Entire house  Entire home/apt  $1,200.00               3
# 2  Entire guesthouse  Entire home/apt    $188.00              30
# 3       Entire house  Entire home/apt    $350.00              30
# 4       Entire house  Entire home/apt    $225.00              30
#
#    Availability 365  Reviews Scores Rating
# 0                55                   98.0
# 1                14                   99.0
# ...

# %%
Portland = pd.read_csv('../Resources/Portland.csv')

# %%
Portland.rename(columns = {
    'host_name':'Host Name',
    'neighbourhood_cleansed': 'Neighbourhood',
    'latitude': 'Latitude',
    'longitude': 'Longitude',
    'property_type': 'Property Type',
    'room_type': 'Room Type',
    'price': 'Price',
    'minimum_nights': 'Minimum Nights',
    'availability_365': 'Availability 365',
    'review_scores_rating': 'Reviews Scores Rating'}, inplace = True)
Portland.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0  12899  https://www.airbnb.com/rooms/12899  20210220181955   2021-02-21
# 1  18130  https://www.airbnb.com/rooms/18130  20210220181955   2021-02-21
# 2  29931  https://www.airbnb.com/rooms/29931  20210220181955   2021-02-21
# 3  37676  https://www.airbnb.com/rooms/37676  20210220181955   2021-02-21
# 4  41601  https://www.airbnb.com/rooms/41601  20210220181955   2021-02-21
#
#                                                 name  \
# 0  Alberta Arts 2 bedroom suite, charming 1906 house
# 1                          Charming Roseway Bungalow
# 2       Lovely SW Victorian w/Bonus Room and Hot Tub
# 3                Mt. Hood View in the Pearl District
# 4                Grandpa's Bunkhouse-Backyard Studio
#
#                                          description  \
# 0  Firstly, please know that we are practicing so...
# 1  An adorable 1925 bungalow home in the Roseway ...
# ...

# %%
Portland["City"] = "Portland,OR"

# %%
Portland = Portland[['City','Host Name','Neighbourhood','Latitude','Longitude','Property Type','Room Type','Price','Minimum Nights','Availability 365','Reviews Scores Rating']]
Portland.head()
# Out:
#           City      Host Name Neighbourhood  Latitude  Longitude  \
# 0  Portland,OR  Ali And David     Concordia  45.56488 -122.63418
# 1  Portland,OR          Katie       Roseway  45.55342 -122.58002
# 2  Portland,OR            Ken      Hayhurst  45.48278 -122.72089
# 3  Portland,OR           Paul         Pearl  45.52555 -122.68193
# 4  Portland,OR           Jean       Roseway  45.54935 -122.58425
#
#       Property Type        Room Type    Price  Minimum Nights  \
# 0  Entire apartment  Entire home/apt   $70.00               2
# 1   Entire bungalow  Entire home/apt   $80.00               3
# 2      Entire house  Entire home/apt  $200.00               2
# 3       Entire loft  Entire home/apt  $100.00              30
# 4      Entire house  Entire home/apt  $169.00               3
#
#    Availability 365  Reviews Scores Rating
# 0               304                   98.0
# 1                 2                  100.0
# 2               232                   94.0
# ...

# %%
RhodeIsland = pd.read_csv('../Resources/Rhode Island.csv')

# %%
RhodeIsland.rename(columns = {
    'host_name':'Host Name',
    'neighbourhood_cleansed': 'Neighbourhood',
    'latitude': 'Latitude',
    'longitude': 'Longitude',
    'property_type': 'Property Type',
    'room_type': 'Room Type',
    'price': 'Price',
    'minimum_nights': 'Minimum Nights',
    'availability_365': 'Availability 365',
    'review_scores_rating': 'Reviews Scores Rating'}, inplace = True)
RhodeIsland.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0  10262  https://www.airbnb.com/rooms/10262  20210227173820   2021-03-01
# 1  15373  https://www.airbnb.com/rooms/15373  20210227173820   2021-03-01
# 2  50817  https://www.airbnb.com/rooms/50817  20210227173820   2021-03-01
# 3  51583  https://www.airbnb.com/rooms/51583  20210227173820   2021-03-01
# 4  55464  https://www.airbnb.com/rooms/55464  20210227173820   2021-03-01
#
#                                                 name  \
# 0                   Secluded 1750's home on 46 acres
# 1        Adorable Beach Cottage Scarborough Beach RI
# 2                           Sanctuary in the Suburbs
# 3                  Bedroom In a large Victorian Home
# 4  Waterfront Narrow River Rent as of 5/1/21  kay...
#
#                                          description  \
# 0  Enjoy relaxing on one of three decks/porches, ...
# 1  see "Adorable Beach Cottage Narragansett RI" a...
# ...

# %%
RhodeIsland["City"] = "Rhode Island,RI"

# %%
RhodeIsland = RhodeIsland[['City','Host Name','Neighbourhood','Latitude','Longitude','Property Type','Room Type','Price','Minimum Nights','Availability 365','Reviews Scores Rating']]
RhodeIsland.head()
# Out:
#               City Host Name    Neighbourhood  Latitude  Longitude  \
# 0  Rhode Island,RI     Paula        Glocester  41.86617  -71.72344
# 1  Rhode Island,RI     Brian     Narragansett  41.39375  -71.47447
# 2  Rhode Island,RI     Nancy        Pawtucket  41.88613  -71.35373
# 3  Rhode Island,RI      Chip       Providence  41.81244  -71.42076
# 4  Rhode Island,RI     Kathy  South Kingstown  41.46965  -71.44939
#
#                Property Type        Room Type    Price  Minimum Nights  \
# 0      Private room in house     Private room   $65.00               1
# 1               Entire house  Entire home/apt  $100.00               7
# 2           Entire apartment  Entire home/apt   $76.00               2
# 3  Private room in apartment     Private room   $58.00               1
# 4             Entire cottage  Entire home/apt  $295.00               7
#
#    Availability 365  Reviews Scores Rating
# 0                 0                  100.0
# 1                35                   93.0
# ...

# %%
Salem = pd.read_csv('../Resources/Salem.csv')

# %%
Salem.rename(columns = {
    'host_name':'Host Name',
    'neighbourhood_cleansed': 'Neighbourhood',
    'latitude': 'Latitude',
    'longitude': 'Longitude',
    'property_type': 'Property Type',
    'room_type': 'Room Type',
    'price': 'Price',
    'minimum_nights': 'Minimum Nights',
    'availability_365': 'Availability 365',
    'review_scores_rating': 'Reviews Scores Rating'}, inplace = True)
Salem.head()
# Out:
#         id                           listing_url       scrape_id last_scraped  \
# 0  1159564  https://www.airbnb.com/rooms/1159564  20210221060143   2021-02-21
# 1  2894591  https://www.airbnb.com/rooms/2894591  20210221060143   2021-02-21
# 2  3454856  https://www.airbnb.com/rooms/3454856  20210221060143   2021-02-21
# 3  4394073  https://www.airbnb.com/rooms/4394073  20210221060143   2021-02-21
# 4  4785215  https://www.airbnb.com/rooms/4785215  20210221060143   2021-02-21
#
#                                   name  \
# 0                    SOLAR ECLIPSE - A
# 1  Quiet and cozy home in South Salem.
# 2   Quiet and cozy home in South Salem
# 3      Warm and Welcoming in Downtown.
# 4          Century House Doug Fir Room
#
#                                          description  \
# 0  I have 2 rooms to rent for the solar eclipse o...
# 1  This cozy, tidy, and well kept home is located...
# 2  My home is located in a well established and w...
# ...

# %%
Salem["City"] = "Salem,OR"

# %%
Salem = Salem[['City','Host Name','Neighbourhood','Latitude','Longitude','Property Type','Room Type','Price','Minimum Nights','Availability 365','Reviews Scores Rating']]
Salem.head()
# Out:
#        City Host Name Neighbourhood  Latitude  Longitude  \
# 0  Salem,OR   Roberta        Ward 3  44.88416 -123.04341
# 1  Salem,OR       Sue        Ward 7  44.90754 -123.07688
# 2  Salem,OR       Sue        Ward 7  44.90781 -123.07676
# 3  Salem,OR   Michael        Ward 1  44.94813 -123.02229
# 4  Salem,OR      Jean        Ward 2  44.93448 -123.02103
#
#                        Property Type     Room Type    Price  Minimum Nights  \
# 0              Private room in house  Private room  $175.00               2
# 1              Private room in house  Private room   $50.00               1
# 2              Private room in house  Private room   $50.00               1
# 3              Private room in house  Private room   $47.00               2
# 4  Private room in bed and breakfast  Private room   $89.00               2
#
#    Availability 365  Reviews Scores Rating
# 0               365                   90.0
# 1               296                   98.0
# ...

# %%
SanDiego = pd.read_csv('../Resources/San Diego.csv')

# %%
SanDiego.rename(columns = {
    'host_name':'Host Name',
    'neighbourhood_cleansed': 'Neighbourhood',
    'latitude': 'Latitude',
    'longitude': 'Longitude',
    'property_type': 'Property Type',
    'room_type': 'Room Type',
    'price': 'Price',
    'minimum_nights': 'Minimum Nights',
    'availability_365': 'Availability 365',
    'review_scores_rating': 'Reviews Scores Rating'}, inplace = True)
SanDiego.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0   5570   https://www.airbnb.com/rooms/5570  20210221060030   2021-02-21
# 1  29967  https://www.airbnb.com/rooms/29967  20210221060030   2021-02-21
# 2  38245  https://www.airbnb.com/rooms/38245  20210221060030   2021-02-21
# 3  54001  https://www.airbnb.com/rooms/54001  20210221060030   2021-02-22
# 4  62274  https://www.airbnb.com/rooms/62274  20210221060030   2021-02-22
#
#                                               name  \
# 0                    Ocean front condo on the sand
# 1                 Great home, 10 min walk to Beach
# 2                       Point Loma: Den downstairs
# 3  La Jolla 2 Bdr Cottage: 1 Qn; 2Twns, Blks 2 Ocn
# 4               charming, colorful, close to beach
#
#                                          description  \
# 0  Missionbeachretreat.   Great Ocean Front Condo...
# 1  This 2 bedroom, 2 full bathroom home offers al...
# ...

# %%
SanDiego["City"] = "San Diego,CA"

# %%
SanDiego = SanDiego[['City','Host Name','Neighbourhood','Latitude','Longitude','Property Type','Room Type','Price','Minimum Nights','Availability 365','Reviews Scores Rating']]
SanDiego.head()
# Out:
#            City    Host Name  Neighbourhood  Latitude  Longitude  \
# 0  San Diego,CA  Jef Karchin    Mission Bay  32.78430 -117.25258
# 1  San Diego,CA      Michael  Pacific Beach  32.80724 -117.25630
# 2  San Diego,CA      Melinda      Roseville  32.74202 -117.21870
# 3  San Diego,CA       Marsha       La Jolla  32.81301 -117.26856
# 4  San Diego,CA       Isabel  Pacific Beach  32.80734 -117.24243
#
#            Property Type        Room Type      Price  Minimum Nights  \
# 0     Entire condominium  Entire home/apt  $2,050.00               3
# 1        Entire bungalow  Entire home/apt    $225.00               4
# 2  Private room in house     Private room     $74.00               1
# 3      Entire guesthouse  Entire home/apt     $80.00               4
# 4      Entire guesthouse  Entire home/apt     $73.00               1
#
#    Availability 365  Reviews Scores Rating
# 0               242                    NaN
# 1               267                   98.0
# ...

# %%
SanFrancisco = pd.read_csv('../Resources/San Francisco.csv')

# %%
SanFrancisco.rename(columns = {
    'host_name':'Host Name',
    'neighbourhood_cleansed': 'Neighbourhood',
    'latitude': 'Latitude',
    'longitude': 'Longitude',
    'property_type': 'Property Type',
    'room_type': 'Room Type',
    'price': 'Price',
    'minimum_nights': 'Minimum Nights',
    'availability_365': 'Availability 365',
    'review_scores_rating': 'Reviews Scores Rating'}, inplace = True)
SanFrancisco.head()
# Out:
#      id                        listing_url       scrape_id last_scraped  \
# 0   958   https://www.airbnb.com/rooms/958  20210301171847   2021-03-02
# 1  5858  https://www.airbnb.com/rooms/5858  20210301171847   2021-03-02
# 2  7918  https://www.airbnb.com/rooms/7918  20210301171847   2021-03-02
# 3  8142  https://www.airbnb.com/rooms/8142  20210301171847   2021-03-02
# 4  8339  https://www.airbnb.com/rooms/8339  20210301171847   2021-03-02
#
#                                                 name  \
# 0              Bright, Modern Garden Unit - 1BR/1BTH
# 1                                 Creative Sanctuary
# 2         A Friendly Room - UCSF/USF - San Francisco
# 3  Friendly Room Apt. Style -UCSF/USF - San Franc...
# 4                    Historic Alamo Square Victorian
#
#                                          description  \
# 0  San Francisco: Out of state visitors are not a...
# 1  <b>The space</b><br />We live in a large Victo...
# ...

# %%
SanFrancisco["City"] = "San Francisco,CA"

# %%
SanFrancisco = SanFrancisco[['City','Host Name','Neighbourhood','Latitude','Longitude','Property Type','Room Type','Price','Minimum Nights','Availability 365','Reviews Scores Rating']]
SanFrancisco.head()
# Out:
#                City         Host Name     Neighbourhood  Latitude  Longitude  \
# 0  San Francisco,CA             Holly  Western Addition  37.77028 -122.43317
# 1  San Francisco,CA  Philip And Tania    Bernal Heights  37.74511 -122.42102
# 2  San Francisco,CA             Aaron    Haight Ashbury  37.76555 -122.45213
# 3  San Francisco,CA             Aaron    Haight Ashbury  37.76555 -122.45213
# 4  San Francisco,CA              Rosy  Western Addition  37.77525 -122.43637
#
#                Property Type        Room Type    Price  Minimum Nights  \
# 0           Entire apartment  Entire home/apt  $130.00               2
# 1           Entire apartment  Entire home/apt  $195.00              30
# 2  Private room in apartment     Private room   $56.00              32
# 3  Private room in apartment     Private room   $56.00              32
# 4         Entire condominium  Entire home/apt  $799.00               5
#
#    Availability 365  Reviews Scores Rating
# ...

# %%
SanMateoCounty = pd.read_csv('../Resources/San Mateo County.csv')

# %%
SanMateoCounty.rename(columns = {
    'host_name':'Host Name',
    'neighbourhood_cleansed': 'Neighbourhood',
    'latitude': 'Latitude',
    'longitude': 'Longitude',
    'property_type': 'Property Type',
    'room_type': 'Room Type',
    'price': 'Price',
    'minimum_nights': 'Minimum Nights',
    'availability_365': 'Availability 365',
    'review_scores_rating': 'Reviews Scores Rating'}, inplace = True)
SanMateoCounty.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0  12651  https://www.airbnb.com/rooms/12651  20210221060122   2021-02-23
# 1  39342  https://www.airbnb.com/rooms/39342  20210221060122   2021-02-23
# 2  40560  https://www.airbnb.com/rooms/40560  20210221060122   2021-02-24
# 3  44504  https://www.airbnb.com/rooms/44504  20210221060122   2021-02-21
# 4  45287  https://www.airbnb.com/rooms/45287  20210221060122   2021-02-23
#
#                                                name  \
# 0                 Private entrance/walk to Stanford
# 1                       Palm Tree Cottage, Pacifica
# 2                         MOST COMFORTABLE BED EVER
# 3  Burlingame  1 bed, & lounge apartment, close SFO
# 4      The Garden Cottage-a secluded nature retreat
#
#                                          description  \
# 0  PRIVATE ENTRANCE, PRIVATE ROOM, PRIVATE BATH<b...
# 1  30 NIGHT MINIMUM.  Walk to Pacifica Beach from...
# ...

# %%
SanMateoCounty["City"] = "San Mateo County,CA"

# %%
SanMateoCounty = SanMateoCounty[['City','Host Name','Neighbourhood','Latitude','Longitude','Property Type','Room Type','Price','Minimum Nights','Availability 365','Reviews Scores Rating']]
SanMateoCounty.head()
# Out:
#                   City       Host Name   Neighbourhood  Latitude  Longitude  \
# 0  San Mateo County,CA          Laurel      Menlo Park  37.43118 -122.19654
# 1  San Mateo County,CA         Annette        Pacifica  37.63144 -122.48825
# 2  San Mateo County,CA           Megan  East Palo Alto  37.45528 -122.13829
# 3  San Mateo County,CA          Maggie      Burlingame  37.58774 -122.36622
# 4  San Mateo County,CA  Diane And Mike      Burlingame  37.57913 -122.34063
#
#            Property Type        Room Type    Price  Minimum Nights  \
# 0     Entire guest suite  Entire home/apt  $197.00               3
# 1           Entire house  Entire home/apt  $120.00              30
# 2  Private room in house     Private room  $110.00               1
# 3       Entire apartment  Entire home/apt  $210.00               3
# 4      Entire guesthouse  Entire home/apt  $135.00               3
#
#    Availability 365  Reviews Scores Rating
# 0               311                   98.0
# ...

# %%
SantaClaraCounty = pd.read_csv('../Resources/Santa Clara County.csv')

# %%
SantaClaraCounty.rename(columns = {
    'host_name':'Host Name',
    'neighbourhood_cleansed': 'Neighbourhood',
    'latitude': 'Latitude',
    'longitude': 'Longitude',
    'property_type': 'Property Type',
    'room_type': 'Room Type',
    'price': 'Price',
    'minimum_nights': 'Minimum Nights',
    'availability_365': 'Availability 365',
    'review_scores_rating': 'Reviews Scores Rating'}, inplace = True)
SantaClaraCounty.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0  11464  https://www.airbnb.com/rooms/11464  20210221153744   2021-02-21
# 1  21373  https://www.airbnb.com/rooms/21373  20210221153744   2021-02-23
# 2  37512  https://www.airbnb.com/rooms/37512  20210221153744   2021-02-22
# 3  52786  https://www.airbnb.com/rooms/52786  20210221153744   2021-02-22
# 4  62799  https://www.airbnb.com/rooms/62799  20210221153744   2021-02-22
#
#                                               name  \
# 0  Deluxe Studio 5 min.  to SC Kaiser & Apple Park
# 1              Bonsai Garden Inn in Professorville
# 2                Private  room - Parking 3 carport
# 3                   Cozy Room in A Quiet Community
# 4                 Zen Office and Sofa in Palo Alto
#
#                                          description  \
# 0  Custom built Studio with exquisite design. Rea...
# 1  Room  in gracious home with beautiful garden. ...
# ...

# %%
SantaClaraCounty["City"] = "Santa Clara County,CA"

# %%
SantaClaraCounty = SantaClaraCounty[['City','Host Name','Neighbourhood','Latitude','Longitude','Property Type','Room Type','Price','Minimum Nights','Availability 365','Reviews Scores Rating']]
SantaClaraCounty.head()
# Out:
#                     City Host Name Neighbourhood  Latitude  Longitude  \
# 0  Santa Clara County,CA      Emey   Santa Clara  37.34342 -121.98829
# 1  Santa Clara County,CA   Mei Lin     Palo Alto  37.44001 -122.15667
# 2  Santa Clara County,CA     Maria      San Jose  37.30598 -121.84036
# 3  Santa Clara County,CA     Maria      San Jose  37.30521 -121.84149
# 4  Santa Clara County,CA   Mei Lin     Palo Alto  37.43925 -122.15617
#
#               Property Type        Room Type    Price  Minimum Nights  \
# 0          Entire apartment  Entire home/apt   $75.00               4
# 1     Private room in villa     Private room   $80.00               2
# 2  Private room in bungalow     Private room   $48.00               1
# 3  Private room in bungalow     Private room   $50.00               1
# 4     Private room in villa     Private room  $100.00               7
#
#    Availability 365  Reviews Scores Rating
# 0               149                   88.0
# ...

# %%
SantaCruzCounty = pd.read_csv('../Resources/Santa Cruz County.csv')

# %%
SantaCruzCounty.rename(columns = {
    'host_name':'Host Name',
    'neighbourhood_cleansed': 'Neighbourhood',
    'latitude': 'Latitude',
    'longitude': 'Longitude',
    'property_type': 'Property Type',
    'room_type': 'Room Type',
    'price': 'Price',
    'minimum_nights': 'Minimum Nights',
    'availability_365': 'Availability 365',
    'review_scores_rating': 'Reviews Scores Rating'}, inplace = True)
SantaCruzCounty.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0  11879  https://www.airbnb.com/rooms/11879  20210227173810   2021-03-01
# 1  24548  https://www.airbnb.com/rooms/24548  20210227173810   2021-02-28
# 2  31721  https://www.airbnb.com/rooms/31721  20210227173810   2021-03-01
# 3  43785  https://www.airbnb.com/rooms/43785  20210227173810   2021-03-01
# 4  49520  https://www.airbnb.com/rooms/49520  20210227173810   2021-03-01
#
#                                                 name  \
# 0                Sunny room close to beach and parks
# 1                        Room with Private Entrance.
# 2  Dog Friendly Private Pleasure Point Beach Cottage
# 3                    Guest bedroom in Victorian home
# 4                     Guest Cottage with shared bath
#
#                                          description  \
# 0  Sunny room in a cozy home with a 40 acre park ...
# 1  Bedroom and bath with private entrance in home...
# ...

# %%
SantaCruzCounty["City"] = "Santa Cruz County,CA"

# %%
SantaCruzCounty = SantaCruzCounty[['City','Host Name','Neighbourhood','Latitude','Longitude','Property Type','Room Type','Price','Minimum Nights','Availability 365','Reviews Scores Rating']]
SantaCruzCounty.head()
# Out:
#                    City  Host Name         Neighbourhood  Latitude  Longitude  \
# 0  Santa Cruz County,CA     Steven  Unincorporated Areas  36.98186 -121.88114
# 1  Santa Cruz County,CA    Kerstin    City of Santa Cruz  36.97167 -121.99774
# 2  Santa Cruz County,CA      Annie      City of Capitola  36.95849 -121.97207
# 3  Santa Cruz County,CA   Caroline    City of Santa Cruz  36.97694 -122.03600
# 4  Santa Cruz County,CA  Christine  Unincorporated Areas  36.96325 -121.82091
#
#                Property Type        Room Type    Price  Minimum Nights  \
# 0      Private room in house     Private room   $75.00               2
# 1      Private room in house     Private room  $100.00               2
# 2             Entire cottage  Entire home/apt  $179.00               4
# 3      Private room in house     Private room   $85.00               2
# 4  Private room in apartment     Private room   $95.00              30
#
#    Availability 365  Reviews Scores Rating
# ...

# %%
Seattle = pd.read_csv('../Resources/Seattle.csv')

# %%
Seattle.rename(columns = {
    'host_name':'Host Name',
    'neighbourhood_cleansed': 'Neighbourhood',
    'latitude': 'Latitude',
    'longitude': 'Longitude',
    'property_type': 'Property Type',
    'room_type': 'Room Type',
    'price': 'Price',
    'minimum_nights': 'Minimum Nights',
    'availability_365': 'Availability 365',
    'review_scores_rating': 'Reviews Scores Rating'}, inplace = True)
Seattle.head()
# Out:
#      id                        listing_url       scrape_id last_scraped  \
# 0  2318  https://www.airbnb.com/rooms/2318  20210221060053   2021-02-22
# 1  9419  https://www.airbnb.com/rooms/9419  20210221060053   2021-02-22
# 2  9531  https://www.airbnb.com/rooms/9531  20210221060053   2021-02-22
# 3  9534  https://www.airbnb.com/rooms/9534  20210221060053   2021-02-22
# 4  9596  https://www.airbnb.com/rooms/9596  20210221060053   2021-02-21
#
#                                                 name  \
# 0  Casa Madrona - Urban Oasis 1 block from the park!
# 1                Glorious sun room w/ memory foambed
# 2                The Adorable Sweet Orange Craftsman
# 3                   The Coolest Tangerine Dream MIL!
# 4         the down home , spacious, central and fab!
#
#                                          description  \
# 0  Gorgeous, architect remodeled, Dutch Colonial ...
# 1  Keeping you safe is our priority, we are adher...
# ...

# %%
Seattle["City"] = "Seattle,WA"

# %%
Seattle = Seattle[['City','Host Name','Neighbourhood','Latitude','Longitude','Property Type','Room Type','Price','Minimum Nights','Availability 365','Reviews Scores Rating']]
Seattle.head()
# Out:
#          City  Host Name   Neighbourhood  Latitude  Longitude  \
# 0  Seattle,WA      Megan         Madrona  47.61082 -122.29082
# 1  Seattle,WA  Angielena      Georgetown  47.55017 -122.31937
# 2  Seattle,WA     Cassie  Fairmount Park  47.55539 -122.38474
# 3  Seattle,WA     Cassie  Fairmount Park  47.55624 -122.38598
# 4  Seattle,WA      Joyce     Wallingford  47.65479 -122.33652
#
#                Property Type        Room Type    Price  Minimum Nights  \
# 0               Entire house  Entire home/apt  $296.00              30
# 1  Private room in apartment     Private room   $55.00               2
# 2               Entire house  Entire home/apt  $155.00              30
# 3         Entire guest suite  Entire home/apt  $125.00              30
# 4           Entire apartment  Entire home/apt  $100.00               4
#
#    Availability 365  Reviews Scores Rating
# 0               107                  100.0
# 1               328                   93.0
# ...

# %%
TwinCities = pd.read_csv('../Resources/Twin Cities.csv')

# %%
TwinCities.rename(columns = {
    'host_name':'Host Name',
    'neighbourhood_cleansed': 'Neighbourhood',
    'latitude': 'Latitude',
    'longitude': 'Longitude',
    'property_type': 'Property Type',
    'room_type': 'Room Type',
    'price': 'Price',
    'minimum_nights': 'Minimum Nights',
    'availability_365': 'Availability 365',
    'review_scores_rating': 'Reviews Scores Rating'}, inplace = True)
TwinCities.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0   2441   https://www.airbnb.com/rooms/2441  20210220181936   2021-02-21
# 1   4534   https://www.airbnb.com/rooms/4534  20210220181936   2021-02-21
# 2  27319  https://www.airbnb.com/rooms/27319  20210220181936   2021-02-21
# 3  55089  https://www.airbnb.com/rooms/55089  20210220181936   2021-02-21
# 4  60977  https://www.airbnb.com/rooms/60977  20210220181936   2021-02-21
#
#                                                 name  \
# 0  Cozy Artist’s Abode, NE Mpls - Pets, Wifi, Rok...
# 1   Charming, 1 or 2BR + private bath, near downtown
# 2                 Parks, Lakes, Downtown, Light rail
# 3                 Minneapolis/Edina "Cabin" on Creek
# 4                  Attic Loft with organic breakfast
#
#                                          description  \
# 0  Make my home your homebase while you check out...
# 1  Note: during the Covid-19 pandemic, our accomm...
# ...

# %%
TwinCities["City"] = "Twin Cities,MN"

# %%
TwinCities = TwinCities[['City','Host Name','Neighbourhood','Latitude','Longitude','Property Type','Room Type','Price','Minimum Nights','Availability 365','Reviews Scores Rating']]
TwinCities.head()
# Out:
#              City Host Name Neighbourhood  Latitude  Longitude  \
# 0  Twin Cities,MN     Emily      Hennepin  45.00886  -93.23407
# 1  Twin Cities,MN    Rachel      Hennepin  44.94566  -93.35721
# 2  Twin Cities,MN     Keith      Hennepin  44.91878  -93.23038
# 3  Twin Cities,MN    Leslie      Hennepin  44.91985  -93.35141
# 4  Twin Cities,MN     Habib        Ramsey  44.94800  -93.19037
#
#            Property Type        Room Type    Price  Minimum Nights  \
# 0           Entire house  Entire home/apt   $85.00               1
# 1  Private room in house     Private room   $49.00               2
# 2  Private room in house     Private room   $50.00               2
# 3           Entire house  Entire home/apt  $160.00               7
# 4            Entire loft  Entire home/apt   $65.00               3
#
#    Availability 365  Reviews Scores Rating
# 0                 0                   95.0
# 1               363                   97.0
# 2               364                   96.0
# ...

# %%
WashingtonDC = pd.read_csv('../Resources/Washington.csv')

# %%
WashingtonDC.rename(columns = {
    'host_name':'Host Name',
    'neighbourhood_cleansed': 'Neighbourhood',
    'latitude': 'Latitude',
    'longitude': 'Longitude',
    'property_type': 'Property Type',
    'room_type': 'Room Type',
    'price': 'Price',
    'minimum_nights': 'Minimum Nights',
    'availability_365': 'Availability 365',
    'review_scores_rating': 'Reviews Scores Rating'}, inplace = True)
WashingtonDC.head()
# Out:
#      id                        listing_url       scrape_id last_scraped  \
# 0  3686  https://www.airbnb.com/rooms/3686  20210217171634   2021-02-19
# 1  3943  https://www.airbnb.com/rooms/3943  20210217171634   2021-02-19
# 2  4197  https://www.airbnb.com/rooms/4197  20210217171634   2021-02-19
# 3  4529  https://www.airbnb.com/rooms/4529  20210217171634   2021-02-19
# 4  4967  https://www.airbnb.com/rooms/4967  20210217171634   2021-02-19
#
#                                name  \
# 0                   Vita's Hideaway
# 1  Historic Rowhouse Near Monuments
# 2   Bedroom in DC 2 blocks to Metro
# 3         Bertina's  House Part One
# 4                    DC, Near Metro
#
#                                          description  \
# 0  IMPORTANT NOTES<br />* Carefully read and be s...
# 1  Please contact us before booking to make sure ...
# 2  This is the middle bedroom upstairs in a resto...
# 3  This is  large private  bedroom with plenty of...
# ...

# %%
WashingtonDC["City"] = "Washington,DC"

# %%
WashingtonDC = WashingtonDC[['City','Host Name','Neighbourhood','Latitude','Longitude','Property Type','Room Type','Price','Minimum Nights','Availability 365','Reviews Scores Rating']]
WashingtonDC.head()
# Out:
#             City        Host Name  \
# 0  Washington,DC             Vita
# 1  Washington,DC             Vasa
# 2  Washington,DC           Sandra
# 3  Washington,DC  Bertina'S House
# 4  Washington,DC           Seveer
#
#                                        Neighbourhood  Latitude  Longitude  \
# 0                                 Historic Anacostia  38.86177  -76.98966
# 1  Edgewood, Bloomingdale, Truxton Circle, Eckington  38.91066  -77.00438
# 2                         Capitol Hill, Lincoln Park  38.88791  -76.99668
# 3                       Eastland Gardens, Kenilworth  38.90645  -76.94305
# 4  Edgewood, Bloomingdale, Truxton Circle, Eckington  38.91409  -76.99368
#
#                Property Type     Room Type   Price  Minimum Nights  \
# 0      Private room in house  Private room  $55.00               2
# 1  Private room in townhouse  Private room  $70.00               2
# 2      Private room in house  Private room  $80.00              28
# ...

# %%
PartB = pd.concat([NewYork, Oakland, PacificGrove, Portland, RhodeIsland, Salem, SanDiego, SanFrancisco, SanMateoCounty, SantaClaraCounty, SantaCruzCounty, Seattle, TwinCities, WashingtonDC])
PartB.head(20)
# Out:
#                 City      Host Name       Neighbourhood  Latitude  Longitude  \
# 0   New York City,NY       Jennifer             Midtown  40.75362  -73.98377
# 1   New York City,NY    LisaRoxanne        Clinton Hill  40.68514  -73.95976
# 2   New York City,NY          Garon  Bedford-Stuyvesant  40.68688  -73.95596
# 3   New York City,NY       Shunichi             Midtown  40.76468  -73.98315
# 4   New York City,NY      MaryEllen     Upper West Side  40.80178  -73.96723
# 5   New York City,NY         Laurie         South Slope  40.66829  -73.98779
# 6   New York City,NY  Allen & Irina        Williamsburg  40.70837  -73.95352
# 7   New York City,NY            Kae         East Harlem  40.80139  -73.94244
# 8   New York City,NY            Cyn         East Harlem  40.78962  -73.94802
# 9   New York City,NY           Jane         Fort Greene  40.69121  -73.97277
# 10  New York City,NY           Sing         East Harlem  40.79685  -73.94872
# ...

# %%
PartB.to_csv('PartB.csv')
