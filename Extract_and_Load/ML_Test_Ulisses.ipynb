# %%
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
import pandas as pd
import os

# %%
df = pd.read_csv(os.path.join("Temperature_Dataset1.csv"))

# %%
df
# Out:
#                  City        Date  Temperature  temp_max  temp_min  humidity  \
# 0        Montreal, QC  2020-01-01          0.2       1.1      -0.8     87.84
# 1        Montreal, QC  2020-01-02          0.9       2.6      -1.0     78.70
# 2        Montreal, QC  2020-01-03          4.8       5.8       2.8     74.88
# 3        Montreal, QC  2020-01-04          0.5       3.2      -1.9     78.79
# 4        Montreal, QC  2020-01-05         -5.3      -1.8      -9.9     69.09
# ...               ...         ...          ...       ...       ...       ...
# 12805  Washington, DC  2020-12-27          1.0       5.6      -3.6     60.64
# 12806  Washington, DC  2020-12-28          6.1      11.3       1.6     64.95
# 12807  Washington, DC  2020-12-29          3.8       6.2       0.3     46.13
# 12808  Washington, DC  2020-12-30          3.8       7.8      -0.3     52.82
# 12809  Washington, DC  2020-12-31          8.1      12.8       4.4     70.87
#
#        precip  snow  windspeed        conditions
# 0        5.71  0.00        7.9              Rain
# 1        0.00  0.00        7.7             Clear
# 2        0.00  0.00        7.6             Clear
# 3        2.27  0.00       11.2              Rain
# 4        0.76  3.88       13.1              Snow
# ...       ...   ...        ...               ...
# 12805    0.00  0.00       17.2  Partially cloudy
# 12806    0.00  0.00       19.5  Partially cloudy
# 12807    0.00  0.00       32.7  Partially cloudy
# 12808    0.00  0.00       29.0          Overcast
# 12809    0.00  0.00       28.8          Overcast
#
# [12810 rows x 10 columns]

# %%
newdf = df[df.City.isin(["Quebec City, QC", "New Brunswick, NB", "Twin Cities, MN", "Ottawa, ON", "Montreal, QC", "Hawaii, HI", "Broward County, FL", "New Orleans, LA", "Austin, TX", "Clark County, NV"])]

newdf
# Out:
#                   City        Date  Temperature  temp_max  temp_min  humidity  \
# 0         Montreal, QC  2020-01-01          0.2       1.1      -0.8     87.84
# 1         Montreal, QC  2020-01-02          0.9       2.6      -1.0     78.70
# 2         Montreal, QC  2020-01-03          4.8       5.8       2.8     74.88
# 3         Montreal, QC  2020-01-04          0.5       3.2      -1.9     78.79
# 4         Montreal, QC  2020-01-05         -5.3      -1.8      -9.9     69.09
# ...                ...         ...          ...       ...       ...       ...
# 12439  Twin Cities, MN  2020-12-27         -5.8      -4.2      -9.6     82.43
# 12440  Twin Cities, MN  2020-12-28         -9.0      -4.5     -13.8     77.48
# 12441  Twin Cities, MN  2020-12-29        -10.1      -5.5     -16.7     83.29
# 12442  Twin Cities, MN  2020-12-30         -5.3      -4.2      -9.1     76.69
# 12443  Twin Cities, MN  2020-12-31         -8.5      -5.7     -12.3     84.88
#
#        precip  snow  windspeed              conditions cluster cluster1
# 0        5.71  0.00        7.9                    Rain       2        5
# 1        0.00  0.00        7.7                   Clear       2        5
# 2        0.00  0.00        7.6                   Clear       2        3
# 3        2.27  0.00       11.2                    Rain       2        5
# 4        0.76  3.88       13.1                    Snow       2        2
# ...       ...   ...        ...                     ...     ...      ...
# 12439    0.28  1.25       20.1          Snow, Overcast       2        2
# 12440    0.00  0.75       16.9  Snow, Partially cloudy       2        5
# 12441    2.44  2.44       20.2  Snow, Partially cloudy       2        1
# 12442    0.18  1.57       25.2          Snow, Overcast       2        2
# 12443    0.00  0.52       18.2  Snow, Partially cloudy       2        2
#
# [3660 rows x 12 columns]

# %%
cluster = []

for i in df['Date']:
    if i < "2020-09-01" and i > "2020-04-01": 
        cluster.append("1")
    else:
        cluster.append("2")
        
df["cluster"] = cluster
print(df)
# Out:
#                  City        Date  Temperature  temp_max  temp_min  humidity  \
# 0        Montreal, QC  2020-01-01          0.2       1.1      -0.8     87.84
# 1        Montreal, QC  2020-01-02          0.9       2.6      -1.0     78.70
# 2        Montreal, QC  2020-01-03          4.8       5.8       2.8     74.88
# 3        Montreal, QC  2020-01-04          0.5       3.2      -1.9     78.79
# 4        Montreal, QC  2020-01-05         -5.3      -1.8      -9.9     69.09
# ...               ...         ...          ...       ...       ...       ...
# 12805  Washington, DC  2020-12-27          1.0       5.6      -3.6     60.64
# 12806  Washington, DC  2020-12-28          6.1      11.3       1.6     64.95
# 12807  Washington, DC  2020-12-29          3.8       6.2       0.3     46.13
# 12808  Washington, DC  2020-12-30          3.8       7.8      -0.3     52.82
# 12809  Washington, DC  2020-12-31          8.1      12.8       4.4     70.87
#
#        precip  snow  windspeed        conditions cluster cluster1
# 0        5.71  0.00        7.9              Rain       2        5
# 1        0.00  0.00        7.7             Clear       2        5
# 2        0.00  0.00        7.6             Clear       2        3
# 3        2.27  0.00       11.2              Rain       2        5
# 4        0.76  3.88       13.1              Snow       2        2
# ...       ...   ...        ...               ...     ...      ...
# 12805    0.00  0.00       17.2  Partially cloudy       2        5
# 12806    0.00  0.00       19.5  Partially cloudy       2        3
# 12807    0.00  0.00       32.7  Partially cloudy       2        3
# 12808    0.00  0.00       29.0          Overcast       2        3
# 12809    0.00  0.00       28.8          Overcast       2        3
#
# [12810 rows x 12 columns]

# %%
cluster1 = []

for i in df['Temperature']:
    if i < -10: 
        cluster1.append("1")
    elif i > -9 and i < 0:
        cluster1.append("2")
    elif i >1 and i < 15:
        cluster1.append("3")
    elif i > 16 and i <25:
        cluster1.append("4")
    else:
        cluster1.append("5")
        
df["cluster1"] = cluster1
print(df)
# Out:
#                  City        Date  Temperature  temp_max  temp_min  humidity  \
# 0        Montreal, QC  2020-01-01          0.2       1.1      -0.8     87.84
# 1        Montreal, QC  2020-01-02          0.9       2.6      -1.0     78.70
# 2        Montreal, QC  2020-01-03          4.8       5.8       2.8     74.88
# 3        Montreal, QC  2020-01-04          0.5       3.2      -1.9     78.79
# 4        Montreal, QC  2020-01-05         -5.3      -1.8      -9.9     69.09
# ...               ...         ...          ...       ...       ...       ...
# 12805  Washington, DC  2020-12-27          1.0       5.6      -3.6     60.64
# 12806  Washington, DC  2020-12-28          6.1      11.3       1.6     64.95
# 12807  Washington, DC  2020-12-29          3.8       6.2       0.3     46.13
# 12808  Washington, DC  2020-12-30          3.8       7.8      -0.3     52.82
# 12809  Washington, DC  2020-12-31          8.1      12.8       4.4     70.87
#
#        precip  snow  windspeed        conditions cluster cluster1
# 0        5.71  0.00        7.9              Rain       2        5
# 1        0.00  0.00        7.7             Clear       2        5
# 2        0.00  0.00        7.6             Clear       2        3
# 3        2.27  0.00       11.2              Rain       2        5
# 4        0.76  3.88       13.1              Snow       2        2
# ...       ...   ...        ...               ...     ...      ...
# 12805    0.00  0.00       17.2  Partially cloudy       2        5
# 12806    0.00  0.00       19.5  Partially cloudy       2        3
# 12807    0.00  0.00       32.7  Partially cloudy       2        3
# 12808    0.00  0.00       29.0          Overcast       2        3
# 12809    0.00  0.00       28.8          Overcast       2        3
#
# [12810 rows x 12 columns]

# %%
#newdf = df[df.cluster.isin(["2"])]

# %%
#newdf.City.unique()

# %%
y = newdf["City"]

# %%
X= newdf[["temp_max", "temp_min", "humidity"]]

# %%
X.shape, y.shape
# Out:
# ((3660, 3), (3660,))

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model = DecisionTreeClassifier()
model.fit(X_train, y_train)
model.score(X_test, y_test)
# Out:
# 0.34972677595628415

# %%
predictions = model.predict(X_test)

# %%
predictions
# Out:
# array(['Clark County, NV', 'Twin Cities, MN', 'Hawaii, HI',
#        'Twin Cities, MN', 'Broward County, FL', 'Twin Cities, MN',
#        'Clark County, NV', 'Hawaii, HI', 'New Orleans, LA',
#        'Broward County, FL', 'New Brunswick, NB', 'Broward County, FL',
#        'Austin, TX', 'Ottawa, ON', 'Ottawa, ON', 'Clark County, NV',
#        'Austin, TX', 'Austin, TX', 'New Brunswick, NB', 'Ottawa, ON',
#        'Austin, TX', 'Quebec City, QC', 'New Brunswick, NB',
#        'New Orleans, LA', 'Twin Cities, MN', 'Twin Cities, MN',
#        'Quebec City, QC', 'Montreal, QC', 'Montreal, QC', 'Montreal, QC',
#        'New Orleans, LA', 'Twin Cities, MN', 'New Brunswick, NB',
#        'Hawaii, HI', 'New Brunswick, NB', 'Broward County, FL',
#        'Austin, TX', 'Ottawa, ON', 'Clark County, NV',
#        'Broward County, FL', 'Clark County, NV', 'Ottawa, ON',
#        'Ottawa, ON', 'New Brunswick, NB', 'Twin Cities, MN', 'Austin, TX',
#        'New Orleans, LA', 'New Orleans, LA', 'Twin Cities, MN',
#        'Austin, TX', 'Austin, TX', 'New Orleans, LA', 'Quebec City, QC',
#        'Clark County, NV', 'Hawaii, HI', 'Ottawa, ON', 'Twin Cities, MN',
#        'Montreal, QC', 'Twin Cities, MN', 'New Brunswick, NB',
#        'Quebec City, QC', 'New Brunswick, NB', 'Clark County, NV',
#        'Quebec City, QC', 'New Orleans, LA', 'New Brunswick, NB',
#        'Montreal, QC', 'Twin Cities, MN', 'New Brunswick, NB',
#        'Clark County, NV', 'Twin Cities, MN', 'Broward County, FL',
#        'Hawaii, HI', 'Twin Cities, MN', 'Twin Cities, MN', 'Austin, TX',
#        'Twin Cities, MN', 'Austin, TX', 'Hawaii, HI', 'Twin Cities, MN',
#        'Montreal, QC', 'Clark County, NV', 'Austin, TX',
#        'New Brunswick, NB', 'Broward County, FL', 'Ottawa, ON',
#        'Broward County, FL', 'Ottawa, ON', 'Twin Cities, MN',
#        'Twin Cities, MN', 'Montreal, QC', 'Quebec City, QC',
#        'New Orleans, LA', 'Hawaii, HI', 'Twin Cities, MN', 'Ottawa, ON',
#        'New Orleans, LA', 'Quebec City, QC', 'New Orleans, LA',
#        'Quebec City, QC', 'New Brunswick, NB', 'New Brunswick, NB',
#        'Quebec City, QC', 'Montreal, QC', 'Austin, TX', 'Montreal, QC',
#        'Clark County, NV', 'New Orleans, LA', 'New Brunswick, NB',
#        'Austin, TX', 'Quebec City, QC', 'Quebec City, QC',
#        'Clark County, NV', 'New Orleans, LA', 'Ottawa, ON',
#        'Montreal, QC', 'Clark County, NV', 'Quebec City, QC',
#        'Austin, TX', 'Hawaii, HI', 'Montreal, QC', 'Austin, TX',
#        'New Brunswick, NB', 'Clark County, NV', 'Montreal, QC',
#        'Hawaii, HI', 'New Brunswick, NB', 'New Orleans, LA',
#        'Twin Cities, MN', 'Montreal, QC', 'Twin Cities, MN',
#        'Quebec City, QC', 'Hawaii, HI', 'Twin Cities, MN',
#        'Clark County, NV', 'Quebec City, QC', 'Montreal, QC',
#        'Broward County, FL', 'Twin Cities, MN', 'Broward County, FL',
#        'Ottawa, ON', 'Montreal, QC', 'Montreal, QC', 'Ottawa, ON',
#        'Montreal, QC', 'Hawaii, HI', 'Hawaii, HI', 'Clark County, NV',
#        'Quebec City, QC', 'Montreal, QC', 'Clark County, NV',
#        'New Brunswick, NB', 'Ottawa, ON', 'Twin Cities, MN',
#        'Quebec City, QC', 'Hawaii, HI', 'New Brunswick, NB',
#        'New Orleans, LA', 'Broward County, FL', 'Hawaii, HI',
#        'Twin Cities, MN', 'Clark County, NV', 'Clark County, NV',
#        'Hawaii, HI', 'Montreal, QC', 'Quebec City, QC',
#        'Clark County, NV', 'Twin Cities, MN', 'Broward County, FL',
#        'Ottawa, ON', 'Broward County, FL', 'Twin Cities, MN',
#        'New Brunswick, NB', 'Clark County, NV', 'Clark County, NV',
#        'Hawaii, HI', 'Austin, TX', 'New Orleans, LA', 'Austin, TX',
#        'Austin, TX', 'Austin, TX', 'Montreal, QC', 'New Orleans, LA',
#        'Hawaii, HI', 'New Orleans, LA', 'Austin, TX', 'Quebec City, QC',
#        'Montreal, QC', 'Broward County, FL', 'New Brunswick, NB',
#        'Twin Cities, MN', 'Clark County, NV', 'Twin Cities, MN',
#        'Quebec City, QC', 'Hawaii, HI', 'New Brunswick, NB', 'Austin, TX',
#        'Quebec City, QC', 'Twin Cities, MN', 'Ottawa, ON',
#        'Broward County, FL', 'New Orleans, LA', 'Twin Cities, MN',
#        'Twin Cities, MN', 'Montreal, QC', 'Clark County, NV',
#        'Twin Cities, MN', 'New Orleans, LA', 'New Orleans, LA',
#        'Quebec City, QC', 'Montreal, QC', 'Twin Cities, MN',
#        'Quebec City, QC', 'Ottawa, ON', 'Twin Cities, MN',
#        'Clark County, NV', 'Clark County, NV', 'New Orleans, LA',
#        'Clark County, NV', 'New Orleans, LA', 'New Brunswick, NB',
#        'Ottawa, ON', 'Ottawa, ON', 'Montreal, QC', 'Twin Cities, MN',
#        'Broward County, FL', 'Ottawa, ON', 'Twin Cities, MN',
#        'Montreal, QC', 'Ottawa, ON', 'Hawaii, HI', 'New Brunswick, NB',
#        'New Brunswick, NB', 'Twin Cities, MN', 'Ottawa, ON',
#        'Broward County, FL', 'Montreal, QC', 'Clark County, NV',
#        'Quebec City, QC', 'Austin, TX', 'Austin, TX', 'Twin Cities, MN',
#        'New Orleans, LA', 'Quebec City, QC', 'Austin, TX', 'Austin, TX',
#        'Twin Cities, MN', 'Clark County, NV', 'Clark County, NV',
#        'Quebec City, QC', 'Ottawa, ON', 'Clark County, NV',
#        'Montreal, QC', 'New Orleans, LA', 'Hawaii, HI', 'Austin, TX',
#        'Montreal, QC', 'Twin Cities, MN', 'Ottawa, ON',
#        'Broward County, FL', 'Broward County, FL', 'Ottawa, ON',
#        'Montreal, QC', 'Twin Cities, MN', 'Twin Cities, MN',
#        'Twin Cities, MN', 'New Brunswick, NB', 'Hawaii, HI',
#        'Clark County, NV', 'Twin Cities, MN', 'Austin, TX',
#        'Montreal, QC', 'New Brunswick, NB', 'Broward County, FL',
#        'Clark County, NV', 'Twin Cities, MN', 'Austin, TX',
#        'New Brunswick, NB', 'Montreal, QC', 'Montreal, QC', 'Hawaii, HI',
#        'Broward County, FL', 'Broward County, FL', 'Ottawa, ON',
#        'Quebec City, QC', 'Ottawa, ON', 'New Orleans, LA',
#        'Quebec City, QC', 'Hawaii, HI', 'Ottawa, ON', 'Montreal, QC',
#        'Twin Cities, MN', 'Austin, TX', 'New Orleans, LA', 'Montreal, QC',
#        'Quebec City, QC', 'Broward County, FL', 'Quebec City, QC',
#        'Hawaii, HI', 'Ottawa, ON', 'Broward County, FL',
#        'New Orleans, LA', 'Hawaii, HI', 'Hawaii, HI',
#        'Broward County, FL', 'New Orleans, LA', 'Hawaii, HI',
#        'Ottawa, ON', 'Twin Cities, MN', 'Broward County, FL',
#        'Austin, TX', 'Broward County, FL', 'Hawaii, HI', 'Ottawa, ON',
#        'Hawaii, HI', 'Austin, TX', 'Austin, TX', 'Clark County, NV',
#        'Austin, TX', 'Broward County, FL', 'Broward County, FL',
#        'Ottawa, ON', 'Montreal, QC', 'Montreal, QC', 'Broward County, FL',
#        'Ottawa, ON', 'Twin Cities, MN', 'Hawaii, HI', 'Quebec City, QC',
#        'Hawaii, HI', 'New Orleans, LA', 'Montreal, QC', 'New Orleans, LA',
#        'Ottawa, ON', 'Quebec City, QC', 'Quebec City, QC', 'Ottawa, ON',
#        'New Brunswick, NB', 'New Brunswick, NB', 'Quebec City, QC',
#        'Austin, TX', 'New Orleans, LA', 'Montreal, QC', 'Montreal, QC',
#        'Twin Cities, MN', 'Hawaii, HI', 'Austin, TX', 'Clark County, NV',
#        'Austin, TX', 'Montreal, QC', 'New Orleans, LA', 'Hawaii, HI',
#        'Broward County, FL', 'Austin, TX', 'New Brunswick, NB',
#        'Austin, TX', 'New Brunswick, NB', 'Austin, TX', 'Twin Cities, MN',
#        'Twin Cities, MN', 'Quebec City, QC', 'Broward County, FL',
#        'New Orleans, LA', 'Twin Cities, MN', 'Clark County, NV',
#        'Clark County, NV', 'Hawaii, HI', 'Montreal, QC', 'Montreal, QC',
#        'Broward County, FL', 'Ottawa, ON', 'Montreal, QC',
#        'Twin Cities, MN', 'New Brunswick, NB', 'Austin, TX',
#        'Twin Cities, MN', 'Ottawa, ON', 'Quebec City, QC',
#        'Broward County, FL', 'Austin, TX', 'Hawaii, HI',
#        'Twin Cities, MN', 'Broward County, FL', 'New Orleans, LA',
#        'Twin Cities, MN', 'Clark County, NV', 'Twin Cities, MN',
#        'Twin Cities, MN', 'Broward County, FL', 'Twin Cities, MN',
#        'New Brunswick, NB', 'Clark County, NV', 'Twin Cities, MN',
#        'New Orleans, LA', 'Montreal, QC', 'Montreal, QC',
#        'Quebec City, QC', 'New Orleans, LA', 'Hawaii, HI', 'Hawaii, HI',
#        'Hawaii, HI', 'Clark County, NV', 'Montreal, QC',
#        'Quebec City, QC', 'Montreal, QC', 'Ottawa, ON', 'Twin Cities, MN',
#        'New Orleans, LA', 'Clark County, NV', 'New Orleans, LA',
#        'Quebec City, QC', 'Quebec City, QC', 'Hawaii, HI', 'Austin, TX',
#        'New Brunswick, NB', 'Quebec City, QC', 'Hawaii, HI',
#        'New Orleans, LA', 'Hawaii, HI', 'New Brunswick, NB',
#        'Clark County, NV', 'Twin Cities, MN', 'Broward County, FL',
#        'Hawaii, HI', 'Quebec City, QC', 'Montreal, QC', 'Quebec City, QC',
#        'New Brunswick, NB', 'Broward County, FL', 'Quebec City, QC',
#        'Hawaii, HI', 'Ottawa, ON', 'Broward County, FL', 'Ottawa, ON',
#        'Hawaii, HI', 'Hawaii, HI', 'New Brunswick, NB', 'Austin, TX',
#        'Austin, TX', 'Twin Cities, MN', 'Ottawa, ON', 'Quebec City, QC',
#        'New Brunswick, NB', 'Twin Cities, MN', 'Quebec City, QC',
#        'Austin, TX', 'Twin Cities, MN', 'New Brunswick, NB',
#        'Montreal, QC', 'Quebec City, QC', 'New Brunswick, NB',
#        'Broward County, FL', 'Hawaii, HI', 'Broward County, FL',
#        'New Brunswick, NB', 'New Brunswick, NB', 'Twin Cities, MN',
#        'New Brunswick, NB', 'Montreal, QC', 'New Orleans, LA',
#        'Austin, TX', 'Hawaii, HI', 'Montreal, QC', 'Quebec City, QC',
#        'Montreal, QC', 'Austin, TX', 'Clark County, NV',
#        'Twin Cities, MN', 'New Orleans, LA', 'New Brunswick, NB',
#        'Ottawa, ON', 'Ottawa, ON', 'Broward County, FL',
#        'Broward County, FL', 'New Brunswick, NB', 'Quebec City, QC',
#        'Twin Cities, MN', 'Montreal, QC', 'Quebec City, QC',
#        'Quebec City, QC', 'New Brunswick, NB', 'New Brunswick, NB',
#        'New Brunswick, NB', 'Montreal, QC', 'Hawaii, HI',
#        'Twin Cities, MN', 'Clark County, NV', 'New Brunswick, NB',
#        'Montreal, QC', 'Ottawa, ON', 'Montreal, QC', 'Hawaii, HI',
#        'Clark County, NV', 'New Orleans, LA', 'Austin, TX',
#        'Montreal, QC', 'Broward County, FL', 'New Orleans, LA',
#        'Twin Cities, MN', 'Austin, TX', 'Broward County, FL',
#        'Ottawa, ON', 'Hawaii, HI', 'Quebec City, QC', 'Twin Cities, MN',
#        'Quebec City, QC', 'Clark County, NV', 'Montreal, QC',
#        'New Brunswick, NB', 'Ottawa, ON', 'Ottawa, ON', 'Montreal, QC',
#        'Twin Cities, MN', 'Montreal, QC', 'Quebec City, QC',
#        'Quebec City, QC', 'New Orleans, LA', 'Montreal, QC',
#        'Broward County, FL', 'New Orleans, LA', 'Quebec City, QC',
#        'Broward County, FL', 'New Brunswick, NB', 'Hawaii, HI',
#        'Quebec City, QC', 'Montreal, QC', 'Clark County, NV',
#        'Montreal, QC', 'Twin Cities, MN', 'Montreal, QC', 'Ottawa, ON',
#        'Hawaii, HI', 'New Brunswick, NB', 'Hawaii, HI',
#        'New Brunswick, NB', 'New Orleans, LA', 'Quebec City, QC',
#        'Ottawa, ON', 'New Orleans, LA', 'Hawaii, HI', 'Montreal, QC',
#        'Hawaii, HI', 'Hawaii, HI', 'Austin, TX', 'Austin, TX',
#        'Montreal, QC', 'New Brunswick, NB', 'Hawaii, HI',
#        'New Orleans, LA', 'Hawaii, HI', 'Ottawa, ON', 'New Brunswick, NB',
#        'Austin, TX', 'Montreal, QC', 'Twin Cities, MN', 'Austin, TX',
#        'Austin, TX', 'Montreal, QC', 'Clark County, NV',
#        'Clark County, NV', 'Twin Cities, MN', 'Ottawa, ON',
#        'New Orleans, LA', 'Hawaii, HI', 'Hawaii, HI', 'Quebec City, QC',
#        'Ottawa, ON', 'Hawaii, HI', 'Austin, TX', 'Twin Cities, MN',
#        'Twin Cities, MN', 'New Orleans, LA', 'Austin, TX', 'Ottawa, ON',
#        'Austin, TX', 'New Brunswick, NB', 'Quebec City, QC', 'Ottawa, ON',
#        'Twin Cities, MN', 'Montreal, QC', 'Austin, TX',
#        'New Brunswick, NB', 'New Brunswick, NB', 'Twin Cities, MN',
#        'New Orleans, LA', 'New Brunswick, NB', 'Montreal, QC',
#        'New Brunswick, NB', 'Ottawa, ON', 'Clark County, NV',
#        'Hawaii, HI', 'New Orleans, LA', 'Austin, TX', 'New Orleans, LA',
#        'New Brunswick, NB', 'Broward County, FL', 'Broward County, FL',
#        'Twin Cities, MN', 'Hawaii, HI', 'Ottawa, ON', 'Quebec City, QC',
#        'New Brunswick, NB', 'New Orleans, LA', 'Montreal, QC',
#        'Broward County, FL', 'Broward County, FL', 'Montreal, QC',
#        'Twin Cities, MN', 'Quebec City, QC', 'Twin Cities, MN',
#        'New Brunswick, NB', 'Quebec City, QC', 'Twin Cities, MN',
#        'Montreal, QC', 'Quebec City, QC', 'Clark County, NV',
#        'Montreal, QC', 'Twin Cities, MN', 'Twin Cities, MN',
#        'Montreal, QC', 'Montreal, QC', 'Broward County, FL', 'Ottawa, ON',
#        'Quebec City, QC', 'Broward County, FL', 'Hawaii, HI',
#        'Twin Cities, MN', 'Austin, TX', 'Quebec City, QC',
#        'Twin Cities, MN', 'Ottawa, ON', 'Broward County, FL',
#        'Hawaii, HI', 'Quebec City, QC', 'Quebec City, QC', 'Ottawa, ON',
#        'Montreal, QC', 'Hawaii, HI', 'New Orleans, LA', 'New Orleans, LA',
#        'Clark County, NV', 'Montreal, QC', 'Ottawa, ON',
#        'New Brunswick, NB', 'Austin, TX', 'Quebec City, QC',
#        'New Orleans, LA', 'Broward County, FL', 'Clark County, NV',
#        'New Brunswick, NB', 'Quebec City, QC', 'New Brunswick, NB',
#        'New Orleans, LA', 'Quebec City, QC', 'Clark County, NV',
#        'Broward County, FL', 'Quebec City, QC', 'Clark County, NV',
#        'Montreal, QC', 'Twin Cities, MN', 'Quebec City, QC',
#        'New Orleans, LA', 'New Orleans, LA', 'Montreal, QC',
#        'Twin Cities, MN', 'Broward County, FL', 'Montreal, QC',
#        'Twin Cities, MN', 'Hawaii, HI', 'Clark County, NV',
#        'Broward County, FL', 'Broward County, FL', 'Quebec City, QC',
#        'Quebec City, QC', 'Austin, TX', 'New Orleans, LA', 'Ottawa, ON',
#        'Broward County, FL', 'Broward County, FL', 'Broward County, FL',
#        'Hawaii, HI', 'Austin, TX', 'New Brunswick, NB', 'New Orleans, LA',
#        'Clark County, NV', 'Broward County, FL', 'New Brunswick, NB',
#        'Clark County, NV', 'Quebec City, QC', 'Ottawa, ON',
#        'Quebec City, QC', 'Austin, TX', 'New Brunswick, NB',
#        'Clark County, NV', 'Hawaii, HI', 'New Brunswick, NB',
#        'Quebec City, QC', 'Twin Cities, MN', 'Quebec City, QC',
#        'Twin Cities, MN', 'Ottawa, ON', 'Broward County, FL',
#        'New Orleans, LA', 'Broward County, FL', 'Austin, TX',
#        'Clark County, NV', 'New Brunswick, NB', 'Broward County, FL',
#        'Quebec City, QC', 'Ottawa, ON', 'Quebec City, QC', 'Hawaii, HI',
#        'Quebec City, QC', 'New Orleans, LA', 'Clark County, NV',
#        'Clark County, NV', 'New Brunswick, NB', 'Austin, TX',
#        'New Orleans, LA', 'Austin, TX', 'Broward County, FL',
#        'Montreal, QC', 'Ottawa, ON', 'Ottawa, ON', 'Clark County, NV',
#        'Quebec City, QC', 'New Brunswick, NB', 'Quebec City, QC',
#        'Quebec City, QC', 'Broward County, FL', 'Ottawa, ON',
#        'New Brunswick, NB', 'Broward County, FL', 'Austin, TX',
#        'New Brunswick, NB', 'Quebec City, QC', 'Twin Cities, MN',
#        'New Brunswick, NB', 'Twin Cities, MN', 'New Brunswick, NB',
#        'Hawaii, HI', 'New Orleans, LA', 'Clark County, NV',
#        'Twin Cities, MN', 'Austin, TX', 'Twin Cities, MN',
#        'Twin Cities, MN', 'Clark County, NV', 'Quebec City, QC',
#        'Twin Cities, MN', 'Twin Cities, MN', 'New Brunswick, NB',
#        'Austin, TX', 'New Orleans, LA', 'Clark County, NV',
#        'Twin Cities, MN', 'Broward County, FL', 'Ottawa, ON',
#        'Quebec City, QC', 'New Brunswick, NB', 'Clark County, NV',
#        'New Orleans, LA', 'Quebec City, QC', 'Clark County, NV',
#        'Quebec City, QC', 'Hawaii, HI', 'Broward County, FL',
#        'Austin, TX', 'Clark County, NV', 'New Brunswick, NB',
#        'Austin, TX', 'Hawaii, HI', 'Twin Cities, MN', 'Quebec City, QC',
#        'Montreal, QC', 'Quebec City, QC', 'Clark County, NV',
#        'Ottawa, ON', 'Quebec City, QC', 'Quebec City, QC',
#        'Twin Cities, MN', 'Hawaii, HI', 'Broward County, FL',
#        'Clark County, NV', 'Quebec City, QC', 'Broward County, FL',
#        'Montreal, QC', 'Hawaii, HI', 'Ottawa, ON', 'Broward County, FL',
#        'Ottawa, ON', 'New Orleans, LA', 'New Orleans, LA',
#        'Quebec City, QC', 'Montreal, QC', 'Montreal, QC', 'Ottawa, ON',
#        'Quebec City, QC', 'New Brunswick, NB', 'New Orleans, LA',
#        'Montreal, QC', 'Quebec City, QC', 'Twin Cities, MN',
#        'Twin Cities, MN', 'Twin Cities, MN', 'New Brunswick, NB',
#        'Montreal, QC', 'Clark County, NV', 'Quebec City, QC',
#        'Clark County, NV', 'Quebec City, QC', 'Twin Cities, MN',
#        'New Orleans, LA', 'Ottawa, ON', 'Broward County, FL',
#        'Hawaii, HI', 'Hawaii, HI', 'Twin Cities, MN', 'Montreal, QC',
#        'Austin, TX', 'Quebec City, QC', 'Quebec City, QC', 'Ottawa, ON',
#        'Twin Cities, MN', 'Twin Cities, MN', 'Twin Cities, MN',
#        'Ottawa, ON', 'Austin, TX', 'Broward County, FL',
#        'Broward County, FL', 'New Orleans, LA', 'Twin Cities, MN',
#        'Hawaii, HI', 'Twin Cities, MN', 'Montreal, QC', 'Ottawa, ON',
#        'Austin, TX', 'Austin, TX', 'New Brunswick, NB', 'Montreal, QC',
#        'Twin Cities, MN', 'Austin, TX', 'Quebec City, QC', 'Ottawa, ON',
#        'Broward County, FL', 'Ottawa, ON', 'Ottawa, ON', 'Montreal, QC',
#        'New Brunswick, NB', 'Clark County, NV', 'Hawaii, HI',
#        'Twin Cities, MN', 'New Brunswick, NB', 'Quebec City, QC',
#        'Quebec City, QC', 'Montreal, QC', 'Montreal, QC',
#        'Quebec City, QC', 'Austin, TX', 'Hawaii, HI', 'Austin, TX',
#        'Austin, TX', 'Clark County, NV', 'Twin Cities, MN',
#        'New Brunswick, NB', 'New Orleans, LA', 'New Orleans, LA',
#        'Austin, TX', 'New Orleans, LA', 'Austin, TX', 'New Brunswick, NB',
#        'Austin, TX', 'Hawaii, HI', 'Quebec City, QC', 'Twin Cities, MN',
#        'New Brunswick, NB', 'Clark County, NV', 'Hawaii, HI',
#        'Twin Cities, MN', 'Twin Cities, MN', 'Austin, TX',
#        'Quebec City, QC', 'Hawaii, HI', 'New Orleans, LA', 'Ottawa, ON',
#        'New Orleans, LA', 'Austin, TX', 'Ottawa, ON', 'Ottawa, ON',
#        'Quebec City, QC', 'Broward County, FL', 'New Brunswick, NB',
#        'Broward County, FL', 'Hawaii, HI', 'Twin Cities, MN',
#        'Ottawa, ON', 'New Brunswick, NB', 'Hawaii, HI', 'Hawaii, HI',
#        'Hawaii, HI', 'Hawaii, HI', 'New Orleans, LA', 'New Brunswick, NB',
#        'Clark County, NV', 'Quebec City, QC', 'Clark County, NV',
#        'Twin Cities, MN', 'Austin, TX', 'Broward County, FL',
#        'Quebec City, QC', 'Quebec City, QC', 'Hawaii, HI', 'Hawaii, HI',
#        'Hawaii, HI', 'Hawaii, HI'], dtype=object)

# %%
data_point = [[20, 25, 2]]

model.predict(data_point)
# Out:
# array(['Clark County, NV'], dtype=object)

# %%
# 1.We find the variable types of each column - We need to change date to a date-time variable
df.dtypes
# Out:
# City            object
# Date            object
# Temperature    float64
# temp_max       float64
# temp_min       float64
# humidity       float64
# precip         float64
# snow           float64
# windspeed      float64
# conditions      object
# cluster         object
# dtype: object

# %%
#User would imput this value
df['day'] = df.Time_stamp.dt.day
df['month'] = df.Time_stamp.dt.month
df['year'] = df.Time_stamp.dt.year
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-67-02458901f2b5> in <module>
#       1 #User would imput this value
# ----> 2 df['day'] = df.Time_stamp.dt.day
#       3 df['month'] = df.Time_stamp.dt.month
#       4 df['year'] = df.Time_stamp.dt.year
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Time_stamp'

# %%
df
# Out:
#                  City        Date  Temperature  temp_max  temp_min  humidity  \
# 0        Montreal, QC  2020-01-01          0.2       1.1      -0.8     87.84
# 1        Montreal, QC  2020-01-02          0.9       2.6      -1.0     78.70
# 2        Montreal, QC  2020-01-03          4.8       5.8       2.8     74.88
# 3        Montreal, QC  2020-01-04          0.5       3.2      -1.9     78.79
# 4        Montreal, QC  2020-01-05         -5.3      -1.8      -9.9     69.09
# ...               ...         ...          ...       ...       ...       ...
# 12805  Washington, DC  2020-12-27          1.0       5.6      -3.6     60.64
# 12806  Washington, DC  2020-12-28          6.1      11.3       1.6     64.95
# 12807  Washington, DC  2020-12-29          3.8       6.2       0.3     46.13
# 12808  Washington, DC  2020-12-30          3.8       7.8      -0.3     52.82
# 12809  Washington, DC  2020-12-31          8.1      12.8       4.4     70.87
#
#        precip  snow  windspeed        conditions
# 0        5.71  0.00        7.9              Rain
# 1        0.00  0.00        7.7             Clear
# 2        0.00  0.00        7.6             Clear
# 3        2.27  0.00       11.2              Rain
# 4        0.76  3.88       13.1              Snow
# ...       ...   ...        ...               ...
# 12805    0.00  0.00       17.2  Partially cloudy
# 12806    0.00  0.00       19.5  Partially cloudy
# 12807    0.00  0.00       32.7  Partially cloudy
# 12808    0.00  0.00       29.0          Overcast
# 12809    0.00  0.00       28.8          Overcast
#
# [12810 rows x 10 columns]

# %%
#Ansers to be provided by user
Month = 12
Start_Day = 21
End_Day = 31

# %%
df_new = df[(df.month == Month) & (df.day >= Start_Day) & (df.day <= End_Day)]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-934f5a960ef5> in <module>
# ----> 1 df_new = df[(df.month == Month) & (df.day >= Start_Day) & (df.day <= End_Day)]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'month'

# %%
df_new
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-94dbd581444b> in <module>
# ----> 1 df_new
#
# NameError: name 'df_new' is not defined

# %%
y = df_new["City"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-c76c01ea2934> in <module>
# ----> 1 y = df_new["City"]
#
# NameError: name 'df_new' is not defined

# %%
X= df_new[["temp_max", "temp_min"]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-8541c2dd03f5> in <module>
# ----> 1 X= df_new[["temp_max", "temp_min"]]
#
# NameError: name 'df_new' is not defined

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
model = DecisionTreeClassifier()
model.fit(X_train, y_train)
model.score(X_test, y_test)

# %%
data_point = [[15, 10]]

model.predict(data_point)

# %%
y = df_new["City"]

# %%
X= df_new[["temp_max", "temp_min", "humidity"]] #"humidity", "windspeed", "precip", "snow"

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
model = DecisionTreeClassifier()
model.fit(X_train, y_train)
model.score(X_test, y_test)

# %%
#For humidity, maybe the user inputs very high high, medium or low --> very high 80 , high 65, medium 40, low 20
data_point = [[-5, -10, 80]]

model.predict(data_point)
