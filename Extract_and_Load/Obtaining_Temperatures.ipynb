# %%
# 1.Importing dependencies

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import os

# %%
#2. We add url. Each city will have a new url

url2 = "https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/Washington%20DC/2020-1-1/2020-12-31?unitGroup=metric&key=SRX784Y4XEDTND44NFLHKK42Z&include=obs"

# %%
response = requests.get(url2).json()

# %%
response
# Out:
# {'queryCost': 366,
#  'latitude': 38.8904,
#  'longitude': -77.032,
#  'resolvedAddress': 'Washington, DC, United States',
#  'address': 'Washington DC',
#  'timezone': 'America/New_York',
#  'tzoffset': -5.0,
#  'days': [{'datetime': '2020-01-01',
#    'datetimeEpoch': 1577854800,
#    'tempmax': 10.6,
#    'tempmin': 2.3,
#    'temp': 6.8,
#    'feelslikemax': 10.6,
#    'feelslikemin': 0.4,
#    'feelslike': 4.7,
#    'dew': -4.2,
#    'humidity': 46.64,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 35.3,
#    'windspeed': 23.6,
#    'winddir': 281.7,
#    'pressure': 1010.9,
#    'cloudcover': 41.6,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:26:47',
#    'sunriseEpoch': 1577881607,
#    'sunset': '16:56:28',
#    'sunsetEpoch': 1577915788,
#    'moonphase': 0.17,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['KDCA',
#     '72405013743',
#     '72403793728',
#     'KADW',
#     'KDAA',
#     '74594013705'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-02',
#    'datetimeEpoch': 1577941200,
#    'tempmax': 11.7,
#    'tempmin': 0.2,
#    'temp': 5.7,
#    'feelslikemax': 11.7,
#    'feelslikemin': -2.1,
#    'feelslike': 4.7,
#    'dew': -0.5,
#    'humidity': 66.3,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 14.2,
#    'winddir': 162.3,
#    'pressure': 1014.3,
#    'cloudcover': 64.2,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:26:55',
#    'sunriseEpoch': 1577968015,
#    'sunset': '16:57:17',
#    'sunsetEpoch': 1578002237,
#    'moonphase': 0.22,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['KDCA',
#     '72405013743',
#     '72403793728',
#     'KADW',
#     'KDAA',
#     '74594013705'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-03',
#    'datetimeEpoch': 1578027600,
#    'tempmax': 11.7,
#    'tempmin': 8.3,
#    'temp': 10.1,
#    'feelslikemax': 11.7,
#    'feelslikemin': 6.1,
#    'feelslike': 9.4,
#    'dew': 8.2,
#    'humidity': 89.04,
#    'precip': 5.43,
#    'precipprob': None,
#    'precipcover': 50.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 17.4,
#    'winddir': 158.8,
#    'pressure': 1010.4,
#    'cloudcover': 84.2,
#    'visibility': 14.9,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:27:01',
#    'sunriseEpoch': 1578054421,
#    'sunset': '16:58:07',
#    'sunsetEpoch': 1578088687,
#    'moonphase': 0.26,
#    'conditions': 'Rain, Overcast',
#    'icon': 'rain',
#    'stations': ['KDCA',
#     '72405013743',
#     '72403793728',
#     'KADW',
#     'KDAA',
#     '74594013705'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-04',
#    'datetimeEpoch': 1578114000,
#    'tempmax': 15.0,
#    'tempmin': 8.3,
#    'temp': 11.6,
#    'feelslikemax': 15.0,
#    'feelslikemin': 4.6,
#    'feelslike': 11.0,
#    'dew': 10.3,
#    'humidity': 92.45,
#    'precip': 8.73,
#    'precipprob': None,
#    'precipcover': 41.67,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 46.1,
#    'windspeed': 26.9,
#    'winddir': 222.4,
#    'pressure': 1004.8,
#    'cloudcover': 79.4,
#    'visibility': 11.6,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:27:05',
#    'sunriseEpoch': 1578140825,
#    'sunset': '16:58:59',
#    'sunsetEpoch': 1578175139,
#    'moonphase': 0.31,
#    'conditions': 'Rain, Overcast',
#    'icon': 'rain',
#    'stations': ['KDCA',
#     '72405013743',
#     '72403793728',
#     'KADW',
#     'KDAA',
#     '74594013705'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-05',
#    'datetimeEpoch': 1578200400,
#    'tempmax': 7.8,
#    'tempmin': 1.9,
#    'temp': 4.8,
#    'feelslikemax': 4.1,
#    'feelslikemin': -1.4,
#    'feelslike': 1.1,
#    'dew': -3.6,
#    'humidity': 54.88,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 58.9,
#    'windspeed': 34.5,
#    'winddir': 299.1,
#    'pressure': 1015.9,
#    'cloudcover': 72.3,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:27:06',
#    'sunriseEpoch': 1578227226,
#    'sunset': '16:59:52',
#    'sunsetEpoch': 1578261592,
#    'moonphase': 0.36,
#    'conditions': 'Partially cloudy',
#    'icon': 'wind',
#    'stations': ['KDCA',
#     '72405013743',
#     '72403793728',
#     'KADW',
#     'KDAA',
#     '74594013705'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-06',
#    'datetimeEpoch': 1578286800,
#    'tempmax': 12.8,
#    'tempmin': 1.9,
#    'temp': 6.7,
#    'feelslikemax': 12.8,
#    'feelslikemin': -0.4,
#    'feelslike': 5.3,
#    'dew': -4.0,
#    'humidity': 49.96,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 44.6,
#    'windspeed': 27.2,
#    'winddir': 226.2,
#    'pressure': 1017.6,
#    'cloudcover': 46.2,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:27:06',
#    'sunriseEpoch': 1578313626,
#    'sunset': '17:00:47',
#    'sunsetEpoch': 1578348047,
#    'moonphase': 0.4,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['KDCA',
#     '72405013743',
#     '72403793728',
#     'KADW',
#     'KDAA',
#     '74594013705'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-07',
#    'datetimeEpoch': 1578373200,
#    'tempmax': 7.7,
#    'tempmin': 0.5,
#    'temp': 2.7,
#    'feelslikemax': 7.1,
#    'feelslikemin': -3.5,
#    'feelslike': 0.6,
#    'dew': -2.2,
#    'humidity': 72.52,
#    'precip': 5.83,
#    'precipprob': None,
#    'precipcover': 25.0,
#    'preciptype': None,
#    'snow': 1.88,
#    'snowdepth': 1.88,
#    'windgust': 29.5,
#    'windspeed': 22.2,
#    'winddir': 167.5,
#    'pressure': 1016.7,
#    'cloudcover': 66.4,
#    'visibility': 13.9,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:27:03',
#    'sunriseEpoch': 1578400023,
#    'sunset': '17:01:42',
#    'sunsetEpoch': 1578434502,
#    'moonphase': 0.44,
#    'conditions': 'Snow, Partially cloudy',
#    'icon': 'snow',
#    'stations': ['KDCA',
#     '72405013743',
#     '72403793728',
#     'KADW',
#     'KDAA',
#     '74594013705'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-08',
#    'datetimeEpoch': 1578459600,
#    'tempmax': 8.2,
#    'tempmin': -0.8,
#    'temp': 3.0,
#    'feelslikemax': 4.1,
#    'feelslikemin': -4.9,
#    'feelslike': -0.9,
#    'dew': -4.8,
#    'humidity': 61.38,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 1.13,
#    'snowdepth': 3.0,
#    'windgust': 55.9,
#    'windspeed': 36.1,
#    'winddir': 270.4,
#    'pressure': 1021.5,
#    'cloudcover': 27.1,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:26:58',
#    'sunriseEpoch': 1578486418,
#    'sunset': '17:02:39',
#    'sunsetEpoch': 1578520959,
#    'moonphase': 0.47,
#    'conditions': 'Snow, Partially cloudy',
#    'icon': 'snow',
#    'stations': ['KDCA',
#     '72405013743',
#     '72403793728',
#     'KADW',
#     'KDAA',
#     '74594013705'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-09',
#    'datetimeEpoch': 1578546000,
#    'tempmax': 4.8,
#    'tempmin': -1.9,
#    'temp': 0.9,
#    'feelslikemax': 4.3,
#    'feelslikemin': -7.1,
#    'feelslike': -2.6,
#    'dew': -8.5,
#    'humidity': 49.94,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 1.0,
#    'windgust': None,
#    'windspeed': 21.1,
#    'winddir': 156.3,
#    'pressure': 1039.2,
#    'cloudcover': 56.9,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:26:51',
#    'sunriseEpoch': 1578572811,
#    'sunset': '17:03:37',
#    'sunsetEpoch': 1578607417,
#    'moonphase': 0.49,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['KDCA',
#     '72405013743',
#     '72403793728',
#     'KADW',
#     'KDAA',
#     '74594013705'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-10',
#    'datetimeEpoch': 1578632400,
#    'tempmax': 12.2,
#    'tempmin': 1.6,
#    'temp': 7.2,
#    'feelslikemax': 12.2,
#    'feelslikemin': -1.6,
#    'feelslike': 5.6,
#    'dew': 2.6,
#    'humidity': 72.88,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 31.7,
#    'windspeed': 19.8,
#    'winddir': 189.3,
#    'pressure': 1033.9,
#    'cloudcover': 70.1,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:26:42',
#    'sunriseEpoch': 1578659202,
#    'sunset': '17:04:36',
#    'sunsetEpoch': 1578693876,
#    'moonphase': 0.5,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['KDCA',
#     '72405013743',
#     '72403793728',
#     'KADW',
#     'KDAA',
#     '74594013705'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-11',
#    'datetimeEpoch': 1578718800,
#    'tempmax': 22.2,
#    'tempmin': 9.2,
#    'temp': 15.6,
#    'feelslikemax': 22.2,
#    'feelslikemin': 9.0,
#    'feelslike': 15.6,
#    'dew': 11.8,
#    'humidity': 78.79,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 53.4,
#    'windspeed': 39.1,
#    'winddir': 188.8,
#    'pressure': 1022.3,
#    'cloudcover': 78.2,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:26:31',
#    'sunriseEpoch': 1578745591,
#    'sunset': '17:05:36',
#    'sunsetEpoch': 1578780336,
#    'moonphase': 0.51,
#    'conditions': 'Overcast',
#    'icon': 'wind',
#    'stations': ['KDCA',
#     '72405013743',
#     '72403793728',
#     'KADW',
#     'KDAA',
#     '74594013705'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-12',
#    'datetimeEpoch': 1578805200,
#    'tempmax': 21.1,
#    'tempmin': 9.2,
#    'temp': 17.3,
#    'feelslikemax': 21.1,
#    'feelslikemin': 7.4,
#    'feelslike': 17.3,
#    'dew': 10.0,
#    'humidity': 65.03,
#    'precip': 11.6,
#    'precipprob': None,
#    'precipcover': 20.83,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 66.2,
#    'windspeed': 49.7,
#    'winddir': 233.9,
#    'pressure': 1020.4,
#    'cloudcover': 47.1,
#    'visibility': 15.5,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:26:17',
#    'sunriseEpoch': 1578831977,
#    'sunset': '17:06:37',
#    'sunsetEpoch': 1578866797,
#    'moonphase': 0.52,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['KDCA',
#     '72405013743',
#     '72403793728',
#     'KADW',
#     'KDAA',
#     '74594013705'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-13',
#    'datetimeEpoch': 1578891600,
#    'tempmax': 11.6,
#    'tempmin': 6.6,
#    'temp': 8.9,
#    'feelslikemax': 11.6,
#    'feelslikemin': 4.9,
#    'feelslike': 8.0,
#    'dew': 4.4,
#    'humidity': 73.63,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 14.0,
#    'winddir': 85.0,
#    'pressure': 1028.2,
#    'cloudcover': 79.4,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:26:02',
#    'sunriseEpoch': 1578918362,
#    'sunset': '17:07:39',
#    'sunsetEpoch': 1578953259,
#    'moonphase': 0.55,
#    'conditions': 'Overcast',
#    'icon': 'cloudy',
#    'stations': ['KDCA',
#     '72405013743',
#     '72403793728',
#     'KADW',
#     'KDAA',
#     '74594013705'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-14',
#    'datetimeEpoch': 1578978000,
#    'tempmax': 9.3,
#    'tempmin': 6.4,
#    'temp': 8.2,
#    'feelslikemax': 8.8,
#    'feelslikemin': 5.1,
#    'feelslike': 7.5,
#    'dew': 7.2,
#    'humidity': 93.0,
#    'precip': 1.06,
#    'precipprob': None,
#    'precipcover': 20.83,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 12.5,
#    'winddir': 95.3,
#    'pressure': 1023.9,
#    'cloudcover': 94.3,
#    'visibility': 9.8,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:25:44',
#    'sunriseEpoch': 1579004744,
#    'sunset': '17:08:42',
#    'sunsetEpoch': 1579039722,
#    'moonphase': 0.59,
#    'conditions': 'Rain, Overcast',
#    'icon': 'rain',
#    'stations': ['KDCA',
#     '72405013743',
#     '72403793728',
#     'KADW',
#     'KDAA',
#     '74594013705'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-15',
#    'datetimeEpoch': 1579064400,
#    'tempmax': 13.9,
#    'tempmin': 7.1,
#    'temp': 9.7,
#    'feelslikemax': 13.9,
#    'feelslikemin': 5.9,
#    'feelslike': 9.0,
#    'dew': 7.2,
#    'humidity': 85.29,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 17.5,
#    'winddir': 226.8,
#    'pressure': 1021.7,
#    'cloudcover': 75.7,
#    'visibility': 12.5,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:25:25',
#    'sunriseEpoch': 1579091125,
#    'sunset': '17:09:45',
#    'sunsetEpoch': 1579126185,
#    'moonphase': 0.64,
#    'conditions': 'Overcast',
#    'icon': 'cloudy',
#    'stations': ['KDCA',
#     '72405013743',
#     '72403793728',
#     'KADW',
#     'KDAA',
#     '74594013705'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-16',
#    'datetimeEpoch': 1579150800,
#    'tempmax': 13.2,
#    'tempmin': 3.3,
#    'temp': 9.3,
#    'feelslikemax': 13.2,
#    'feelslikemin': -2.7,
#    'feelslike': 7.1,
#    'dew': -0.5,
#    'humidity': 54.31,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 60.7,
#    'windspeed': 43.7,
#    'winddir': 288.2,
#    'pressure': 1019.9,
#    'cloudcover': 38.7,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:25:03',
#    'sunriseEpoch': 1579177503,
#    'sunset': '17:10:50',
#    'sunsetEpoch': 1579212650,
#    'moonphase': 0.69,
#    'conditions': 'Partially cloudy',
#    'icon': 'wind',
#    'stations': ['KDCA',
#     '72405013743',
#     '72403793728',
#     'KADW',
#     'KDAA',
#     '74594013705'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-17',
#    'datetimeEpoch': 1579237200,
#    'tempmax': 3.8,
#    'tempmin': -1.0,
#    'temp': 1.2,
#    'feelslikemax': 0.2,
#    'feelslikemin': -7.2,
#    'feelslike': -3.8,
#    'dew': -9.9,
#    'humidity': 43.9,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 60.5,
#    'windspeed': 40.3,
#    'winddir': 321.3,
#    'pressure': 1037.9,
#    'cloudcover': 47.3,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:24:39',
#    'sunriseEpoch': 1579263879,
#    'sunset': '17:11:55',
#    'sunsetEpoch': 1579299115,
#    'moonphase': 0.75,
#    'conditions': 'Partially cloudy',
#    'icon': 'wind',
#    'stations': ['KDCA',
#     '72405013743',
#     '72403793728',
#     'KADW',
#     'KDAA',
#     '74594013705'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-18',
#    'datetimeEpoch': 1579323600,
#    'tempmax': 4.3,
#    'tempmin': -2.9,
#    'temp': 0.0,
#    'feelslikemax': -0.3,
#    'feelslikemin': -8.1,
#    'feelslike': -4.2,
#    'dew': -4.9,
#    'humidity': 71.61,
#    'precip': 5.31,
#    'precipprob': None,
#    'precipcover': 25.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 49.1,
#    'windspeed': 30.6,
#    'winddir': 151.5,
#    'pressure': 1027.8,
#    'cloudcover': 84.5,
#    'visibility': 14.7,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:24:13',
#    'sunriseEpoch': 1579350253,
#    'sunset': '17:13:00',
#    'sunsetEpoch': 1579385580,
#    'moonphase': 0.81,
#    'conditions': 'Snow, Overcast',
#    'icon': 'snow',
#    'stations': ['KDCA',
#     '72405013743',
#     '72403793728',
#     'KADW',
#     'KDAA',
#     '74594013705'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-19',
#    'datetimeEpoch': 1579410000,
#    'tempmax': 7.2,
#    'tempmin': -1.7,
#    'temp': 4.2,
#    'feelslikemax': 6.6,
#    'feelslikemin': -8.3,
#    'feelslike': 0.2,
#    'dew': -2.5,
#    'humidity': 63.98,
#    'precip': 0.01,
#    'precipprob': None,
#    'precipcover': 4.17,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 58.0,
#    'windspeed': 37.8,
#    'winddir': 292.1,
#    'pressure': 1013.1,
#    'cloudcover': 68.4,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:23:45',
#    'sunriseEpoch': 1579436625,
#    'sunset': '17:14:07',
#    'sunsetEpoch': 1579472047,
#    'moonphase': 0.86,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['KDCA',
#     '72405013743',
#     '72403793728',
#     'KADW',
#     'KDAA',
#     '74594013705'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-20',
#    'datetimeEpoch': 1579496400,
#    'tempmax': 2.1,
#    'tempmin': -4.0,
#    'temp': -1.5,
#    'feelslikemax': -3.5,
#    'feelslikemin': -10.8,
#    'feelslike': -7.4,
#    'dew': -12.3,
#    'humidity': 44.5,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 51.6,
#    'windspeed': 32.1,
#    'winddir': 334.7,
#    'pressure': 1027.5,
#    'cloudcover': 11.0,
#    'visibility': 15.9,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:23:15',
#    'sunriseEpoch': 1579522995,
#    'sunset': '17:15:13',
#    'sunsetEpoch': 1579558513,
#    'moonphase': 0.91,
#    'conditions': 'Clear',
#    'icon': 'wind',
#    'stations': ['KDCA',
#     '72405013743',
#     '72403793728',
#     'KADW',
#     'KDAA',
#     '74594013705'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-21',
#    'datetimeEpoch': 1579582800,
#    'tempmax': 2.7,
#    'tempmin': -5.1,
#    'temp': -1.3,
#    'feelslikemax': -1.0,
#    'feelslikemin': -11.6,
#    'feelslike': -6.6,
#    'dew': -10.7,
#    'humidity': 49.46,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 35.3,
#    'windspeed': 27.1,
#    'winddir': 309.7,
#    'pressure': 1032.6,
#    'cloudcover': 9.1,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:22:43',
#    'sunriseEpoch': 1579609363,
#    'sunset': '17:16:21',
#    'sunsetEpoch': 1579644981,
#    'moonphase': 0.95,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['KDCA',
#     '72405013743',
#     '72403793728',
#     'KADW',
#     'KDAA',
#     '74594013705'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-22',
#    'datetimeEpoch': 1579669200,
#    'tempmax': 3.9,
#    'tempmin': -4.6,
#    'temp': -0.4,
#    'feelslikemax': 3.7,
#    'feelslikemin': -8.6,
#    'feelslike': -2.7,
#    'dew': -8.5,
#    'humidity': 55.46,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 14.4,
#    'winddir': 190.0,
#    'pressure': 1032.0,
#    'cloudcover': 30.8,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:22:09',
#    'sunriseEpoch': 1579695729,
#    'sunset': '17:17:29',
#    'sunsetEpoch': 1579731449,
#    'moonphase': 0.98,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['KDCA',
#     '72405013743',
#     '72403793728',
#     'KADW',
#     'KDAA',
#     '74594013705'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-23',
#    'datetimeEpoch': 1579755600,
#    'tempmax': 6.6,
#    'tempmin': -2.1,
#    'temp': 1.8,
#    'feelslikemax': 6.1,
#    'feelslikemin': -2.1,
#    'feelslike': 1.4,
#    'dew': -4.5,
#    'humidity': 64.85,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 9.9,
#    'winddir': 18.5,
#    'pressure': 1029.3,
#    'cloudcover': 70.3,
#    'visibility': 15.9,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:21:33',
#    'sunriseEpoch': 1579782093,
#    'sunset': '17:18:37',
#    'sunsetEpoch': 1579817917,
#    'moonphase': 0.99,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['KDCA',
#     '72405013743',
#     '72403793728',
#     'KADW',
#     'KDAA',
#     '74594013705'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-24',
#    'datetimeEpoch': 1579842000,
#    'tempmax': 10.7,
#    'tempmin': 1.0,
#    'temp': 6.1,
#    'feelslikemax': 10.7,
#    'feelslikemin': -2.1,
#    'feelslike': 4.4,
#    'dew': 1.6,
#    'humidity': 72.89,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 31.7,
#    'windspeed': 18.6,
#    'winddir': 56.4,
#    'pressure': 1024.1,
#    'cloudcover': 74.9,
#    'visibility': 15.8,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:20:55',
#    'sunriseEpoch': 1579868455,
#    'sunset': '17:19:45',
#    'sunsetEpoch': 1579904385,
#    'moonphase': 1.0,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['KDCA',
#     '72405013743',
#     '72403793728',
#     'KADW',
#     'KDAA',
#     '74594013705'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-25',
#    'datetimeEpoch': 1579928400,
#    'tempmax': 10.5,
#    'tempmin': 6.5,
#    'temp': 8.9,
#    'feelslikemax': 10.5,
#    'feelslikemin': 3.4,
#    'feelslike': 7.1,
#    'dew': 6.1,
#    'humidity': 83.59,
#    'precip': 31.2,
#    'precipprob': None,
#    'precipcover': 45.83,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 40.7,
#    'windspeed': 22.8,
#    'winddir': 234.9,
#    'pressure': 1012.2,
#    'cloudcover': 73.6,
#    'visibility': 14.2,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:20:16',
#    'sunriseEpoch': 1579954816,
#    'sunset': '17:20:54',
#    'sunsetEpoch': 1579990854,
#    'moonphase': 0.0,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['KDCA',
#     '72405013743',
#     '72403793728',
#     'KADW',
#     'KDAA',
#     '74594013705'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-26',
#    'datetimeEpoch': 1580014800,
#    'tempmax': 9.3,
#    'tempmin': 1.9,
#    'temp': 6.3,
#    'feelslikemax': 6.7,
#    'feelslikemin': -0.3,
#    'feelslike': 4.5,
#    'dew': -1.2,
#    'humidity': 59.98,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 38.1,
#    'windspeed': 24.0,
#    'winddir': 248.8,
#    'pressure': 1012.5,
#    'cloudcover': 66.3,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:19:34',
#    'sunriseEpoch': 1580041174,
#    'sunset': '17:22:03',
#    'sunsetEpoch': 1580077323,
#    'moonphase': 0.01,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['KDCA',
#     '72405013743',
#     '72403793728',
#     'KADW',
#     'KDAA',
#     '74594013705'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-27',
#    'datetimeEpoch': 1580101200,
#    'tempmax': 9.3,
#    'tempmin': 1.9,
#    'temp': 5.7,
#    'feelslikemax': 7.5,
#    'feelslikemin': -1.4,
#    'feelslike': 3.1,
#    'dew': -1.6,
#    'humidity': 60.54,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 36.8,
#    'windspeed': 25.2,
#    'winddir': 249.7,
#    'pressure': 1009.8,
#    'cloudcover': 79.1,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:18:51',
#    'sunriseEpoch': 1580127531,
#    'sunset': '17:23:12',
#    'sunsetEpoch': 1580163792,
#    'moonphase': 0.03,
#    'conditions': 'Overcast',
#    'icon': 'cloudy',
#    'stations': ['KDCA',
#     '72405013743',
#     '72403793728',
#     'KADW',
#     'KDAA',
#     '74594013705'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-28',
#    'datetimeEpoch': 1580187600,
#    'tempmax': 8.2,
#    'tempmin': 4.3,
#    'temp': 6.3,
#    'feelslikemax': 4.9,
#    'feelslikemin': 0.9,
#    'feelslike': 2.8,
#    'dew': -2.1,
#    'humidity': 55.35,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 43.6,
#    'windspeed': 33.8,
#    'winddir': 318.0,
#    'pressure': 1013.8,
#    'cloudcover': 88.8,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:18:06',
#    'sunriseEpoch': 1580213886,
#    'sunset': '17:24:22',
#    'sunsetEpoch': 1580250262,
#    'moonphase': 0.06,
#    'conditions': 'Overcast',
#    'icon': 'wind',
#    'stations': ['KDCA',
#     '72405013743',
#     '72403793728',
#     'KADW',
#     'KDAA',
#     '74594013705'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-29',
#    'datetimeEpoch': 1580274000,
#    'tempmax': 8.2,
#    'tempmin': 1.9,
#    'temp': 5.0,
#    'feelslikemax': 5.2,
#    'feelslikemin': -1.0,
#    'feelslike': 1.9,
#    'dew': -3.9,
#    'humidity': 52.94,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 33.5,
#    'windspeed': 26.2,
#    'winddir': 297.8,
#    'pressure': 1019.7,
#    'cloudcover': 69.5,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:17:19',
#    'sunriseEpoch': 1580300239,
#    'sunset': '17:25:32',
#    'sunsetEpoch': 1580336732,
#    'moonphase': 0.09,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['KDCA',
#     '72405013743',
#     '72403793728',
#     'KADW',
#     'KDAA',
#     '74594013705'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-30',
#    'datetimeEpoch': 1580360400,
#    'tempmax': 6.0,
#    'tempmin': -0.9,
#    'temp': 2.2,
#    'feelslikemax': 4.7,
#    'feelslikemin': -4.8,
#    'feelslike': -0.3,
#    'dew': -5.7,
#    'humidity': 56.89,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 14.8,
#    'winddir': 56.5,
#    'pressure': 1025.1,
#    'cloudcover': 66.8,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:16:30',
#    'sunriseEpoch': 1580386590,
#    'sunset': '17:26:41',
#    'sunsetEpoch': 1580423201,
#    'moonphase': 0.13,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['KDCA',
#     '72405013743',
#     '72403793728',
#     'KADW',
#     'KDAA',
#     '74594013705'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-31',
#    'datetimeEpoch': 1580446800,
#    'tempmax': 8.2,
#    'tempmin': 0.5,
#    'temp': 4.1,
#    'feelslikemax': 8.2,
#    'feelslikemin': -2.2,
#    'feelslike': 3.1,
#    'dew': -1.5,
#    'humidity': 67.72,
#    'precip': 0.27,
#    'precipprob': None,
#    'precipcover': 4.17,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 10.7,
#    'winddir': 91.6,
#    'pressure': 1025.2,
#    'cloudcover': 76.8,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:15:39',
#    'sunriseEpoch': 1580472939,
#    'sunset': '17:27:51',
#    'sunsetEpoch': 1580509671,
#    'moonphase': 0.18,
#    'conditions': 'Rain, Overcast',
#    'icon': 'rain',
#    'stations': ['KDCA',
#     '72405013743',
#     '72403793728',
#     'KADW',
#     'KDAA',
#     '74594013705'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-01',
#    'datetimeEpoch': 1580533200,
#    'tempmax': 10.0,
#    'tempmin': 0.9,
#    'temp': 5.3,
#    'feelslikemax': 10.0,
#    'feelslikemin': -1.5,
#    'feelslike': 4.3,
#    'dew': 1.7,
#    'humidity': 78.67,
#    'precip': 1.39,
#    'precipprob': None,
#    'precipcover': 12.5,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 20.5,
#    'winddir': 127.4,
#    'pressure': 1013.4,
#    'cloudcover': 60.0,
#    'visibility': 14.3,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:14:47',
#    'sunriseEpoch': 1580559287,
#    'sunset': '17:29:01',
#    'sunsetEpoch': 1580596141,
#    'moonphase': 0.22,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['KDCA',
#     '72405013743',
#     '72403793728',
#     'KADW',
#     'KDAA',
#     '74594013705'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-02',
#    'datetimeEpoch': 1580619600,
#    'tempmax': 12.2,
#    'tempmin': 1.7,
#    'temp': 6.9,
#    'feelslikemax': 12.2,
#    'feelslikemin': -1.2,
#    'feelslike': 5.4,
#    'dew': 0.9,
#    'humidity': 68.67,
#    'precip': 0.28,
#    'precipprob': None,
#    'precipcover': 8.33,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 40.7,
#    'windspeed': 25.2,
#    'winddir': 225.6,
#    'pressure': 1003.7,
#    'cloudcover': 47.9,
#    'visibility': 14.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:13:53',
#    'sunriseEpoch': 1580645633,
#    'sunset': '17:30:11',
#    'sunsetEpoch': 1580682611,
#    'moonphase': 0.27,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['KDCA',
#     '72405013743',
#     '72403793728',
#     'KADW',
#     'KDAA',
#     '74594013705'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-03',
#    'datetimeEpoch': 1580706000,
#    'tempmax': 16.4,
#    'tempmin': 6.5,
#    'temp': 12.2,
#    'feelslikemax': 16.4,
#    'feelslikemin': 4.7,
#    'feelslike': 11.9,
#    'dew': 2.5,
#    'humidity': 52.6,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 42.5,
#    'windspeed': 14.7,
#    'winddir': 198.8,
#    'pressure': 1010.1,
#    'cloudcover': 48.9,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:12:58',
#    'sunriseEpoch': 1580731978,
#    'sunset': '17:31:21',
#    'sunsetEpoch': 1580769081,
#    'moonphase': 0.32,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['KDCA',
#     '72405013743',
#     '72403793728',
#     'KADW',
#     'KDAA',
#     '74594013705'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-04',
#    'datetimeEpoch': 1580792400,
#    'tempmax': 18.1,
#    'tempmin': 10.1,
#    'temp': 14.0,
#    'feelslikemax': 18.1,
#    'feelslikemin': 10.1,
#    'feelslike': 14.0,
#    'dew': 7.4,
#    'humidity': 64.98,
#    'precip': 0.6,
#    'precipprob': None,
#    'precipcover': 8.33,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 16.0,
#    'winddir': 184.8,
#    'pressure': 1009.9,
#    'cloudcover': 85.1,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:12:01',
#    'sunriseEpoch': 1580818321,
#    'sunset': '17:32:31',
#    'sunsetEpoch': 1580855551,
#    'moonphase': 0.37,
#    'conditions': 'Rain, Overcast',
#    'icon': 'rain',
#    'stations': ['KDCA',
#     '72405013743',
#     '72403793728',
#     'KADW',
#     'KDAA',
#     '74594013705'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-05',
#    'datetimeEpoch': 1580878800,
#    'tempmax': 13.4,
#    'tempmin': 3.8,
#    'temp': 7.5,
#    'feelslikemax': 13.4,
#    'feelslikemin': 0.2,
#    'feelslike': 5.1,
#    'dew': 4.8,
#    'humidity': 83.24,
#    'precip': 1.76,
#    'precipprob': None,
#    'precipcover': 25.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 30.7,
#    'winddir': 80.6,
#    'pressure': 1014.4,
#    'cloudcover': 86.4,
#    'visibility': 14.6,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:11:02',
#    'sunriseEpoch': 1580904662,
#    'sunset': '17:33:41',
#    'sunsetEpoch': 1580942021,
#    'moonphase': 0.41,
#    'conditions': 'Rain, Overcast',
#    'icon': 'rain',
#    'stations': ['KDCA',
#     '72405013743',
#     '72403793728',
#     'KADW',
#     'KDAA',
#     '74594013705'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-06',
#    'datetimeEpoch': 1580965200,
#    'tempmax': 8.3,
#    'tempmin': 3.8,
#    'temp': 5.7,
#    'feelslikemax': 7.8,
#    'feelslikemin': 1.1,
#    'feelslike': 4.0,
#    'dew': 4.9,
#    'humidity': 94.97,
#    'precip': 15.88,
#    'precipprob': None,
#    'precipcover': 75.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 18.4,
#    'winddir': 162.4,
#    'pressure': 1002.5,
#    'cloudcover': 93.9,
#    'visibility': 11.1,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:10:02',
#    'sunriseEpoch': 1580991002,
#    'sunset': '17:34:50',
#    'sunsetEpoch': 1581028490,
#    'moonphase': 0.45,
#    'conditions': 'Rain, Overcast',
#    'icon': 'rain',
#    'stations': ['KDCA',
#     '72405013743',
#     '72403793728',
#     'KADW',
#     'KDAA',
#     '74594013705'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-07',
#    'datetimeEpoch': 1581051600,
#    'tempmax': 13.8,
#    'tempmin': 2.8,
#    'temp': 8.9,
#    'feelslikemax': 13.8,
#    'feelslikemin': -2.6,
#    'feelslike': 6.3,
#    'dew': 2.9,
#    'humidity': 69.48,
#    'precip': 12.47,
#    'precipprob': None,
#    'precipcover': 41.67,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 64.3,
#    'windspeed': 40.1,
#    'winddir': 250.6,
#    'pressure': 994.6,
#    'cloudcover': 80.6,
#    'visibility': 14.6,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:09:00',
#    'sunriseEpoch': 1581077340,
#    'sunset': '17:36:00',
#    'sunsetEpoch': 1581114960,
#    'moonphase': 0.48,
#    'conditions': 'Rain, Overcast',
#    'icon': 'rain',
#    'stations': ['KDCA',
#     '72405013743',
#     '72403793728',
#     'KADW',
#     'KDAA',
#     '74594013705'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-08',
#    'datetimeEpoch': 1581138000,
#    'tempmax': 7.1,
#    'tempmin': -0.2,
#    'temp': 3.5,
#    'feelslikemax': 5.7,
#    'feelslikemin': -3.6,
#    'feelslike': 0.4,
#    'dew': -6.1,
#    'humidity': 50.47,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 33.5,
#    'windspeed': 20.2,
#    'winddir': 219.6,
#    'pressure': 1022.9,
#    'cloudcover': 42.4,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:07:57',
#    'sunriseEpoch': 1581163677,
#    'sunset': '17:37:09',
#    'sunsetEpoch': 1581201429,
#    'moonphase': 0.5,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['KDCA',
#     '72405013743',
#     '72403793728',
#     'KADW',
#     'KDAA',
#     '74594013705'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-09',
#    'datetimeEpoch': 1581224400,
#    'tempmax': 9.9,
#    'tempmin': -0.3,
#    'temp': 5.1,
#    'feelslikemax': 8.9,
#    'feelslikemin': -2.0,
#    'feelslike': 3.4,
#    'dew': -2.9,
#    'humidity': 59.1,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 23.6,
#    'winddir': 193.4,
#    'pressure': 1030.9,
#    'cloudcover': 43.0,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:06:52',
#    'sunriseEpoch': 1581250012,
#    'sunset': '17:38:18',
#    'sunsetEpoch': 1581287898,
#    'moonphase': 0.5,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['KDCA',
#     '72405013743',
#     '72403793728',
#     'KADW',
#     'KDAA',
#     '74594013705'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-10',
#    'datetimeEpoch': 1581310800,
#    'tempmax': 9.3,
#    'tempmin': 5.5,
#    'temp': 7.8,
#    'feelslikemax': 8.3,
#    'feelslikemin': 1.7,
#    'feelslike': 4.9,
#    'dew': 4.1,
#    'humidity': 78.67,
#    'precip': 11.02,
#    'precipprob': None,
#    'precipcover': 54.17,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 50.1,
#    'windspeed': 33.3,
#    'winddir': 194.0,
#    'pressure': 1022.5,
#    'cloudcover': 86.5,
#    'visibility': 14.7,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:05:46',
#    'sunriseEpoch': 1581336346,
#    'sunset': '17:39:27',
#    'sunsetEpoch': 1581374367,
#    'moonphase': 0.52,
#    'conditions': 'Rain, Overcast',
#    'icon': 'rain',
#    'stations': ['KDCA',
#     '72405013743',
#     '72403793728',
#     'KADW',
#     'KDAA',
#     '74594013705'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-11',
#    'datetimeEpoch': 1581397200,
#    'tempmax': 13.8,
#    'tempmin': 8.9,
#    'temp': 11.4,
#    'feelslikemax': 13.8,
#    'feelslikemin': 6.5,
#    'feelslike': 10.9,
#    'dew': 9.5,
#    'humidity': 88.79,
#    'precip': 9.7,
#    'precipprob': None,
#    'precipcover': 58.33,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 35.3,
#    'windspeed': 24.9,
#    'winddir': 261.3,
#    'pressure': 1014.2,
#    'cloudcover': 86.0,
#    'visibility': 10.1,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:04:39',
#    'sunriseEpoch': 1581422679,
#    'sunset': '17:40:36',
#    'sunsetEpoch': 1581460836,
#    'moonphase': 0.53,
#    'conditions': 'Rain, Overcast',
#    'icon': 'rain',
#    'stations': ['KDCA',
#     '72405013743',
#     '72403793728',
#     'KADW',
#     'KDAA',
#     '74594013705'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-12',
#    'datetimeEpoch': 1581483600,
#    'tempmax': 9.3,
#    'tempmin': 5.5,
#    'temp': 7.4,
#    'feelslikemax': 9.3,
#    'feelslikemin': 1.6,
#    'feelslike': 5.0,
#    'dew': -0.3,
#    'humidity': 59.45,
#    'precip': 2.27,
#    'precipprob': None,
#    'precipcover': 16.67,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 40.7,
#    'windspeed': 22.4,
#    'winddir': 196.0,
#    'pressure': 1021.1,
#    'cloudcover': 78.8,
#    'visibility': 15.2,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:03:30',
#    'sunriseEpoch': 1581509010,
#    'sunset': '17:41:45',
#    'sunsetEpoch': 1581547305,
#    'moonphase': 0.57,
#    'conditions': 'Rain, Overcast',
#    'icon': 'rain',
#    'stations': ['KDCA',
#     '72405013743',
#     '72403793728',
#     'KADW',
#     'KDAA',
#     '74594013705'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-13',
#    'datetimeEpoch': 1581570000,
#    'tempmax': 13.3,
#    'tempmin': 4.9,
#    'temp': 9.0,
#    'feelslikemax': 13.3,
#    'feelslikemin': 1.3,
#    'feelslike': 7.1,
#    'dew': 6.0,
#    'humidity': 83.11,
#    'precip': 8.27,
#    'precipprob': None,
#    'precipcover': 45.83,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 53.7,
#    'windspeed': 37.1,
#    'winddir': 241.0,
#    'pressure': 1008.7,
#    'cloudcover': 72.2,
#    'visibility': 13.5,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:02:20',
#    'sunriseEpoch': 1581595340,
#    'sunset': '17:42:53',
#    'sunsetEpoch': 1581633773,
#    'moonphase': 0.62,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['KDCA',
#     '72405013743',
#     '72403793728',
#     'KADW',
#     'KDAA',
#     '74594013705'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-14',
#    'datetimeEpoch': 1581656400,
#    'tempmax': 6.6,
#    'tempmin': -2.9,
#    'temp': 2.6,
#    'feelslikemax': 3.7,
#    'feelslikemin': -9.7,
#    'feelslike': -2.2,
#    'dew': -7.7,
#    'humidity': 47.22,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 51.2,
#    'windspeed': 32.7,
#    'winddir': 323.8,
#    'pressure': 1026.8,
#    'cloudcover': 39.3,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:01:09',
#    'sunriseEpoch': 1581681669,
#    'sunset': '17:44:01',
#    'sunsetEpoch': 1581720241,
#    'moonphase': 0.67,
#    'conditions': 'Partially cloudy',
#    'icon': 'wind',
#    'stations': ['KDCA',
#     '72405013743',
#     '72403793728',
#     'KADW',
#     'KDAA',
#     '74594013705'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-15',
#    'datetimeEpoch': 1581742800,
#    'tempmax': 2.2,
#    'tempmin': -6.0,
#    'temp': -1.5,
#    'feelslikemax': -1.6,
#    'feelslikemin': -11.0,
#    'feelslike': -6.0,
#    'dew': -10.9,
#    'humidity': 49.18,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 21.2,
#    'winddir': 155.1,
#    'pressure': 1034.7,
#    'cloudcover': 45.6,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:59:56',
#    'sunriseEpoch': 1581767996,
#    'sunset': '17:45:09',
#    'sunsetEpoch': 1581806709,
#    'moonphase': 0.73,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['KDCA',
#     '72405013743',
#     '72403793728',
#     'KADW',
#     'KDAA',
#     '74594013705'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-16',
#    'datetimeEpoch': 1581829200,
#    'tempmax': 11.2,
#    'tempmin': 0.5,
#    'temp': 4.5,
#    'feelslikemax': 11.2,
#    'feelslikemin': -3.9,
#    'feelslike': 2.4,
#    'dew': -2.9,
#    'humidity': 59.3,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 17.6,
#    'winddir': 172.5,
#    'pressure': 1022.3,
#    'cloudcover': 69.2,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:58:42',
#    'sunriseEpoch': 1581854322,
#    'sunset': '17:46:17',
#    'sunsetEpoch': 1581893177,
#    'moonphase': 0.78,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['KDCA',
#     '72405013743',
#     '72403793728',
#     'KADW',
#     'KDAA',
#     '74594013705'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-17',
#    'datetimeEpoch': 1581915600,
#    'tempmax': 12.7,
#    'tempmin': 3.1,
#    'temp': 7.5,
#    'feelslikemax': 12.7,
#    'feelslikemin': 0.3,
#    'feelslike': 6.3,
#    'dew': -1.7,
#    'humidity': 55.03,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 20.0,
#    'winddir': 104.1,
#    'pressure': 1023.9,
#    'cloudcover': 56.2,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:57:27',
#    'sunriseEpoch': 1581940647,
#    'sunset': '17:47:24',
#    'sunsetEpoch': 1581979644,
#    'moonphase': 0.84,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['KDCA',
#     '72405013743',
#     '72403793728',
#     'KADW',
#     'KDAA',
#     '74594013705'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-18',
#    'datetimeEpoch': 1582002000,
#    'tempmax': 14.9,
#    'tempmin': 4.8,
#    'temp': 9.6,
#    'feelslikemax': 14.9,
#    'feelslikemin': 2.9,
#    'feelslike': 9.3,
#    'dew': 4.3,
#    'humidity': 69.87,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 37.3,
#    'windspeed': 24.5,
#    'winddir': 130.2,
#    'pressure': 1021.2,
#    'cloudcover': 75.7,
#    'visibility': 15.6,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:56:11',
#    'sunriseEpoch': 1582026971,
#    'sunset': '17:48:31',
#    'sunsetEpoch': 1582066111,
#    'moonphase': 0.88,
#    'conditions': 'Overcast',
#    'icon': 'cloudy',
#    'stations': ['KDCA',
#     '72405013743',
#     '72403793728',
#     'KADW',
#     'KDAA',
#     '74594013705'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-19',
#    'datetimeEpoch': 1582088400,
#    'tempmax': 13.1,
#    'tempmin': 4.8,
#    'temp': 8.8,
#    'feelslikemax': 13.1,
#    'feelslikemin': 1.9,
#    'feelslike': 6.5,
#    'dew': -4.2,
#    'humidity': 42.01,
#    'precip': 0.28,
#    'precipprob': None,
#    'precipcover': 4.17,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 44.1,
#    'windspeed': 32.5,
#    'winddir': 325.7,
#    'pressure': 1025.9,
#    'cloudcover': 75.6,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:54:54',
#    'sunriseEpoch': 1582113294,
#    'sunset': '17:49:38',
#    'sunsetEpoch': 1582152578,
#    'moonphase': 0.93,
#    'conditions': 'Rain, Overcast',
#    'icon': 'rain',
#    'stations': ['KDCA',
#     '72405013743',
#     '72403793728',
#     'KADW',
#     'KDAA',
#     '74594013705'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-20',
#    'datetimeEpoch': 1582174800,
#    'tempmax': 4.9,
#    'tempmin': 0.4,
#    'temp': 3.2,
#    'feelslikemax': 3.3,
#    'feelslikemin': -4.4,
#    'feelslike': 0.3,
#    'dew': -8.5,
#    'humidity': 42.96,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 30.5,
#    'winddir': 173.1,
#    'pressure': 1030.8,
#    'cloudcover': 73.2,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:53:36',
#    'sunriseEpoch': 1582199616,
#    'sunset': '17:50:44',
#    'sunsetEpoch': 1582239044,
#    'moonphase': 0.96,
#    'conditions': 'Partially cloudy',
#    'icon': 'wind',
#    'stations': ['KDCA',
#     '72405013743',
#     '72403793728',
#     'KADW',
#     'KDAA',
#     '74594013705'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-21',
#    'datetimeEpoch': 1582261200,
#    'tempmax': 3.7,
#    'tempmin': -4.4,
#    'temp': -0.1,
#    'feelslikemax': 2.7,
#    'feelslikemin': -11.8,
#    'feelslike': -4.8,
#    'dew': -12.4,
#    'humidity': 39.96,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 35.0,
#    'windspeed': 32.9,
#    'winddir': 242.3,
#    'pressure': 1033.0,
#    'cloudcover': 16.0,
#    'visibility': 15.9,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:52:17',
#    'sunriseEpoch': 1582285937,
#    'sunset': '17:51:50',
#    'sunsetEpoch': 1582325510,
#    'moonphase': 0.98,
#    'conditions': 'Clear',
#    'icon': 'wind',
#    'stations': ['KDCA',
#     '72405013743',
#     '72403793728',
#     'KADW',
#     'KDAA',
#     '74594013705'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-22',
#    'datetimeEpoch': 1582347600,
#    'tempmax': 11.7,
#    'tempmin': -3.1,
#    'temp': 4.0,
#    'feelslikemax': 11.7,
#    'feelslikemin': -7.2,
#    'feelslike': 1.6,
#    'dew': -9.9,
#    'humidity': 37.3,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 25.9,
#    'windspeed': 19.8,
#    'winddir': 198.8,
#    'pressure': 1027.7,
#    'cloudcover': 11.2,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:50:57',
#    'sunriseEpoch': 1582372257,
#    'sunset': '17:52:56',
#    'sunsetEpoch': 1582411976,
#    'moonphase': 1.0,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['KDCA',
#     '72405013743',
#     '72403793728',
#     'KADW',
#     'KDAA',
#     '74594013705'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-23',
#    'datetimeEpoch': 1582434000,
#    'tempmax': 14.9,
#    'tempmin': -1.6,
#    'temp': 6.5,
#    'feelslikemax': 14.9,
#    'feelslikemin': -1.6,
#    'feelslike': 6.0,
#    'dew': -5.9,
#    'humidity': 46.16,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 16.5,
#    'winddir': 153.4,
#    'pressure': 1022.9,
#    'cloudcover': 17.8,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:49:36',
#    'sunriseEpoch': 1582458576,
#    'sunset': '17:54:01',
#    'sunsetEpoch': 1582498441,
#    'moonphase': 1.0,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['KDCA',
#     '72405013743',
#     '72403793728',
#     'KADW',
#     'KDAA',
#     '74594013705'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-24',
#    'datetimeEpoch': 1582520400,
#    'tempmax': 14.9,
#    'tempmin': 1.9,
#    'temp': 8.0,
#    'feelslikemax': 14.9,
#    'feelslikemin': -0.2,
#    'feelslike': 7.5,
#    'dew': -0.1,
#    'humidity': 58.22,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 22.0,
#    'winddir': 148.9,
#    'pressure': 1016.6,
#    'cloudcover': 67.3,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:48:14',
#    'sunriseEpoch': 1582544894,
#    'sunset': '17:55:06',
#    'sunsetEpoch': 1582584906,
#    'moonphase': 0.0,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['KDCA',
# ...
#    'datetimeEpoch': 1608008400,
#    'tempmax': 5.6,
#    'tempmin': 0.4,
#    'temp': 2.6,
#    'feelslikemax': 3.5,
#    'feelslikemin': -3.9,
#    'feelslike': -0.7,
#    'dew': -6.1,
#    'humidity': 53.48,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 29.5,
#    'windspeed': 23.4,
#    'winddir': 270.0,
#    'pressure': 1026.7,
#    'cloudcover': 61.3,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:19:59',
#    'sunriseEpoch': 1608034799,
#    'sunset': '16:47:11',
#    'sunsetEpoch': 1608068831,
#    'moonphase': 0.0,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['KDCA',
#     '72405013743',
#     '72403793728',
#     'KADW',
#     'KDAA',
#     '74594013705'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-16',
#    'datetimeEpoch': 1608094800,
#    'tempmax': 2.8,
#    'tempmin': -0.2,
#    'temp': 0.8,
#    'feelslikemax': -1.4,
#    'feelslikemin': -5.9,
#    'feelslike': -4.1,
#    'dew': -2.5,
#    'humidity': 79.18,
#    'precip': 26.8,
#    'precipprob': None,
#    'precipcover': 54.17,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 52.9,
#    'windspeed': 33.8,
#    'winddir': 75.9,
#    'pressure': 1019.7,
#    'cloudcover': 96.4,
#    'visibility': 11.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:20:38',
#    'sunriseEpoch': 1608121238,
#    'sunset': '16:47:31',
#    'sunsetEpoch': 1608155251,
#    'moonphase': 0.02,
#    'conditions': 'Rain, Overcast',
#    'icon': 'rain',
#    'stations': ['KDCA',
#     '72405013743',
#     '72403793728',
#     'KADW',
#     'KDAA',
#     '74594013705'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-17',
#    'datetimeEpoch': 1608181200,
#    'tempmax': 4.9,
#    'tempmin': -2.2,
#    'temp': 0.9,
#    'feelslikemax': 1.7,
#    'feelslikemin': -7.7,
#    'feelslike': -3.5,
#    'dew': -3.2,
#    'humidity': 74.68,
#    'precip': 0.45,
#    'precipprob': None,
#    'precipcover': 8.33,
#    'preciptype': None,
#    'snow': 2.88,
#    'snowdepth': 2.88,
#    'windgust': 53.2,
#    'windspeed': 27.0,
#    'winddir': 290.8,
#    'pressure': 1016.0,
#    'cloudcover': 46.0,
#    'visibility': 15.8,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:21:15',
#    'sunriseEpoch': 1608207675,
#    'sunset': '16:47:53',
#    'sunsetEpoch': 1608241673,
#    'moonphase': 0.05,
#    'conditions': 'Snow, Partially cloudy',
#    'icon': 'snow',
#    'stations': ['KDCA',
#     '72405013743',
#     '72403793728',
#     'KADW',
#     'KDAA',
#     '74594013705'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-18',
#    'datetimeEpoch': 1608267600,
#    'tempmax': 3.8,
#    'tempmin': -0.7,
#    'temp': 1.7,
#    'feelslikemax': 1.8,
#    'feelslikemin': -5.0,
#    'feelslike': -1.4,
#    'dew': -3.0,
#    'humidity': 71.51,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 1.0,
#    'windgust': None,
#    'windspeed': 15.4,
#    'winddir': 259.7,
#    'pressure': 1026.9,
#    'cloudcover': 92.9,
#    'visibility': 15.6,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:21:51',
#    'sunriseEpoch': 1608294111,
#    'sunset': '16:48:16',
#    'sunsetEpoch': 1608328096,
#    'moonphase': 0.09,
#    'conditions': 'Overcast',
#    'icon': 'cloudy',
#    'stations': ['KDCA',
#     '72405013743',
#     '72403793728',
#     'KADW',
#     'KDAA',
#     '74594013705'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-19',
#    'datetimeEpoch': 1608354000,
#    'tempmax': 2.8,
#    'tempmin': -2.4,
#    'temp': 0.3,
#    'feelslikemax': 0.5,
#    'feelslikemin': -5.5,
#    'feelslike': -2.1,
#    'dew': -4.1,
#    'humidity': 72.24,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 14.8,
#    'winddir': 132.4,
#    'pressure': 1029.3,
#    'cloudcover': 79.7,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:22:26',
#    'sunriseEpoch': 1608380546,
#    'sunset': '16:48:42',
#    'sunsetEpoch': 1608414522,
#    'moonphase': 0.13,
#    'conditions': 'Overcast',
#    'icon': 'cloudy',
#    'stations': ['KDCA',
#     '72405013743',
#     '72403793728',
#     'KADW',
#     'KDAA',
#     '74594013705'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-20',
#    'datetimeEpoch': 1608440400,
#    'tempmax': 6.6,
#    'tempmin': 0.9,
#    'temp': 4.3,
#    'feelslikemax': 5.5,
#    'feelslikemin': -1.7,
#    'feelslike': 2.0,
#    'dew': 1.1,
#    'humidity': 79.73,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 33.5,
#    'windspeed': 22.0,
#    'winddir': 173.0,
#    'pressure': 1019.8,
#    'cloudcover': 92.2,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:22:58',
#    'sunriseEpoch': 1608466978,
#    'sunset': '16:49:10',
#    'sunsetEpoch': 1608500950,
#    'moonphase': 0.18,
#    'conditions': 'Overcast',
#    'icon': 'cloudy',
#    'stations': ['KDCA',
#     '72405013743',
#     '72403793728',
#     'KADW',
#     'KDAA',
#     '74594013705'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-21',
#    'datetimeEpoch': 1608526800,
#    'tempmax': 8.0,
#    'tempmin': 4.3,
#    'temp': 5.6,
#    'feelslikemax': 5.7,
#    'feelslikemin': 2.3,
#    'feelslike': 3.7,
#    'dew': 3.2,
#    'humidity': 85.0,
#    'precip': 0.75,
#    'precipprob': None,
#    'precipcover': 4.17,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 16.3,
#    'winddir': 191.7,
#    'pressure': 1011.3,
#    'cloudcover': 92.0,
#    'visibility': 13.1,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:23:28',
#    'sunriseEpoch': 1608553408,
#    'sunset': '16:49:40',
#    'sunsetEpoch': 1608587380,
#    'moonphase': 0.23,
#    'conditions': 'Rain, Overcast',
#    'icon': 'rain',
#    'stations': ['KDCA',
#     '72405013743',
#     '72403793728',
#     'KADW',
#     'KDAA',
#     '74594013705'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-22',
#    'datetimeEpoch': 1608613200,
#    'tempmax': 10.5,
#    'tempmin': 4.3,
#    'temp': 7.1,
#    'feelslikemax': 10.5,
#    'feelslikemin': 1.6,
#    'feelslike': 4.4,
#    'dew': 0.4,
#    'humidity': 63.91,
#    'precip': 0.28,
#    'precipprob': None,
#    'precipcover': 4.17,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 64.1,
#    'windspeed': 39.6,
#    'winddir': 271.5,
#    'pressure': 1015.7,
#    'cloudcover': 64.0,
#    'visibility': 15.8,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:23:57',
#    'sunriseEpoch': 1608639837,
#    'sunset': '16:50:11',
#    'sunsetEpoch': 1608673811,
#    'moonphase': 0.28,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['KDCA',
#     '72405013743',
#     '72403793728',
#     'KADW',
#     'KDAA',
#     '74594013705'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-23',
#    'datetimeEpoch': 1608699600,
#    'tempmax': 8.4,
#    'tempmin': -0.3,
#    'temp': 4.6,
#    'feelslikemax': 5.8,
#    'feelslikemin': -2.9,
#    'feelslike': 2.7,
#    'dew': -0.7,
#    'humidity': 69.32,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 23.8,
#    'winddir': 150.8,
#    'pressure': 1027.6,
#    'cloudcover': 61.1,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:24:24',
#    'sunriseEpoch': 1608726264,
#    'sunset': '16:50:45',
#    'sunsetEpoch': 1608760245,
#    'moonphase': 0.32,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['KDCA',
#     '72405013743',
#     '72403793728',
#     'KADW',
#     'KDAA',
#     '74594013705'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-24',
#    'datetimeEpoch': 1608786000,
#    'tempmax': 16.1,
#    'tempmin': 6.0,
#    'temp': 11.8,
#    'feelslikemax': 16.1,
#    'feelslikemin': 3.5,
#    'feelslike': 11.3,
#    'dew': 9.1,
#    'humidity': 83.59,
#    'precip': 23.85,
#    'precipprob': None,
#    'precipcover': 54.17,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 48.1,
#    'windspeed': 30.7,
#    'winddir': 125.3,
#    'pressure': 1012.0,
#    'cloudcover': 98.4,
#    'visibility': 13.7,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:24:49',
#    'sunriseEpoch': 1608812689,
#    'sunset': '16:51:20',
#    'sunsetEpoch': 1608846680,
#    'moonphase': 0.37,
#    'conditions': 'Rain, Overcast',
#    'icon': 'rain',
#    'stations': ['KDCA',
#     '72405013743',
#     '72403793728',
#     'KADW',
#     'KDAA',
#     '74594013705'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-25',
#    'datetimeEpoch': 1608872400,
#    'tempmax': 13.8,
#    'tempmin': -3.9,
#    'temp': 2.1,
#    'feelslikemax': 13.8,
#    'feelslikemin': -10.0,
#    'feelslike': -2.5,
#    'dew': -4.2,
#    'humidity': 64.56,
#    'precip': 12.65,
#    'precipprob': None,
#    'precipcover': 29.17,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 57.2,
#    'windspeed': 29.2,
#    'winddir': 283.9,
#    'pressure': 1004.6,
#    'cloudcover': 91.1,
#    'visibility': 15.5,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:25:11',
#    'sunriseEpoch': 1608899111,
#    'sunset': '16:51:57',
#    'sunsetEpoch': 1608933117,
#    'moonphase': 0.4,
#    'conditions': 'Rain, Overcast',
#    'icon': 'rain',
#    'stations': ['KDCA',
#     '72405013743',
#     '72403793728',
#     'KDAA',
#     'KADW',
#     '74594013705'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-26',
#    'datetimeEpoch': 1608958800,
#    'tempmax': 2.1,
#    'tempmin': -5.0,
#    'temp': -1.5,
#    'feelslikemax': 0.8,
#    'feelslikemin': -10.1,
#    'feelslike': -5.9,
#    'dew': -11.9,
#    'humidity': 45.68,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 35.3,
#    'windspeed': 20.4,
#    'winddir': 261.4,
#    'pressure': 1017.3,
#    'cloudcover': 58.2,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:25:32',
#    'sunriseEpoch': 1608985532,
#    'sunset': '16:52:36',
#    'sunsetEpoch': 1609019556,
#    'moonphase': 0.44,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['KDCA',
#     '72405013743',
#     '72403793728',
#     'KADW',
#     'KDAA',
#     '74594013705'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-27',
#    'datetimeEpoch': 1609045200,
#    'tempmax': 5.6,
#    'tempmin': -3.6,
#    'temp': 1.0,
#    'feelslikemax': 3.5,
#    'feelslikemin': -7.1,
#    'feelslike': -1.4,
#    'dew': -5.9,
#    'humidity': 60.64,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 17.2,
#    'winddir': 141.5,
#    'pressure': 1025.4,
#    'cloudcover': 68.3,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:25:51',
#    'sunriseEpoch': 1609071951,
#    'sunset': '16:53:17',
#    'sunsetEpoch': 1609105997,
#    'moonphase': 0.47,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['KDCA',
#     '72405013743',
#     '72403793728',
#     'KADW',
#     'KDAA',
#     '74594013705'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-28',
#    'datetimeEpoch': 1609131600,
#    'tempmax': 11.3,
#    'tempmin': 1.6,
#    'temp': 6.1,
#    'feelslikemax': 11.3,
#    'feelslikemin': -1.6,
#    'feelslike': 3.6,
#    'dew': -0.2,
#    'humidity': 64.95,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 31.7,
#    'windspeed': 19.5,
#    'winddir': 203.8,
#    'pressure': 1022.0,
#    'cloudcover': 67.4,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:26:08',
#    'sunriseEpoch': 1609158368,
#    'sunset': '16:53:59',
#    'sunsetEpoch': 1609192439,
#    'moonphase': 0.49,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['KDCA',
#     '72405013743',
#     '72403793728',
#     'KADW',
#     'KDAA',
#     '74594013705'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-29',
#    'datetimeEpoch': 1609218000,
#    'tempmax': 6.2,
#    'tempmin': 0.3,
#    'temp': 3.8,
#    'feelslikemax': 2.5,
#    'feelslikemin': -2.5,
#    'feelslike': 0.0,
#    'dew': -7.1,
#    'humidity': 46.13,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 52.9,
#    'windspeed': 32.7,
#    'winddir': 303.1,
#    'pressure': 1031.8,
#    'cloudcover': 26.9,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:26:23',
#    'sunriseEpoch': 1609244783,
#    'sunset': '16:54:43',
#    'sunsetEpoch': 1609278883,
#    'moonphase': 0.5,
#    'conditions': 'Partially cloudy',
#    'icon': 'wind',
#    'stations': ['KDCA',
#     '72405013743',
#     '72403793728',
#     'KADW',
#     'KDAA',
#     '74594013705'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-30',
#    'datetimeEpoch': 1609304400,
#    'tempmax': 7.8,
#    'tempmin': -0.3,
#    'temp': 3.8,
#    'feelslikemax': 4.1,
#    'feelslikemin': -4.1,
#    'feelslike': 0.6,
#    'dew': -5.2,
#    'humidity': 52.82,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 44.5,
#    'windspeed': 29.0,
#    'winddir': 158.3,
#    'pressure': 1029.1,
#    'cloudcover': 80.6,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:26:35',
#    'sunriseEpoch': 1609331195,
#    'sunset': '16:55:29',
#    'sunsetEpoch': 1609365329,
#    'moonphase': 0.5,
#    'conditions': 'Overcast',
#    'icon': 'cloudy',
#    'stations': ['KDCA',
#     '72405013743',
#     '72403793728',
#     'KADW',
#     'KDAA',
#     '74594013705'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-31',
#    'datetimeEpoch': 1609390800,
#    'tempmax': 12.8,
#    'tempmin': 4.4,
#    'temp': 8.1,
#    'feelslikemax': 12.8,
#    'feelslikemin': 0.7,
#    'feelslike': 5.6,
#    'dew': 3.0,
#    'humidity': 70.87,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 47.6,
#    'windspeed': 28.8,
#    'winddir': 176.6,
#    'pressure': 1022.7,
#    'cloudcover': 94.3,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:26:46',
#    'sunriseEpoch': 1609417606,
#    'sunset': '16:56:16',
#    'sunsetEpoch': 1609451776,
#    'moonphase': 0.51,
#    'conditions': 'Overcast',
#    'icon': 'cloudy',
#    'stations': ['KDCA',
#     '72405013743',
#     '72403793728',
#     'KADW',
#     'KDAA',
#     '74594013705'],
#    'source': 'obs',
#    'hours': None}],
#  'stations': {'KDCA': {'distance': 4501.0,
#    'latitude': 38.85,
#    'longitude': -77.03,
#    'useCount': 0,
#    'id': 'KDCA',
#    'name': 'KDCA',
#    'quality': 100,
#    'contribution': 0.0},
#   '72405013743': {'distance': 4814.0,
#    'latitude': 38.847,
#    'longitude': -77.034,
#    'useCount': 0,
#    'id': '72405013743',
#    'name': 'WASHINGTON REAGAN NATIONAL AIRPORT, VA US',
#    'quality': 100,
#    'contribution': 0.0},
#   '72403793728': {'distance': 23370.0,
#    'latitude': 38.717,
#    'longitude': -77.183,
#    'useCount': 0,
#    'id': '72403793728',
#    'name': 'DAVISON ARMY AIR FIELD, VA US',
#    'quality': 100,
#    'contribution': 0.0},
#   'KADW': {'distance': 16082.0,
#    'latitude': 38.82,
#    'longitude': -76.87,
#    'useCount': 0,
#    'id': 'KADW',
#    'name': 'KADW',
#    'quality': 100,
#    'contribution': 0.0},
#   'KDAA': {'distance': 22905.0,
#    'latitude': 38.72,
#    'longitude': -77.18,
#    'useCount': 0,
#    'id': 'KDAA',
#    'name': 'KDAA',
#    'quality': 100,
#    'contribution': 0.0},
#   '74594013705': {'distance': 16512.0,
#    'latitude': 38.817,
#    'longitude': -76.867,
#    'useCount': 0,
#    'id': '74594013705',
#    'name': 'CAMP SPRINGS ANDREWS AFB, MD US',
#    'quality': 100,
#    'contribution': 0.0}}}

# %%
#3. We create empty lists to transfer the data
temperature = []
temp_max = []
temp_min = []
humidity = []
precip = []
snow = []
windspeed = []
conditions = []
date = []
city = []

# %%
#4. We loop thropugh the API and extract the info we need
for x in range(366):
    temperature.append(response["days"][x]["temp"])
    temp_max.append(response["days"][x]["tempmax"])
    temp_min.append(response["days"][x]["tempmin"])
    humidity.append(response["days"][x]["humidity"])
    precip.append(response["days"][x]["precip"])
    snow.append(response["days"][x]["snow"])
    windspeed.append(response["days"][x]["windspeed"])
    conditions.append(response["days"][x]["conditions"])
    date.append(response["days"][x]["datetime"])
    city.append("Twin Cities, MN")

# %%
print(len(temperature),len(temp_max),len(temp_min),len(humidity),len(precip),len(snow),len(windspeed),len(conditions),len(date),len(city))
# Out:
# 366 366 366 366 366 366 366 366 366 366

# %%
#5. We create a dataframe based on the lists
New_df = pd.DataFrame(
    {'City': city,
     'Date': date,
     'Temperature': temperature,
     'temp_max': temp_max,
     'temp_min':temp_min,
     'humidity':humidity,
     'precip':precip,
     'snow':snow,
     'windspeed':windspeed,
     'conditions': conditions
    })

# %%
New_df
# Out:
#                 City        Date  Temperature  temp_max  temp_min  humidity  \
# 0    Twin Cities, MN  2020-01-01         -4.1       1.1     -10.9     77.08
# 1    Twin Cities, MN  2020-01-02          0.9       2.5      -0.6     77.04
# 2    Twin Cities, MN  2020-01-03         -0.6       1.3      -4.7     78.71
# 3    Twin Cities, MN  2020-01-04         -3.3      -1.3      -4.9     75.41
# 4    Twin Cities, MN  2020-01-05         -0.7       2.5      -3.5     68.44
# ..               ...         ...          ...       ...       ...       ...
# 361  Twin Cities, MN  2020-12-27         -5.8      -4.2      -9.6     82.43
# 362  Twin Cities, MN  2020-12-28         -9.0      -4.5     -13.8     77.48
# 363  Twin Cities, MN  2020-12-29        -10.1      -5.5     -16.7     83.29
# 364  Twin Cities, MN  2020-12-30         -5.3      -4.2      -9.1     76.69
# 365  Twin Cities, MN  2020-12-31         -8.5      -5.7     -12.3     84.88
#
#      precip  snow  windspeed              conditions
# 0      0.00  0.00       15.3        Partially cloudy
# 1      0.00  0.00       22.0                Overcast
# 2      0.00  0.00       20.3                Overcast
# 3      0.00  0.00       18.5        Partially cloudy
# 4      0.16  0.00       35.6  Snow, Partially cloudy
# ..      ...   ...        ...                     ...
# 361    0.28  1.25       20.1          Snow, Overcast
# 362    0.00  0.75       16.9  Snow, Partially cloudy
# 363    2.44  2.44       20.2  Snow, Partially cloudy
# 364    0.18  1.57       25.2          Snow, Overcast
# 365    0.00  0.52       18.2  Snow, Partially cloudy
#
# [366 rows x 10 columns]

# %%
#6. We add new city dataframe to original dataframe including cities already evaluated 

frames = [Final_df,New_df]

# %%
Final_df = pd.concat(frames)

# %%
Final_df
# Out:
#                 City        Date  Temperature  temp_max  temp_min  humidity  \
# 0       Montreal, QC  2020-01-01          0.2       1.1      -0.8     87.84
# 1       Montreal, QC  2020-01-02          0.9       2.6      -1.0     78.70
# 2       Montreal, QC  2020-01-03          4.8       5.8       2.8     74.88
# 3       Montreal, QC  2020-01-04          0.5       3.2      -1.9     78.79
# 4       Montreal, QC  2020-01-05         -5.3      -1.8      -9.9     69.09
# ..               ...         ...          ...       ...       ...       ...
# 361  Twin Cities, MN  2020-12-27         -5.8      -4.2      -9.6     82.43
# 362  Twin Cities, MN  2020-12-28         -9.0      -4.5     -13.8     77.48
# 363  Twin Cities, MN  2020-12-29        -10.1      -5.5     -16.7     83.29
# 364  Twin Cities, MN  2020-12-30         -5.3      -4.2      -9.1     76.69
# 365  Twin Cities, MN  2020-12-31         -8.5      -5.7     -12.3     84.88
#
#      precip  snow  windspeed              conditions
# 0      5.71  0.00        7.9                    Rain
# 1      0.00  0.00        7.7                   Clear
# 2      0.00  0.00        7.6                   Clear
# 3      2.27  0.00       11.2                    Rain
# 4      0.76  3.88       13.1                    Snow
# ..      ...   ...        ...                     ...
# 361    0.28  1.25       20.1          Snow, Overcast
# 362    0.00  0.75       16.9  Snow, Partially cloudy
# 363    2.44  2.44       20.2  Snow, Partially cloudy
# 364    0.18  1.57       25.2          Snow, Overcast
# 365    0.00  0.52       18.2  Snow, Partially cloudy
#
# [12444 rows x 10 columns]

# %%
#7.Update to csv by converting df to csv
Final_df.to_csv("Temperature_Dataset1.csv", index=False)

# %%
#8. Will need to import CSV with temp for cities already evaluated every time this document is open again for the 1st time. 
#Name dataframe: Final_df

file_path = os.path.join("Temperature_Dataset1.csv")
Final_df = pd.read_csv(file_path)
Final_df
# Out:
#                   City        Date  Temperature  temp_max  temp_min  humidity  \
# 0         Montreal, QC  2020-01-01          0.2       1.1      -0.8     87.84
# 1         Montreal, QC  2020-01-02          0.9       2.6      -1.0     78.70
# 2         Montreal, QC  2020-01-03          4.8       5.8       2.8     74.88
# 3         Montreal, QC  2020-01-04          0.5       3.2      -1.9     78.79
# 4         Montreal, QC  2020-01-05         -5.3      -1.8      -9.9     69.09
# ...                ...         ...          ...       ...       ...       ...
# 12439  Twin Cities, MN  2020-12-27         -5.8      -4.2      -9.6     82.43
# 12440  Twin Cities, MN  2020-12-28         -9.0      -4.5     -13.8     77.48
# 12441  Twin Cities, MN  2020-12-29        -10.1      -5.5     -16.7     83.29
# 12442  Twin Cities, MN  2020-12-30         -5.3      -4.2      -9.1     76.69
# 12443  Twin Cities, MN  2020-12-31         -8.5      -5.7     -12.3     84.88
#
#        precip  snow  windspeed              conditions
# 0        5.71  0.00        7.9                    Rain
# 1        0.00  0.00        7.7                   Clear
# 2        0.00  0.00        7.6                   Clear
# 3        2.27  0.00       11.2                    Rain
# 4        0.76  3.88       13.1                    Snow
# ...       ...   ...        ...                     ...
# 12439    0.28  1.25       20.1          Snow, Overcast
# 12440    0.00  0.75       16.9  Snow, Partially cloudy
# 12441    2.44  2.44       20.2  Snow, Partially cloudy
# 12442    0.18  1.57       25.2          Snow, Overcast
# 12443    0.00  0.52       18.2  Snow, Partially cloudy
#
# [12444 rows x 10 columns]
