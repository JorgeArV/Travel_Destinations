# %%
# 1.Importing dependencies

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import os

# %%
#2. We add url. Each city will have a new url

url2 = "https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/Jersey%20City/2020-1-1/2020-12-31?unitGroup=metric&key=SRX784Y4XEDTND44NFLHKK42Z&include=obs"

# %%
response = requests.get(url2).json()

# %%
response
# Out:
# {'queryCost': 366,
#  'latitude': 40.7175,
#  'longitude': -74.0439,
#  'resolvedAddress': 'Jersey City, NJ, United States',
#  'address': 'Jersey City',
#  'timezone': 'America/New_York',
#  'tzoffset': -5.0,
#  'days': [{'datetime': '2020-01-01',
#    'datetimeEpoch': 1577854800,
#    'tempmax': 5.0,
#    'tempmin': 1.5,
#    'temp': 3.5,
#    'feelslikemax': 2.6,
#    'feelslikemin': -2.5,
#    'feelslike': -0.2,
#    'dew': -4.5,
#    'humidity': 56.27,
#    'precip': 1.12,
#    'precipprob': None,
#    'precipcover': 4.17,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 46.4,
#    'windspeed': 28.1,
#    'winddir': 270.2,
#    'pressure': 1008.1,
#    'cloudcover': 42.5,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:20:17',
#    'sunriseEpoch': 1577881217,
#    'sunset': '16:39:04',
#    'sunsetEpoch': 1577914744,
#    'moonphase': 0.17,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['72505394728',
#     '72055399999',
#     'KEWR',
#     '72502014734',
#     'KJRB',
#     'KNYC'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-02',
#    'datetimeEpoch': 1577941200,
#    'tempmax': 9.0,
#    'tempmin': 0.4,
#    'temp': 4.7,
#    'feelslikemax': 7.6,
#    'feelslikemin': -3.7,
#    'feelslike': 2.0,
#    'dew': -2.7,
#    'humidity': 59.41,
#    'precip': 0.96,
#    'precipprob': None,
#    'precipcover': 12.5,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 81.4,
#    'windspeed': 19.2,
#    'winddir': 252.0,
#    'pressure': 1013.7,
#    'cloudcover': 6.6,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:20:24',
#    'sunriseEpoch': 1577967624,
#    'sunset': '16:39:54',
#    'sunsetEpoch': 1578001194,
#    'moonphase': 0.22,
#    'conditions': 'Rain',
#    'icon': 'rain',
#    'stations': ['72505394728',
#     '72055399999',
#     'KEWR',
#     '72502014734',
#     'KJRB',
#     'KNYC'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-03',
#    'datetimeEpoch': 1578027600,
#    'tempmax': 8.5,
#    'tempmin': 6.8,
#    'temp': 7.7,
#    'feelslikemax': 7.6,
#    'feelslikemin': 4.9,
#    'feelslike': 6.3,
#    'dew': 5.0,
#    'humidity': 83.59,
#    'precip': 3.14,
#    'precipprob': None,
#    'precipcover': 50.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 11.3,
#    'winddir': 257.6,
#    'pressure': 1010.0,
#    'cloudcover': 47.9,
#    'visibility': 12.9,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:20:28',
#    'sunriseEpoch': 1578054028,
#    'sunset': '16:40:46',
#    'sunsetEpoch': 1578087646,
#    'moonphase': 0.26,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['72505394728',
#     '72055399999',
#     'KEWR',
#     '72502014734',
#     'KJRB',
#     'KNYC'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-04',
#    'datetimeEpoch': 1578114000,
#    'tempmax': 9.6,
#    'tempmin': 6.6,
#    'temp': 8.4,
#    'feelslikemax': 9.6,
#    'feelslikemin': 5.1,
#    'feelslike': 7.5,
#    'dew': 7.3,
#    'humidity': 93.1,
#    'precip': 4.49,
#    'precipprob': None,
#    'precipcover': 37.5,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 40.4,
#    'windspeed': 10.7,
#    'winddir': 151.5,
#    'pressure': 1003.7,
#    'cloudcover': 52.6,
#    'visibility': 8.8,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:20:30',
#    'sunriseEpoch': 1578140430,
#    'sunset': '16:41:40',
#    'sunsetEpoch': 1578174100,
#    'moonphase': 0.31,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['72505394728',
#     '72055399999',
#     'KEWR',
#     '72502014734',
#     'KJRB',
#     'KNYC'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-05',
#    'datetimeEpoch': 1578200400,
#    'tempmax': 6.9,
#    'tempmin': 2.7,
#    'temp': 4.5,
#    'feelslikemax': 5.6,
#    'feelslikemin': -0.6,
#    'feelslike': 2.0,
#    'dew': -4.6,
#    'humidity': 52.45,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 1.87,
#    'snowdepth': 1.87,
#    'windgust': 65.4,
#    'windspeed': 16.0,
#    'winddir': 303.9,
#    'pressure': 1010.0,
#    'cloudcover': 42.6,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:20:29',
#    'sunriseEpoch': 1578226829,
#    'sunset': '16:42:35',
#    'sunsetEpoch': 1578260555,
#    'moonphase': 0.36,
#    'conditions': 'Snow, Partially cloudy',
#    'icon': 'snow',
#    'stations': ['72505394728',
#     '72055399999',
#     'KEWR',
#     '72502014734',
#     'KJRB',
#     'KNYC'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-06',
#    'datetimeEpoch': 1578286800,
#    'tempmax': 7.1,
#    'tempmin': 0.5,
#    'temp': 3.8,
#    'feelslikemax': 3.9,
#    'feelslikemin': -3.4,
#    'feelslike': 0.4,
#    'dew': -2.1,
#    'humidity': 67.35,
#    'precip': 1.45,
#    'precipprob': None,
#    'precipcover': 16.67,
#    'preciptype': None,
#    'snow': 1.13,
#    'snowdepth': 3.0,
#    'windgust': 83.2,
#    'windspeed': 23.2,
#    'winddir': 255.1,
#    'pressure': 1015.2,
#    'cloudcover': 34.6,
#    'visibility': 14.3,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:20:27',
#    'sunriseEpoch': 1578313227,
#    'sunset': '16:43:32',
#    'sunsetEpoch': 1578347012,
#    'moonphase': 0.4,
#    'conditions': 'Snow, Partially cloudy',
#    'icon': 'snow',
#    'stations': ['72505394728',
#     '72055399999',
#     'KEWR',
#     '72502014734',
#     'KJRB',
#     'KNYC'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-07',
#    'datetimeEpoch': 1578373200,
#    'tempmax': 6.7,
#    'tempmin': 3.3,
#    'temp': 4.6,
#    'feelslikemax': 6.2,
#    'feelslikemin': 0.3,
#    'feelslike': 2.3,
#    'dew': -3.7,
#    'humidity': 55.63,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 1.0,
#    'windgust': 63.0,
#    'windspeed': 15.7,
#    'winddir': 188.0,
#    'pressure': 1016.1,
#    'cloudcover': 18.4,
#    'visibility': 15.8,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:20:22',
#    'sunriseEpoch': 1578399622,
#    'sunset': '16:44:30',
#    'sunsetEpoch': 1578433470,
#    'moonphase': 0.44,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['72505394728',
#     '72055399999',
#     'KEWR',
#     '72502014734',
#     'KJRB',
#     'KNYC'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-08',
#    'datetimeEpoch': 1578459600,
#    'tempmax': 6.5,
#    'tempmin': -0.8,
#    'temp': 2.4,
#    'feelslikemax': 3.9,
#    'feelslikemin': -3.9,
#    'feelslike': -1.2,
#    'dew': -5.1,
#    'humidity': 60.76,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 70.3,
#    'windspeed': 25.1,
#    'winddir': 272.4,
#    'pressure': 1016.5,
#    'cloudcover': 24.2,
#    'visibility': 15.4,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:20:15',
#    'sunriseEpoch': 1578486015,
#    'sunset': '16:45:29',
#    'sunsetEpoch': 1578519929,
#    'moonphase': 0.47,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['72505394728',
#     '72055399999',
#     'KEWR',
#     '72502014734',
#     'KJRB',
#     'KNYC'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-09',
#    'datetimeEpoch': 1578546000,
#    'tempmax': 1.8,
#    'tempmin': -3.7,
#    'temp': -0.8,
#    'feelslikemax': 1.8,
#    'feelslikemin': -8.2,
#    'feelslike': -3.8,
#    'dew': -11.3,
#    'humidity': 45.72,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 65.7,
#    'windspeed': 14.2,
#    'winddir': 258.4,
#    'pressure': 1038.6,
#    'cloudcover': 10.0,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:20:05',
#    'sunriseEpoch': 1578572405,
#    'sunset': '16:46:29',
#    'sunsetEpoch': 1578606389,
#    'moonphase': 0.49,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['72505394728',
#     '72055399999',
#     'KEWR',
#     '72502014734',
#     'KJRB',
#     'KNYC'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-10',
#    'datetimeEpoch': 1578632400,
#    'tempmax': 11.9,
#    'tempmin': 0.9,
#    'temp': 6.5,
#    'feelslikemax': 11.9,
#    'feelslikemin': -3.0,
#    'feelslike': 4.4,
#    'dew': 1.7,
#    'humidity': 71.4,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 69.7,
#    'windspeed': 20.1,
#    'winddir': 259.3,
#    'pressure': 1034.3,
#    'cloudcover': 39.2,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:19:53',
#    'sunriseEpoch': 1578658793,
#    'sunset': '16:47:31',
#    'sunsetEpoch': 1578692851,
#    'moonphase': 0.5,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['72505394728',
#     '72055399999',
#     'KEWR',
#     '72502014734',
#     'KJRB',
#     'KNYC'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-11',
#    'datetimeEpoch': 1578718800,
#    'tempmax': 18.9,
#    'tempmin': 10.9,
#    'temp': 14.9,
#    'feelslikemax': 18.9,
#    'feelslikemin': 10.9,
#    'feelslike': 15.0,
#    'dew': 9.9,
#    'humidity': 72.41,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 63.2,
#    'windspeed': 25.7,
#    'winddir': 246.8,
#    'pressure': 1023.2,
#    'cloudcover': 45.0,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:19:40',
#    'sunriseEpoch': 1578745180,
#    'sunset': '16:48:34',
#    'sunsetEpoch': 1578779314,
#    'moonphase': 0.51,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['72505394728',
#     '72055399999',
#     'KEWR',
#     '72502014734',
#     'KJRB',
#     'KNYC'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-12',
#    'datetimeEpoch': 1578805200,
#    'tempmax': 19.3,
#    'tempmin': 9.2,
#    'temp': 15.9,
#    'feelslikemax': 19.3,
#    'feelslikemin': 7.5,
#    'feelslike': 15.8,
#    'dew': 7.7,
#    'humidity': 61.29,
#    'precip': 1.38,
#    'precipprob': None,
#    'precipcover': 16.67,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 56.5,
#    'windspeed': 36.1,
#    'winddir': 244.4,
#    'pressure': 1018.0,
#    'cloudcover': 22.4,
#    'visibility': 15.6,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:19:23',
#    'sunriseEpoch': 1578831563,
#    'sunset': '16:49:37',
#    'sunsetEpoch': 1578865777,
#    'moonphase': 0.52,
#    'conditions': 'Rain',
#    'icon': 'rain',
#    'stations': ['72505394728',
#     '72055399999',
#     'KEWR',
#     '72502014734',
#     'KJRB',
#     'KNYC'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-13',
#    'datetimeEpoch': 1578891600,
#    'tempmax': 8.4,
#    'tempmin': 3.6,
#    'temp': 6.2,
#    'feelslikemax': 7.7,
#    'feelslikemin': -0.5,
#    'feelslike': 4.2,
#    'dew': 1.7,
#    'humidity': 72.98,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 55.4,
#    'windspeed': 20.6,
#    'winddir': 52.0,
#    'pressure': 1029.2,
#    'cloudcover': 43.0,
#    'visibility': 15.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:19:05',
#    'sunriseEpoch': 1578917945,
#    'sunset': '16:50:42',
#    'sunsetEpoch': 1578952242,
#    'moonphase': 0.55,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['72505394728',
#     '72055399999',
#     'KEWR',
#     '72502014734',
#     'KJRB',
#     'KNYC'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-14',
#    'datetimeEpoch': 1578978000,
#    'tempmax': 7.8,
#    'tempmin': 4.7,
#    'temp': 6.1,
#    'feelslikemax': 6.6,
#    'feelslikemin': 1.8,
#    'feelslike': 4.3,
#    'dew': 3.6,
#    'humidity': 83.99,
#    'precip': 1.35,
#    'precipprob': None,
#    'precipcover': 12.5,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 14.8,
#    'winddir': 63.0,
#    'pressure': 1025.2,
#    'cloudcover': 41.7,
#    'visibility': 10.9,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:18:44',
#    'sunriseEpoch': 1579004324,
#    'sunset': '16:51:48',
#    'sunsetEpoch': 1579038708,
#    'moonphase': 0.59,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['72505394728',
#     '72055399999',
#     'KEWR',
#     '72502014734',
#     'KJRB',
#     'KNYC'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-15',
#    'datetimeEpoch': 1579064400,
#    'tempmax': 11.4,
#    'tempmin': 6.1,
#    'temp': 8.1,
#    'feelslikemax': 11.4,
#    'feelslikemin': 3.6,
#    'feelslike': 6.9,
#    'dew': 2.6,
#    'humidity': 70.27,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 52.0,
#    'windspeed': 15.4,
#    'winddir': 253.1,
#    'pressure': 1020.8,
#    'cloudcover': 17.7,
#    'visibility': 13.9,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:18:22',
#    'sunriseEpoch': 1579090702,
#    'sunset': '16:52:55',
#    'sunsetEpoch': 1579125175,
#    'moonphase': 0.64,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['72505394728',
#     '72055399999',
#     'KEWR',
#     '72502014734',
#     'KJRB',
#     'KNYC'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-16',
#    'datetimeEpoch': 1579150800,
#    'tempmax': 9.7,
#    'tempmin': 2.1,
#    'temp': 6.6,
#    'feelslikemax': 7.8,
#    'feelslikemin': -0.9,
#    'feelslike': 4.3,
#    'dew': 0.4,
#    'humidity': 66.58,
#    'precip': 2.76,
#    'precipprob': None,
#    'precipcover': 29.17,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 63.1,
#    'windspeed': 23.7,
#    'winddir': 265.4,
#    'pressure': 1015.0,
#    'cloudcover': 33.4,
#    'visibility': 13.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:17:57',
#    'sunriseEpoch': 1579177077,
#    'sunset': '16:54:02',
#    'sunsetEpoch': 1579211642,
#    'moonphase': 0.69,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['72505394728',
#     '72055399999',
#     'KEWR',
#     '72502014734',
#     'KJRB',
#     'KNYC'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-17',
#    'datetimeEpoch': 1579237200,
#    'tempmax': 2.0,
#    'tempmin': -4.2,
#    'temp': -1.5,
#    'feelslikemax': -1.0,
#    'feelslikemin': -9.8,
#    'feelslike': -5.4,
#    'dew': -13.0,
#    'humidity': 42.24,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 65.3,
#    'windspeed': 15.8,
#    'winddir': 308.7,
#    'pressure': 1034.6,
#    'cloudcover': 9.5,
#    'visibility': 15.8,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:17:29',
#    'sunriseEpoch': 1579263449,
#    'sunset': '16:55:11',
#    'sunsetEpoch': 1579298111,
#    'moonphase': 0.75,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['72505394728',
#     '72055399999',
#     'KEWR',
#     '72502014734',
#     'KJRB',
#     'KNYC'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-18',
#    'datetimeEpoch': 1579323600,
#    'tempmax': 2.8,
#    'tempmin': -5.3,
#    'temp': -2.4,
#    'feelslikemax': -1.3,
#    'feelslikemin': -10.0,
#    'feelslike': -5.7,
#    'dew': -8.1,
#    'humidity': 67.16,
#    'precip': 6.79,
#    'precipprob': None,
#    'precipcover': 41.67,
#    'preciptype': None,
#    'snow': 1.88,
#    'snowdepth': 1.88,
#    'windgust': 39.0,
#    'windspeed': 26.6,
#    'winddir': 204.6,
#    'pressure': 1028.3,
#    'cloudcover': 36.6,
#    'visibility': 11.8,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:17:00',
#    'sunriseEpoch': 1579349820,
#    'sunset': '16:56:20',
#    'sunsetEpoch': 1579384580,
#    'moonphase': 0.81,
#    'conditions': 'Snow, Partially cloudy',
#    'icon': 'snow',
#    'stations': ['72505394728',
#     '72055399999',
#     'KEWR',
#     '72502014734',
#     'KJRB',
#     'KNYC'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-19',
#    'datetimeEpoch': 1579410000,
#    'tempmax': 7.0,
#    'tempmin': 0.4,
#    'temp': 3.8,
#    'feelslikemax': 5.4,
#    'feelslikemin': -2.4,
#    'feelslike': 1.1,
#    'dew': -2.5,
#    'humidity': 65.9,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 1.13,
#    'snowdepth': 3.0,
#    'windgust': 43.8,
#    'windspeed': 20.1,
#    'winddir': 280.2,
#    'pressure': 1008.7,
#    'cloudcover': 35.3,
#    'visibility': 15.4,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:16:29',
#    'sunriseEpoch': 1579436189,
#    'sunset': '16:57:29',
#    'sunsetEpoch': 1579471049,
#    'moonphase': 0.86,
#    'conditions': 'Snow, Partially cloudy',
#    'icon': 'snow',
#    'stations': ['72505394728',
#     '72055399999',
#     'KEWR',
#     '72502014734',
#     'KJRB',
#     'KNYC'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-20',
#    'datetimeEpoch': 1579496400,
#    'tempmax': 2.2,
#    'tempmin': -5.2,
#    'temp': -2.1,
#    'feelslikemax': -0.4,
#    'feelslikemin': -10.0,
#    'feelslike': -5.8,
#    'dew': -12.7,
#    'humidity': 46.03,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 2.88,
#    'snowdepth': 2.88,
#    'windgust': 75.1,
#    'windspeed': 17.8,
#    'winddir': 312.4,
#    'pressure': 1024.1,
#    'cloudcover': 3.6,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:15:55',
#    'sunriseEpoch': 1579522555,
#    'sunset': '16:58:40',
#    'sunsetEpoch': 1579557520,
#    'moonphase': 0.91,
#    'conditions': 'Snow',
#    'icon': 'snow',
#    'stations': ['72505394728',
#     '72055399999',
#     'KEWR',
#     '72502014734',
#     'KJRB',
#     'KNYC'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-21',
#    'datetimeEpoch': 1579582800,
#    'tempmax': 2.8,
#    'tempmin': -4.8,
#    'temp': -1.8,
#    'feelslikemax': -0.3,
#    'feelslikemin': -9.4,
#    'feelslike': -5.1,
#    'dew': -10.5,
#    'humidity': 52.82,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 1.0,
#    'windgust': 68.4,
#    'windspeed': 15.2,
#    'winddir': 248.8,
#    'pressure': 1030.7,
#    'cloudcover': 2.6,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:15:20',
#    'sunriseEpoch': 1579608920,
#    'sunset': '16:59:51',
#    'sunsetEpoch': 1579643991,
#    'moonphase': 0.95,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['72505394728',
#     '72055399999',
#     'KEWR',
#     '72502014734',
#     'KJRB',
#     'KNYC'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-22',
#    'datetimeEpoch': 1579669200,
#    'tempmax': 5.5,
#    'tempmin': -2.5,
#    'temp': 0.7,
#    'feelslikemax': 3.6,
#    'feelslikemin': -6.4,
#    'feelslike': -1.8,
#    'dew': -7.4,
#    'humidity': 55.64,
#    'precip': 0.22,
#    'precipprob': None,
#    'precipcover': 4.17,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 77.8,
#    'windspeed': 12.8,
#    'winddir': 218.0,
#    'pressure': 1031.2,
#    'cloudcover': 2.4,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:14:42',
#    'sunriseEpoch': 1579695282,
#    'sunset': '17:01:02',
#    'sunsetEpoch': 1579730462,
#    'moonphase': 0.98,
#    'conditions': 'Rain',
#    'icon': 'rain',
#    'stations': ['72505394728',
#     '72055399999',
#     'KEWR',
#     '72502014734',
#     'KJRB',
#     'KNYC'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-23',
#    'datetimeEpoch': 1579755600,
#    'tempmax': 7.3,
#    'tempmin': -0.2,
#    'temp': 3.5,
#    'feelslikemax': 7.3,
#    'feelslikemin': -3.7,
#    'feelslike': 1.6,
#    'dew': -4.8,
#    'humidity': 55.69,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 77.8,
#    'windspeed': 11.3,
#    'winddir': 220.3,
#    'pressure': 1029.2,
#    'cloudcover': 6.0,
#    'visibility': 15.9,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:14:02',
#    'sunriseEpoch': 1579781642,
#    'sunset': '17:02:14',
#    'sunsetEpoch': 1579816934,
#    'moonphase': 0.99,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['72505394728',
#     '72055399999',
#     'KEWR',
#     '72502014734',
#     'KJRB',
#     'KNYC'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-24',
#    'datetimeEpoch': 1579842000,
#    'tempmax': 11.4,
#    'tempmin': 3.1,
#    'temp': 6.4,
#    'feelslikemax': 11.4,
#    'feelslikemin': 0.7,
#    'feelslike': 4.8,
#    'dew': -2.5,
#    'humidity': 54.61,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 63.0,
#    'windspeed': 21.6,
#    'winddir': 66.8,
#    'pressure': 1027.4,
#    'cloudcover': 5.2,
#    'visibility': 15.1,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:13:21',
#    'sunriseEpoch': 1579868001,
#    'sunset': '17:03:27',
#    'sunsetEpoch': 1579903407,
#    'moonphase': 1.0,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['72505394728',
#     '72055399999',
#     'KEWR',
#     '72502014734',
#     'KJRB',
#     'KNYC'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-25',
#    'datetimeEpoch': 1579928400,
#    'tempmax': 10.1,
#    'tempmin': 4.2,
#    'temp': 6.6,
#    'feelslikemax': 10.1,
#    'feelslikemin': -0.9,
#    'feelslike': 3.0,
#    'dew': 4.6,
#    'humidity': 87.37,
#    'precip': 16.44,
#    'precipprob': None,
#    'precipcover': 33.33,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 53.0,
#    'windspeed': 34.8,
#    'winddir': 98.5,
#    'pressure': 1014.5,
#    'cloudcover': 49.5,
#    'visibility': 11.6,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:12:37',
#    'sunriseEpoch': 1579954357,
#    'sunset': '17:04:40',
#    'sunsetEpoch': 1579989880,
#    'moonphase': 0.0,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['72505394728',
#     '72055399999',
#     'KEWR',
#     '72502014734',
#     'KJRB',
#     'KNYC'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-26',
#    'datetimeEpoch': 1580014800,
#    'tempmax': 8.6,
#    'tempmin': 3.2,
#    'temp': 5.4,
#    'feelslikemax': 6.4,
#    'feelslikemin': 0.3,
#    'feelslike': 2.4,
#    'dew': 0.0,
#    'humidity': 69.82,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 38.9,
#    'windspeed': 22.5,
#    'winddir': 260.6,
#    'pressure': 1009.2,
#    'cloudcover': 30.1,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:11:52',
#    'sunriseEpoch': 1580040712,
#    'sunset': '17:05:53',
#    'sunsetEpoch': 1580076353,
#    'moonphase': 0.01,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['72505394728',
#     '72055399999',
#     'KEWR',
#     '72502014734',
#     'KJRB',
#     'KNYC'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-27',
#    'datetimeEpoch': 1580101200,
#    'tempmax': 8.2,
#    'tempmin': 3.2,
#    'temp': 5.0,
#    'feelslikemax': 6.1,
#    'feelslikemin': -0.9,
#    'feelslike': 1.9,
#    'dew': -1.7,
#    'humidity': 62.58,
#    'precip': 0.45,
#    'precipprob': None,
#    'precipcover': 4.17,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 94.5,
#    'windspeed': 22.5,
#    'winddir': 272.6,
#    'pressure': 1006.4,
#    'cloudcover': 46.5,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:11:04',
#    'sunriseEpoch': 1580127064,
#    'sunset': '17:07:06',
#    'sunsetEpoch': 1580162826,
#    'moonphase': 0.03,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['72505394728',
#     '72055399999',
#     'KEWR',
#     '72502014734',
#     'KJRB',
#     'KNYC'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-28',
#    'datetimeEpoch': 1580187600,
#    'tempmax': 7.0,
#    'tempmin': 3.7,
#    'temp': 4.7,
#    'feelslikemax': 5.1,
#    'feelslikemin': 0.2,
#    'feelslike': 2.9,
#    'dew': -3.3,
#    'humidity': 56.38,
#    'precip': 0.22,
#    'precipprob': None,
#    'precipcover': 4.17,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 72.0,
#    'windspeed': 14.9,
#    'winddir': 304.5,
#    'pressure': 1010.1,
#    'cloudcover': 55.2,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:10:15',
#    'sunriseEpoch': 1580213415,
#    'sunset': '17:08:20',
#    'sunsetEpoch': 1580249300,
#    'moonphase': 0.06,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['72505394728',
#     '72055399999',
#     'KEWR',
#     '72502014734',
#     'KJRB',
#     'KNYC'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-29',
#    'datetimeEpoch': 1580274000,
#    'tempmax': 6.8,
#    'tempmin': 1.1,
#    'temp': 3.3,
#    'feelslikemax': 6.8,
#    'feelslikemin': -2.7,
#    'feelslike': 1.0,
#    'dew': -6.8,
#    'humidity': 48.01,
#    'precip': 0.22,
#    'precipprob': None,
#    'precipcover': 4.17,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 79.6,
#    'windspeed': 14.2,
#    'winddir': 269.2,
#    'pressure': 1018.1,
#    'cloudcover': 28.1,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:09:23',
#    'sunriseEpoch': 1580299763,
#    'sunset': '17:09:34',
#    'sunsetEpoch': 1580335774,
#    'moonphase': 0.09,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['72505394728',
#     '72055399999',
#     'KEWR',
#     '72502014734',
#     'KJRB',
#     'KNYC'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-30',
#    'datetimeEpoch': 1580360400,
#    'tempmax': 4.0,
#    'tempmin': -2.1,
#    'temp': 1.0,
#    'feelslikemax': 3.4,
#    'feelslikemin': -8.2,
#    'feelslike': -2.0,
#    'dew': -6.3,
#    'humidity': 59.32,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 76.0,
#    'windspeed': 21.9,
#    'winddir': 76.8,
#    'pressure': 1026.2,
#    'cloudcover': 10.8,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:08:30',
#    'sunriseEpoch': 1580386110,
#    'sunset': '17:10:48',
#    'sunsetEpoch': 1580422248,
#    'moonphase': 0.13,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['72505394728',
#     '72055399999',
#     'KEWR',
#     '72502014734',
#     'KJRB',
#     'KNYC'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-31',
#    'datetimeEpoch': 1580446800,
#    'tempmax': 6.2,
#    'tempmin': 1.8,
#    'temp': 4.1,
#    'feelslikemax': 6.2,
#    'feelslikemin': -1.5,
#    'feelslike': 2.3,
#    'dew': -0.1,
#    'humidity': 74.27,
#    'precip': 0.74,
#    'precipprob': None,
#    'precipcover': 12.5,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 53.6,
#    'windspeed': 11.8,
#    'winddir': 49.3,
#    'pressure': 1025.9,
#    'cloudcover': 51.1,
#    'visibility': 15.7,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:07:36',
#    'sunriseEpoch': 1580472456,
#    'sunset': '17:12:02',
#    'sunsetEpoch': 1580508722,
#    'moonphase': 0.18,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['72505394728',
#     '72055399999',
#     'KEWR',
#     '72502014734',
#     'KJRB',
#     'KNYC'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-01',
#    'datetimeEpoch': 1580533200,
#    'tempmax': 6.2,
#    'tempmin': 3.6,
#    'temp': 4.8,
#    'feelslikemax': 5.7,
#    'feelslikemin': 0.8,
#    'feelslike': 3.1,
#    'dew': 2.2,
#    'humidity': 83.41,
#    'precip': 0.22,
#    'precipprob': None,
#    'precipcover': 4.17,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 66.6,
#    'windspeed': 14.6,
#    'winddir': 203.9,
#    'pressure': 1013.1,
#    'cloudcover': 57.1,
#    'visibility': 11.5,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:06:39',
#    'sunriseEpoch': 1580558799,
#    'sunset': '17:13:16',
#    'sunsetEpoch': 1580595196,
#    'moonphase': 0.22,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['72505394728',
#     '72055399999',
#     'KEWR',
#     '72502014734',
#     'KJRB',
#     'KNYC'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-02',
#    'datetimeEpoch': 1580619600,
#    'tempmax': 6.3,
#    'tempmin': 2.1,
#    'temp': 3.9,
#    'feelslikemax': 4.2,
#    'feelslikemin': -1.5,
#    'feelslike': 1.1,
#    'dew': 0.4,
#    'humidity': 78.57,
#    'precip': 2.09,
#    'precipprob': None,
#    'precipcover': 37.5,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 47.2,
#    'windspeed': 25.2,
#    'winddir': 259.8,
#    'pressure': 1002.1,
#    'cloudcover': 43.8,
#    'visibility': 13.1,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:05:41',
#    'sunriseEpoch': 1580645141,
#    'sunset': '17:14:31',
#    'sunsetEpoch': 1580681671,
#    'moonphase': 0.27,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['72505394728',
#     '72055399999',
#     'KEWR',
#     '72502014734',
#     'KJRB',
#     'KNYC'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-03',
#    'datetimeEpoch': 1580706000,
#    'tempmax': 13.8,
#    'tempmin': 2.8,
#    'temp': 8.1,
#    'feelslikemax': 13.8,
#    'feelslikemin': -0.5,
#    'feelslike': 6.7,
#    'dew': 1.9,
#    'humidity': 67.51,
#    'precip': 0.86,
#    'precipprob': None,
#    'precipcover': 16.67,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 85.0,
#    'windspeed': 16.3,
#    'winddir': 219.8,
#    'pressure': 1008.9,
#    'cloudcover': 31.0,
#    'visibility': 15.5,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:04:41',
#    'sunriseEpoch': 1580731481,
#    'sunset': '17:15:45',
#    'sunsetEpoch': 1580768145,
#    'moonphase': 0.32,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['72505394728',
#     '72055399999',
#     'KEWR',
#     '72502014734',
#     'KJRB',
#     'KNYC'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-04',
#    'datetimeEpoch': 1580792400,
#    'tempmax': 14.1,
#    'tempmin': 6.2,
#    'temp': 9.7,
#    'feelslikemax': 14.1,
#    'feelslikemin': 3.7,
#    'feelslike': 8.9,
#    'dew': 5.5,
#    'humidity': 75.88,
#    'precip': 0.22,
#    'precipprob': None,
#    'precipcover': 4.17,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 70.2,
#    'windspeed': 16.0,
#    'winddir': 151.6,
#    'pressure': 1009.2,
#    'cloudcover': 34.0,
#    'visibility': 15.8,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:03:39',
#    'sunriseEpoch': 1580817819,
#    'sunset': '17:16:59',
#    'sunsetEpoch': 1580854619,
#    'moonphase': 0.37,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['72505394728',
#     '72055399999',
#     'KEWR',
#     '72502014734',
#     'KJRB',
#     'KNYC'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-05',
#    'datetimeEpoch': 1580878800,
#    'tempmax': 10.6,
#    'tempmin': 4.4,
#    'temp': 6.0,
#    'feelslikemax': 10.6,
#    'feelslikemin': 0.7,
#    'feelslike': 3.9,
#    'dew': -0.7,
#    'humidity': 63.58,
#    'precip': 0.19,
#    'precipprob': None,
#    'precipcover': 4.17,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 59.0,
#    'windspeed': 17.3,
#    'winddir': 142.3,
#    'pressure': 1015.4,
#    'cloudcover': 54.5,
#    'visibility': 15.6,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:02:36',
#    'sunriseEpoch': 1580904156,
#    'sunset': '17:18:14',
#    'sunsetEpoch': 1580941094,
#    'moonphase': 0.41,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['72505394728',
#     '72055399999',
#     'KEWR',
#     '72502014734',
#     'KJRB',
#     'KNYC'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-06',
#    'datetimeEpoch': 1580965200,
#    'tempmax': 5.6,
#    'tempmin': 3.0,
#    'temp': 4.6,
#    'feelslikemax': 2.2,
#    'feelslikemin': -0.5,
#    'feelslike': 1.0,
#    'dew': 3.1,
#    'humidity': 90.95,
#    'precip': 8.1,
#    'precipprob': None,
#    'precipcover': 54.17,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 34.1,
#    'windspeed': 24.7,
#    'winddir': 43.1,
#    'pressure': 1003.6,
#    'cloudcover': 58.5,
#    'visibility': 6.1,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:01:31',
#    'sunriseEpoch': 1580990491,
#    'sunset': '17:19:28',
#    'sunsetEpoch': 1581027568,
#    'moonphase': 0.45,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['72505394728',
#     '72055399999',
#     'KEWR',
#     '72502014734',
#     'KJRB',
#     'KNYC'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-07',
#    'datetimeEpoch': 1581051600,
#    'tempmax': 12.4,
#    'tempmin': 1.5,
#    'temp': 5.3,
#    'feelslikemax': 12.4,
#    'feelslikemin': -2.4,
#    'feelslike': 2.2,
#    'dew': 2.0,
#    'humidity': 80.82,
#    'precip': 6.67,
#    'precipprob': None,
#    'precipcover': 58.33,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 70.0,
#    'windspeed': 43.7,
#    'winddir': 162.5,
#    'pressure': 990.5,
#    'cloudcover': 54.3,
#    'visibility': 9.6,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:00:25',
#    'sunriseEpoch': 1581076825,
#    'sunset': '17:20:42',
#    'sunsetEpoch': 1581114042,
#    'moonphase': 0.48,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['72505394728',
#     '72055399999',
#     'KEWR',
#     '72502014734',
#     'KJRB',
#     'KNYC'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-08',
#    'datetimeEpoch': 1581138000,
#    'tempmax': 5.8,
#    'tempmin': -0.2,
#    'temp': 2.4,
#    'feelslikemax': 3.2,
#    'feelslikemin': -4.6,
#    'feelslike': -0.9,
#    'dew': -7.1,
#    'humidity': 49.81,
#    'precip': 0.21,
#    'precipprob': None,
#    'precipcover': 4.17,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 56.2,
#    'windspeed': 28.6,
#    'winddir': 270.3,
#    'pressure': 1020.4,
#    'cloudcover': 18.8,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:59:17',
#    'sunriseEpoch': 1581163157,
#    'sunset': '17:21:56',
#    'sunsetEpoch': 1581200516,
#    'moonphase': 0.5,
#    'conditions': 'Rain',
#    'icon': 'rain',
#    'stations': ['72505394728',
#     '72055399999',
#     'KEWR',
#     '72502014734',
#     'KJRB',
#     'KNYC'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-09',
#    'datetimeEpoch': 1581224400,
#    'tempmax': 7.0,
#    'tempmin': 0.7,
#    'temp': 3.8,
#    'feelslikemax': 5.7,
#    'feelslikemin': -4.2,
#    'feelslike': 0.7,
#    'dew': -1.4,
#    'humidity': 69.24,
#    'precip': 0.45,
#    'precipprob': None,
#    'precipcover': 8.33,
#    'preciptype': None,
#    'snow': 157.5,
#    'snowdepth': 157.5,
#    'windgust': 64.6,
#    'windspeed': 20.2,
#    'winddir': 64.7,
#    'pressure': 1031.4,
#    'cloudcover': 44.0,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:58:08',
#    'sunriseEpoch': 1581249488,
#    'sunset': '17:23:10',
#    'sunsetEpoch': 1581286990,
#    'moonphase': 0.5,
#    'conditions': 'Snow, Partially cloudy',
#    'icon': 'snow',
#    'stations': ['72505394728',
#     '72055399999',
#     'KEWR',
#     '72502014734',
#     'KJRB',
#     'KNYC'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-10',
#    'datetimeEpoch': 1581310800,
#    'tempmax': 8.0,
#    'tempmin': 5.6,
#    'temp': 6.5,
#    'feelslikemax': 5.8,
#    'feelslikemin': 2.2,
#    'feelslike': 3.9,
#    'dew': 3.3,
#    'humidity': 80.54,
#    'precip': 6.59,
#    'precipprob': None,
#    'precipcover': 54.17,
#    'preciptype': None,
#    'snow': 94.5,
#    'snowdepth': 252.0,
#    'windgust': 37.1,
#    'windspeed': 19.5,
#    'winddir': 235.8,
#    'pressure': 1022.1,
#    'cloudcover': 51.8,
#    'visibility': 12.8,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:56:57',
#    'sunriseEpoch': 1581335817,
#    'sunset': '17:24:24',
#    'sunsetEpoch': 1581373464,
#    'moonphase': 0.52,
#    'conditions': 'Snow, Partially cloudy',
#    'icon': 'snow',
#    'stations': ['72505394728',
#     '72055399999',
#     'KEWR',
#     '72502014734',
#     'KJRB',
#     'KNYC'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-11',
#    'datetimeEpoch': 1581397200,
#    'tempmax': 9.2,
#    'tempmin': 6.3,
#    'temp': 7.6,
#    'feelslikemax': 8.1,
#    'feelslikemin': 5.1,
#    'feelslike': 6.9,
#    'dew': 6.0,
#    'humidity': 90.21,
#    'precip': 6.42,
#    'precipprob': None,
#    'precipcover': 54.17,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 84.0,
#    'windgust': 37.1,
#    'windspeed': 10.5,
#    'winddir': 149.9,
#    'pressure': 1013.7,
#    'cloudcover': 49.6,
#    'visibility': 8.9,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:55:45',
#    'sunriseEpoch': 1581422145,
#    'sunset': '17:25:37',
#    'sunsetEpoch': 1581459937,
#    'moonphase': 0.53,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['72505394728',
#     '72055399999',
#     'KEWR',
#     '72502014734',
#     'KJRB',
#     'KNYC'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-12',
#    'datetimeEpoch': 1581483600,
#    'tempmax': 8.2,
#    'tempmin': 4.2,
#    'temp': 5.8,
#    'feelslikemax': 6.6,
#    'feelslikemin': 0.1,
#    'feelslike': 3.9,
#    'dew': -3.0,
#    'humidity': 53.95,
#    'precip': 0.45,
#    'precipprob': None,
#    'precipcover': 8.33,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 73.8,
#    'windspeed': 20.3,
#    'winddir': 262.9,
#    'pressure': 1020.2,
#    'cloudcover': 27.2,
#    'visibility': 15.7,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:54:31',
#    'sunriseEpoch': 1581508471,
#    'sunset': '17:26:51',
#    'sunsetEpoch': 1581546411,
#    'moonphase': 0.57,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['72505394728',
#     '72055399999',
#     'KEWR',
#     '72502014734',
#     'KJRB',
#     'KNYC'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-13',
#    'datetimeEpoch': 1581570000,
#    'tempmax': 6.2,
#    'tempmin': 2.9,
#    'temp': 4.6,
#    'feelslikemax': 6.2,
#    'feelslikemin': 1.3,
#    'feelslike': 3.3,
#    'dew': 2.8,
#    'humidity': 88.08,
#    'precip': 9.15,
#    'precipprob': None,
#    'precipcover': 58.33,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 45.2,
#    'windspeed': 12.3,
#    'winddir': 215.4,
#    'pressure': 1007.6,
#    'cloudcover': 48.2,
#    'visibility': 9.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:53:16',
#    'sunriseEpoch': 1581594796,
#    'sunset': '17:28:04',
#    'sunsetEpoch': 1581632884,
#    'moonphase': 0.62,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['72505394728',
#     '72055399999',
#     'KEWR',
#     '72502014734',
#     'KJRB',
#     'KNYC'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-14',
#    'datetimeEpoch': 1581656400,
#    'tempmax': 4.4,
#    'tempmin': -6.0,
#    'temp': 0.5,
#    'feelslikemax': 2.2,
#    'feelslikemin': -9.6,
#    'feelslike': -2.9,
#    'dew': -9.8,
#    'humidity': 47.67,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 65.7,
#    'windspeed': 22.6,
#    'winddir': 296.5,
#    'pressure': 1024.8,
#    'cloudcover': 8.0,
#    'visibility': 15.8,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:52:00',
#    'sunriseEpoch': 1581681120,
#    'sunset': '17:29:17',
#    'sunsetEpoch': 1581719357,
#    'moonphase': 0.67,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['72505394728',
#     '72055399999',
#     'KEWR',
#     '72502014734',
#     'KJRB',
#     'KNYC'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-15',
#    'datetimeEpoch': 1581742800,
#    'tempmax': -0.3,
#    'tempmin': -7.7,
#    'temp': -3.8,
#    'feelslikemax': -4.3,
#    'feelslikemin': -13.4,
#    'feelslike': -7.9,
#    'dew': -11.3,
#    'humidity': 56.26,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 30.4,
#    'windspeed': 19.8,
#    'winddir': 156.7,
#    'pressure': 1034.9,
#    'cloudcover': 2.5,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:50:43',
#    'sunriseEpoch': 1581767443,
#    'sunset': '17:30:30',
#    'sunsetEpoch': 1581805830,
#    'moonphase': 0.73,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['72505394728',
#     '72055399999',
#     'KEWR',
#     '72502014734',
#     'KJRB',
#     'KNYC'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-16',
#    'datetimeEpoch': 1581829200,
#    'tempmax': 7.6,
#    'tempmin': -1.3,
#    'temp': 2.8,
#    'feelslikemax': 7.6,
#    'feelslikemin': -7.3,
#    'feelslike': -0.1,
#    'dew': -3.4,
#    'humidity': 64.55,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 66.6,
#    'windspeed': 22.9,
#    'winddir': 232.3,
#    'pressure': 1022.3,
#    'cloudcover': 25.1,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:49:24',
#    'sunriseEpoch': 1581853764,
#    'sunset': '17:31:42',
#    'sunsetEpoch': 1581892302,
#    'moonphase': 0.78,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['72505394728',
#     '72055399999',
#     'KEWR',
#     '72502014734',
#     'KJRB',
#     'KNYC'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-17',
#    'datetimeEpoch': 1581915600,
#    'tempmax': 11.0,
#    'tempmin': 3.7,
#    'temp': 6.8,
#    'feelslikemax': 11.0,
#    'feelslikemin': 0.7,
#    'feelslike': 5.5,
#    'dew': -3.1,
#    'humidity': 51.05,
#    'precip': 0.22,
#    'precipprob': None,
#    'precipcover': 4.17,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 64.8,
#    'windspeed': 22.8,
#    'winddir': 233.1,
#    'pressure': 1024.1,
#    'cloudcover': 10.2,
#    'visibility': 15.9,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:48:05',
#    'sunriseEpoch': 1581940085,
#    'sunset': '17:32:54',
#    'sunsetEpoch': 1581978774,
#    'moonphase': 0.84,
#    'conditions': 'Rain',
#    'icon': 'rain',
#    'stations': ['72505394728',
#     '72055399999',
#     'KEWR',
#     '72502014734',
#     'KJRB',
#     'KNYC'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-18',
#    'datetimeEpoch': 1582002000,
#    'tempmax': 8.8,
#    'tempmin': 3.8,
#    'temp': 6.0,
#    'feelslikemax': 7.1,
#    'feelslikemin': -0.9,
#    'feelslike': 3.2,
#    'dew': 1.7,
#    'humidity': 74.48,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 35.3,
#    'windspeed': 25.9,
#    'winddir': 85.5,
#    'pressure': 1022.7,
#    'cloudcover': 50.1,
#    'visibility': 13.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:46:44',
#    'sunriseEpoch': 1582026404,
#    'sunset': '17:34:06',
#    'sunsetEpoch': 1582065246,
#    'moonphase': 0.88,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['72505394728',
#     '72055399999',
#     'KEWR',
#     '72502014734',
#     'KJRB',
#     'KNYC'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-19',
#    'datetimeEpoch': 1582088400,
#    'tempmax': 10.6,
#    'tempmin': 2.0,
#    'temp': 7.0,
#    'feelslikemax': 10.6,
#    'feelslikemin': -1.3,
#    'feelslike': 5.6,
#    'dew': -4.6,
#    'humidity': 46.84,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 66.5,
#    'windspeed': 17.5,
#    'winddir': 278.8,
#    'pressure': 1022.9,
#    'cloudcover': 20.0,
#    'visibility': 15.4,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:45:22',
#    'sunriseEpoch': 1582112722,
#    'sunset': '17:35:18',
#    'sunsetEpoch': 1582151718,
#    'moonphase': 0.93,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['72505394728',
#     '72055399999',
#     'KEWR',
#     '72502014734',
#     'KJRB',
#     'KNYC'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-20',
#    'datetimeEpoch': 1582174800,
#    'tempmax': 2.7,
#    'tempmin': -1.9,
#    'temp': 0.8,
#    'feelslikemax': 1.5,
#    'feelslikemin': -4.7,
#    'feelslike': -2.1,
#    'dew': -10.3,
#    'humidity': 43.83,
#    'precip': 0.22,
#    'precipprob': None,
#    'precipcover': 4.17,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 86.0,
#    'windspeed': 22.0,
#    'winddir': 302.2,
#    'pressure': 1030.6,
#    'cloudcover': 12.7,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:43:58',
#    'sunriseEpoch': 1582199038,
#    'sunset': '17:36:29',
#    'sunsetEpoch': 1582238189,
#    'moonphase': 0.96,
#    'conditions': 'Rain',
#    'icon': 'rain',
#    'stations': ['72505394728',
#     '72055399999',
#     'KEWR',
#     '72502014734',
#     'KJRB',
#     'KNYC'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-21',
#    'datetimeEpoch': 1582261200,
#    'tempmax': 3.0,
#    'tempmin': -4.4,
#    'temp': -0.9,
#    'feelslikemax': 0.2,
#    'feelslikemin': -9.4,
#    'feelslike': -4.8,
#    'dew': -12.5,
#    'humidity': 43.4,
#    'precip': 0.22,
#    'precipprob': None,
#    'precipcover': 4.17,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 68.4,
#    'windspeed': 18.6,
#    'winddir': 231.4,
#    'pressure': 1031.3,
#    'cloudcover': 1.1,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:42:34',
#    'sunriseEpoch': 1582285354,
#    'sunset': '17:37:40',
#    'sunsetEpoch': 1582324660,
#    'moonphase': 0.98,
#    'conditions': 'Snow',
#    'icon': 'snow',
#    'stations': ['72505394728',
#     '72055399999',
#     'KEWR',
#     '72502014734',
#     'KJRB',
#     'KNYC'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-22',
#    'datetimeEpoch': 1582347600,
#    'tempmax': 10.5,
#    'tempmin': -1.0,
#    'temp': 4.3,
#    'feelslikemax': 10.5,
#    'feelslikemin': -6.2,
#    'feelslike': 0.9,
#    'dew': -10.7,
#    'humidity': 34.58,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 77.8,
#    'windspeed': 24.3,
#    'winddir': 256.9,
#    'pressure': 1024.5,
#    'cloudcover': 0.5,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:41:09',
#    'sunriseEpoch': 1582371669,
#    'sunset': '17:38:51',
#    'sunsetEpoch': 1582411131,
#    'moonphase': 1.0,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['72505394728',
#     '72055399999',
#     'KEWR',
#     '72502014734',
#     'KJRB',
#     'KNYC'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-23',
#    'datetimeEpoch': 1582434000,
#    'tempmax': 13.8,
#    'tempmin': 2.2,
#    'temp': 7.7,
#    'feelslikemax': 13.8,
#    'feelslikemin': -0.6,
#    'feelslike': 6.3,
#    'dew': -7.7,
#    'humidity': 34.0,
#    'precip': 0.22,
#    'precipprob': None,
#    'precipcover': 4.17,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 76.0,
#    'windspeed': 20.7,
#    'winddir': 234.3,
#    'pressure': 1021.7,
#    'cloudcover': 5.8,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:39:43',
#    'sunriseEpoch': 1582457983,
#    'sunset': '17:40:02',
#    'sunsetEpoch': 1582497602,
#    'moonphase': 1.0,
#    'conditions': 'Rain',
#    'icon': 'rain',
#    'stations': ['72505394728',
#     '72055399999',
#     'KEWR',
#     '72502014734',
#     'KJRB',
#     'KNYC'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-24',
#    'datetimeEpoch': 1582520400,
#    'tempmax': 16.6,
#    'tempmin': 4.3,
#    'temp': 8.9,
#    'feelslikemax': 16.6,
#    'feelslikemin': 3.0,
#    'feelslike': 8.1,
#    'dew': -1.4,
#    'humidity': 51.18,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 77.8,
#    'windspeed': 11.6,
#    'winddir': 189.1,
#    'pressure': 1016.9,
#    'cloudcover': 20.6,
#    'visibility': 15.8,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:38:16',
#    'sunriseEpoch': 1582544296,
#    'sunset': '17:41:12',
#    'sunsetEpoch': 1582584072,
#    'moonphase': 0.0,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['72505394728',
#     '72055399999',
#     'KEWR',
#     '72502014734',
#     'KJRB',
#     'KNYC'],
#    'source': 'obs',
#    'hours': None},
# ...
#    'tempmax': 6.1,
#    'tempmin': 1.1,
#    'temp': 2.8,
#    'feelslikemax': 4.0,
#    'feelslikemin': -3.0,
#    'feelslike': 0.1,
#    'dew': -6.8,
#    'humidity': 49.65,
#    'precip': 0.22,
#    'precipprob': None,
#    'precipcover': 4.17,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 40.2,
#    'windspeed': 19.2,
#    'winddir': 278.1,
#    'pressure': 1024.7,
#    'cloudcover': 6.2,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:13:33',
#    'sunriseEpoch': 1608034413,
#    'sunset': '16:29:41',
#    'sunsetEpoch': 1608067781,
#    'moonphase': 0.0,
#    'conditions': 'Rain',
#    'icon': 'rain',
#    'stations': ['72505394728',
#     '72055399999',
#     'KEWR',
#     '72502014734',
#     'KJRB',
#     'KNYC'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-16',
#    'datetimeEpoch': 1608094800,
#    'tempmax': 0.8,
#    'tempmin': -2.4,
#    'temp': -0.7,
#    'feelslikemax': -3.5,
#    'feelslikemin': -9.7,
#    'feelslike': -6.9,
#    'dew': -6.8,
#    'humidity': 65.35,
#    'precip': 3.37,
#    'precipprob': None,
#    'precipcover': 29.17,
#    'preciptype': None,
#    'snow': 11.98,
#    'snowdepth': 11.98,
#    'windgust': 60.7,
#    'windspeed': 37.1,
#    'winddir': 36.4,
#    'pressure': 1025.3,
#    'cloudcover': 36.6,
#    'visibility': 11.3,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:14:13',
#    'sunriseEpoch': 1608120853,
#    'sunset': '16:30:00',
#    'sunsetEpoch': 1608154200,
#    'moonphase': 0.02,
#    'conditions': 'Snow, Partially cloudy',
#    'icon': 'snow',
#    'stations': ['72505394728',
#     '72055399999',
#     'KEWR',
#     '72502014734',
#     'KJRB',
#     'KNYC'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-17',
#    'datetimeEpoch': 1608181200,
#    'tempmax': 2.3,
#    'tempmin': -3.1,
#    'temp': -0.4,
#    'feelslikemax': -0.1,
#    'feelslikemin': -7.8,
#    'feelslike': -4.8,
#    'dew': -3.1,
#    'humidity': 82.65,
#    'precip': 4.58,
#    'precipprob': None,
#    'precipcover': 62.5,
#    'preciptype': None,
#    'snow': 8.18,
#    'snowdepth': 20.17,
#    'windgust': 61.4,
#    'windspeed': 37.2,
#    'winddir': 153.5,
#    'pressure': 1012.9,
#    'cloudcover': 37.4,
#    'visibility': 9.2,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:14:52',
#    'sunriseEpoch': 1608207292,
#    'sunset': '16:30:22',
#    'sunsetEpoch': 1608240622,
#    'moonphase': 0.05,
#    'conditions': 'Snow, Partially cloudy',
#    'icon': 'snow',
#    'stations': ['72505394728',
#     '72055399999',
#     'KEWR',
#     '72502014734',
#     'KJRB',
#     'KNYC'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-18',
#    'datetimeEpoch': 1608267600,
#    'tempmax': 1.4,
#    'tempmin': -2.6,
#    'temp': -0.9,
#    'feelslikemax': -1.8,
#    'feelslikemin': -5.9,
#    'feelslike': -3.4,
#    'dew': -6.2,
#    'humidity': 67.42,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.72,
#    'snowdepth': 19.02,
#    'windgust': 35.3,
#    'windspeed': 13.3,
#    'winddir': 168.9,
#    'pressure': 1025.1,
#    'cloudcover': 39.1,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:15:28',
#    'sunriseEpoch': 1608293728,
#    'sunset': '16:30:45',
#    'sunsetEpoch': 1608327045,
#    'moonphase': 0.09,
#    'conditions': 'Snow, Partially cloudy',
#    'icon': 'snow',
#    'stations': ['72505394728',
#     '72055399999',
#     'KEWR',
#     '72502014734',
#     'KJRB',
#     'KNYC'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-19',
#    'datetimeEpoch': 1608354000,
#    'tempmax': 0.8,
#    'tempmin': -4.4,
#    'temp': -1.4,
#    'feelslikemax': -0.9,
#    'feelslikemin': -7.3,
#    'feelslike': -4.2,
#    'dew': -7.3,
#    'humidity': 64.83,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 17.62,
#    'windgust': None,
#    'windspeed': 13.0,
#    'winddir': 217.1,
#    'pressure': 1028.8,
#    'cloudcover': 7.2,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:16:03',
#    'sunriseEpoch': 1608380163,
#    'sunset': '16:31:10',
#    'sunsetEpoch': 1608413470,
#    'moonphase': 0.13,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['72505394728',
#     '72055399999',
#     'KEWR',
#     '72502014734',
#     'KJRB',
#     'KNYC'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-20',
#    'datetimeEpoch': 1608440400,
#    'tempmax': 4.3,
#    'tempmin': -0.3,
#    'temp': 2.1,
#    'feelslikemax': 4.3,
#    'feelslikemin': -2.7,
#    'feelslike': 0.8,
#    'dew': -2.4,
#    'humidity': 73.33,
#    'precip': 0.04,
#    'precipprob': None,
#    'precipcover': 4.17,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 16.33,
#    'windgust': 27.7,
#    'windspeed': 14.3,
#    'winddir': 175.8,
#    'pressure': 1021.2,
#    'cloudcover': 51.0,
#    'visibility': 15.2,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:16:35',
#    'sunriseEpoch': 1608466595,
#    'sunset': '16:31:38',
#    'sunsetEpoch': 1608499898,
#    'moonphase': 0.18,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['72505394728',
#     '72055399999',
#     'KEWR',
#     '72502014734',
#     'KJRB',
#     'KNYC'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-21',
#    'datetimeEpoch': 1608526800,
#    'tempmax': 8.6,
#    'tempmin': 3.7,
#    'temp': 5.1,
#    'feelslikemax': 7.6,
#    'feelslikemin': 1.4,
#    'feelslike': 3.5,
#    'dew': 1.5,
#    'humidity': 78.22,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 13.14,
#    'windgust': None,
#    'windspeed': 14.1,
#    'winddir': 228.1,
#    'pressure': 1010.4,
#    'cloudcover': 45.1,
#    'visibility': 14.4,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:17:06',
#    'sunriseEpoch': 1608553026,
#    'sunset': '16:32:08',
#    'sunsetEpoch': 1608586328,
#    'moonphase': 0.23,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['72505394728',
#     '72055399999',
#     'KEWR',
#     '72502014734',
#     'KJRB',
#     'KNYC'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-22',
#    'datetimeEpoch': 1608613200,
#    'tempmax': 8.5,
#    'tempmin': 3.3,
#    'temp': 5.6,
#    'feelslikemax': 7.2,
#    'feelslikemin': 0.4,
#    'feelslike': 3.6,
#    'dew': -0.3,
#    'humidity': 67.95,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 9.15,
#    'windgust': 47.3,
#    'windspeed': 13.1,
#    'winddir': 272.0,
#    'pressure': 1011.0,
#    'cloudcover': 52.0,
#    'visibility': 13.3,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:17:34',
#    'sunriseEpoch': 1608639454,
#    'sunset': '16:32:39',
#    'sunsetEpoch': 1608672759,
#    'moonphase': 0.28,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['72505394728',
#     '72055399999',
#     'KEWR',
#     '72502014734',
#     'KJRB',
#     'KNYC'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-23',
#    'datetimeEpoch': 1608699600,
#    'tempmax': 7.7,
#    'tempmin': 3.2,
#    'temp': 5.1,
#    'feelslikemax': 7.0,
#    'feelslikemin': 0.5,
#    'feelslike': 3.3,
#    'dew': -3.7,
#    'humidity': 53.98,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 2.85,
#    'snowdepth': 5.84,
#    'windgust': 31.7,
#    'windspeed': 17.5,
#    'winddir': 240.1,
#    'pressure': 1027.6,
#    'cloudcover': 7.3,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:18:01',
#    'sunriseEpoch': 1608725881,
#    'sunset': '16:33:13',
#    'sunsetEpoch': 1608759193,
#    'moonphase': 0.32,
#    'conditions': 'Snow',
#    'icon': 'snow',
#    'stations': ['72505394728',
#     '72055399999',
#     'KEWR',
#     '72502014734',
#     'KJRB',
#     'KNYC'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-24',
#    'datetimeEpoch': 1608786000,
#    'tempmax': 14.4,
#    'tempmin': 5.6,
#    'temp': 11.6,
#    'feelslikemax': 14.4,
#    'feelslikemin': 5.6,
#    'feelslike': 11.4,
#    'dew': 8.3,
#    'humidity': 80.05,
#    'precip': 0.4,
#    'precipprob': None,
#    'precipcover': 16.67,
#    'preciptype': None,
#    'snow': 1.66,
#    'snowdepth': 5.26,
#    'windgust': 46.0,
#    'windspeed': 23.4,
#    'winddir': 135.5,
#    'pressure': 1018.4,
#    'cloudcover': 52.9,
#    'visibility': 15.6,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:18:25',
#    'sunriseEpoch': 1608812305,
#    'sunset': '16:33:49',
#    'sunsetEpoch': 1608845629,
#    'moonphase': 0.37,
#    'conditions': 'Snow, Partially cloudy',
#    'icon': 'snow',
#    'stations': ['72505394728',
#     '72055399999',
#     'KEWR',
#     '72502014734',
#     'KJRB',
#     'KNYC'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-25',
#    'datetimeEpoch': 1608872400,
#    'tempmax': 15.2,
#    'tempmin': -0.2,
#    'temp': 9.2,
#    'feelslikemax': 15.2,
#    'feelslikemin': -6.5,
#    'feelslike': 7.0,
#    'dew': 6.7,
#    'humidity': 84.81,
#    'precip': 14.47,
#    'precipprob': None,
#    'precipcover': 54.17,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 1.0,
#    'windgust': 58.8,
#    'windspeed': 31.9,
#    'winddir': 199.5,
#    'pressure': 1001.9,
#    'cloudcover': 57.5,
#    'visibility': 12.3,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:18:47',
#    'sunriseEpoch': 1608898727,
#    'sunset': '16:34:27',
#    'sunsetEpoch': 1608932067,
#    'moonphase': 0.4,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['72505394728',
#     '72055399999',
#     'KEWR',
#     '72502014734',
#     'KJRB',
#     'KNYC'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-26',
#    'datetimeEpoch': 1608958800,
#    'tempmax': 1.3,
#    'tempmin': -3.5,
#    'temp': -1.5,
#    'feelslikemax': -3.5,
#    'feelslikemin': -11.0,
#    'feelslike': -7.8,
#    'dew': -8.7,
#    'humidity': 58.51,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 44.7,
#    'windspeed': 30.7,
#    'winddir': 260.8,
#    'pressure': 1013.2,
#    'cloudcover': 22.8,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:19:08',
#    'sunriseEpoch': 1608985148,
#    'sunset': '16:35:06',
#    'sunsetEpoch': 1609018506,
#    'moonphase': 0.44,
#    'conditions': 'Clear',
#    'icon': 'wind',
#    'stations': ['72505394728',
#     '72055399999',
#     'KEWR',
#     '72502014734',
#     'KJRB',
#     'KNYC'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-27',
#    'datetimeEpoch': 1609045200,
#    'tempmax': 5.1,
#    'tempmin': -3.5,
#    'temp': 0.2,
#    'feelslikemax': 3.2,
#    'feelslikemin': -8.5,
#    'feelslike': -3.1,
#    'dew': -7.3,
#    'humidity': 58.45,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 27.7,
#    'windspeed': 15.3,
#    'winddir': 227.4,
#    'pressure': 1025.1,
#    'cloudcover': 4.0,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:19:26',
#    'sunriseEpoch': 1609071566,
#    'sunset': '16:35:48',
#    'sunsetEpoch': 1609104948,
#    'moonphase': 0.47,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['72505394728',
#     '72055399999',
#     'KEWR',
#     '72502014734',
#     'KJRB',
#     'KNYC'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-28',
#    'datetimeEpoch': 1609131600,
#    'tempmax': 11.8,
#    'tempmin': 2.0,
#    'temp': 6.7,
#    'feelslikemax': 11.8,
#    'feelslikemin': -1.4,
#    'feelslike': 5.0,
#    'dew': 0.3,
#    'humidity': 64.59,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 29.5,
#    'windspeed': 19.4,
#    'winddir': 222.5,
#    'pressure': 1021.8,
#    'cloudcover': 28.3,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:19:42',
#    'sunriseEpoch': 1609157982,
#    'sunset': '16:36:31',
#    'sunsetEpoch': 1609191391,
#    'moonphase': 0.49,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['72505394728',
#     '72055399999',
#     'KEWR',
#     '72502014734',
#     'KJRB',
#     'KNYC'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-29',
#    'datetimeEpoch': 1609218000,
#    'tempmax': 6.1,
#    'tempmin': -0.2,
#    'temp': 3.6,
#    'feelslikemax': 4.2,
#    'feelslikemin': -3.2,
#    'feelslike': 1.4,
#    'dew': -7.6,
#    'humidity': 45.01,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 47.2,
#    'windspeed': 13.1,
#    'winddir': 299.2,
#    'pressure': 1028.6,
#    'cloudcover': 21.4,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:19:55',
#    'sunriseEpoch': 1609244395,
#    'sunset': '16:37:16',
#    'sunsetEpoch': 1609277836,
#    'moonphase': 0.5,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['72505394728',
#     '72055399999',
#     'KEWR',
#     '72502014734',
#     'KJRB',
#     'KNYC'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-30',
#    'datetimeEpoch': 1609304400,
#    'tempmax': 5.1,
#    'tempmin': -0.9,
#    'temp': 2.1,
#    'feelslikemax': 2.2,
#    'feelslikemin': -4.1,
#    'feelslike': -0.7,
#    'dew': -5.9,
#    'humidity': 56.07,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 42.5,
#    'windspeed': 24.0,
#    'winddir': 225.0,
#    'pressure': 1028.8,
#    'cloudcover': 14.4,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:20:07',
#    'sunriseEpoch': 1609330807,
#    'sunset': '16:38:03',
#    'sunsetEpoch': 1609364283,
#    'moonphase': 0.5,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['72505394728',
#     '72055399999',
#     'KEWR',
#     '72502014734',
#     'KJRB',
#     'KNYC'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-31',
#    'datetimeEpoch': 1609390800,
#    'tempmax': 8.8,
#    'tempmin': 2.7,
#    'temp': 6.0,
#    'feelslikemax': 7.0,
#    'feelslikemin': -0.2,
#    'feelslike': 4.1,
#    'dew': 1.3,
#    'humidity': 72.5,
#    'precip': 3.54,
#    'precipprob': None,
#    'precipcover': 37.5,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 31.7,
#    'windspeed': 23.0,
#    'winddir': 254.0,
#    'pressure': 1021.6,
#    'cloudcover': 46.5,
#    'visibility': 15.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:20:16',
#    'sunriseEpoch': 1609417216,
#    'sunset': '16:38:52',
#    'sunsetEpoch': 1609450732,
#    'moonphase': 0.51,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['72505394728',
#     '72055399999',
#     'KEWR',
#     '72502014734',
#     'KJRB',
#     'KNYC'],
#    'source': 'obs',
#    'hours': None}],
#  'stations': {'72505394728': {'distance': 9298.0,
#    'latitude': 40.779,
#    'longitude': -73.969,
#    'useCount': 0,
#    'id': '72505394728',
#    'name': 'NY CITY CENTRAL PARK, NY US',
#    'quality': 100,
#    'contribution': 0.0},
#   '72055399999': {'distance': 3459.0,
#    'latitude': 40.701,
#    'longitude': -74.009,
#    'useCount': 0,
#    'id': '72055399999',
#    'name': 'PORT AUTH DOWNTN MANHATTAN WALL ST HEL, NY US',
#    'quality': 100,
#    'contribution': 0.0},
#   'KEWR': {'distance': 10818.0,
#    'latitude': 40.7,
#    'longitude': -74.17,
#    'useCount': 0,
#    'id': 'KEWR',
#    'name': 'KEWR',
#    'quality': 100,
#    'contribution': 0.0},
#   '72502014734': {'distance': 11285.0,
#    'latitude': 40.683,
#    'longitude': -74.169,
#    'useCount': 0,
#    'id': '72502014734',
#    'name': 'NEWARK LIBERTY INTERNATIONAL AIRPORT, NJ US',
#    'quality': 100,
#    'contribution': 0.0},
#   'KJRB': {'distance': 3459.0,
#    'latitude': 40.701,
#    'longitude': -74.009,
#    'useCount': 0,
#    'id': 'KJRB',
#    'name': 'Downtown Manhattan/wall St, New York',
#    'quality': 100,
#    'contribution': 0.0},
#   'KNYC': {'distance': 7950.0,
#    'latitude': 40.77,
#    'longitude': -73.98,
#    'useCount': 0,
#    'id': 'KNYC',
#    'name': 'KNYC',
#    'quality': 100,
#    'contribution': 0.0}}}

# %%
#3. We create empty lists to transfer the data
temperature = []
date = []
city = []

# %%
#4. We loop thropugh the API and extract the info we need
for x in range(366):
    temperature.append(response["days"][x]["temp"])
    date.append(response["days"][x]["datetime"])
    city.append("Jersey City, NJ")

# %%
len(city)
# Out:
# 366

# %%
len(date)
# Out:
# 366

# %%
len (temperature)
# Out:
# 366

# %%
#5. We create a dataframe based on the lists
New_df = pd.DataFrame(
    {'City': city,
     'Date': date,
     'Temperature': temperature
    })

# %%
New_df
# Out:
#                 City        Date  Temperature
# 0    Jersey City, NJ  2020-01-01          3.5
# 1    Jersey City, NJ  2020-01-02          4.7
# 2    Jersey City, NJ  2020-01-03          7.7
# 3    Jersey City, NJ  2020-01-04          8.4
# 4    Jersey City, NJ  2020-01-05          4.5
# ..               ...         ...          ...
# 361  Jersey City, NJ  2020-12-27          0.2
# 362  Jersey City, NJ  2020-12-28          6.7
# 363  Jersey City, NJ  2020-12-29          3.6
# 364  Jersey City, NJ  2020-12-30          2.1
# 365  Jersey City, NJ  2020-12-31          6.0
#
# [366 rows x 3 columns]

# %%
#6. We add new city dataframe to original dataframe including cities already evaluated 

frames = [Final_df,New_df]

# %%
Final_df = pd.concat(frames)

# %%
Final_df
# Out:
#                 City        Date  Temperature
# 0      Asheville, NC  2020-01-01          3.8
# 1      Asheville, NC  2020-01-02          3.8
# 2      Asheville, NC  2020-01-03         10.8
# 3      Asheville, NC  2020-01-04          8.2
# 4      Asheville, NC  2020-01-05          1.9
# ..               ...         ...          ...
# 361  Jersey City, NJ  2020-12-27          0.2
# 362  Jersey City, NJ  2020-12-28          6.7
# 363  Jersey City, NJ  2020-12-29          3.6
# 364  Jersey City, NJ  2020-12-30          2.1
# 365  Jersey City, NJ  2020-12-31          6.0
#
# [4392 rows x 3 columns]

# %%
#7.Update to csv by converting df to csv
Final_df.to_csv("Temperature_Dataset1.csv", index=False)

# %%
#8. Will need to import CSV with temp for cities already evaluated every time this document is open again for the 1st time. 
#Name dataframe: Final_df

file_path = os.path.join("Temperature_Dataset1.csv")
Final_df = pd.read_csv(file_path)
Final_df
# Out:
#                  City        Date  Temperature
# 0       Asheville, NC  2020-01-01          3.8
# 1       Asheville, NC  2020-01-02          3.8
# 2       Asheville, NC  2020-01-03         10.8
# 3       Asheville, NC  2020-01-04          8.2
# 4       Asheville, NC  2020-01-05          1.9
# ...               ...         ...          ...
# 4387  Jersey City, NJ  2020-12-27          0.2
# 4388  Jersey City, NJ  2020-12-28          6.7
# 4389  Jersey City, NJ  2020-12-29          3.6
# 4390  Jersey City, NJ  2020-12-30          2.1
# 4391  Jersey City, NJ  2020-12-31          6.0
#
# [4392 rows x 3 columns]
