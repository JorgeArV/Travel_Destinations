# %%
# 1.Importing dependencies

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import os

# %%
#2. We add url. Each city will have a new url

url2 = "https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/Hawaii/2020-1-1/2020-12-31?unitGroup=metric&key=SRX784Y4XEDTND44NFLHKK42Z&include=obs"

# %%
response = requests.get(url2).json()

# %%
response
# Out:
# {'queryCost': 366,
#  'latitude': 21.3049,
#  'longitude': -157.858,
#  'resolvedAddress': 'HI, United States',
#  'address': 'Hawaii',
#  'timezone': 'Pacific/Honolulu',
#  'tzoffset': -10.0,
#  'days': [{'datetime': '2020-01-01',
#    'datetimeEpoch': 1577872800,
#    'tempmax': 26.6,
#    'tempmin': 20.8,
#    'temp': 24.0,
#    'feelslikemax': 26.6,
#    'feelslikemin': 20.8,
#    'feelslike': 24.0,
#    'dew': 16.9,
#    'humidity': 64.88,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 29.5,
#    'windspeed': 17.3,
#    'winddir': 103.6,
#    'pressure': 1017.3,
#    'cloudcover': 41.6,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:09:09',
#    'sunriseEpoch': 1577898549,
#    'sunset': '18:00:51',
#    'sunsetEpoch': 1577937651,
#    'moonphase': 0.17,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['91176022519',
#     'PHNL',
#     'PHNG',
#     '91178022551',
#     '91182022521',
#     '91170022508'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-02',
#    'datetimeEpoch': 1577959200,
#    'tempmax': 26.5,
#    'tempmin': 21.0,
#    'temp': 23.6,
#    'feelslikemax': 26.5,
#    'feelslikemin': 21.0,
#    'feelslike': 23.6,
#    'dew': 18.4,
#    'humidity': 73.26,
#    'precip': 2.58,
#    'precipprob': None,
#    'precipcover': 41.67,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 29.5,
#    'windspeed': 19.3,
#    'winddir': 147.5,
#    'pressure': 1016.9,
#    'cloudcover': 49.9,
#    'visibility': 15.6,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:09:28',
#    'sunriseEpoch': 1577984968,
#    'sunset': '18:01:29',
#    'sunsetEpoch': 1578024089,
#    'moonphase': 0.22,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['91176022519',
#     'PHNL',
#     'PHNG',
#     '91178022551',
#     '91182022521',
#     '91170022508'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-03',
#    'datetimeEpoch': 1578045600,
#    'tempmax': 26.8,
#    'tempmin': 21.8,
#    'temp': 24.0,
#    'feelslikemax': 27.8,
#    'feelslikemin': 21.8,
#    'feelslike': 24.0,
#    'dew': 18.9,
#    'humidity': 74.01,
#    'precip': 4.39,
#    'precipprob': None,
#    'precipcover': 45.83,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 51.8,
#    'windspeed': 32.6,
#    'winddir': 66.6,
#    'pressure': 1020.2,
#    'cloudcover': 61.6,
#    'visibility': 15.7,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:09:45',
#    'sunriseEpoch': 1578071385,
#    'sunset': '18:02:08',
#    'sunsetEpoch': 1578110528,
#    'moonphase': 0.26,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['91176022519',
#     'PHNL',
#     'PHNG',
#     '91178022551',
#     '91182022521',
#     '91170022508'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-04',
#    'datetimeEpoch': 1578132000,
#    'tempmax': 28.1,
#    'tempmin': 22.8,
#    'temp': 24.3,
#    'feelslikemax': 30.9,
#    'feelslikemin': 22.8,
#    'feelslike': 24.7,
#    'dew': 21.1,
#    'humidity': 82.38,
#    'precip': 6.97,
#    'precipprob': None,
#    'precipcover': 91.67,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 50.5,
#    'windspeed': 32.9,
#    'winddir': 60.5,
#    'pressure': 1021.7,
#    'cloudcover': 63.6,
#    'visibility': 14.5,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:10:01',
#    'sunriseEpoch': 1578157801,
#    'sunset': '18:02:46',
#    'sunsetEpoch': 1578196966,
#    'moonphase': 0.31,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['91176022519',
#     'PHNL',
#     'PHNG',
#     '91178022551',
#     '91182022521',
#     '91170022508'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-05',
#    'datetimeEpoch': 1578218400,
#    'tempmax': 27.5,
#    'tempmin': 22.9,
#    'temp': 24.7,
#    'feelslikemax': 28.6,
#    'feelslikemin': 22.9,
#    'feelslike': 24.9,
#    'dew': 19.4,
#    'humidity': 73.04,
#    'precip': 5.64,
#    'precipprob': None,
#    'precipcover': 33.33,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 43.5,
#    'windspeed': 29.7,
#    'winddir': 68.8,
#    'pressure': 1021.1,
#    'cloudcover': 45.1,
#    'visibility': 15.9,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:10:16',
#    'sunriseEpoch': 1578244216,
#    'sunset': '18:03:26',
#    'sunsetEpoch': 1578283406,
#    'moonphase': 0.36,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['91176022519',
#     'PHNL',
#     'PHNG',
#     '91178022551',
#     '91182022521',
#     '91170022508'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-06',
#    'datetimeEpoch': 1578304800,
#    'tempmax': 27.5,
#    'tempmin': 23.3,
#    'temp': 24.9,
#    'feelslikemax': 28.1,
#    'feelslikemin': 23.3,
#    'feelslike': 25.0,
#    'dew': 18.0,
#    'humidity': 65.84,
#    'precip': 1.74,
#    'precipprob': None,
#    'precipcover': 33.33,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 57.4,
#    'windspeed': 31.1,
#    'winddir': 64.8,
#    'pressure': 1020.2,
#    'cloudcover': 46.9,
#    'visibility': 15.9,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:10:30',
#    'sunriseEpoch': 1578330630,
#    'sunset': '18:04:05',
#    'sunsetEpoch': 1578369845,
#    'moonphase': 0.4,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['91176022519',
#     'PHNL',
#     'PHNG',
#     '91178022551',
#     '91182022521',
#     '91170022508'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-07',
#    'datetimeEpoch': 1578391200,
#    'tempmax': 27.3,
#    'tempmin': 23.0,
#    'temp': 24.7,
#    'feelslikemax': 27.9,
#    'feelslikemin': 23.0,
#    'feelslike': 24.7,
#    'dew': 17.6,
#    'humidity': 65.15,
#    'precip': 0.13,
#    'precipprob': None,
#    'precipcover': 20.83,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 72.4,
#    'windspeed': 48.3,
#    'winddir': 61.4,
#    'pressure': 1019.6,
#    'cloudcover': 50.8,
#    'visibility': 15.9,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:10:43',
#    'sunriseEpoch': 1578417043,
#    'sunset': '18:04:45',
#    'sunsetEpoch': 1578456285,
#    'moonphase': 0.44,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['91176022519',
#     'PHNL',
#     'PHNG',
#     '91178022551',
#     '91182022521',
#     '91170022508'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-08',
#    'datetimeEpoch': 1578477600,
#    'tempmax': 27.0,
#    'tempmin': 21.9,
#    'temp': 24.1,
#    'feelslikemax': 27.5,
#    'feelslikemin': 21.9,
#    'feelslike': 24.2,
#    'dew': 17.1,
#    'humidity': 65.12,
#    'precip': 0.39,
#    'precipprob': None,
#    'precipcover': 33.33,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 55.3,
#    'windspeed': 36.5,
#    'winddir': 60.0,
#    'pressure': 1017.5,
#    'cloudcover': 50.4,
#    'visibility': 15.7,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:10:54',
#    'sunriseEpoch': 1578503454,
#    'sunset': '18:05:25',
#    'sunsetEpoch': 1578542725,
#    'moonphase': 0.47,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['91176022519',
#     'PHNL',
#     'PHNG',
#     '91178022551',
#     '91182022521',
#     '91170022508'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-09',
#    'datetimeEpoch': 1578564000,
#    'tempmax': 26.0,
#    'tempmin': 21.9,
#    'temp': 23.7,
#    'feelslikemax': 26.0,
#    'feelslikemin': 21.9,
#    'feelslike': 23.7,
#    'dew': 18.0,
#    'humidity': 70.69,
#    'precip': 1.59,
#    'precipprob': None,
#    'precipcover': 62.5,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 64.5,
#    'windspeed': 41.8,
#    'winddir': 63.9,
#    'pressure': 1016.0,
#    'cloudcover': 57.6,
#    'visibility': 15.5,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:11:04',
#    'sunriseEpoch': 1578589864,
#    'sunset': '18:06:05',
#    'sunsetEpoch': 1578629165,
#    'moonphase': 0.49,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['91176022519',
#     'PHNL',
#     'PHNG',
#     '91178022551',
#     '91182022521',
#     '91170022508'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-10',
#    'datetimeEpoch': 1578650400,
#    'tempmax': 26.4,
#    'tempmin': 22.3,
#    'temp': 24.0,
#    'feelslikemax': 26.4,
#    'feelslikemin': 22.3,
#    'feelslike': 24.0,
#    'dew': 19.4,
#    'humidity': 75.3,
#    'precip': 4.83,
#    'precipprob': None,
#    'precipcover': 91.67,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 53.2,
#    'windspeed': 35.0,
#    'winddir': 66.0,
#    'pressure': 1013.9,
#    'cloudcover': 65.8,
#    'visibility': 15.3,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:11:13',
#    'sunriseEpoch': 1578676273,
#    'sunset': '18:06:46',
#    'sunsetEpoch': 1578715606,
#    'moonphase': 0.5,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['91176022519',
#     'PHNL',
#     'PHNG',
#     '91178022551',
#     '91182022521',
#     '91170022508'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-11',
#    'datetimeEpoch': 1578736800,
#    'tempmax': 26.5,
#    'tempmin': 23.1,
#    'temp': 24.4,
#    'feelslikemax': 26.5,
#    'feelslikemin': 23.1,
#    'feelslike': 24.4,
#    'dew': 19.8,
#    'humidity': 76.13,
#    'precip': 6.01,
#    'precipprob': None,
#    'precipcover': 70.83,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 64.8,
#    'windspeed': 34.0,
#    'winddir': 69.7,
#    'pressure': 1012.5,
#    'cloudcover': 69.9,
#    'visibility': 15.8,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:11:20',
#    'sunriseEpoch': 1578762680,
#    'sunset': '18:07:27',
#    'sunsetEpoch': 1578802047,
#    'moonphase': 0.51,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['91176022519',
#     'PHNL',
#     'PHNG',
#     '91178022551',
#     '91182022521',
#     '91170022508'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-12',
#    'datetimeEpoch': 1578823200,
#    'tempmax': 24.3,
#    'tempmin': 22.9,
#    'temp': 23.8,
#    'feelslikemax': 24.3,
#    'feelslikemin': 22.9,
#    'feelslike': 23.8,
#    'dew': 20.6,
#    'humidity': 82.28,
#    'precip': 10.94,
#    'precipprob': None,
#    'precipcover': 62.5,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 57.4,
#    'windspeed': 31.8,
#    'winddir': 76.1,
#    'pressure': 1013.3,
#    'cloudcover': 69.2,
#    'visibility': 14.9,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:11:27',
#    'sunriseEpoch': 1578849087,
#    'sunset': '18:08:08',
#    'sunsetEpoch': 1578888488,
#    'moonphase': 0.52,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['91176022519',
#     'PHNL',
#     'PHNG',
#     '91178022551',
#     '91182022521',
#     '91170022508'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-13',
#    'datetimeEpoch': 1578909600,
#    'tempmax': 26.4,
#    'tempmin': 23.9,
#    'temp': 25.1,
#    'feelslikemax': 26.4,
#    'feelslikemin': 23.9,
#    'feelslike': 25.2,
#    'dew': 19.4,
#    'humidity': 70.77,
#    'precip': 0.27,
#    'precipprob': None,
#    'precipcover': 4.17,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 52.6,
#    'windspeed': 31.4,
#    'winddir': 71.5,
#    'pressure': 1014.8,
#    'cloudcover': 71.5,
#    'visibility': 15.4,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:11:31',
#    'sunriseEpoch': 1578935491,
#    'sunset': '18:08:49',
#    'sunsetEpoch': 1578974929,
#    'moonphase': 0.55,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['91176022519',
#     'PHNL',
#     'PHNG',
#     '91178022551',
#     '91182022521',
#     '91170022508'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-14',
#    'datetimeEpoch': 1578996000,
#    'tempmax': 26.4,
#    'tempmin': 23.4,
#    'temp': 24.7,
#    'feelslikemax': 26.4,
#    'feelslikemin': 23.4,
#    'feelslike': 24.8,
#    'dew': 18.4,
#    'humidity': 68.16,
#    'precip': 0.06,
#    'precipprob': None,
#    'precipcover': 4.17,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 59.4,
#    'windspeed': 30.9,
#    'winddir': 67.8,
#    'pressure': 1015.1,
#    'cloudcover': 63.2,
#    'visibility': 15.9,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:11:35',
#    'sunriseEpoch': 1579021895,
#    'sunset': '18:09:30',
#    'sunsetEpoch': 1579061370,
#    'moonphase': 0.59,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['91176022519',
#     'PHNL',
#     'PHNG',
#     '91178022551',
#     '91182022521',
#     '91170022508'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-15',
#    'datetimeEpoch': 1579082400,
#    'tempmax': 26.8,
#    'tempmin': 22.8,
#    'temp': 24.4,
#    'feelslikemax': 27.9,
#    'feelslikemin': 22.8,
#    'feelslike': 24.5,
#    'dew': 18.6,
#    'humidity': 70.66,
#    'precip': 0.22,
#    'precipprob': None,
#    'precipcover': 16.67,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 46.2,
#    'windspeed': 30.3,
#    'winddir': 67.6,
#    'pressure': 1013.6,
#    'cloudcover': 67.5,
#    'visibility': 15.7,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:11:37',
#    'sunriseEpoch': 1579108297,
#    'sunset': '18:10:11',
#    'sunsetEpoch': 1579147811,
#    'moonphase': 0.64,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['91176022519',
#     'PHNL',
#     'PHNG',
#     '91178022551',
#     '91182022521',
#     '91170022508'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-16',
#    'datetimeEpoch': 1579168800,
#    'tempmax': 26.2,
#    'tempmin': 21.3,
#    'temp': 23.5,
#    'feelslikemax': 26.2,
#    'feelslikemin': 21.3,
#    'feelslike': 23.5,
#    'dew': 19.1,
#    'humidity': 76.54,
#    'precip': 1.9,
#    'precipprob': None,
#    'precipcover': 20.83,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 25.9,
#    'windspeed': 13.5,
#    'winddir': 100.5,
#    'pressure': 1011.5,
#    'cloudcover': 56.5,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:11:38',
#    'sunriseEpoch': 1579194698,
#    'sunset': '18:10:52',
#    'sunsetEpoch': 1579234252,
#    'moonphase': 0.69,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['91176022519',
#     'PHNL',
#     'PHNG',
#     '91178022551',
#     '91182022521',
#     '91170022508'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-17',
#    'datetimeEpoch': 1579255200,
#    'tempmax': 25.8,
#    'tempmin': 21.2,
#    'temp': 23.2,
#    'feelslikemax': 25.8,
#    'feelslikemin': 21.2,
#    'feelslike': 23.3,
#    'dew': 17.5,
#    'humidity': 70.94,
#    'precip': 0.24,
#    'precipprob': None,
#    'precipcover': 16.67,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 46.2,
#    'windspeed': 27.0,
#    'winddir': 136.1,
#    'pressure': 1013.6,
#    'cloudcover': 45.2,
#    'visibility': 15.8,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:11:37',
#    'sunriseEpoch': 1579281097,
#    'sunset': '18:11:33',
#    'sunsetEpoch': 1579320693,
#    'moonphase': 0.75,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['91176022519',
#     'PHNL',
#     'PHNG',
#     '91178022551',
#     '91182022521',
#     '91170022508'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-18',
#    'datetimeEpoch': 1579341600,
#    'tempmax': 26.2,
#    'tempmin': 21.1,
#    'temp': 23.3,
#    'feelslikemax': 26.2,
#    'feelslikemin': 21.1,
#    'feelslike': 23.3,
#    'dew': 14.3,
#    'humidity': 57.35,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 46.4,
#    'windspeed': 27.7,
#    'winddir': 35.1,
#    'pressure': 1017.2,
#    'cloudcover': 53.8,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:11:35',
#    'sunriseEpoch': 1579367495,
#    'sunset': '18:12:14',
#    'sunsetEpoch': 1579407134,
#    'moonphase': 0.81,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['91176022519',
#     'PHNL',
#     'PHNG',
#     '91178022551',
#     '91182022521',
#     '91170022508'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-19',
#    'datetimeEpoch': 1579428000,
#    'tempmax': 26.8,
#    'tempmin': 21.5,
#    'temp': 23.7,
#    'feelslikemax': 26.9,
#    'feelslikemin': 21.5,
#    'feelslike': 23.7,
#    'dew': 14.5,
#    'humidity': 56.83,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 44.9,
#    'windspeed': 28.8,
#    'winddir': 51.3,
#    'pressure': 1019.0,
#    'cloudcover': 51.1,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:11:32',
#    'sunriseEpoch': 1579453892,
#    'sunset': '18:12:55',
#    'sunsetEpoch': 1579493575,
#    'moonphase': 0.86,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['91176022519',
#     'PHNL',
#     'PHNG',
#     '91178022551',
#     '91182022521',
#     '91170022508'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-20',
#    'datetimeEpoch': 1579514400,
#    'tempmax': 26.8,
#    'tempmin': 21.7,
#    'temp': 23.9,
#    'feelslikemax': 27.8,
#    'feelslikemin': 21.7,
#    'feelslike': 24.0,
#    'dew': 17.8,
#    'humidity': 68.89,
#    'precip': 0.56,
#    'precipprob': None,
#    'precipcover': 25.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 35.3,
#    'windspeed': 24.3,
#    'winddir': 58.5,
#    'pressure': 1019.4,
#    'cloudcover': 49.3,
#    'visibility': 15.6,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:11:28',
#    'sunriseEpoch': 1579540288,
#    'sunset': '18:13:36',
#    'sunsetEpoch': 1579580016,
#    'moonphase': 0.91,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['91176022519',
#     'PHNL',
#     'PHNG',
#     '91178022551',
#     '91182022521',
#     '91170022508'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-21',
#    'datetimeEpoch': 1579600800,
#    'tempmax': 26.7,
#    'tempmin': 19.2,
#    'temp': 23.2,
#    'feelslikemax': 27.4,
#    'feelslikemin': 19.2,
#    'feelslike': 23.2,
#    'dew': 16.7,
#    'humidity': 67.85,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 29.5,
#    'windspeed': 15.8,
#    'winddir': 183.0,
#    'pressure': 1018.9,
#    'cloudcover': 31.9,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:11:22',
#    'sunriseEpoch': 1579626682,
#    'sunset': '18:14:16',
#    'sunsetEpoch': 1579666456,
#    'moonphase': 0.95,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['91176022519',
#     'PHNL',
#     'PHNG',
#     '91178022551',
#     '91182022521',
#     '91170022508'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-22',
#    'datetimeEpoch': 1579687200,
#    'tempmax': 26.5,
#    'tempmin': 18.5,
#    'temp': 22.4,
#    'feelslikemax': 26.5,
#    'feelslikemin': 18.5,
#    'feelslike': 22.4,
#    'dew': 16.4,
#    'humidity': 70.19,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 16.1,
#    'winddir': 218.0,
#    'pressure': 1017.7,
#    'cloudcover': 18.4,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:11:15',
#    'sunriseEpoch': 1579713075,
#    'sunset': '18:14:57',
#    'sunsetEpoch': 1579752897,
#    'moonphase': 0.98,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['91176022519',
#     'PHNL',
#     'PHNG',
#     '91178022551',
#     '91182022521',
#     '91170022508'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-23',
#    'datetimeEpoch': 1579773600,
#    'tempmax': 26.3,
#    'tempmin': 17.7,
#    'temp': 22.2,
#    'feelslikemax': 26.3,
#    'feelslikemin': 17.7,
#    'feelslike': 22.2,
#    'dew': 16.1,
#    'humidity': 69.17,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 14.2,
#    'winddir': 252.8,
#    'pressure': 1016.7,
#    'cloudcover': 13.0,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:11:06',
#    'sunriseEpoch': 1579799466,
#    'sunset': '18:15:37',
#    'sunsetEpoch': 1579839337,
#    'moonphase': 0.99,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['91176022519',
#     'PHNL',
#     'PHNG',
#     '91178022551',
#     '91182022521',
#     '91170022508'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-24',
#    'datetimeEpoch': 1579860000,
#    'tempmax': 26.6,
#    'tempmin': 18.5,
#    'temp': 23.0,
#    'feelslikemax': 26.6,
#    'feelslikemin': 18.5,
#    'feelslike': 23.0,
#    'dew': 17.4,
#    'humidity': 71.53,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 16.5,
#    'winddir': 230.5,
#    'pressure': 1017.8,
#    'cloudcover': 33.4,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:10:56',
#    'sunriseEpoch': 1579885856,
#    'sunset': '18:16:17',
#    'sunsetEpoch': 1579925777,
#    'moonphase': 1.0,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['91176022519',
#     'PHNL',
#     'PHNG',
#     '91178022551',
#     '91182022521',
#     '91170022508'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-25',
#    'datetimeEpoch': 1579946400,
#    'tempmax': 28.0,
#    'tempmin': 20.8,
#    'temp': 23.9,
#    'feelslikemax': 28.7,
#    'feelslikemin': 20.8,
#    'feelslike': 24.1,
#    'dew': 17.9,
#    'humidity': 69.96,
#    'precip': 0.3,
#    'precipprob': None,
#    'precipcover': 8.33,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 29.5,
#    'windspeed': 17.9,
#    'winddir': 179.0,
#    'pressure': 1018.9,
#    'cloudcover': 47.3,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:10:45',
#    'sunriseEpoch': 1579972245,
#    'sunset': '18:16:57',
#    'sunsetEpoch': 1580012217,
#    'moonphase': 0.0,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['91176022519',
#     'PHNL',
#     'PHNG',
#     '91178022551',
#     '91182022521',
#     '91170022508'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-26',
#    'datetimeEpoch': 1580032800,
#    'tempmax': 28.4,
#    'tempmin': 20.8,
#    'temp': 24.3,
#    'feelslikemax': 28.9,
#    'feelslikemin': 20.8,
#    'feelslike': 24.4,
#    'dew': 17.5,
#    'humidity': 67.02,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 35.3,
#    'windspeed': 23.7,
#    'winddir': 158.4,
#    'pressure': 1019.3,
#    'cloudcover': 34.8,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:10:32',
#    'sunriseEpoch': 1580058632,
#    'sunset': '18:17:36',
#    'sunsetEpoch': 1580098656,
#    'moonphase': 0.01,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['91176022519',
#     'PHNL',
#     'PHNG',
#     '91178022551',
#     '91182022521',
#     '91170022508'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-27',
#    'datetimeEpoch': 1580119200,
#    'tempmax': 27.5,
#    'tempmin': 20.2,
#    'temp': 23.7,
#    'feelslikemax': 28.0,
#    'feelslikemin': 20.2,
#    'feelslike': 23.9,
#    'dew': 16.7,
#    'humidity': 65.89,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 35.3,
#    'windspeed': 21.7,
#    'winddir': 97.8,
#    'pressure': 1019.7,
#    'cloudcover': 35.5,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:10:18',
#    'sunriseEpoch': 1580145018,
#    'sunset': '18:18:15',
#    'sunsetEpoch': 1580185095,
#    'moonphase': 0.03,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['91176022519',
#     'PHNL',
#     'PHNG',
#     '91178022551',
#     '91182022521',
#     '91170022508'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-28',
#    'datetimeEpoch': 1580205600,
#    'tempmax': 27.8,
#    'tempmin': 18.3,
#    'temp': 23.0,
#    'feelslikemax': 28.2,
#    'feelslikemin': 18.3,
#    'feelslike': 23.2,
#    'dew': 16.9,
#    'humidity': 69.32,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 18.8,
#    'winddir': 195.0,
#    'pressure': 1019.0,
#    'cloudcover': 37.3,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:10:03',
#    'sunriseEpoch': 1580231403,
#    'sunset': '18:18:54',
#    'sunsetEpoch': 1580271534,
#    'moonphase': 0.06,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['91176022519',
#     'PHNL',
#     'PHNG',
#     '91178022551',
#     '91182022521',
#     '91170022508'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-29',
#    'datetimeEpoch': 1580292000,
#    'tempmax': 27.6,
#    'tempmin': 19.8,
#    'temp': 24.0,
#    'feelslikemax': 28.5,
#    'feelslikemin': 19.8,
#    'feelslike': 24.2,
#    'dew': 17.5,
#    'humidity': 67.58,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 19.2,
#    'winddir': 201.8,
#    'pressure': 1017.6,
#    'cloudcover': 39.2,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:09:47',
#    'sunriseEpoch': 1580317787,
#    'sunset': '18:19:33',
#    'sunsetEpoch': 1580357973,
#    'moonphase': 0.09,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['91176022519',
#     'PHNL',
#     'PHNG',
#     '91178022551',
#     '91182022521',
#     '91170022508'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-30',
#    'datetimeEpoch': 1580378400,
#    'tempmax': 27.6,
#    'tempmin': 20.3,
#    'temp': 23.8,
#    'feelslikemax': 28.4,
#    'feelslikemin': 20.3,
#    'feelslike': 24.0,
#    'dew': 17.1,
#    'humidity': 66.62,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 19.1,
#    'winddir': 206.5,
#    'pressure': 1017.2,
#    'cloudcover': 34.8,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:09:29',
#    'sunriseEpoch': 1580404169,
#    'sunset': '18:20:11',
#    'sunsetEpoch': 1580444411,
#    'moonphase': 0.13,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['91176022519',
#     'PHNL',
#     'PHNG',
#     '91178022551',
#     '91182022521',
#     '91170022508'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-31',
#    'datetimeEpoch': 1580464800,
#    'tempmax': 27.8,
#    'tempmin': 20.6,
#    'temp': 23.9,
#    'feelslikemax': 27.8,
#    'feelslikemin': 20.6,
#    'feelslike': 24.0,
#    'dew': 16.9,
#    'humidity': 65.9,
#    'precip': 0.4,
#    'precipprob': None,
#    'precipcover': 8.33,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 27.7,
#    'windspeed': 17.9,
#    'winddir': 174.3,
#    'pressure': 1017.5,
#    'cloudcover': 50.4,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:09:10',
#    'sunriseEpoch': 1580490550,
#    'sunset': '18:20:49',
#    'sunsetEpoch': 1580530849,
#    'moonphase': 0.18,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['91176022519',
#     'PHNL',
#     'PHNG',
#     '91178022551',
#     '91182022521',
#     '91170022508'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-01',
#    'datetimeEpoch': 1580551200,
#    'tempmax': 27.9,
#    'tempmin': 21.7,
#    'temp': 23.7,
#    'feelslikemax': 28.3,
#    'feelslikemin': 21.7,
#    'feelslike': 23.7,
#    'dew': 17.4,
#    'humidity': 68.11,
#    'precip': 0.66,
#    'precipprob': None,
#    'precipcover': 25.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 42.5,
#    'windspeed': 26.9,
#    'winddir': 93.0,
#    'pressure': 1017.5,
#    'cloudcover': 56.1,
#    'visibility': 15.8,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:08:50',
#    'sunriseEpoch': 1580576930,
#    'sunset': '18:21:26',
#    'sunsetEpoch': 1580617286,
#    'moonphase': 0.22,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['91176022519',
#     'PHNL',
#     'PHNG',
#     '91178022551',
#     '91182022521',
#     '91170022508'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-02',
#    'datetimeEpoch': 1580637600,
#    'tempmax': 27.7,
#    'tempmin': 19.2,
#    'temp': 23.3,
#    'feelslikemax': 28.2,
#    'feelslikemin': 19.2,
#    'feelslike': 23.4,
#    'dew': 16.8,
#    'humidity': 67.9,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 38.9,
#    'windspeed': 22.7,
#    'winddir': 149.0,
#    'pressure': 1016.0,
#    'cloudcover': 37.3,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:08:28',
#    'sunriseEpoch': 1580663308,
#    'sunset': '18:22:03',
#    'sunsetEpoch': 1580703723,
#    'moonphase': 0.27,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['91176022519',
#     'PHNL',
#     'PHNG',
#     '91178022551',
#     '91182022521',
#     '91170022508'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-03',
#    'datetimeEpoch': 1580724000,
#    'tempmax': 27.8,
#    'tempmin': 21.8,
#    'temp': 24.5,
#    'feelslikemax': 28.7,
#    'feelslikemin': 21.8,
#    'feelslike': 24.7,
#    'dew': 17.0,
#    'humidity': 63.37,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 36.1,
#    'windspeed': 23.3,
#    'winddir': 86.7,
#    'pressure': 1015.5,
#    'cloudcover': 36.5,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:08:05',
#    'sunriseEpoch': 1580749685,
#    'sunset': '18:22:39',
#    'sunsetEpoch': 1580790159,
#    'moonphase': 0.32,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['91176022519',
#     'PHNL',
#     'PHNG',
#     '91178022551',
#     '91182022521',
#     '91170022508'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-04',
#    'datetimeEpoch': 1580810400,
#    'tempmax': 27.0,
#    'tempmin': 19.8,
#    'temp': 23.3,
#    'feelslikemax': 28.1,
#    'feelslikemin': 19.8,
#    'feelslike': 23.4,
#    'dew': 17.9,
#    'humidity': 72.07,
#    'precip': 0.46,
#    'precipprob': None,
#    'precipcover': 4.17,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 17.4,
#    'winddir': 198.3,
#    'pressure': 1015.4,
#    'cloudcover': 36.0,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:07:41',
#    'sunriseEpoch': 1580836061,
#    'sunset': '18:23:16',
#    'sunsetEpoch': 1580876596,
#    'moonphase': 0.37,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['91176022519',
#     'PHNL',
#     'PHNG',
#     '91178022551',
#     '91182022521',
#     '91170022508'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-05',
#    'datetimeEpoch': 1580896800,
#    'tempmax': 25.5,
#    'tempmin': 20.2,
#    'temp': 22.6,
#    'feelslikemax': 25.5,
#    'feelslikemin': 20.2,
#    'feelslike': 22.6,
#    'dew': 18.4,
#    'humidity': 77.6,
#    'precip': 9.9,
#    'precipprob': None,
#    'precipcover': 54.17,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 27.7,
#    'windspeed': 18.0,
#    'winddir': 185.1,
#    'pressure': 1013.9,
#    'cloudcover': 53.5,
#    'visibility': 15.7,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:07:16',
#    'sunriseEpoch': 1580922436,
#    'sunset': '18:23:51',
#    'sunsetEpoch': 1580963031,
#    'moonphase': 0.41,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['91176022519',
#     'PHNL',
#     'PHNG',
#     '91178022551',
#     '91182022521',
#     '91170022508'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-06',
#    'datetimeEpoch': 1580983200,
#    'tempmax': 22.4,
#    'tempmin': 20.6,
#    'temp': 21.3,
#    'feelslikemax': 22.4,
#    'feelslikemin': 20.6,
#    'feelslike': 21.3,
#    'dew': 16.4,
#    'humidity': 74.09,
#    'precip': 5.46,
#    'precipprob': None,
#    'precipcover': 62.5,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 53.6,
#    'windspeed': 26.4,
#    'winddir': 192.0,
#    'pressure': 1012.1,
#    'cloudcover': 64.3,
#    'visibility': 15.3,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:06:50',
#    'sunriseEpoch': 1581008810,
#    'sunset': '18:24:26',
#    'sunsetEpoch': 1581049466,
#    'moonphase': 0.45,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['91176022519',
#     'PHNL',
#     'PHNG',
#     '91178022551',
#     '91182022521',
#     '91170022508'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-07',
#    'datetimeEpoch': 1581069600,
#    'tempmax': 24.5,
#    'tempmin': 17.4,
#    'temp': 20.7,
#    'feelslikemax': 24.5,
#    'feelslikemin': 17.4,
#    'feelslike': 20.7,
#    'dew': 12.8,
#    'humidity': 61.37,
#    'precip': 0.71,
#    'precipprob': None,
#    'precipcover': 25.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 44.6,
#    'windspeed': 24.2,
#    'winddir': 308.8,
#    'pressure': 1010.0,
#    'cloudcover': 37.2,
#    'visibility': 15.9,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:06:22',
#    'sunriseEpoch': 1581095182,
#    'sunset': '18:25:01',
#    'sunsetEpoch': 1581135901,
#    'moonphase': 0.48,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['91176022519',
#     'PHNL',
#     'PHNG',
#     '91178022551',
#     '91182022521',
#     '91170022508'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-08',
#    'datetimeEpoch': 1581156000,
#    'tempmax': 25.2,
#    'tempmin': 17.0,
#    'temp': 20.8,
#    'feelslikemax': 25.2,
#    'feelslikemin': 17.0,
#    'feelslike': 20.8,
#    'dew': 13.7,
#    'humidity': 66.11,
#    'precip': 1.44,
#    'precipprob': None,
#    'precipcover': 41.67,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 46.1,
#    'windspeed': 34.2,
#    'winddir': 299.4,
#    'pressure': 1011.0,
#    'cloudcover': 45.7,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:05:54',
#    'sunriseEpoch': 1581181554,
#    'sunset': '18:25:35',
#    'sunsetEpoch': 1581222335,
#    'moonphase': 0.5,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['91176022519',
#     'PHNL',
#     'PHNG',
#     '91178022551',
#     '91182022521',
#     '91170022508'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-09',
#    'datetimeEpoch': 1581242400,
#    'tempmax': 25.8,
#    'tempmin': 18.5,
#    'temp': 21.6,
#    'feelslikemax': 25.8,
#    'feelslikemin': 18.5,
#    'feelslike': 21.6,
#    'dew': 13.3,
#    'humidity': 60.54,
#    'precip': 2.41,
#    'precipprob': None,
#    'precipcover': 16.67,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 55.4,
#    'windspeed': 32.0,
#    'winddir': 295.9,
#    'pressure': 1011.5,
#    'cloudcover': 46.6,
#    'visibility': 15.6,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:05:24',
#    'sunriseEpoch': 1581267924,
#    'sunset': '18:26:09',
#    'sunsetEpoch': 1581308769,
#    'moonphase': 0.5,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['91176022519',
#     'PHNL',
#     'PHNG',
#     '91178022551',
#     '91182022521',
#     '91170022508'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-10',
#    'datetimeEpoch': 1581328800,
#    'tempmax': 22.7,
#    'tempmin': 16.6,
#    'temp': 19.5,
#    'feelslikemax': 22.7,
#    'feelslikemin': 16.6,
#    'feelslike': 19.5,
#    'dew': 14.7,
#    'humidity': 73.89,
#    'precip': 6.86,
#    'precipprob': None,
#    'precipcover': 70.83,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 52.5,
#    'windspeed': 36.7,
#    'winddir': 304.9,
#    'pressure': 1007.2,
#    'cloudcover': 52.0,
#    'visibility': 15.7,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:04:53',
#    'sunriseEpoch': 1581354293,
#    'sunset': '18:26:43',
#    'sunsetEpoch': 1581395203,
#    'moonphase': 0.52,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['91176022519',
#     'PHNL',
#     'PHNG',
#     '91178022551',
#     '91182022521',
#     '91170022508'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-11',
#    'datetimeEpoch': 1581415200,
#    'tempmax': 25.8,
#    'tempmin': 19.2,
#    'temp': 21.8,
#    'feelslikemax': 25.8,
#    'feelslikemin': 19.2,
#    'feelslike': 21.8,
#    'dew': 16.0,
#    'humidity': 70.58,
#    'precip': 0.61,
#    'precipprob': None,
#    'precipcover': 12.5,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 48.2,
#    'windspeed': 24.8,
#    'winddir': 229.7,
#    'pressure': 1008.2,
#    'cloudcover': 40.4,
#    'visibility': 15.9,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:04:21',
#    'sunriseEpoch': 1581440661,
#    'sunset': '18:27:15',
#    'sunsetEpoch': 1581481635,
#    'moonphase': 0.53,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['91176022519',
#     'PHNL',
#     'PHNG',
#     '91178022551',
#     '91182022521',
#     '91170022508'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-12',
#    'datetimeEpoch': 1581501600,
#    'tempmax': 27.2,
#    'tempmin': 18.5,
#    'temp': 22.6,
#    'feelslikemax': 27.9,
#    'feelslikemin': 18.5,
#    'feelslike': 22.7,
#    'dew': 17.4,
#    'humidity': 73.76,
#    'precip': 0.25,
#    'precipprob': None,
#    'precipcover': 4.17,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 38.9,
#    'windspeed': 25.7,
#    'winddir': 157.0,
#    'pressure': 1010.5,
#    'cloudcover': 37.7,
#    'visibility': 15.9,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:03:48',
#    'sunriseEpoch': 1581527028,
#    'sunset': '18:27:48',
#    'sunsetEpoch': 1581568068,
#    'moonphase': 0.57,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['91176022519',
#     'PHNL',
#     'PHNG',
#     '91178022551',
#     '91182022521',
#     '91170022508'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-13',
#    'datetimeEpoch': 1581588000,
#    'tempmax': 29.4,
#    'tempmin': 21.4,
#    'temp': 25.5,
#    'feelslikemax': 30.3,
#    'feelslikemin': 21.4,
#    'feelslike': 25.8,
#    'dew': 18.8,
#    'humidity': 67.38,
#    'precip': 0.58,
#    'precipprob': None,
#    'precipcover': 8.33,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 40.7,
#    'windspeed': 23.9,
#    'winddir': 98.2,
#    'pressure': 1013.8,
#    'cloudcover': 40.6,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:03:14',
#    'sunriseEpoch': 1581613394,
#    'sunset': '18:28:20',
#    'sunsetEpoch': 1581654500,
#    'moonphase': 0.62,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['91176022519',
#     'PHNL',
#     'PHNG',
#     '91178022551',
#     '91182022521',
#     '91170022508'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-14',
#    'datetimeEpoch': 1581674400,
#    'tempmax': 27.9,
#    'tempmin': 23.7,
#    'temp': 25.4,
#    'feelslikemax': 29.0,
#    'feelslikemin': 23.7,
#    'feelslike': 25.7,
#    'dew': 18.5,
#    'humidity': 66.2,
#    'precip': 0.2,
#    'precipprob': None,
#    'precipcover': 4.17,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 44.7,
#    'windspeed': 27.4,
#    'winddir': 71.8,
#    'pressure': 1015.3,
#    'cloudcover': 55.6,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:02:39',
#    'sunriseEpoch': 1581699759,
#    'sunset': '18:28:51',
#    'sunsetEpoch': 1581740931,
#    'moonphase': 0.67,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['91176022519',
#     'PHNL',
#     'PHNG',
#     '91178022551',
#     '91182022521',
#     '91170022508'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-15',
#    'datetimeEpoch': 1581760800,
#    'tempmax': 27.9,
#    'tempmin': 22.1,
#    'temp': 24.7,
#    'feelslikemax': 28.1,
#    'feelslikemin': 22.1,
#    'feelslike': 24.8,
#    'dew': 16.9,
#    'humidity': 62.85,
#    'precip': 0.04,
#    'precipprob': None,
#    'precipcover': 4.17,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 45.3,
#    'windspeed': 31.8,
#    'winddir': 64.0,
#    'pressure': 1016.3,
#    'cloudcover': 59.1,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:02:03',
#    'sunriseEpoch': 1581786123,
#    'sunset': '18:29:22',
#    'sunsetEpoch': 1581827362,
#    'moonphase': 0.73,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['91176022519',
#     'PHNL',
#     'PHNG',
#     '91178022551',
#     '91182022521',
#     '91170022508'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-16',
#    'datetimeEpoch': 1581847200,
#    'tempmax': 27.1,
#    'tempmin': 22.8,
#    'temp': 24.4,
#    'feelslikemax': 27.7,
#    'feelslikemin': 22.8,
#    'feelslike': 24.5,
#    'dew': 16.2,
#    'humidity': 60.54,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 48.9,
#    'windspeed': 34.3,
#    'winddir': 62.8,
#    'pressure': 1016.6,
#    'cloudcover': 58.4,
#    'visibility': 15.8,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:01:26',
#    'sunriseEpoch': 1581872486,
#    'sunset': '18:29:52',
#    'sunsetEpoch': 1581913792,
#    'moonphase': 0.78,
#    'conditions': 'Partially cloudy',
#    'icon': 'wind',
#    'stations': ['91176022519',
#     'PHNL',
#     'PHNG',
#     '91178022551',
#     '91182022521',
#     '91170022508'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-17',
#    'datetimeEpoch': 1581933600,
#    'tempmax': 26.6,
#    'tempmin': 22.0,
#    'temp': 23.9,
#    'feelslikemax': 26.6,
#    'feelslikemin': 22.0,
#    'feelslike': 23.9,
#    'dew': 16.4,
#    'humidity': 63.36,
#    'precip': 0.06,
#    'precipprob': None,
#    'precipcover': 16.67,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 44.9,
#    'windspeed': 31.5,
#    'winddir': 60.4,
#    'pressure': 1017.0,
#    'cloudcover': 57.0,
#    'visibility': 15.9,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:00:48',
#    'sunriseEpoch': 1581958848,
#    'sunset': '18:30:22',
#    'sunsetEpoch': 1582000222,
#    'moonphase': 0.84,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['91176022519',
#     'PHNL',
#     'PHNG',
#     '91178022551',
#     '91182022521',
#     '91170022508'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-18',
#    'datetimeEpoch': 1582020000,
#    'tempmax': 27.3,
#    'tempmin': 22.6,
#    'temp': 23.9,
#    'feelslikemax': 27.7,
#    'feelslikemin': 22.6,
#    'feelslike': 24.0,
#    'dew': 16.6,
#    'humidity': 64.1,
#    'precip': 0.21,
#    'precipprob': None,
#    'precipcover': 25.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 52.4,
#    'windspeed': 32.4,
#    'winddir': 57.5,
#    'pressure': 1018.7,
#    'cloudcover': 56.1,
#    'visibility': 15.2,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:00:09',
#    'sunriseEpoch': 1582045209,
#    'sunset': '18:30:52',
#    'sunsetEpoch': 1582086652,
#    'moonphase': 0.88,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['91176022519',
#     'PHNL',
#     'PHNG',
#     '91178022551',
#     '91182022521',
#     '91170022508'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-19',
#    'datetimeEpoch': 1582106400,
#    'tempmax': 26.9,
#    'tempmin': 21.7,
#    'temp': 23.6,
#    'feelslikemax': 27.6,
#    'feelslikemin': 21.7,
#    'feelslike': 23.6,
#    'dew': 17.9,
#    'humidity': 71.36,
#    'precip': 1.78,
#    'precipprob': None,
#    'precipcover': 66.67,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 63.0,
#    'windspeed': 39.8,
#    'winddir': 59.6,
#    'pressure': 1020.6,
#    'cloudcover': 65.7,
#    'visibility': 15.4,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:59:29',
#    'sunriseEpoch': 1582131569,
#    'sunset': '18:31:21',
#    'sunsetEpoch': 1582173081,
#    'moonphase': 0.93,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['91176022519',
#     'PHNL',
#     'PHNG',
#     '91178022551',
#     '91182022521',
#     '91170022508'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-20',
#    'datetimeEpoch': 1582192800,
#    'tempmax': 26.0,
#    'tempmin': 21.8,
#    'temp': 23.6,
#    'feelslikemax': 26.0,
#    'feelslikemin': 21.8,
#    'feelslike': 23.6,
#    'dew': 15.7,
#    'humidity': 61.65,
#    'precip': 0.51,
#    'precipprob': None,
#    'precipcover': 29.17,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 60.7,
#    'windspeed': 36.8,
#    'winddir': 62.5,
#    'pressure': 1021.6,
#    'cloudcover': 49.9,
#    'visibility': 15.9,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:58:48',
#    'sunriseEpoch': 1582217928,
#    'sunset': '18:31:49',
#    'sunsetEpoch': 1582259509,
#    'moonphase': 0.96,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['91176022519',
#     'PHNL',
#     'PHNG',
#     '91178022551',
#     '91182022521',
#     '91170022508'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-21',
#    'datetimeEpoch': 1582279200,
#    'tempmax': 27.3,
#    'tempmin': 21.6,
#    'temp': 24.0,
#    'feelslikemax': 27.5,
#    'feelslikemin': 21.6,
#    'feelslike': 24.1,
#    'dew': 16.2,
#    'humidity': 62.32,
#    'precip': 0.11,
#    'precipprob': None,
#    'precipcover': 8.33,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 48.2,
#    'windspeed': 31.2,
#    'winddir': 67.8,
#    'pressure': 1020.1,
#    'cloudcover': 53.7,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:58:07',
#    'sunriseEpoch': 1582304287,
#    'sunset': '18:32:17',
#    'sunsetEpoch': 1582345937,
#    'moonphase': 0.98,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['91176022519',
#     'PHNL',
#     'PHNG',
#     '91178022551',
#     '91182022521',
#     '91170022508'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-22',
#    'datetimeEpoch': 1582365600,
#    'tempmax': 27.4,
#    'tempmin': 19.8,
#    'temp': 23.6,
#    'feelslikemax': 27.9,
#    'feelslikemin': 19.8,
#    'feelslike': 23.6,
#    'dew': 16.8,
#    'humidity': 66.43,
#    'precip': 0.13,
#    'precipprob': None,
#    'precipcover': 8.33,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 29.5,
#    'windspeed': 22.8,
#    'winddir': 114.0,
#    'pressure': 1019.1,
#    'cloudcover': 42.5,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:57:24',
#    'sunriseEpoch': 1582390644,
#    'sunset': '18:32:44',
#    'sunsetEpoch': 1582432364,
#    'moonphase': 1.0,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['91176022519',
#     'PHNL',
#     'PHNG',
#     '91178022551',
#     '91182022521',
#     '91170022508'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-23',
#    'datetimeEpoch': 1582452000,
#    'tempmax': 27.6,
#    'tempmin': 19.7,
#    'temp': 23.4,
#    'feelslikemax': 28.5,
#    'feelslikemin': 19.7,
#    'feelslike': 23.5,
#    'dew': 17.2,
#    'humidity': 69.07,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 23.9,
#    'winddir': 263.6,
#    'pressure': 1019.2,
#    'cloudcover': 42.2,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:56:41',
#    'sunriseEpoch': 1582477001,
#    'sunset': '18:33:12',
#    'sunsetEpoch': 1582518792,
#    'moonphase': 1.0,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['91176022519',
#     'PHNL',
#     'PHNG',
#     '91178022551',
#     '91182022521',
#     '91170022508'],
# ...
#    'temp': 25.3,
#    'feelslikemax': 30.2,
#    'feelslikemin': 21.8,
#    'feelslike': 25.7,
#    'dew': 19.0,
#    'humidity': 68.61,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 35.3,
#    'windspeed': 21.8,
#    'winddir': 82.0,
#    'pressure': 1015.4,
#    'cloudcover': 53.5,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:01:47',
#    'sunriseEpoch': 1608051707,
#    'sunset': '17:52:15',
#    'sunsetEpoch': 1608090735,
#    'moonphase': 0.0,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['91176022519',
#     'PHNL',
#     'PHNG',
#     '91178022551',
#     '91182022521',
#     '91170022508'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-16',
#    'datetimeEpoch': 1608112800,
#    'tempmax': 28.4,
#    'tempmin': 22.9,
#    'temp': 25.2,
#    'feelslikemax': 29.7,
#    'feelslikemin': 22.9,
#    'feelslike': 25.6,
#    'dew': 19.3,
#    'humidity': 70.35,
#    'precip': 0.02,
#    'precipprob': None,
#    'precipcover': 4.17,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 38.9,
#    'windspeed': 26.1,
#    'winddir': 52.8,
#    'pressure': 1014.9,
#    'cloudcover': 46.0,
#    'visibility': 15.9,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:02:20',
#    'sunriseEpoch': 1608138140,
#    'sunset': '17:52:40',
#    'sunsetEpoch': 1608177160,
#    'moonphase': 0.02,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['91176022519',
#     'PHNL',
#     'PHNG',
#     '91178022551',
#     '91182022521',
#     '91170022508'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-17',
#    'datetimeEpoch': 1608199200,
#    'tempmax': 28.5,
#    'tempmin': 22.0,
#    'temp': 24.9,
#    'feelslikemax': 29.4,
#    'feelslikemin': 22.0,
#    'feelslike': 25.2,
#    'dew': 18.7,
#    'humidity': 68.92,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 33.5,
#    'windspeed': 24.5,
#    'winddir': 130.0,
#    'pressure': 1014.5,
#    'cloudcover': 38.9,
#    'visibility': 15.9,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:02:53',
#    'sunriseEpoch': 1608224573,
#    'sunset': '17:53:06',
#    'sunsetEpoch': 1608263586,
#    'moonphase': 0.05,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['91176022519',
#     'PHNL',
#     'PHNG',
#     '91178022551',
#     '91182022521',
#     '91170022508'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-18',
#    'datetimeEpoch': 1608285600,
#    'tempmax': 28.2,
#    'tempmin': 23.8,
#    'temp': 25.6,
#    'feelslikemax': 28.9,
#    'feelslikemin': 23.8,
#    'feelslike': 25.8,
#    'dew': 17.7,
#    'humidity': 62.21,
#    'precip': 0.02,
#    'precipprob': None,
#    'precipcover': 4.17,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 63.3,
#    'windspeed': 40.6,
#    'winddir': 64.5,
#    'pressure': 1015.8,
#    'cloudcover': 43.5,
#    'visibility': 15.9,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:03:25',
#    'sunriseEpoch': 1608311005,
#    'sunset': '17:53:33',
#    'sunsetEpoch': 1608350013,
#    'moonphase': 0.09,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['91176022519',
#     'PHNL',
#     'PHNG',
#     '91178022551',
#     '91182022521',
#     '91170022508'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-19',
#    'datetimeEpoch': 1608372000,
#    'tempmax': 28.5,
#    'tempmin': 23.1,
#    'temp': 25.5,
#    'feelslikemax': 29.6,
#    'feelslikemin': 23.1,
#    'feelslike': 25.9,
#    'dew': 18.9,
#    'humidity': 67.24,
#    'precip': 0.56,
#    'precipprob': None,
#    'precipcover': 12.5,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 49.6,
#    'windspeed': 34.1,
#    'winddir': 58.4,
#    'pressure': 1016.0,
#    'cloudcover': 49.9,
#    'visibility': 15.8,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:03:57',
#    'sunriseEpoch': 1608397437,
#    'sunset': '17:54:01',
#    'sunsetEpoch': 1608436441,
#    'moonphase': 0.13,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['91176022519', 'PHNL', 'PHNG', '91178022551', '91182022521'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-20',
#    'datetimeEpoch': 1608458400,
#    'tempmax': 28.2,
#    'tempmin': 23.9,
#    'temp': 25.7,
#    'feelslikemax': 29.7,
#    'feelslikemin': 23.9,
#    'feelslike': 26.1,
#    'dew': 19.3,
#    'humidity': 68.11,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 40.7,
#    'windspeed': 27.4,
#    'winddir': 55.5,
#    'pressure': 1016.0,
#    'cloudcover': 44.3,
#    'visibility': 15.8,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:04:28',
#    'sunriseEpoch': 1608483868,
#    'sunset': '17:54:30',
#    'sunsetEpoch': 1608522870,
#    'moonphase': 0.18,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['91176022519', 'PHNL', 'PHNG', '91178022551', '91182022521'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-21',
#    'datetimeEpoch': 1608544800,
#    'tempmax': 28.5,
#    'tempmin': 23.4,
#    'temp': 25.7,
#    'feelslikemax': 29.6,
#    'feelslikemin': 23.4,
#    'feelslike': 26.0,
#    'dew': 18.7,
#    'humidity': 65.9,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 40.7,
#    'windspeed': 31.3,
#    'winddir': 59.3,
#    'pressure': 1015.8,
#    'cloudcover': 41.2,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:04:58',
#    'sunriseEpoch': 1608570298,
#    'sunset': '17:55:00',
#    'sunsetEpoch': 1608609300,
#    'moonphase': 0.23,
#    'conditions': 'Partially cloudy',
#    'icon': 'wind',
#    'stations': ['91176022519',
#     'PHNL',
#     'PHNG',
#     '91178022551',
#     '91182022521',
#     '91170022508'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-22',
#    'datetimeEpoch': 1608631200,
#    'tempmax': 28.8,
#    'tempmin': 20.2,
#    'temp': 24.3,
#    'feelslikemax': 29.5,
#    'feelslikemin': 20.2,
#    'feelslike': 24.5,
#    'dew': 17.6,
#    'humidity': 67.56,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 17.8,
#    'winddir': 123.5,
#    'pressure': 1015.8,
#    'cloudcover': 26.3,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:05:27',
#    'sunriseEpoch': 1608656727,
#    'sunset': '17:55:31',
#    'sunsetEpoch': 1608695731,
#    'moonphase': 0.28,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['91176022519',
#     'PHNL',
#     'PHNG',
#     '91178022551',
#     '91182022521',
#     '91170022508'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-23',
#    'datetimeEpoch': 1608717600,
#    'tempmax': 27.5,
#    'tempmin': 19.4,
#    'temp': 23.5,
#    'feelslikemax': 28.4,
#    'feelslikemin': 19.4,
#    'feelslike': 23.6,
#    'dew': 17.8,
#    'humidity': 71.87,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 15.7,
#    'winddir': 275.5,
#    'pressure': 1016.8,
#    'cloudcover': 19.5,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:05:55',
#    'sunriseEpoch': 1608743155,
#    'sunset': '17:56:03',
#    'sunsetEpoch': 1608782163,
#    'moonphase': 0.32,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['91176022519',
#     'PHNL',
#     'PHNG',
#     '91178022551',
#     '91182022521',
#     '91170022508'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-24',
#    'datetimeEpoch': 1608804000,
#    'tempmax': 28.0,
#    'tempmin': 19.9,
#    'temp': 24.1,
#    'feelslikemax': 28.8,
#    'feelslikemin': 19.9,
#    'feelslike': 24.2,
#    'dew': 17.8,
#    'humidity': 69.06,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 31.7,
#    'windspeed': 22.1,
#    'winddir': 113.6,
#    'pressure': 1018.6,
#    'cloudcover': 38.1,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:06:22',
#    'sunriseEpoch': 1608829582,
#    'sunset': '17:56:35',
#    'sunsetEpoch': 1608868595,
#    'moonphase': 0.37,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['91176022519', 'PHNL', 'PHNG', '91178022551', '91182022521'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-25',
#    'datetimeEpoch': 1608890400,
#    'tempmax': 26.5,
#    'tempmin': 22.1,
#    'temp': 23.5,
#    'feelslikemax': 26.5,
#    'feelslikemin': 22.1,
#    'feelslike': 23.5,
#    'dew': 19.3,
#    'humidity': 77.86,
#    'precip': 1.96,
#    'precipprob': None,
#    'precipcover': 20.83,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 51.8,
#    'windspeed': 22.6,
#    'winddir': 138.2,
#    'pressure': 1019.8,
#    'cloudcover': 79.7,
#    'visibility': 14.7,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:06:49',
#    'sunriseEpoch': 1608916009,
#    'sunset': '17:57:09',
#    'sunsetEpoch': 1608955029,
#    'moonphase': 0.4,
#    'conditions': 'Rain, Overcast',
#    'icon': 'rain',
#    'stations': ['91176022519', 'PHNL', 'PHNG', '91178022551', '91182022521'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-26',
#    'datetimeEpoch': 1608976800,
#    'tempmax': 23.5,
#    'tempmin': 21.8,
#    'temp': 22.7,
#    'feelslikemax': 23.5,
#    'feelslikemin': 21.8,
#    'feelslike': 22.7,
#    'dew': 18.3,
#    'humidity': 77.0,
#    'precip': 3.54,
#    'precipprob': None,
#    'precipcover': 37.5,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 61.2,
#    'windspeed': 36.6,
#    'winddir': 76.2,
#    'pressure': 1019.6,
#    'cloudcover': 83.7,
#    'visibility': 14.4,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:07:14',
#    'sunriseEpoch': 1609002434,
#    'sunset': '17:57:43',
#    'sunsetEpoch': 1609041463,
#    'moonphase': 0.44,
#    'conditions': 'Rain, Overcast',
#    'icon': 'rain',
#    'stations': ['91176022519', 'PHNL', 'PHNG', '91178022551', '91182022521'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-27',
#    'datetimeEpoch': 1609063200,
#    'tempmax': 28.6,
#    'tempmin': 23.1,
#    'temp': 25.1,
#    'feelslikemax': 29.9,
#    'feelslikemin': 23.1,
#    'feelslike': 25.4,
#    'dew': 17.8,
#    'humidity': 64.14,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 46.0,
#    'windspeed': 26.2,
#    'winddir': 61.4,
#    'pressure': 1018.3,
#    'cloudcover': 41.9,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:07:38',
#    'sunriseEpoch': 1609088858,
#    'sunset': '17:58:17',
#    'sunsetEpoch': 1609127897,
#    'moonphase': 0.47,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['91176022519', 'PHNL', 'PHNG', '91178022551', '91182022521'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-28',
#    'datetimeEpoch': 1609149600,
#    'tempmax': 27.7,
#    'tempmin': 20.9,
#    'temp': 24.2,
#    'feelslikemax': 28.9,
#    'feelslikemin': 20.9,
#    'feelslike': 24.5,
#    'dew': 18.6,
#    'humidity': 71.86,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 14.0,
#    'winddir': 214.9,
#    'pressure': 1018.1,
#    'cloudcover': 42.8,
#    'visibility': 15.9,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:08:02',
#    'sunriseEpoch': 1609175282,
#    'sunset': '17:58:53',
#    'sunsetEpoch': 1609214333,
#    'moonphase': 0.49,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['91176022519',
#     'PHNL',
#     'PHNG',
#     '91178022551',
#     '91182022521',
#     '91170022508'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-29',
#    'datetimeEpoch': 1609236000,
#    'tempmax': 26.3,
#    'tempmin': 20.0,
#    'temp': 23.3,
#    'feelslikemax': 26.3,
#    'feelslikemin': 20.0,
#    'feelslike': 23.3,
#    'dew': 19.1,
#    'humidity': 77.83,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 31.7,
#    'windspeed': 15.8,
#    'winddir': 137.7,
#    'pressure': 1018.6,
#    'cloudcover': 59.3,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:08:24',
#    'sunriseEpoch': 1609261704,
#    'sunset': '17:59:29',
#    'sunsetEpoch': 1609300769,
#    'moonphase': 0.5,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['91176022519',
#     'PHNL',
#     'PHNG',
#     '91178022551',
#     '91182022521',
#     '91170022508'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-30',
#    'datetimeEpoch': 1609322400,
#    'tempmax': 28.4,
#    'tempmin': 21.0,
#    'temp': 24.5,
#    'feelslikemax': 28.8,
#    'feelslikemin': 21.0,
#    'feelslike': 24.6,
#    'dew': 17.5,
#    'humidity': 66.48,
#    'precip': 0.28,
#    'precipprob': None,
#    'precipcover': 8.33,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 36.1,
#    'windspeed': 24.4,
#    'winddir': 90.5,
#    'pressure': 1019.3,
#    'cloudcover': 52.0,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:08:45',
#    'sunriseEpoch': 1609348125,
#    'sunset': '18:00:06',
#    'sunsetEpoch': 1609387206,
#    'moonphase': 0.5,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['91176022519',
#     'PHNL',
#     'PHNG',
#     '91178022551',
#     '91182022521',
#     '91170022508'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-31',
#    'datetimeEpoch': 1609408800,
#    'tempmax': 27.3,
#    'tempmin': 23.2,
#    'temp': 24.6,
#    'feelslikemax': 27.8,
#    'feelslikemin': 23.2,
#    'feelslike': 24.7,
#    'dew': 17.4,
#    'humidity': 64.64,
#    'precip': 0.03,
#    'precipprob': None,
#    'precipcover': 8.33,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 46.4,
#    'windspeed': 29.6,
#    'winddir': 54.4,
#    'pressure': 1019.4,
#    'cloudcover': 51.8,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:09:05',
#    'sunriseEpoch': 1609434545,
#    'sunset': '18:00:43',
#    'sunsetEpoch': 1609473643,
#    'moonphase': 0.51,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['91176022519',
#     'PHNL',
#     'PHNG',
#     '91178022551',
#     '91182022521',
#     '91170022508'],
#    'source': 'obs',
#    'hours': None}],
#  'stations': {'91176022519': {'distance': 18701.0,
#    'latitude': 21.451,
#    'longitude': -157.768,
#    'useCount': 0,
#    'id': '91176022519',
#    'name': 'KANEOHE BAY MCAS, HI US',
#    'quality': 98,
#    'contribution': 0.0},
#   'PHNL': {'distance': 8997.0,
#    'latitude': 21.35,
#    'longitude': -157.93,
#    'useCount': 0,
#    'id': 'PHNL',
#    'name': 'HONOLULU INTL,HI',
#    'quality': 100,
#    'contribution': 0.0},
#   'PHNG': {'distance': 18550.0,
#    'latitude': 21.45,
#    'longitude': -157.77,
#    'useCount': 0,
#    'id': 'PHNG',
#    'name': 'PHNG',
#    'quality': 97,
#    'contribution': 0.0},
#   '91178022551': {'distance': 21715.0,
#    'latitude': 21.317,
#    'longitude': -158.067,
#    'useCount': 0,
#    'id': '91178022551',
#    'name': 'EWA KALAELOA AIRPORT, HI US',
#    'quality': 98,
#    'contribution': 0.0},
#   '91182022521': {'distance': 7664.0,
#    'latitude': 21.324,
#    'longitude': -157.929,
#    'useCount': 0,
#    'id': '91182022521',
#    'name': 'HONOLULU INTERNATIONAL AIRPORT, HI US',
#    'quality': 100,
#    'contribution': 0.0},
#   '91170022508': {'distance': 26876.0,
#    'latitude': 21.487,
#    'longitude': -158.028,
#    'useCount': 0,
#    'id': '91170022508',
#    'name': 'WHEELER ARMY AIR FIELD 810.1, HI US',
#    'quality': 99,
#    'contribution': 0.0}}}

# %%
#3. We create empty lists to transfer the data
temperature = []
temp_max = []
temp_min = []
humidity = []
precip = []
snow = []
windspeed = []
conditions = []
date = []
city = []

# %%
#4. We loop thropugh the API and extract the info we need
for x in range(366):
    temperature.append(response["days"][x]["temp"])
    temp_max.append(response["days"][x]["tempmax"])
    temp_min.append(response["days"][x]["tempmin"])
    humidity.append(response["days"][x]["humidity"])
    precip.append(response["days"][x]["precip"])
    snow.append(response["days"][x]["snow"])
    windspeed.append(response["days"][x]["windspeed"])
    conditions.append(response["days"][x]["conditions"])
    date.append(response["days"][x]["datetime"])
    city.append("Hawaii, HI")

# %%
print(len(temperature),len(temp_max),len(temp_min),len(humidity),len(precip),len(snow),len(windspeed),len(conditions),len(date),len(city))
# Out:
# 366 366 366 366 366 366 366 366 366 366

# %%
#5. We create a dataframe based on the lists
New_df = pd.DataFrame(
    {'City': city,
     'Date': date,
     'Temperature': temperature,
     'temp_max': temp_max,
     'temp_min':temp_min,
     'humidity':humidity,
     'precip':precip,
     'snow':snow,
     'windspeed':windspeed,
     'conditions': conditions
    })

# %%
New_df
# Out:
#            City        Date  Temperature  temp_max  temp_min  humidity  \
# 0    Hawaii, HI  2020-01-01         24.0      26.6      20.8     64.88
# 1    Hawaii, HI  2020-01-02         23.6      26.5      21.0     73.26
# 2    Hawaii, HI  2020-01-03         24.0      26.8      21.8     74.01
# 3    Hawaii, HI  2020-01-04         24.3      28.1      22.8     82.38
# 4    Hawaii, HI  2020-01-05         24.7      27.5      22.9     73.04
# ..          ...         ...          ...       ...       ...       ...
# 361  Hawaii, HI  2020-12-27         25.1      28.6      23.1     64.14
# 362  Hawaii, HI  2020-12-28         24.2      27.7      20.9     71.86
# 363  Hawaii, HI  2020-12-29         23.3      26.3      20.0     77.83
# 364  Hawaii, HI  2020-12-30         24.5      28.4      21.0     66.48
# 365  Hawaii, HI  2020-12-31         24.6      27.3      23.2     64.64
#
#      precip  snow  windspeed              conditions
# 0      0.00   0.0       17.3        Partially cloudy
# 1      2.58   0.0       19.3  Rain, Partially cloudy
# 2      4.39   0.0       32.6  Rain, Partially cloudy
# 3      6.97   0.0       32.9  Rain, Partially cloudy
# 4      5.64   0.0       29.7  Rain, Partially cloudy
# ..      ...   ...        ...                     ...
# 361    0.00   0.0       26.2        Partially cloudy
# 362    0.00   0.0       14.0        Partially cloudy
# 363    0.00   0.0       15.8        Partially cloudy
# 364    0.28   0.0       24.4  Rain, Partially cloudy
# 365    0.03   0.0       29.6  Rain, Partially cloudy
#
# [366 rows x 10 columns]

# %%
#6. We add new city dataframe to original dataframe including cities already evaluated 

frames = [Final_df,New_df]

# %%
Final_df = pd.concat(frames)

# %%
Final_df
# Out:
#              City        Date  Temperature  temp_max  temp_min  humidity  \
# 0    Montreal, QC  2020-01-01          0.2       1.1      -0.8     87.84
# 1    Montreal, QC  2020-01-02          0.9       2.6      -1.0     78.70
# 2    Montreal, QC  2020-01-03          4.8       5.8       2.8     74.88
# 3    Montreal, QC  2020-01-04          0.5       3.2      -1.9     78.79
# 4    Montreal, QC  2020-01-05         -5.3      -1.8      -9.9     69.09
# ..            ...         ...          ...       ...       ...       ...
# 361    Hawaii, HI  2020-12-27         25.1      28.6      23.1     64.14
# 362    Hawaii, HI  2020-12-28         24.2      27.7      20.9     71.86
# 363    Hawaii, HI  2020-12-29         23.3      26.3      20.0     77.83
# 364    Hawaii, HI  2020-12-30         24.5      28.4      21.0     66.48
# 365    Hawaii, HI  2020-12-31         24.6      27.3      23.2     64.64
#
#      precip  snow  windspeed              conditions
# 0      5.71  0.00        7.9                    Rain
# 1      0.00  0.00        7.7                   Clear
# 2      0.00  0.00        7.6                   Clear
# 3      2.27  0.00       11.2                    Rain
# 4      0.76  3.88       13.1                    Snow
# ..      ...   ...        ...                     ...
# 361    0.00  0.00       26.2        Partially cloudy
# 362    0.00  0.00       14.0        Partially cloudy
# 363    0.00  0.00       15.8        Partially cloudy
# 364    0.28  0.00       24.4  Rain, Partially cloudy
# 365    0.03  0.00       29.6  Rain, Partially cloudy
#
# [6222 rows x 10 columns]

# %%
#7.Update to csv by converting df to csv
Final_df.to_csv("Temperature_Dataset1.csv", index=False)

# %%
#8. Will need to import CSV with temp for cities already evaluated every time this document is open again for the 1st time. 
#Name dataframe: Final_df

file_path = os.path.join("Temperature_Dataset1.csv")
Final_df = pd.read_csv(file_path)
Final_df
# Out:
#               City        Date  Temperature  temp_max  temp_min  humidity  \
# 0     Montreal, QC  2020-01-01          0.2       1.1      -0.8     87.84
# 1     Montreal, QC  2020-01-02          0.9       2.6      -1.0     78.70
# 2     Montreal, QC  2020-01-03          4.8       5.8       2.8     74.88
# 3     Montreal, QC  2020-01-04          0.5       3.2      -1.9     78.79
# 4     Montreal, QC  2020-01-05         -5.3      -1.8      -9.9     69.09
# ...            ...         ...          ...       ...       ...       ...
# 6217    Hawaii, HI  2020-12-27         25.1      28.6      23.1     64.14
# 6218    Hawaii, HI  2020-12-28         24.2      27.7      20.9     71.86
# 6219    Hawaii, HI  2020-12-29         23.3      26.3      20.0     77.83
# 6220    Hawaii, HI  2020-12-30         24.5      28.4      21.0     66.48
# 6221    Hawaii, HI  2020-12-31         24.6      27.3      23.2     64.64
#
#       precip  snow  windspeed              conditions
# 0       5.71  0.00        7.9                    Rain
# 1       0.00  0.00        7.7                   Clear
# 2       0.00  0.00        7.6                   Clear
# 3       2.27  0.00       11.2                    Rain
# 4       0.76  3.88       13.1                    Snow
# ...      ...   ...        ...                     ...
# 6217    0.00  0.00       26.2        Partially cloudy
# 6218    0.00  0.00       14.0        Partially cloudy
# 6219    0.00  0.00       15.8        Partially cloudy
# 6220    0.28  0.00       24.4  Rain, Partially cloudy
# 6221    0.03  0.00       29.6  Rain, Partially cloudy
#
# [6222 rows x 10 columns]
