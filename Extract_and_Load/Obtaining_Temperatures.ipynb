# %%
# 1.Importing dependencies

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import os

# %%
#2. We add url. Each city will have a new url

url2 = "https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/columbus%20ohio/2020-1-1/2020-12-31?unitGroup=metric&key=SRX784Y4XEDTND44NFLHKK42Z&include=obs"

# %%
response = requests.get(url2).json()

# %%
response
# Out:
# {'queryCost': 366,
#  'latitude': 39.962,
#  'longitude': -83.0028,
#  'resolvedAddress': 'Columbus, OH, United States',
#  'address': 'columbus ohio',
#  'timezone': 'America/New_York',
#  'tzoffset': -5.0,
#  'days': [{'datetime': '2020-01-01',
#    'datetimeEpoch': 1577854800,
#    'tempmax': 6.5,
#    'tempmin': 0.0,
#    'temp': 2.4,
#    'feelslikemax': 3.3,
#    'feelslikemin': -5.6,
#    'feelslike': -1.9,
#    'dew': -3.6,
#    'humidity': 65.11,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 37.1,
#    'windspeed': 24.4,
#    'winddir': 227.5,
#    'pressure': 1012.1,
#    'cloudcover': 61.5,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:53:50',
#    'sunriseEpoch': 1577883230,
#    'sunset': '17:17:12',
#    'sunsetEpoch': 1577917032,
#    'moonphase': 0.17,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['KCMH',
#     'KOSU',
#     'KLHQ',
#     '72092800315',
#     '72428804804',
#     '72428014821'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-02',
#    'datetimeEpoch': 1577941200,
#    'tempmax': 9.2,
#    'tempmin': 1.2,
#    'temp': 5.5,
#    'feelslikemax': 6.9,
#    'feelslikemin': -2.5,
#    'feelslike': 2.5,
#    'dew': -1.0,
#    'humidity': 63.83,
#    'precip': 0.72,
#    'precipprob': None,
#    'precipcover': 12.5,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 35.3,
#    'windspeed': 21.1,
#    'winddir': 182.5,
#    'pressure': 1009.1,
#    'cloudcover': 67.4,
#    'visibility': 15.6,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:53:57',
#    'sunriseEpoch': 1577969637,
#    'sunset': '17:18:02',
#    'sunsetEpoch': 1578003482,
#    'moonphase': 0.22,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['KCMH',
#     'KOSU',
#     '72092800315',
#     'KLHQ',
#     '72428804804',
#     '72428014821'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-03',
#    'datetimeEpoch': 1578027600,
#    'tempmax': 11.1,
#    'tempmin': 8.1,
#    'temp': 9.4,
#    'feelslikemax': 11.1,
#    'feelslikemin': 6.0,
#    'feelslike': 8.7,
#    'dew': 8.4,
#    'humidity': 93.81,
#    'precip': 22.21,
#    'precipprob': None,
#    'precipcover': 95.83,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 13.0,
#    'winddir': 199.7,
#    'pressure': 1007.2,
#    'cloudcover': 94.2,
#    'visibility': 6.3,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:54:02',
#    'sunriseEpoch': 1578056042,
#    'sunset': '17:18:54',
#    'sunsetEpoch': 1578089934,
#    'moonphase': 0.26,
#    'conditions': 'Rain, Overcast',
#    'icon': 'rain',
#    'stations': ['KCMH',
#     'KOSU',
#     '72092800315',
#     'KLHQ',
#     '72428804804',
#     '72428014821'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-04',
#    'datetimeEpoch': 1578114000,
#    'tempmax': 7.6,
#    'tempmin': 0.6,
#    'temp': 3.6,
#    'feelslikemax': 5.4,
#    'feelslikemin': -4.7,
#    'feelslike': -0.2,
#    'dew': 1.3,
#    'humidity': 85.01,
#    'precip': 2.29,
#    'precipprob': None,
#    'precipcover': 20.83,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 41.7,
#    'windspeed': 24.8,
#    'winddir': 313.3,
#    'pressure': 1011.0,
#    'cloudcover': 90.7,
#    'visibility': 11.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:54:04',
#    'sunriseEpoch': 1578142444,
#    'sunset': '17:19:47',
#    'sunsetEpoch': 1578176387,
#    'moonphase': 0.31,
#    'conditions': 'Rain, Overcast',
#    'icon': 'rain',
#    'stations': ['KCMH',
#     'KOSU',
#     'KLHQ',
#     '72092800315',
#     '72428804804',
#     '72428014821'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-05',
#    'datetimeEpoch': 1578200400,
#    'tempmax': 5.3,
#    'tempmin': -0.3,
#    'temp': 1.9,
#    'feelslikemax': 3.0,
#    'feelslikemin': -6.2,
#    'feelslike': -2.5,
#    'dew': -3.5,
#    'humidity': 67.8,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 46.6,
#    'windspeed': 28.3,
#    'winddir': 245.9,
#    'pressure': 1019.0,
#    'cloudcover': 79.3,
#    'visibility': 15.9,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:54:05',
#    'sunriseEpoch': 1578228845,
#    'sunset': '17:20:41',
#    'sunsetEpoch': 1578262841,
#    'moonphase': 0.36,
#    'conditions': 'Overcast',
#    'icon': 'cloudy',
#    'stations': ['KCMH',
#     'KOSU',
#     'KLHQ',
#     '72092800315',
#     '72428804804',
#     '72428014821'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-06',
#    'datetimeEpoch': 1578286800,
#    'tempmax': 6.4,
#    'tempmin': -0.2,
#    'temp': 3.0,
#    'feelslikemax': 3.7,
#    'feelslikemin': -4.8,
#    'feelslike': -0.5,
#    'dew': -4.0,
#    'humidity': 60.78,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 51.8,
#    'windspeed': 29.2,
#    'winddir': 241.0,
#    'pressure': 1020.0,
#    'cloudcover': 57.6,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:54:03',
#    'sunriseEpoch': 1578315243,
#    'sunset': '17:21:37',
#    'sunsetEpoch': 1578349297,
#    'moonphase': 0.4,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['KCMH',
#     'KOSU',
#     'KLHQ',
#     '72092800315',
#     '72428804804',
#     '72428014821'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-07',
#    'datetimeEpoch': 1578373200,
#    'tempmax': 7.8,
#    'tempmin': -2.8,
#    'temp': 2.1,
#    'feelslikemax': 5.6,
#    'feelslikemin': -5.4,
#    'feelslike': 0.3,
#    'dew': -5.8,
#    'humidity': 59.62,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 35.3,
#    'windspeed': 20.4,
#    'winddir': 171.3,
#    'pressure': 1016.5,
#    'cloudcover': 51.0,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:53:59',
#    'sunriseEpoch': 1578401639,
#    'sunset': '17:22:34',
#    'sunsetEpoch': 1578435754,
#    'moonphase': 0.44,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['KCMH',
#     'KOSU',
#     '72092800315',
#     'KLHQ',
#     '72428804804',
#     '72428014821'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-08',
#    'datetimeEpoch': 1578459600,
#    'tempmax': 3.1,
#    'tempmin': -5.5,
#    'temp': -0.7,
#    'feelslikemax': -1.4,
#    'feelslikemin': -9.4,
#    'feelslike': -5.9,
#    'dew': -8.4,
#    'humidity': 56.51,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 51.8,
#    'windspeed': 35.6,
#    'winddir': 242.7,
#    'pressure': 1025.2,
#    'cloudcover': 35.4,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:53:53',
#    'sunriseEpoch': 1578488033,
#    'sunset': '17:23:32',
#    'sunsetEpoch': 1578522212,
#    'moonphase': 0.47,
#    'conditions': 'Partially cloudy',
#    'icon': 'wind',
#    'stations': ['KCMH',
#     'KOSU',
#     '72092800315',
#     'KLHQ',
#     '72428804804',
#     '72428014821'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-09',
#    'datetimeEpoch': 1578546000,
#    'tempmax': 11.5,
#    'tempmin': -6.0,
#    'temp': 2.8,
#    'feelslikemax': 11.5,
#    'feelslikemin': -11.2,
#    'feelslike': -0.6,
#    'dew': -7.6,
#    'humidity': 48.91,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 35.3,
#    'windspeed': 22.3,
#    'winddir': 136.0,
#    'pressure': 1029.9,
#    'cloudcover': 33.6,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:53:44',
#    'sunriseEpoch': 1578574424,
#    'sunset': '17:24:31',
#    'sunsetEpoch': 1578608671,
#    'moonphase': 0.49,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['KCMH',
#     'KOSU',
#     'KLHQ',
#     '72092800315',
#     '72428804804',
#     '72428014821'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-10',
#    'datetimeEpoch': 1578632400,
#    'tempmax': 13.5,
#    'tempmin': 7.6,
#    'temp': 10.6,
#    'feelslikemax': 13.5,
#    'feelslikemin': 4.7,
#    'feelslike': 9.8,
#    'dew': 5.2,
#    'humidity': 71.63,
#    'precip': 8.46,
#    'precipprob': None,
#    'precipcover': 70.83,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 45.5,
#    'windspeed': 23.2,
#    'winddir': 161.5,
#    'pressure': 1023.3,
#    'cloudcover': 83.1,
#    'visibility': 14.6,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:53:34',
#    'sunriseEpoch': 1578660814,
#    'sunset': '17:25:32',
#    'sunsetEpoch': 1578695132,
#    'moonphase': 0.5,
#    'conditions': 'Rain, Overcast',
#    'icon': 'rain',
#    'stations': ['KCMH',
#     'KOSU',
#     'KLHQ',
#     '72092800315',
#     '72428804804',
#     '72428014821'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-11',
#    'datetimeEpoch': 1578718800,
#    'tempmax': 20.7,
#    'tempmin': 12.0,
#    'temp': 15.5,
#    'feelslikemax': 20.7,
#    'feelslikemin': 12.0,
#    'feelslike': 15.5,
#    'dew': 11.4,
#    'humidity': 77.59,
#    'precip': 15.29,
#    'precipprob': None,
#    'precipcover': 66.67,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 58.8,
#    'windspeed': 34.9,
#    'winddir': 166.2,
#    'pressure': 1009.4,
#    'cloudcover': 83.6,
#    'visibility': 15.1,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:53:21',
#    'sunriseEpoch': 1578747201,
#    'sunset': '17:26:34',
#    'sunsetEpoch': 1578781594,
#    'moonphase': 0.51,
#    'conditions': 'Rain, Overcast',
#    'icon': 'rain',
#    'stations': ['KCMH',
#     'KOSU',
#     '72092800315',
#     'KLHQ',
#     '72428804804',
#     '72428014821'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-12',
#    'datetimeEpoch': 1578805200,
#    'tempmax': 14.0,
#    'tempmin': 3.1,
#    'temp': 5.1,
#    'feelslikemax': 14.0,
#    'feelslikemin': -1.0,
#    'feelslike': 2.5,
#    'dew': 1.5,
#    'humidity': 77.91,
#    'precip': 1.16,
#    'precipprob': None,
#    'precipcover': 8.33,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 70.0,
#    'windspeed': 43.0,
#    'winddir': 207.8,
#    'pressure': 1022.4,
#    'cloudcover': 90.2,
#    'visibility': 15.8,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:53:06',
#    'sunriseEpoch': 1578833586,
#    'sunset': '17:27:36',
#    'sunsetEpoch': 1578868056,
#    'moonphase': 0.52,
#    'conditions': 'Rain, Overcast',
#    'icon': 'rain',
#    'stations': ['KCMH',
#     'KOSU',
#     'KLHQ',
#     '72092800315',
#     '72428804804',
#     '72428014821'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-13',
#    'datetimeEpoch': 1578891600,
#    'tempmax': 7.6,
#    'tempmin': 1.4,
#    'temp': 4.6,
#    'feelslikemax': 6.1,
#    'feelslikemin': -1.0,
#    'feelslike': 3.2,
#    'dew': 0.7,
#    'humidity': 76.16,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 15.4,
#    'winddir': 189.3,
#    'pressure': 1026.8,
#    'cloudcover': 81.0,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:52:48',
#    'sunriseEpoch': 1578919968,
#    'sunset': '17:28:40',
#    'sunsetEpoch': 1578954520,
#    'moonphase': 0.55,
#    'conditions': 'Overcast',
#    'icon': 'cloudy',
#    'stations': ['KCMH',
#     'KOSU',
#     'KLHQ',
#     '72092800315',
#     '72428804804',
#     '72428014821'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-14',
#    'datetimeEpoch': 1578978000,
#    'tempmax': 9.7,
#    'tempmin': 1.9,
#    'temp': 5.0,
#    'feelslikemax': 6.6,
#    'feelslikemin': -1.1,
#    'feelslike': 2.6,
#    'dew': 2.1,
#    'humidity': 81.62,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 33.5,
#    'windspeed': 24.9,
#    'winddir': 180.8,
#    'pressure': 1021.5,
#    'cloudcover': 78.4,
#    'visibility': 13.6,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:52:29',
#    'sunriseEpoch': 1579006349,
#    'sunset': '17:29:44',
#    'sunsetEpoch': 1579040984,
#    'moonphase': 0.59,
#    'conditions': 'Overcast',
#    'icon': 'cloudy',
#    'stations': ['KCMH',
#     'KOSU',
#     '72092800315',
#     'KLHQ',
#     '72428804804',
#     '72428014821'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-15',
#    'datetimeEpoch': 1579064400,
#    'tempmax': 10.5,
#    'tempmin': -0.7,
#    'temp': 4.3,
#    'feelslikemax': 10.5,
#    'feelslikemin': -4.3,
#    'feelslike': 2.6,
#    'dew': 3.1,
#    'humidity': 91.85,
#    'precip': 0.01,
#    'precipprob': None,
#    'precipcover': 4.17,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 44.7,
#    'windspeed': 24.9,
#    'winddir': 151.7,
#    'pressure': 1019.7,
#    'cloudcover': 75.9,
#    'visibility': 4.4,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:52:07',
#    'sunriseEpoch': 1579092727,
#    'sunset': '17:30:50',
#    'sunsetEpoch': 1579127450,
#    'moonphase': 0.64,
#    'conditions': 'Rain, Overcast',
#    'icon': 'rain',
#    'stations': ['KCMH',
#     'KOSU',
#     'KLHQ',
#     '72092800315',
#     '72428804804',
#     '72428014821'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-16',
#    'datetimeEpoch': 1579150800,
#    'tempmax': 7.4,
#    'tempmin': -3.5,
#    'temp': 1.9,
#    'feelslikemax': 3.5,
#    'feelslikemin': -10.1,
#    'feelslike': -3.7,
#    'dew': -4.1,
#    'humidity': 65.19,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 50.8,
#    'windspeed': 35.7,
#    'winddir': 300.8,
#    'pressure': 1030.2,
#    'cloudcover': 89.6,
#    'visibility': 15.8,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:51:44',
#    'sunriseEpoch': 1579179104,
#    'sunset': '17:31:56',
#    'sunsetEpoch': 1579213916,
#    'moonphase': 0.69,
#    'conditions': 'Overcast',
#    'icon': 'wind',
#    'stations': ['KCMH',
#     'KOSU',
#     '72092800315',
#     'KLHQ',
#     '72428804804',
#     '72428014821'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-17',
#    'datetimeEpoch': 1579237200,
#    'tempmax': -0.8,
#    'tempmin': -6.0,
#    'temp': -2.8,
#    'feelslikemax': -4.0,
#    'feelslikemin': -10.3,
#    'feelslike': -7.4,
#    'dew': -9.9,
#    'humidity': 58.53,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 37.9,
#    'windspeed': 23.0,
#    'winddir': 120.5,
#    'pressure': 1039.9,
#    'cloudcover': 70.8,
#    'visibility': 15.9,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:51:18',
#    'sunriseEpoch': 1579265478,
#    'sunset': '17:33:03',
#    'sunsetEpoch': 1579300383,
#    'moonphase': 0.75,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['KCMH',
#     'KOSU',
#     'KLHQ',
#     '72092800315',
#     '72428804804',
#     '72428014821'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-18',
#    'datetimeEpoch': 1579323600,
#    'tempmax': 8.7,
#    'tempmin': -1.3,
#    'temp': 2.0,
#    'feelslikemax': 5.3,
#    'feelslikemin': -8.0,
#    'feelslike': -2.9,
#    'dew': -1.1,
#    'humidity': 80.17,
#    'precip': 24.29,
#    'precipprob': None,
#    'precipcover': 66.67,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 58.9,
#    'windspeed': 39.6,
#    'winddir': 184.0,
#    'pressure': 1016.0,
#    'cloudcover': 90.9,
#    'visibility': 12.2,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:50:50',
#    'sunriseEpoch': 1579351850,
#    'sunset': '17:34:11',
#    'sunsetEpoch': 1579386851,
#    'moonphase': 0.81,
#    'conditions': 'Rain, Overcast',
#    'icon': 'rain',
#    'stations': ['KCMH',
#     'KOSU',
#     'KLHQ',
#     '72092800315',
#     '72428804804',
#     '72428014821'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-19',
#    'datetimeEpoch': 1579410000,
#    'tempmax': -1.3,
#    'tempmin': -9.6,
#    'temp': -7.9,
#    'feelslikemax': -8.2,
#    'feelslikemin': -18.6,
#    'feelslike': -16.2,
#    'dew': -12.5,
#    'humidity': 69.27,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 59.1,
#    'windspeed': 43.1,
#    'winddir': 281.0,
#    'pressure': 1022.4,
#    'cloudcover': 94.0,
#    'visibility': 11.3,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:50:20',
#    'sunriseEpoch': 1579438220,
#    'sunset': '17:35:19',
#    'sunsetEpoch': 1579473319,
#    'moonphase': 0.86,
#    'conditions': 'Overcast',
#    'icon': 'wind',
#    'stations': ['KCMH',
#     'KOSU',
#     '72092800315',
#     'KLHQ',
#     '72428804804',
#     '72428014821'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-20',
#    'datetimeEpoch': 1579496400,
#    'tempmax': -3.2,
#    'tempmin': -11.5,
#    'temp': -7.1,
#    'feelslikemax': -7.4,
#    'feelslikemin': -16.8,
#    'feelslike': -11.9,
#    'dew': -11.8,
#    'humidity': 70.21,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 16.4,
#    'winddir': 279.3,
#    'pressure': 1033.8,
#    'cloudcover': 67.7,
#    'visibility': 15.1,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:49:48',
#    'sunriseEpoch': 1579524588,
#    'sunset': '17:36:28',
#    'sunsetEpoch': 1579559788,
#    'moonphase': 0.91,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['KCMH',
#     'KOSU',
#     'KLHQ',
#     '72092800315',
#     '72428804804',
#     '72428014821'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-21',
#    'datetimeEpoch': 1579582800,
#    'tempmax': -2.1,
#    'tempmin': -10.3,
#    'temp': -6.1,
#    'feelslikemax': -2.1,
#    'feelslikemin': -15.1,
#    'feelslike': -8.2,
#    'dew': -11.6,
#    'humidity': 66.35,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 9.4,
#    'winddir': 217.7,
#    'pressure': 1036.0,
#    'cloudcover': 23.1,
#    'visibility': 15.6,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:49:14',
#    'sunriseEpoch': 1579610954,
#    'sunset': '17:37:37',
#    'sunsetEpoch': 1579646257,
#    'moonphase': 0.95,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['KCMH',
#     'KOSU',
#     '72092800315',
#     'KLHQ',
#     '72428804804',
#     '72428014821'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-22',
#    'datetimeEpoch': 1579669200,
#    'tempmax': 2.0,
#    'tempmin': -10.0,
#    'temp': -3.7,
#    'feelslikemax': -0.6,
#    'feelslikemin': -13.3,
#    'feelslike': -6.2,
#    'dew': -10.1,
#    'humidity': 62.93,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 14.8,
#    'winddir': 119.6,
#    'pressure': 1029.7,
#    'cloudcover': 30.0,
#    'visibility': 15.6,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:48:38',
#    'sunriseEpoch': 1579697318,
#    'sunset': '17:38:47',
#    'sunsetEpoch': 1579732727,
#    'moonphase': 0.98,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['KCMH',
#     'KOSU',
#     'KLHQ',
#     '72092800315',
#     '72428804804',
#     '72428014821'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-23',
#    'datetimeEpoch': 1579755600,
#    'tempmax': 6.0,
#    'tempmin': -2.5,
#    'temp': 2.0,
#    'feelslikemax': 4.1,
#    'feelslikemin': -4.8,
#    'feelslike': 0.0,
#    'dew': -7.1,
#    'humidity': 51.75,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 14.0,
#    'winddir': 103.9,
#    'pressure': 1023.2,
#    'cloudcover': 70.0,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:48:00',
#    'sunriseEpoch': 1579783680,
#    'sunset': '17:39:58',
#    'sunsetEpoch': 1579819198,
#    'moonphase': 0.99,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['KCMH',
#     'KOSU',
#     'KLHQ',
#     '72092800315',
#     '72428804804',
#     '72428014821'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-24',
#    'datetimeEpoch': 1579842000,
#    'tempmax': 8.7,
#    'tempmin': 3.8,
#    'temp': 6.1,
#    'feelslikemax': 7.0,
#    'feelslikemin': 0.1,
#    'feelslike': 3.4,
#    'dew': 2.7,
#    'humidity': 80.69,
#    'precip': 14.33,
#    'precipprob': None,
#    'precipcover': 62.5,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 33.5,
#    'windspeed': 24.1,
#    'winddir': 136.4,
#    'pressure': 1013.7,
#    'cloudcover': 83.2,
#    'visibility': 12.5,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:47:20',
#    'sunriseEpoch': 1579870040,
#    'sunset': '17:41:08',
#    'sunsetEpoch': 1579905668,
#    'moonphase': 1.0,
#    'conditions': 'Rain, Overcast',
#    'icon': 'rain',
#    'stations': ['KCMH',
#     'KOSU',
#     'KLHQ',
#     '72092800315',
#     '72428804804',
#     '72428014821'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-25',
#    'datetimeEpoch': 1579928400,
#    'tempmax': 5.0,
#    'tempmin': 0.6,
#    'temp': 2.7,
#    'feelslikemax': 4.3,
#    'feelslikemin': -4.3,
#    'feelslike': -1.0,
#    'dew': 0.8,
#    'humidity': 87.34,
#    'precip': 5.95,
#    'precipprob': None,
#    'precipcover': 58.33,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 40.7,
#    'windspeed': 26.0,
#    'winddir': 227.8,
#    'pressure': 1012.8,
#    'cloudcover': 87.9,
#    'visibility': 11.1,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:46:38',
#    'sunriseEpoch': 1579956398,
#    'sunset': '17:42:19',
#    'sunsetEpoch': 1579992139,
#    'moonphase': 0.0,
#    'conditions': 'Rain, Overcast',
#    'icon': 'rain',
#    'stations': ['KCMH',
#     'KOSU',
#     'KLHQ',
#     '72092800315',
#     '72428804804',
#     '72428014821'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-26',
#    'datetimeEpoch': 1580014800,
#    'tempmax': 1.7,
#    'tempmin': 0.0,
#    'temp': 0.7,
#    'feelslikemax': -0.9,
#    'feelslikemin': -5.5,
#    'feelslike': -3.7,
#    'dew': -1.5,
#    'humidity': 84.9,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 38.9,
#    'windspeed': 22.3,
#    'winddir': 241.3,
#    'pressure': 1014.0,
#    'cloudcover': 96.5,
#    'visibility': 14.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:45:54',
#    'sunriseEpoch': 1580042754,
#    'sunset': '17:43:31',
#    'sunsetEpoch': 1580078611,
#    'moonphase': 0.01,
#    'conditions': 'Overcast',
#    'icon': 'cloudy',
#    'stations': ['KCMH',
#     'KOSU',
#     '72092800315',
#     'KLHQ',
#     '72428804804',
#     '72428014821'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-27',
#    'datetimeEpoch': 1580101200,
#    'tempmax': 2.0,
#    'tempmin': 0.6,
#    'temp': 1.2,
#    'feelslikemax': -0.6,
#    'feelslikemin': -3.6,
#    'feelslike': -2.2,
#    'dew': -1.7,
#    'humidity': 81.2,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 19.7,
#    'winddir': 292.4,
#    'pressure': 1013.0,
#    'cloudcover': 96.4,
#    'visibility': 12.4,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:45:08',
#    'sunriseEpoch': 1580129108,
#    'sunset': '17:44:43',
#    'sunsetEpoch': 1580165083,
#    'moonphase': 0.03,
#    'conditions': 'Overcast',
#    'icon': 'cloudy',
#    'stations': ['KCMH',
#     'KOSU',
#     'KLHQ',
#     '72092800315',
#     '72428804804',
#     '72428014821'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-28',
#    'datetimeEpoch': 1580187600,
#    'tempmax': 2.0,
#    'tempmin': 0.0,
#    'temp': 0.8,
#    'feelslikemax': -1.3,
#    'feelslikemin': -3.5,
#    'feelslike': -2.7,
#    'dew': -2.5,
#    'humidity': 78.81,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 14.9,
#    'winddir': 302.4,
#    'pressure': 1018.1,
#    'cloudcover': 95.7,
#    'visibility': 14.4,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:44:20',
#    'sunriseEpoch': 1580215460,
#    'sunset': '17:45:54',
#    'sunsetEpoch': 1580251554,
#    'moonphase': 0.06,
#    'conditions': 'Overcast',
#    'icon': 'cloudy',
#    'stations': ['KCMH',
#     'KOSU',
#     '72092800315',
#     'KLHQ',
#     '72428804804',
#     '72428014821'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-29',
#    'datetimeEpoch': 1580274000,
#    'tempmax': 0.9,
#    'tempmin': -0.2,
#    'temp': 0.3,
#    'feelslikemax': 0.7,
#    'feelslikemin': -3.3,
#    'feelslike': -1.7,
#    'dew': -5.0,
#    'humidity': 68.09,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 13.3,
#    'winddir': 79.1,
#    'pressure': 1021.4,
#    'cloudcover': 98.9,
#    'visibility': 15.8,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:43:31',
#    'sunriseEpoch': 1580301811,
#    'sunset': '17:47:07',
#    'sunsetEpoch': 1580338027,
#    'moonphase': 0.09,
#    'conditions': 'Overcast',
#    'icon': 'cloudy',
#    'stations': ['KCMH',
#     'KOSU',
#     'KLHQ',
#     '72092800315',
#     '72428804804',
#     '72428014821'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-30',
#    'datetimeEpoch': 1580360400,
#    'tempmax': 1.5,
#    'tempmin': -1.1,
#    'temp': -0.2,
#    'feelslikemax': 1.0,
#    'feelslikemin': -4.5,
#    'feelslike': -2.4,
#    'dew': -5.8,
#    'humidity': 66.18,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 11.8,
#    'winddir': 45.6,
#    'pressure': 1023.1,
#    'cloudcover': 98.8,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:42:39',
#    'sunriseEpoch': 1580388159,
#    'sunset': '17:48:19',
#    'sunsetEpoch': 1580424499,
#    'moonphase': 0.13,
#    'conditions': 'Overcast',
#    'icon': 'cloudy',
#    'stations': ['KCMH',
#     'KOSU',
#     'KLHQ',
#     '72092800315',
#     '72428804804',
#     '72428014821'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-31',
#    'datetimeEpoch': 1580446800,
#    'tempmax': 2.2,
#    'tempmin': -2.0,
#    'temp': 0.4,
#    'feelslikemax': 2.2,
#    'feelslikemin': -5.3,
#    'feelslike': -0.9,
#    'dew': -2.9,
#    'humidity': 78.66,
#    'precip': 0.66,
#    'precipprob': None,
#    'precipcover': 25.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 9.2,
#    'winddir': 78.6,
#    'pressure': 1022.2,
#    'cloudcover': 84.3,
#    'visibility': 11.1,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:41:46',
#    'sunriseEpoch': 1580474506,
#    'sunset': '17:49:31',
#    'sunsetEpoch': 1580510971,
#    'moonphase': 0.18,
#    'conditions': 'Rain, Overcast',
#    'icon': 'rain',
#    'stations': ['KCMH',
#     'KOSU',
#     '72092800315',
#     'KLHQ',
#     '72428804804',
#     '72428014821'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-01',
#    'datetimeEpoch': 1580533200,
#    'tempmax': 3.3,
#    'tempmin': -0.2,
#    'temp': 1.4,
#    'feelslikemax': 2.2,
#    'feelslikemin': -3.3,
#    'feelslike': -0.6,
#    'dew': -1.0,
#    'humidity': 83.94,
#    'precip': 0.74,
#    'precipprob': None,
#    'precipcover': 16.67,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 50.0,
#    'windspeed': 28.5,
#    'winddir': 190.6,
#    'pressure': 1014.6,
#    'cloudcover': 91.8,
#    'visibility': 8.4,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:40:52',
#    'sunriseEpoch': 1580560852,
#    'sunset': '17:50:44',
#    'sunsetEpoch': 1580597444,
#    'moonphase': 0.22,
#    'conditions': 'Rain, Overcast',
#    'icon': 'rain',
#    'stations': ['KCMH',
#     'KOSU',
#     '72092800315',
#     'KLHQ',
#     '72428804804',
#     '72428014821'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-02',
#    'datetimeEpoch': 1580619600,
#    'tempmax': 16.1,
#    'tempmin': 1.2,
#    'temp': 7.5,
#    'feelslikemax': 16.1,
#    'feelslikemin': -3.6,
#    'feelslike': 4.9,
#    'dew': -0.2,
#    'humidity': 60.55,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 55.5,
#    'windspeed': 35.5,
#    'winddir': 240.5,
#    'pressure': 1004.6,
#    'cloudcover': 42.5,
#    'visibility': 15.9,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:39:55',
#    'sunriseEpoch': 1580647195,
#    'sunset': '17:51:56',
#    'sunsetEpoch': 1580683916,
#    'moonphase': 0.27,
#    'conditions': 'Partially cloudy',
#    'icon': 'wind',
#    'stations': ['KCMH',
#     'KOSU',
#     '72092800315',
#     'KLHQ',
#     '72428804804',
#     '72428014821'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-03',
#    'datetimeEpoch': 1580706000,
#    'tempmax': 16.7,
#    'tempmin': 1.0,
#    'temp': 9.9,
#    'feelslikemax': 16.7,
#    'feelslikemin': -1.3,
#    'feelslike': 9.4,
#    'dew': 2.1,
#    'humidity': 60.93,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 46.7,
#    'windspeed': 29.0,
#    'winddir': 195.7,
#    'pressure': 1009.4,
#    'cloudcover': 35.3,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:38:57',
#    'sunriseEpoch': 1580733537,
#    'sunset': '17:53:09',
#    'sunsetEpoch': 1580770389,
#    'moonphase': 0.32,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['KCMH',
#     'KOSU',
#     '72092800315',
#     'KLHQ',
#     '72428804804',
#     '72428014821'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-04',
#    'datetimeEpoch': 1580792400,
#    'tempmax': 14.0,
#    'tempmin': 0.6,
#    'temp': 8.6,
#    'feelslikemax': 14.0,
#    'feelslikemin': -4.9,
#    'feelslike': 6.7,
#    'dew': 4.8,
#    'humidity': 77.95,
#    'precip': 8.56,
#    'precipprob': None,
#    'precipcover': 70.83,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 44.6,
#    'windspeed': 27.1,
#    'winddir': 168.8,
#    'pressure': 1010.2,
#    'cloudcover': 92.5,
#    'visibility': 13.1,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:37:57',
#    'sunriseEpoch': 1580819877,
#    'sunset': '17:54:21',
#    'sunsetEpoch': 1580856861,
#    'moonphase': 0.37,
#    'conditions': 'Rain, Overcast',
#    'icon': 'rain',
#    'stations': ['KCMH',
#     'KOSU',
#     '72092800315',
#     'KLHQ',
#     '72428804804',
#     '72428014821'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-05',
#    'datetimeEpoch': 1580878800,
#    'tempmax': 3.1,
#    'tempmin': -0.6,
#    'temp': 0.8,
#    'feelslikemax': -0.9,
#    'feelslikemin': -6.6,
#    'feelslike': -4.0,
#    'dew': -3.9,
#    'humidity': 71.68,
#    'precip': 7.01,
#    'precipprob': None,
#    'precipcover': 25.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 35.3,
#    'windspeed': 24.5,
#    'winddir': 56.0,
#    'pressure': 1014.6,
#    'cloudcover': 86.7,
#    'visibility': 15.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:36:56',
#    'sunriseEpoch': 1580906216,
#    'sunset': '17:55:33',
#    'sunsetEpoch': 1580943333,
#    'moonphase': 0.41,
#    'conditions': 'Rain, Overcast',
#    'icon': 'rain',
#    'stations': ['KCMH',
#     'KOSU',
#     '72092800315',
#     'KLHQ',
#     '72428804804',
#     '72428014821'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-06',
#    'datetimeEpoch': 1580965200,
#    'tempmax': 1.3,
#    'tempmin': -1.5,
#    'temp': 0.0,
#    'feelslikemax': -1.8,
#    'feelslikemin': -7.0,
#    'feelslike': -4.0,
#    'dew': -1.7,
#    'humidity': 88.63,
#    'precip': 2.04,
#    'precipprob': None,
#    'precipcover': 41.67,
#    'preciptype': None,
#    'snow': 1.88,
#    'snowdepth': 1.88,
#    'windgust': None,
#    'windspeed': 21.8,
#    'winddir': 210.2,
#    'pressure': 999.3,
#    'cloudcover': 95.7,
#    'visibility': 9.3,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:35:53',
#    'sunriseEpoch': 1580992553,
#    'sunset': '17:56:46',
#    'sunsetEpoch': 1581029806,
#    'moonphase': 0.45,
#    'conditions': 'Snow, Overcast',
#    'icon': 'snow',
#    'stations': ['KCMH',
#     'KOSU',
#     '72092800315',
#     'KLHQ',
#     '72428804804',
#     '72428014821'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-07',
#    'datetimeEpoch': 1581051600,
#    'tempmax': 0.2,
#    'tempmin': -3.4,
#    'temp': -2.0,
#    'feelslikemax': -5.7,
#    'feelslikemin': -9.8,
#    'feelslike': -7.6,
#    'dew': -5.3,
#    'humidity': 78.73,
#    'precip': 1.36,
#    'precipprob': None,
#    'precipcover': 29.17,
#    'preciptype': None,
#    'snow': 2.47,
#    'snowdepth': 4.34,
#    'windgust': 40.7,
#    'windspeed': 27.7,
#    'winddir': 299.1,
#    'pressure': 1003.3,
#    'cloudcover': 72.5,
#    'visibility': 10.7,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:34:49',
#    'sunriseEpoch': 1581078889,
#    'sunset': '17:57:58',
#    'sunsetEpoch': 1581116278,
#    'moonphase': 0.48,
#    'conditions': 'Snow, Partially cloudy',
#    'icon': 'snow',
#    'stations': ['KCMH',
#     'KOSU',
#     '72092800315',
#     'KLHQ',
#     '72428804804',
#     '72428014821'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-08',
#    'datetimeEpoch': 1581138000,
#    'tempmax': 0.4,
#    'tempmin': -3.9,
#    'temp': -1.3,
#    'feelslikemax': -0.1,
#    'feelslikemin': -8.1,
#    'feelslike': -4.8,
#    'dew': -3.5,
#    'humidity': 85.02,
#    'precip': 1.47,
#    'precipprob': None,
#    'precipcover': 29.17,
#    'preciptype': None,
#    'snow': 0.81,
#    'snowdepth': 5.15,
#    'windgust': None,
#    'windspeed': 15.3,
#    'winddir': 199.3,
#    'pressure': 1021.3,
#    'cloudcover': 77.3,
#    'visibility': 8.7,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:33:43',
#    'sunriseEpoch': 1581165223,
#    'sunset': '17:59:10',
#    'sunsetEpoch': 1581202750,
#    'moonphase': 0.5,
#    'conditions': 'Snow, Overcast',
#    'icon': 'snow',
#    'stations': ['KCMH',
#     'KOSU',
#     '72092800315',
#     'KLHQ',
#     '72428804804',
#     '72428014821'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-09',
#    'datetimeEpoch': 1581224400,
#    'tempmax': 3.5,
#    'tempmin': -2.4,
#    'temp': 0.4,
#    'feelslikemax': -0.1,
#    'feelslikemin': -5.3,
#    'feelslike': -3.3,
#    'dew': -2.8,
#    'humidity': 79.01,
#    'precip': 1.49,
#    'precipprob': None,
#    'precipcover': 25.0,
#    'preciptype': None,
#    'snow': 2.42,
#    'snowdepth': 3.62,
#    'windgust': 38.9,
#    'windspeed': 21.2,
#    'winddir': 165.4,
#    'pressure': 1026.1,
#    'cloudcover': 81.4,
#    'visibility': 12.8,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:32:35',
#    'sunriseEpoch': 1581251555,
#    'sunset': '18:00:22',
#    'sunsetEpoch': 1581289222,
#    'moonphase': 0.5,
#    'conditions': 'Snow, Overcast',
#    'icon': 'snow',
#    'stations': ['KCMH',
#     'KOSU',
#     '72092800315',
#     'KLHQ',
#     '72428804804',
#     '72428014821'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-10',
#    'datetimeEpoch': 1581310800,
#    'tempmax': 8.0,
#    'tempmin': 3.2,
#    'temp': 5.2,
#    'feelslikemax': 5.7,
#    'feelslikemin': 0.0,
#    'feelslike': 2.3,
#    'dew': 3.3,
#    'humidity': 87.72,
#    'precip': 3.19,
#    'precipprob': None,
#    'precipcover': 37.5,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 1.21,
#    'windgust': 37.1,
#    'windspeed': 22.1,
#    'winddir': 276.6,
#    'pressure': 1017.3,
#    'cloudcover': 95.4,
#    'visibility': 9.3,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:31:27',
#    'sunriseEpoch': 1581337887,
#    'sunset': '18:01:34',
#    'sunsetEpoch': 1581375694,
#    'moonphase': 0.52,
#    'conditions': 'Rain, Overcast',
#    'icon': 'rain',
#    'stations': ['KCMH',
#     'KOSU',
#     '72092800315',
#     'KLHQ',
#     '72428804804',
#     '72428014821'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-11',
#    'datetimeEpoch': 1581397200,
#    'tempmax': 3.8,
#    'tempmin': 0.7,
#    'temp': 2.4,
#    'feelslikemax': 2.4,
#    'feelslikemin': -3.0,
#    'feelslike': -1.0,
#    'dew': -1.1,
#    'humidity': 78.44,
#    'precip': 0.34,
#    'precipprob': None,
#    'precipcover': 8.33,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 23.0,
#    'winddir': 300.0,
#    'pressure': 1018.9,
#    'cloudcover': 78.4,
#    'visibility': 10.5,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:30:16',
#    'sunriseEpoch': 1581424216,
#    'sunset': '18:02:45',
#    'sunsetEpoch': 1581462165,
#    'moonphase': 0.53,
#    'conditions': 'Rain, Overcast',
#    'icon': 'rain',
#    'stations': ['KCMH',
#     'KOSU',
#     '72092800315',
#     'KLHQ',
#     '72428804804',
#     '72428014821'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-12',
#    'datetimeEpoch': 1581483600,
#    'tempmax': 2.8,
#    'tempmin': -3.3,
#    'temp': 0.0,
#    'feelslikemax': -0.1,
#    'feelslikemin': -4.9,
#    'feelslike': -2.8,
#    'dew': -3.7,
#    'humidity': 77.31,
#    'precip': 12.24,
#    'precipprob': None,
#    'precipcover': 37.5,
#    'preciptype': None,
#    'snow': 1.88,
#    'snowdepth': 1.88,
#    'windgust': 29.5,
#    'windspeed': 14.3,
#    'winddir': 137.8,
#    'pressure': 1018.4,
#    'cloudcover': 65.9,
#    'visibility': 12.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:29:05',
#    'sunriseEpoch': 1581510545,
#    'sunset': '18:03:57',
#    'sunsetEpoch': 1581548637,
#    'moonphase': 0.57,
#    'conditions': 'Snow, Partially cloudy',
#    'icon': 'snow',
#    'stations': ['KCMH',
#     'KOSU',
#     '72092800315',
#     'KLHQ',
#     '72428804804',
#     '72428014821'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-13',
#    'datetimeEpoch': 1581570000,
#    'tempmax': 1.5,
#    'tempmin': -3.6,
#    'temp': 0.2,
#    'feelslikemax': -2.2,
#    'feelslikemin': -10.8,
#    'feelslike': -4.8,
#    'dew': -2.4,
#    'humidity': 83.34,
#    'precip': 2.38,
#    'precipprob': None,
#    'precipcover': 25.0,
#    'preciptype': None,
#    'snow': 1.13,
#    'snowdepth': 3.0,
#    'windgust': 45.2,
#    'windspeed': 32.7,
#    'winddir': 266.6,
#    'pressure': 1012.7,
#    'cloudcover': 93.2,
#    'visibility': 9.7,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:27:52',
#    'sunriseEpoch': 1581596872,
#    'sunset': '18:05:08',
#    'sunsetEpoch': 1581635108,
#    'moonphase': 0.62,
#    'conditions': 'Snow, Overcast',
#    'icon': 'snow',
#    'stations': ['KCMH',
#     'KOSU',
#     '72092800315',
#     'KLHQ',
#     '72428804804',
#     '72428014821'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-14',
#    'datetimeEpoch': 1581656400,
#    'tempmax': -4.8,
#    'tempmin': -9.1,
#    'temp': -7.2,
#    'feelslikemax': -5.7,
#    'feelslikemin': -15.5,
#    'feelslike': -12.4,
#    'dew': -13.4,
#    'humidity': 61.79,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 3.0,
#    'windgust': 37.1,
#    'windspeed': 28.3,
#    'winddir': 235.0,
#    'pressure': 1032.5,
#    'cloudcover': 56.7,
#    'visibility': 14.6,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:26:38',
#    'sunriseEpoch': 1581683198,
#    'sunset': '18:06:19',
#    'sunsetEpoch': 1581721579,
#    'moonphase': 0.67,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['KCMH',
#     'KOSU',
#     '72092800315',
#     'KLHQ',
#     '72428804804',
#     '72428014821'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-15',
#    'datetimeEpoch': 1581742800,
#    'tempmax': 2.2,
#    'tempmin': -10.7,
#    'temp': -3.9,
#    'feelslikemax': -1.0,
#    'feelslikemin': -15.0,
#    'feelslike': -7.8,
#    'dew': -11.2,
#    'humidity': 58.63,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 1.0,
#    'windgust': 37.1,
#    'windspeed': 24.6,
#    'winddir': 144.9,
#    'pressure': 1028.6,
#    'cloudcover': 32.5,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:25:23',
#    'sunriseEpoch': 1581769523,
#    'sunset': '18:07:30',
#    'sunsetEpoch': 1581808050,
#    'moonphase': 0.73,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['KCMH',
#     'KOSU',
#     '72092800315',
#     'KLHQ',
#     '72428804804',
#     '72428014821'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-16',
#    'datetimeEpoch': 1581829200,
#    'tempmax': 6.7,
#    'tempmin': -1.9,
#    'temp': 2.7,
#    'feelslikemax': 4.8,
#    'feelslikemin': -3.8,
#    'feelslike': 0.9,
#    'dew': -4.1,
#    'humidity': 61.5,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 11.9,
#    'winddir': 243.3,
#    'pressure': 1020.4,
#    'cloudcover': 73.3,
#    'visibility': 15.9,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:24:06',
#    'sunriseEpoch': 1581855846,
#    'sunset': '18:08:40',
#    'sunsetEpoch': 1581894520,
#    'moonphase': 0.78,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['KCMH', 'KOSU', 'KLHQ', '72428804804', '72428014821'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-17',
#    'datetimeEpoch': 1581915600,
#    'tempmax': 8.7,
#    'tempmin': -4.8,
#    'temp': 2.5,
#    'feelslikemax': 6.2,
#    'feelslikemin': -7.9,
#    'feelslike': 0.2,
#    'dew': -4.1,
#    'humidity': 64.97,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 37.1,
#    'windspeed': 21.7,
#    'winddir': 72.3,
#    'pressure': 1020.6,
#    'cloudcover': 57.1,
#    'visibility': 14.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:22:48',
#    'sunriseEpoch': 1581942168,
#    'sunset': '18:09:50',
#    'sunsetEpoch': 1581980990,
#    'moonphase': 0.84,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['KCMH', 'KOSU', 'KLHQ', '72428804804', '72428014821'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-18',
#    'datetimeEpoch': 1582002000,
#    'tempmax': 10.9,
#    'tempmin': 0.7,
#    'temp': 7.5,
#    'feelslikemax': 10.9,
#    'feelslikemin': -2.9,
#    'feelslike': 4.9,
#    'dew': 2.5,
#    'humidity': 71.26,
#    'precip': 0.11,
#    'precipprob': None,
#    'precipcover': 12.5,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 38.9,
#    'windspeed': 26.1,
#    'winddir': 256.3,
#    'pressure': 1017.1,
#    'cloudcover': 74.8,
#    'visibility': 15.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:21:29',
#    'sunriseEpoch': 1582028489,
#    'sunset': '18:11:00',
#    'sunsetEpoch': 1582067460,
#    'moonphase': 0.88,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['KCMH',
#     'KOSU',
#     'KLHQ',
#     '72092800315',
#     '72428804804',
#     '72428014821'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-19',
#    'datetimeEpoch': 1582088400,
#    'tempmax': 4.0,
#    'tempmin': -3.7,
#    'temp': -0.3,
#    'feelslikemax': 0.9,
#    'feelslikemin': -7.6,
#    'feelslike': -4.1,
#    'dew': -7.0,
#    'humidity': 62.37,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 31.7,
#    'windspeed': 20.6,
#    'winddir': 323.5,
#    'pressure': 1031.4,
#    'cloudcover': 18.8,
#    'visibility': 15.2,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:20:09',
#    'sunriseEpoch': 1582114809,
#    'sunset': '18:12:09',
#    'sunsetEpoch': 1582153929,
#    'moonphase': 0.93,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['KCMH', 'KOSU', 'KLHQ', '72428804804', '72428014821'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-20',
#    'datetimeEpoch': 1582174800,
#    'tempmax': -1.6,
#    'tempmin': -7.4,
#    'temp': -3.8,
#    'feelslikemax': -1.7,
#    'feelslikemin': -12.0,
#    'feelslike': -8.7,
#    'dew': -11.3,
#    'humidity': 56.83,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 35.3,
#    'windspeed': 24.5,
#    'winddir': 279.8,
#    'pressure': 1034.7,
#    'cloudcover': 46.2,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:18:48',
#    'sunriseEpoch': 1582201128,
#    'sunset': '18:13:19',
#    'sunsetEpoch': 1582240399,
#    'moonphase': 0.96,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['KCMH',
#     'KOSU',
#     'KLHQ',
#     '72092800315',
#     '72428804804',
#     '72428014821'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-21',
#    'datetimeEpoch': 1582261200,
#    'tempmax': 1.6,
#    'tempmin': -10.4,
#    'temp': -4.5,
#    'feelslikemax': -2.7,
#    'feelslikemin': -10.4,
#    'feelslike': -7.0,
#    'dew': -12.4,
#    'humidity': 57.1,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 17.0,
#    'winddir': 242.0,
#    'pressure': 1035.9,
#    'cloudcover': 0.6,
#    'visibility': 15.9,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:17:26',
#    'sunriseEpoch': 1582287446,
#    'sunset': '18:14:28',
#    'sunsetEpoch': 1582326868,
#    'moonphase': 0.98,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['KCMH',
#     'KOSU',
#     '72092800315',
#     'KLHQ',
#     '72428804804',
#     '72428014821'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-22',
#    'datetimeEpoch': 1582347600,
#    'tempmax': 8.1,
#    'tempmin': -6.3,
#    'temp': 0.6,
#    'feelslikemax': 5.0,
#    'feelslikemin': -10.5,
#    'feelslike': -2.7,
#    'dew': -10.3,
#    'humidity': 46.69,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 37.7,
#    'windspeed': 26.2,
#    'winddir': 205.3,
#    'pressure': 1028.3,
#    'cloudcover': 8.8,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:16:03',
#    'sunriseEpoch': 1582373763,
#    'sunset': '18:15:36',
#    'sunsetEpoch': 1582413336,
#    'moonphase': 1.0,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['KCMH',
#     'KOSU',
#     '72092800315',
#     'KLHQ',
#     '72428804804',
#     '72428014821'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-23',
#    'datetimeEpoch': 1582434000,
#    'tempmax': 10.0,
#    'tempmin': -3.9,
#    'temp': 3.7,
#    'feelslikemax': 7.2,
#    'feelslikemin': -7.6,
#    'feelslike': 1.3,
#    'dew': -7.3,
#    'humidity': 45.88,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 40.7,
#    'windspeed': 25.5,
#    'winddir': 184.5,
#    'pressure': 1020.6,
#    'cloudcover': 50.3,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:14:39',
#    'sunriseEpoch': 1582460079,
#    'sunset': '18:16:45',
#    'sunsetEpoch': 1582499805,
#    'moonphase': 1.0,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['KCMH',
#     'KOSU',
#     '72092800315',
#     'KLHQ',
#     '72428804804',
#     '72428014821'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-24',
#    'datetimeEpoch': 1582520400,
#    'tempmax': 8.1,
#    'tempmin': 0.2,
#    'temp': 4.5,
#    'feelslikemax': 6.2,
#    'feelslikemin': -1.0,
#    'feelslike': 2.9,
#    'dew': -0.3,
#    'humidity': 71.9,
#    'precip': 6.92,
#    'precipprob': None,
#    'precipcover': 25.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 18.5,
#    'winddir': 149.5,
#    'pressure': 1014.0,
#    'cloudcover': 61.6,
#    'visibility': 14.8,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:13:14',
#    'sunriseEpoch': 1582546394,
#    'sunset': '18:17:53',
#    'sunsetEpoch': 1582586273,
#    'moonphase': 0.0,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['KCMH',
#     'KOSU',
#     '72092800315',
#     'KLHQ',
#     '72428804804',
#     '72428014821'],
#    'source': 'obs',
# ...
#    'temp': -2.0,
#    'feelslikemax': -2.1,
#    'feelslikemin': -8.9,
#    'feelslike': -5.0,
#    'dew': -7.4,
#    'humidity': 67.49,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 16.1,
#    'winddir': 113.1,
#    'pressure': 1026.5,
#    'cloudcover': 47.3,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:47:05',
#    'sunriseEpoch': 1608036425,
#    'sunset': '17:07:52',
#    'sunsetEpoch': 1608070072,
#    'moonphase': 0.0,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['KCMH',
#     'KOSU',
#     '72092800315',
#     'KLHQ',
#     '72428804804',
#     '72428014821'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-16',
#    'datetimeEpoch': 1608094800,
#    'tempmax': 0.6,
#    'tempmin': -1.6,
#    'temp': -0.4,
#    'feelslikemax': 0.3,
#    'feelslikemin': -6.1,
#    'feelslike': -3.3,
#    'dew': -3.3,
#    'humidity': 81.67,
#    'precip': 4.67,
#    'precipprob': None,
#    'precipcover': 50.0,
#    'preciptype': None,
#    'snow': 6.51,
#    'snowdepth': 6.51,
#    'windgust': None,
#    'windspeed': 14.8,
#    'winddir': 113.0,
#    'pressure': 1015.3,
#    'cloudcover': 93.2,
#    'visibility': 7.4,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:47:44',
#    'sunriseEpoch': 1608122864,
#    'sunset': '17:08:11',
#    'sunsetEpoch': 1608156491,
#    'moonphase': 0.02,
#    'conditions': 'Snow, Overcast',
#    'icon': 'snow',
#    'stations': ['KCMH',
#     'KOSU',
#     '72092800315',
#     'KLHQ',
#     '72428804804',
#     '72428014821'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-17',
#    'datetimeEpoch': 1608181200,
#    'tempmax': 0.2,
#    'tempmin': -1.6,
#    'temp': -0.7,
#    'feelslikemax': -2.2,
#    'feelslikemin': -5.6,
#    'feelslike': -4.6,
#    'dew': -1.9,
#    'humidity': 91.75,
#    'precip': 0.89,
#    'precipprob': None,
#    'precipcover': 25.0,
#    'preciptype': None,
#    'snow': 1.41,
#    'snowdepth': 7.93,
#    'windgust': None,
#    'windspeed': 14.1,
#    'winddir': 286.5,
#    'pressure': 1018.4,
#    'cloudcover': 100.0,
#    'visibility': 5.9,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:48:22',
#    'sunriseEpoch': 1608209302,
#    'sunset': '17:08:33',
#    'sunsetEpoch': 1608242913,
#    'moonphase': 0.05,
#    'conditions': 'Snow, Overcast',
#    'icon': 'snow',
#    'stations': ['KCMH',
#     'KOSU',
#     '72092800315',
#     'KLHQ',
#     '72428804804',
#     '72428014821'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-18',
#    'datetimeEpoch': 1608267600,
#    'tempmax': 1.3,
#    'tempmin': -2.1,
#    'temp': -0.8,
#    'feelslikemax': 0.4,
#    'feelslikemin': -6.4,
#    'feelslike': -3.8,
#    'dew': -4.0,
#    'humidity': 79.49,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 1.66,
#    'snowdepth': 7.88,
#    'windgust': None,
#    'windspeed': 13.2,
#    'winddir': 229.5,
#    'pressure': 1029.0,
#    'cloudcover': 84.1,
#    'visibility': 11.2,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:48:58',
#    'sunriseEpoch': 1608295738,
#    'sunset': '17:08:56',
#    'sunsetEpoch': 1608329336,
#    'moonphase': 0.09,
#    'conditions': 'Snow, Overcast',
#    'icon': 'snow',
#    'stations': ['KCMH',
#     'KOSU',
#     '72092800315',
#     'KLHQ',
#     '72428804804',
#     '72428014821'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-19',
#    'datetimeEpoch': 1608354000,
#    'tempmax': 4.1,
#    'tempmin': -1.7,
#    'temp': 1.3,
#    'feelslikemax': 1.0,
#    'feelslikemin': -6.0,
#    'feelslike': -2.5,
#    'dew': -2.4,
#    'humidity': 76.74,
#    'precip': 2.64,
#    'precipprob': None,
#    'precipcover': 12.5,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 6.0,
#    'windgust': 35.3,
#    'windspeed': 20.3,
#    'winddir': 159.5,
#    'pressure': 1023.3,
#    'cloudcover': 71.3,
#    'visibility': 15.5,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:49:33',
#    'sunriseEpoch': 1608382173,
#    'sunset': '17:09:22',
#    'sunsetEpoch': 1608415762,
#    'moonphase': 0.13,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['KCMH',
#     'KOSU',
#     '72092800315',
#     'KLHQ',
#     '72428804804',
#     '72428014821'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-20',
#    'datetimeEpoch': 1608440400,
#    'tempmax': 5.8,
#    'tempmin': 0.1,
#    'temp': 3.1,
#    'feelslikemax': 2.8,
#    'feelslikemin': -3.0,
#    'feelslike': 0.0,
#    'dew': 1.9,
#    'humidity': 91.73,
#    'precip': 2.87,
#    'precipprob': None,
#    'precipcover': 29.17,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 1.67,
#    'windgust': 27.7,
#    'windspeed': 16.1,
#    'winddir': 197.4,
#    'pressure': 1014.9,
#    'cloudcover': 80.3,
#    'visibility': 12.3,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:50:05',
#    'sunriseEpoch': 1608468605,
#    'sunset': '17:09:50',
#    'sunsetEpoch': 1608502190,
#    'moonphase': 0.18,
#    'conditions': 'Rain, Overcast',
#    'icon': 'rain',
#    'stations': ['KCMH',
#     'KOSU',
#     '72092800315',
#     'KLHQ',
#     '72428804804',
#     '72428014821'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-21',
#    'datetimeEpoch': 1608526800,
#    'tempmax': 5.6,
#    'tempmin': 0.7,
#    'temp': 2.8,
#    'feelslikemax': 1.8,
#    'feelslikemin': -2.7,
#    'feelslike': -0.6,
#    'dew': 1.2,
#    'humidity': 89.03,
#    'precip': 1.7,
#    'precipprob': None,
#    'precipcover': 8.33,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 37.1,
#    'windspeed': 28.8,
#    'winddir': 208.6,
#    'pressure': 1009.2,
#    'cloudcover': 85.3,
#    'visibility': 11.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:50:36',
#    'sunriseEpoch': 1608555036,
#    'sunset': '17:10:19',
#    'sunsetEpoch': 1608588619,
#    'moonphase': 0.23,
#    'conditions': 'Rain, Overcast',
#    'icon': 'rain',
#    'stations': ['KCMH',
#     'KOSU',
#     '72092800315',
#     'KLHQ',
#     '72428804804',
#     '72428014821'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-22',
#    'datetimeEpoch': 1608613200,
#    'tempmax': 5.6,
#    'tempmin': 0.1,
#    'temp': 3.4,
#    'feelslikemax': 2.4,
#    'feelslikemin': -2.9,
#    'feelslike': -0.3,
#    'dew': -0.4,
#    'humidity': 76.49,
#    'precip': 0.31,
#    'precipprob': None,
#    'precipcover': 8.33,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 48.7,
#    'windspeed': 31.0,
#    'winddir': 251.8,
#    'pressure': 1019.7,
#    'cloudcover': 81.3,
#    'visibility': 15.9,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:51:04',
#    'sunriseEpoch': 1608641464,
#    'sunset': '17:10:51',
#    'sunsetEpoch': 1608675051,
#    'moonphase': 0.28,
#    'conditions': 'Rain, Overcast',
#    'icon': 'rain',
#    'stations': ['KCMH',
#     'KOSU',
#     '72092800315',
#     'KLHQ',
#     '72428804804',
#     '72428014821'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-23',
#    'datetimeEpoch': 1608699600,
#    'tempmax': 12.0,
#    'tempmin': -0.5,
#    'temp': 5.9,
#    'feelslikemax': 12.0,
#    'feelslikemin': -4.1,
#    'feelslike': 3.9,
#    'dew': -2.2,
#    'humidity': 59.83,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 39.7,
#    'windspeed': 27.4,
#    'winddir': 154.0,
#    'pressure': 1017.2,
#    'cloudcover': 60.1,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:51:31',
#    'sunriseEpoch': 1608727891,
#    'sunset': '17:11:25',
#    'sunsetEpoch': 1608761485,
#    'moonphase': 0.32,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['KCMH',
#     'KOSU',
#     '72092800315',
#     'KLHQ',
#     '72428804804',
#     '72428014821'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-24',
#    'datetimeEpoch': 1608786000,
#    'tempmax': 11.0,
#    'tempmin': -7.8,
#    'temp': 1.3,
#    'feelslikemax': 11.0,
#    'feelslikemin': -14.8,
#    'feelslike': -3.5,
#    'dew': -1.1,
#    'humidity': 85.09,
#    'precip': 10.05,
#    'precipprob': None,
#    'precipcover': 87.5,
#    'preciptype': None,
#    'snow': 6.61,
#    'snowdepth': 6.61,
#    'windgust': 50.0,
#    'windspeed': 30.4,
#    'winddir': 256.1,
#    'pressure': 1007.0,
#    'cloudcover': 97.0,
#    'visibility': 7.5,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:51:55',
#    'sunriseEpoch': 1608814315,
#    'sunset': '17:12:01',
#    'sunsetEpoch': 1608847921,
#    'moonphase': 0.37,
#    'conditions': 'Snow, Overcast',
#    'icon': 'snow',
#    'stations': ['KCMH',
#     'KOSU',
#     '72092800315',
#     'KLHQ',
#     '72428804804',
#     '72428014821'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-25',
#    'datetimeEpoch': 1608872400,
#    'tempmax': -7.8,
#    'tempmin': -9.4,
#    'temp': -8.7,
#    'feelslikemax': -15.4,
#    'feelslikemin': -17.7,
#    'feelslike': -16.4,
#    'dew': -12.2,
#    'humidity': 75.7,
#    'precip': 0.46,
#    'precipprob': None,
#    'precipcover': 12.5,
#    'preciptype': None,
#    'snow': 1.5,
#    'snowdepth': 8.11,
#    'windgust': 41.9,
#    'windspeed': 26.0,
#    'winddir': 261.8,
#    'pressure': 1012.3,
#    'cloudcover': 98.7,
#    'visibility': 9.2,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:52:18',
#    'sunriseEpoch': 1608900738,
#    'sunset': '17:12:38',
#    'sunsetEpoch': 1608934358,
#    'moonphase': 0.4,
#    'conditions': 'Snow, Overcast',
#    'icon': 'snow',
#    'stations': ['KCMH',
#     'KOSU',
#     '72092800315',
#     'KLHQ',
#     '72428804804',
#     '72428014821'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-26',
#    'datetimeEpoch': 1608958800,
#    'tempmax': -2.6,
#    'tempmin': -10.2,
#    'temp': -7.0,
#    'feelslikemax': -6.2,
#    'feelslikemin': -19.4,
#    'feelslike': -12.9,
#    'dew': -11.7,
#    'humidity': 69.34,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.07,
#    'snowdepth': 8.18,
#    'windgust': 37.4,
#    'windspeed': 28.1,
#    'winddir': 192.7,
#    'pressure': 1017.4,
#    'cloudcover': 53.0,
#    'visibility': 15.6,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:52:38',
#    'sunriseEpoch': 1608987158,
#    'sunset': '17:13:18',
#    'sunsetEpoch': 1609020798,
#    'moonphase': 0.44,
#    'conditions': 'Snow, Partially cloudy',
#    'icon': 'snow',
#    'stations': ['KCMH',
#     'KOSU',
#     '72092800315',
#     'KLHQ',
#     '72428804804',
#     '72428014821'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-27',
#    'datetimeEpoch': 1609045200,
#    'tempmax': 7.6,
#    'tempmin': -8.4,
#    'temp': -0.4,
#    'feelslikemax': 3.6,
#    'feelslikemin': -10.5,
#    'feelslike': -3.4,
#    'dew': -5.3,
#    'humidity': 71.22,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.68,
#    'snowdepth': 5.48,
#    'windgust': 42.5,
#    'windspeed': 28.3,
#    'winddir': 139.0,
#    'pressure': 1016.5,
#    'cloudcover': 50.4,
#    'visibility': 15.9,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:52:57',
#    'sunriseEpoch': 1609073577,
#    'sunset': '17:13:59',
#    'sunsetEpoch': 1609107239,
#    'moonphase': 0.47,
#    'conditions': 'Snow, Partially cloudy',
#    'icon': 'snow',
#    'stations': ['KCMH',
#     'KOSU',
#     '72092800315',
#     'KLHQ',
#     '72428804804',
#     '72428014821'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-28',
#    'datetimeEpoch': 1609131600,
#    'tempmax': 8.3,
#    'tempmin': -0.6,
#    'temp': 2.8,
#    'feelslikemax': 4.8,
#    'feelslikemin': -5.3,
#    'feelslike': -1.8,
#    'dew': -1.8,
#    'humidity': 72.25,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 1.67,
#    'windgust': 53.6,
#    'windspeed': 27.3,
#    'winddir': 264.7,
#    'pressure': 1021.6,
#    'cloudcover': 97.5,
#    'visibility': 15.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:53:13',
#    'sunriseEpoch': 1609159993,
#    'sunset': '17:14:42',
#    'sunsetEpoch': 1609193682,
#    'moonphase': 0.49,
#    'conditions': 'Overcast',
#    'icon': 'cloudy',
#    'stations': ['KCMH',
#     'KOSU',
#     '72092800315',
#     'KLHQ',
#     '72428804804',
#     '72428014821'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-29',
#    'datetimeEpoch': 1609218000,
#    'tempmax': 2.2,
#    'tempmin': -5.1,
#    'temp': -0.7,
#    'feelslikemax': 1.7,
#    'feelslikemin': -8.3,
#    'feelslike': -3.3,
#    'dew': -7.8,
#    'humidity': 60.85,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 16.0,
#    'winddir': 172.2,
#    'pressure': 1033.2,
#    'cloudcover': 48.5,
#    'visibility': 15.9,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:53:27',
#    'sunriseEpoch': 1609246407,
#    'sunset': '17:15:26',
#    'sunsetEpoch': 1609280126,
#    'moonphase': 0.5,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['KCMH',
#     'KOSU',
#     '72092800315',
#     'KLHQ',
#     '72428804804',
#     '72428014821'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-30',
#    'datetimeEpoch': 1609304400,
#    'tempmax': 9.6,
#    'tempmin': 0.3,
#    'temp': 4.7,
#    'feelslikemax': 7.5,
#    'feelslikemin': -4.8,
#    'feelslike': 1.2,
#    'dew': -0.5,
#    'humidity': 70.86,
#    'precip': 15.15,
#    'precipprob': None,
#    'precipcover': 45.83,
#    'preciptype': None,
#    'snow': 1.88,
#    'snowdepth': 1.88,
#    'windgust': 59.2,
#    'windspeed': 28.8,
#    'winddir': 186.8,
#    'pressure': 1018.2,
#    'cloudcover': 88.0,
#    'visibility': 12.6,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:53:39',
#    'sunriseEpoch': 1609332819,
#    'sunset': '17:16:13',
#    'sunsetEpoch': 1609366573,
#    'moonphase': 0.5,
#    'conditions': 'Snow, Overcast',
#    'icon': 'snow',
#    'stations': ['KCMH',
#     'KOSU',
#     '72092800315',
#     'KLHQ',
#     '72428804804',
#     '72428014821'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-31',
#    'datetimeEpoch': 1609390800,
#    'tempmax': 0.9,
#    'tempmin': -1.3,
#    'temp': -0.3,
#    'feelslikemax': -1.9,
#    'feelslikemin': -5.2,
#    'feelslike': -3.5,
#    'dew': -2.9,
#    'humidity': 82.95,
#    'precip': 3.49,
#    'precipprob': None,
#    'precipcover': 25.0,
#    'preciptype': None,
#    'snow': 1.12,
#    'snowdepth': 3.0,
#    'windgust': None,
#    'windspeed': 18.2,
#    'winddir': 140.5,
#    'pressure': 1024.4,
#    'cloudcover': 93.5,
#    'visibility': 12.6,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:53:48',
#    'sunriseEpoch': 1609419228,
#    'sunset': '17:17:01',
#    'sunsetEpoch': 1609453021,
#    'moonphase': 0.51,
#    'conditions': 'Snow, Overcast',
#    'icon': 'snow',
#    'stations': ['KCMH',
#     'KOSU',
#     '72092800315',
#     'KLHQ',
#     '72428804804',
#     '72428014821'],
#    'source': 'obs',
#    'hours': None}],
#  'stations': {'KCMH': {'distance': 11297.0,
#    'latitude': 40.0,
#    'longitude': -82.88,
#    'useCount': 0,
#    'id': 'KCMH',
#    'name': 'KCMH',
#    'quality': 100,
#    'contribution': 0.0},
#   'KOSU': {'distance': 14331.0,
#    'latitude': 40.08,
#    'longitude': -83.07,
#    'useCount': 0,
#    'id': 'KOSU',
#    'name': 'KOSU',
#    'quality': 100,
#    'contribution': 0.0},
#   'KLHQ': {'distance': 36928.0,
#    'latitude': 39.76,
#    'longitude': -82.66,
#    'useCount': 0,
#    'id': 'KLHQ',
#    'name': 'KLHQ',
#    'quality': 100,
#    'contribution': 0.0},
#   '72092800315': {'distance': 36665.0,
#    'latitude': 40.28,
#    'longitude': -83.115,
#    'useCount': 0,
#    'id': '72092800315',
#    'name': 'DELAWARE MUNICIPAL JIM MOORE FIELD AIRPORT, OH US',
#    'quality': 100,
#    'contribution': 0.0},
#   '72428804804': {'distance': 14431.0,
#    'latitude': 40.078,
#    'longitude': -83.078,
#    'useCount': 0,
#    'id': '72428804804',
#    'name': 'COLUMBUS OHIO STATE UNIVERSITY AIRPORT, OH US',
#    'quality': 100,
#    'contribution': 0.0},
#   '72428014821': {'distance': 11197.0,
#    'latitude': 39.991,
#    'longitude': -82.877,
#    'useCount': 0,
#    'id': '72428014821',
#    'name': 'PORT COLUMBUS INTERNATIONAL AIRPORT, OH US',
#    'quality': 100,
#    'contribution': 0.0}}}

# %%
#3. We create empty lists to transfer the data
temperature = []
date = []
city = []

# %%
#4. We loop thropugh the API and extract the info we need
for x in range(366):
    temperature.append(response["days"][x]["temp"])
    date.append(response["days"][x]["datetime"])
    city.append("Columbus, OH")

# %%
len(city)
# Out:
# 366

# %%
len(date)
# Out:
# 366

# %%
len (temperature)
# Out:
# 366

# %%
#5. We create a dataframe based on the lists
New_df = pd.DataFrame(
    {'City': city,
     'Date': date,
     'Temperature': temperature
    })

# %%
New_df
# Out:
#              City        Date  Temperature
# 0    Columbus, OH  2020-01-01          2.4
# 1    Columbus, OH  2020-01-02          5.5
# 2    Columbus, OH  2020-01-03          9.4
# 3    Columbus, OH  2020-01-04          3.6
# 4    Columbus, OH  2020-01-05          1.9
# ..            ...         ...          ...
# 361  Columbus, OH  2020-12-27         -0.4
# 362  Columbus, OH  2020-12-28          2.8
# 363  Columbus, OH  2020-12-29         -0.7
# 364  Columbus, OH  2020-12-30          4.7
# 365  Columbus, OH  2020-12-31         -0.3
#
# [366 rows x 3 columns]

# %%
#6. We add new city dataframe to original dataframe including cities already evaluated 

frames = [Final_df,New_df]

# %%
Final_df = pd.concat(frames)

# %%
Final_df
# Out:
#               City        Date  Temperature
# 0    Asheville, NC  2020-01-01          3.8
# 1    Asheville, NC  2020-01-02          3.8
# 2    Asheville, NC  2020-01-03         10.8
# 3    Asheville, NC  2020-01-04          8.2
# 4    Asheville, NC  2020-01-05          1.9
# ..             ...         ...          ...
# 361   Columbus, OH  2020-12-27         -0.4
# 362   Columbus, OH  2020-12-28          2.8
# 363   Columbus, OH  2020-12-29         -0.7
# 364   Columbus, OH  2020-12-30          4.7
# 365   Columbus, OH  2020-12-31         -0.3
#
# [2928 rows x 3 columns]

# %%
#7.Update to csv by converting df to csv
Final_df.to_csv("Temperature_Dataset1.csv", index=False)

# %%
#8. Will need to import CSV with temp for cities already evaluated every time this document is open again for the 1st time. 
#Name dataframe: Final_df

file_path = os.path.join("Temperature_Dataset1.csv")
Final_df = pd.read_csv(file_path)
Final_df
# Out:
#                City        Date  Temperature
# 0     Asheville, NC  2020-01-01          3.8
# 1     Asheville, NC  2020-01-02          3.8
# 2     Asheville, NC  2020-01-03         10.8
# 3     Asheville, NC  2020-01-04          8.2
# 4     Asheville, NC  2020-01-05          1.9
# ...             ...         ...          ...
# 2923   Columbus, OH  2020-12-27         -0.4
# 2924   Columbus, OH  2020-12-28          2.8
# 2925   Columbus, OH  2020-12-29         -0.7
# 2926   Columbus, OH  2020-12-30          4.7
# 2927   Columbus, OH  2020-12-31         -0.3
#
# [2928 rows x 3 columns]
