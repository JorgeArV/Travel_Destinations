# %%
# 1.Importing dependencies

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import os

# %%
#2. We add url. Each city will have a new url

url2 = "https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/Pacific%20Grove/2020-1-1/2020-12-31?unitGroup=metric&key=SRX784Y4XEDTND44NFLHKK42Z&include=obs"

# %%
response = requests.get(url2).json()

# %%
response
# Out:
# {'queryCost': 366,
#  'latitude': 36.61933,
#  'longitude': -121.91859,
#  'resolvedAddress': 'Pacific Grove, CA, United States',
#  'address': 'Pacific Grove',
#  'timezone': 'America/Los_Angeles',
#  'tzoffset': -8.0,
#  'days': [{'datetime': '2020-01-01',
#    'datetimeEpoch': 1577865600,
#    'tempmax': 15.0,
#    'tempmin': 8.0,
#    'temp': 12.2,
#    'feelslikemax': 15.0,
#    'feelslikemin': 6.8,
#    'feelslike': 12.2,
#    'dew': 9.5,
#    'humidity': 83.47,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 31.7,
#    'windspeed': 16.4,
#    'winddir': 239.9,
#    'pressure': 1022.0,
#    'cloudcover': 60.5,
#    'visibility': 14.9,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:20:01',
#    'sunriseEpoch': 1577892001,
#    'sunset': '17:02:26',
#    'sunsetEpoch': 1577926946,
#    'moonphase': 0.17,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['72593023233',
#     '74505823277',
#     'KMRY',
#     'KWVI',
#     'KSNS',
#     '72491523259'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-02',
#    'datetimeEpoch': 1577952000,
#    'tempmax': 16.3,
#    'tempmin': 9.2,
#    'temp': 12.9,
#    'feelslikemax': 16.3,
#    'feelslikemin': 8.3,
#    'feelslike': 12.9,
#    'dew': 8.9,
#    'humidity': 77.05,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 27.7,
#    'windspeed': 13.8,
#    'winddir': 196.2,
#    'pressure': 1021.0,
#    'cloudcover': 22.0,
#    'visibility': 14.7,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:20:10',
#    'sunriseEpoch': 1577978410,
#    'sunset': '17:03:14',
#    'sunsetEpoch': 1578013394,
#    'moonphase': 0.22,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['72593023233',
#     '74505823277',
#     'KMRY',
#     'KWVI',
#     'KSNS',
#     '72491523259'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-03',
#    'datetimeEpoch': 1578038400,
#    'tempmax': 19.2,
#    'tempmin': 7.7,
#    'temp': 12.4,
#    'feelslikemax': 19.2,
#    'feelslikemin': 6.3,
#    'feelslike': 11.8,
#    'dew': 4.6,
#    'humidity': 60.66,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 14.3,
#    'winddir': 113.1,
#    'pressure': 1024.0,
#    'cloudcover': 0.3,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:20:18',
#    'sunriseEpoch': 1578064818,
#    'sunset': '17:04:02',
#    'sunsetEpoch': 1578099842,
#    'moonphase': 0.26,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['72593023233',
#     '74505823277',
#     'KMRY',
#     'KWVI',
#     'KSNS',
#     '72491523259'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-04',
#    'datetimeEpoch': 1578124800,
#    'tempmax': 15.4,
#    'tempmin': 8.3,
#    'temp': 12.1,
#    'feelslikemax': 15.4,
#    'feelslikemin': 7.1,
#    'feelslike': 11.9,
#    'dew': 8.5,
#    'humidity': 78.67,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 14.8,
#    'winddir': 188.4,
#    'pressure': 1029.9,
#    'cloudcover': 59.7,
#    'visibility': 15.9,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:20:23',
#    'sunriseEpoch': 1578151223,
#    'sunset': '17:04:52',
#    'sunsetEpoch': 1578186292,
#    'moonphase': 0.31,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['72593023233',
#     '74505823277',
#     'KMRY',
#     'KWVI',
#     'KSNS',
#     '72491523259'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-05',
#    'datetimeEpoch': 1578211200,
#    'tempmax': 16.1,
#    'tempmin': 6.6,
#    'temp': 11.5,
#    'feelslikemax': 16.1,
#    'feelslikemin': 3.9,
#    'feelslike': 11.2,
#    'dew': 6.6,
#    'humidity': 73.07,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 13.9,
#    'winddir': 217.8,
#    'pressure': 1034.4,
#    'cloudcover': 15.8,
#    'visibility': 15.8,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:20:27',
#    'sunriseEpoch': 1578237627,
#    'sunset': '17:05:43',
#    'sunsetEpoch': 1578272743,
#    'moonphase': 0.36,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['72593023233',
#     '74505823277',
#     'KMRY',
#     'KWVI',
#     'KSNS',
#     '72491523259'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-06',
#    'datetimeEpoch': 1578297600,
#    'tempmax': 19.2,
#    'tempmin': 5.9,
#    'temp': 11.1,
#    'feelslikemax': 19.2,
#    'feelslikemin': 4.0,
#    'feelslike': 10.4,
#    'dew': 3.4,
#    'humidity': 62.77,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 15.7,
#    'winddir': 108.6,
#    'pressure': 1031.5,
#    'cloudcover': 0.0,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:20:28',
#    'sunriseEpoch': 1578324028,
#    'sunset': '17:06:36',
#    'sunsetEpoch': 1578359196,
#    'moonphase': 0.4,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['72593023233',
#     '74505823277',
#     'KMRY',
#     'KWVI',
#     'KSNS',
#     '72491523259'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-07',
#    'datetimeEpoch': 1578384000,
#    'tempmax': 14.9,
#    'tempmin': 4.9,
#    'temp': 10.3,
#    'feelslikemax': 14.9,
#    'feelslikemin': 3.5,
#    'feelslike': 10.0,
#    'dew': 4.5,
#    'humidity': 67.35,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 16.0,
#    'winddir': 167.6,
#    'pressure': 1023.7,
#    'cloudcover': 27.8,
#    'visibility': 15.6,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:20:28',
#    'sunriseEpoch': 1578410428,
#    'sunset': '17:07:29',
#    'sunsetEpoch': 1578445649,
#    'moonphase': 0.44,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['72593023233',
#     '74505823277',
#     'KMRY',
#     'KWVI',
#     'KSNS',
#     '72491523259'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-08',
#    'datetimeEpoch': 1578470400,
#    'tempmax': 13.8,
#    'tempmin': 8.7,
#    'temp': 11.7,
#    'feelslikemax': 13.8,
#    'feelslikemin': 7.6,
#    'feelslike': 11.6,
#    'dew': 8.0,
#    'humidity': 78.82,
#    'precip': 2.79,
#    'precipprob': None,
#    'precipcover': 12.5,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 15.0,
#    'winddir': 220.5,
#    'pressure': 1021.7,
#    'cloudcover': 53.9,
#    'visibility': 15.5,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:20:25',
#    'sunriseEpoch': 1578496825,
#    'sunset': '17:08:23',
#    'sunsetEpoch': 1578532103,
#    'moonphase': 0.47,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['72593023233',
#     '74505823277',
#     'KMRY',
#     'KWVI',
#     'KSNS',
#     '72491523259'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-09',
#    'datetimeEpoch': 1578556800,
#    'tempmax': 15.5,
#    'tempmin': 6.7,
#    'temp': 11.0,
#    'feelslikemax': 15.5,
#    'feelslikemin': 5.3,
#    'feelslike': 10.7,
#    'dew': 7.0,
#    'humidity': 76.68,
#    'precip': 3.63,
#    'precipprob': None,
#    'precipcover': 25.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 50.4,
#    'windspeed': 23.2,
#    'winddir': 184.8,
#    'pressure': 1019.7,
#    'cloudcover': 48.1,
#    'visibility': 14.8,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:20:21',
#    'sunriseEpoch': 1578583221,
#    'sunset': '17:09:18',
#    'sunsetEpoch': 1578618558,
#    'moonphase': 0.49,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['72593023233',
#     '74505823277',
#     'KMRY',
#     'KWVI',
#     'KSNS',
#     '72491523259'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-10',
#    'datetimeEpoch': 1578643200,
#    'tempmax': 14.3,
#    'tempmin': 5.4,
#    'temp': 10.1,
#    'feelslikemax': 14.3,
#    'feelslikemin': 3.5,
#    'feelslike': 9.4,
#    'dew': 5.0,
#    'humidity': 71.49,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 13.9,
#    'winddir': 190.8,
#    'pressure': 1027.0,
#    'cloudcover': 15.0,
#    'visibility': 15.8,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:20:14',
#    'sunriseEpoch': 1578669614,
#    'sunset': '17:10:14',
#    'sunsetEpoch': 1578705014,
#    'moonphase': 0.5,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['72593023233',
#     '74505823277',
#     'KMRY',
#     'KWVI',
#     'KSNS',
#     '72491523259'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-11',
#    'datetimeEpoch': 1578729600,
#    'tempmax': 14.3,
#    'tempmin': 8.7,
#    'temp': 11.6,
#    'feelslikemax': 14.3,
#    'feelslikemin': 8.2,
#    'feelslike': 11.5,
#    'dew': 6.8,
#    'humidity': 73.08,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 38.9,
#    'windspeed': 25.0,
#    'winddir': 242.9,
#    'pressure': 1026.0,
#    'cloudcover': 53.5,
#    'visibility': 15.6,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:20:06',
#    'sunriseEpoch': 1578756006,
#    'sunset': '17:11:12',
#    'sunsetEpoch': 1578791472,
#    'moonphase': 0.51,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['72593023233',
#     '74505823277',
#     'KMRY',
#     'KWVI',
#     'KSNS',
#     '72491523259'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-12',
#    'datetimeEpoch': 1578816000,
#    'tempmax': 13.3,
#    'tempmin': 6.4,
#    'temp': 10.3,
#    'feelslikemax': 13.3,
#    'feelslikemin': 5.6,
#    'feelslike': 10.0,
#    'dew': 5.3,
#    'humidity': 71.93,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 17.6,
#    'winddir': 233.8,
#    'pressure': 1024.3,
#    'cloudcover': 18.9,
#    'visibility': 15.6,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:19:56',
#    'sunriseEpoch': 1578842396,
#    'sunset': '17:12:09',
#    'sunsetEpoch': 1578877929,
#    'moonphase': 0.52,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['72593023233',
#     '74505823277',
#     'KMRY',
#     'KWVI',
#     'KSNS',
#     '72491523259'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-13',
#    'datetimeEpoch': 1578902400,
#    'tempmax': 14.0,
#    'tempmin': 7.7,
#    'temp': 10.6,
#    'feelslikemax': 14.0,
#    'feelslikemin': 6.9,
#    'feelslike': 10.0,
#    'dew': 5.9,
#    'humidity': 73.39,
#    'precip': 0.02,
#    'precipprob': None,
#    'precipcover': 4.17,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 14.7,
#    'winddir': 163.2,
#    'pressure': 1024.2,
#    'cloudcover': 39.8,
#    'visibility': 15.6,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:19:43',
#    'sunriseEpoch': 1578928783,
#    'sunset': '17:13:08',
#    'sunsetEpoch': 1578964388,
#    'moonphase': 0.55,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['72593023233',
#     '74505823277',
#     'KMRY',
#     'KWVI',
#     'KSNS',
#     '72491523259'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-14',
#    'datetimeEpoch': 1578988800,
#    'tempmax': 13.6,
#    'tempmin': 6.6,
#    'temp': 10.9,
#    'feelslikemax': 13.6,
#    'feelslikemin': 5.1,
#    'feelslike': 10.6,
#    'dew': 5.7,
#    'humidity': 71.09,
#    'precip': 0.95,
#    'precipprob': None,
#    'precipcover': 12.5,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 38.9,
#    'windspeed': 16.1,
#    'winddir': 181.8,
#    'pressure': 1024.4,
#    'cloudcover': 38.5,
#    'visibility': 15.6,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:19:29',
#    'sunriseEpoch': 1579015169,
#    'sunset': '17:14:07',
#    'sunsetEpoch': 1579050847,
#    'moonphase': 0.59,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['72593023233',
#     '74505823277',
#     'KMRY',
#     'KWVI',
#     'KSNS',
#     '72491523259'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-15',
#    'datetimeEpoch': 1579075200,
#    'tempmax': 13.9,
#    'tempmin': 3.7,
#    'temp': 8.3,
#    'feelslikemax': 13.9,
#    'feelslikemin': 1.4,
#    'feelslike': 7.2,
#    'dew': 3.4,
#    'humidity': 72.08,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 29.5,
#    'windspeed': 19.2,
#    'winddir': 139.6,
#    'pressure': 1019.1,
#    'cloudcover': 0.3,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:19:12',
#    'sunriseEpoch': 1579101552,
#    'sunset': '17:15:08',
#    'sunsetEpoch': 1579137308,
#    'moonphase': 0.64,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['72593023233',
#     '74505823277',
#     'KMRY',
#     'KWVI',
#     'KSNS',
#     '72491523259'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-16',
#    'datetimeEpoch': 1579161600,
#    'tempmax': 15.2,
#    'tempmin': 7.5,
#    'temp': 9.8,
#    'feelslikemax': 15.2,
#    'feelslikemin': 5.6,
#    'feelslike': 8.4,
#    'dew': 4.9,
#    'humidity': 72.54,
#    'precip': 23.39,
#    'precipprob': None,
#    'precipcover': 58.33,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 64.8,
#    'windspeed': 31.8,
#    'winddir': 165.5,
#    'pressure': 1014.4,
#    'cloudcover': 58.9,
#    'visibility': 14.1,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:18:54',
#    'sunriseEpoch': 1579187934,
#    'sunset': '17:16:08',
#    'sunsetEpoch': 1579223768,
#    'moonphase': 0.69,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['72593023233',
#     '74505823277',
#     'KMRY',
#     'KWVI',
#     'KSNS',
#     '72491523259'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-17',
#    'datetimeEpoch': 1579248000,
#    'tempmax': 13.4,
#    'tempmin': 5.9,
#    'temp': 9.0,
#    'feelslikemax': 13.4,
#    'feelslikemin': 2.9,
#    'feelslike': 7.7,
#    'dew': 4.2,
#    'humidity': 72.87,
#    'precip': 0.49,
#    'precipprob': None,
#    'precipcover': 8.33,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 14.9,
#    'winddir': 160.7,
#    'pressure': 1026.0,
#    'cloudcover': 4.9,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:18:33',
#    'sunriseEpoch': 1579274313,
#    'sunset': '17:17:09',
#    'sunsetEpoch': 1579310229,
#    'moonphase': 0.75,
#    'conditions': 'Rain',
#    'icon': 'rain',
#    'stations': ['72593023233',
#     '74505823277',
#     'KMRY',
#     'KWVI',
#     'KSNS',
#     '72491523259'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-18',
#    'datetimeEpoch': 1579334400,
#    'tempmax': 14.3,
#    'tempmin': 4.4,
#    'temp': 8.6,
#    'feelslikemax': 14.3,
#    'feelslikemin': 2.6,
#    'feelslike': 8.3,
#    'dew': 3.3,
#    'humidity': 70.43,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 12.8,
#    'winddir': 44.5,
#    'pressure': 1026.2,
#    'cloudcover': 0.0,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:18:11',
#    'sunriseEpoch': 1579360691,
#    'sunset': '17:18:11',
#    'sunsetEpoch': 1579396691,
#    'moonphase': 0.81,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['72593023233',
#     '74505823277',
#     'KMRY',
#     'KWVI',
#     'KSNS',
#     '72491523259'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-19',
#    'datetimeEpoch': 1579420800,
#    'tempmax': 15.2,
#    'tempmin': 4.5,
#    'temp': 9.6,
#    'feelslikemax': 15.2,
#    'feelslikemin': 3.0,
#    'feelslike': 9.0,
#    'dew': 4.0,
#    'humidity': 68.78,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 51.8,
#    'windspeed': 12.3,
#    'winddir': 116.4,
#    'pressure': 1020.2,
#    'cloudcover': 0.0,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:17:47',
#    'sunriseEpoch': 1579447067,
#    'sunset': '17:19:14',
#    'sunsetEpoch': 1579483154,
#    'moonphase': 0.86,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['72593023233',
#     '74505823277',
#     'KMRY',
#     'KWVI',
#     'KSNS',
#     '72491523259'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-20',
#    'datetimeEpoch': 1579507200,
#    'tempmax': 13.8,
#    'tempmin': 8.7,
#    'temp': 11.6,
#    'feelslikemax': 13.8,
#    'feelslikemin': 8.6,
#    'feelslike': 11.4,
#    'dew': 6.3,
#    'humidity': 70.61,
#    'precip': 0.38,
#    'precipprob': None,
#    'precipcover': 8.33,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 11.0,
#    'winddir': 154.8,
#    'pressure': 1018.3,
#    'cloudcover': 41.0,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:17:21',
#    'sunriseEpoch': 1579533441,
#    'sunset': '17:20:16',
#    'sunsetEpoch': 1579569616,
#    'moonphase': 0.91,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['72593023233',
#     '74505823277',
#     'KMRY',
#     'KWVI',
#     'KSNS',
#     '72491523259'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-21',
#    'datetimeEpoch': 1579593600,
#    'tempmax': 17.0,
#    'tempmin': 7.7,
#    'temp': 12.2,
#    'feelslikemax': 17.0,
#    'feelslikemin': 5.9,
#    'feelslike': 11.7,
#    'dew': 8.2,
#    'humidity': 77.96,
#    'precip': 0.16,
#    'precipprob': None,
#    'precipcover': 25.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 31.7,
#    'windspeed': 19.4,
#    'winddir': 136.0,
#    'pressure': 1022.1,
#    'cloudcover': 67.0,
#    'visibility': 15.4,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:16:53',
#    'sunriseEpoch': 1579619813,
#    'sunset': '17:21:19',
#    'sunsetEpoch': 1579656079,
#    'moonphase': 0.95,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['72593023233',
#     '74505823277',
#     'KMRY',
#     'KWVI',
#     'KSNS',
#     '72491523259'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-22',
#    'datetimeEpoch': 1579680000,
#    'tempmax': 16.7,
#    'tempmin': 10.0,
#    'temp': 13.2,
#    'feelslikemax': 16.7,
#    'feelslikemin': 10.0,
#    'feelslike': 13.2,
#    'dew': 10.8,
#    'humidity': 85.81,
#    'precip': 0.74,
#    'precipprob': None,
#    'precipcover': 29.17,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 8.0,
#    'winddir': 151.0,
#    'pressure': 1024.7,
#    'cloudcover': 57.0,
#    'visibility': 12.3,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:16:23',
#    'sunriseEpoch': 1579706183,
#    'sunset': '17:22:23',
#    'sunsetEpoch': 1579742543,
#    'moonphase': 0.98,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['72593023233',
#     '74505823277',
#     'KMRY',
#     'KWVI',
#     'KSNS',
#     '72491523259'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-23',
#    'datetimeEpoch': 1579766400,
#    'tempmax': 18.4,
#    'tempmin': 8.0,
#    'temp': 12.3,
#    'feelslikemax': 18.4,
#    'feelslikemin': 7.2,
#    'feelslike': 12.2,
#    'dew': 8.9,
#    'humidity': 80.57,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 11.0,
#    'winddir': 127.2,
#    'pressure': 1023.0,
#    'cloudcover': 10.8,
#    'visibility': 14.8,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:15:51',
#    'sunriseEpoch': 1579792551,
#    'sunset': '17:23:27',
#    'sunsetEpoch': 1579829007,
#    'moonphase': 0.99,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['72593023233',
#     '74505823277',
#     'KMRY',
#     'KWVI',
#     'KSNS',
#     '72491523259'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-24',
#    'datetimeEpoch': 1579852800,
#    'tempmax': 18.8,
#    'tempmin': 8.8,
#    'temp': 13.2,
#    'feelslikemax': 18.8,
#    'feelslikemin': 7.2,
#    'feelslike': 13.1,
#    'dew': 10.0,
#    'humidity': 81.96,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 15.1,
#    'winddir': 227.1,
#    'pressure': 1022.2,
#    'cloudcover': 17.6,
#    'visibility': 14.6,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:15:18',
#    'sunriseEpoch': 1579878918,
#    'sunset': '17:24:31',
#    'sunsetEpoch': 1579915471,
#    'moonphase': 1.0,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['72593023233',
#     '74505823277',
#     'KMRY',
#     'KWVI',
#     'KSNS',
#     '72491523259'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-25',
#    'datetimeEpoch': 1579939200,
#    'tempmax': 16.4,
#    'tempmin': 9.9,
#    'temp': 13.4,
#    'feelslikemax': 16.4,
#    'feelslikemin': 9.4,
#    'feelslike': 13.3,
#    'dew': 10.7,
#    'humidity': 84.4,
#    'precip': 0.24,
#    'precipprob': None,
#    'precipcover': 4.17,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 13.3,
#    'winddir': 194.9,
#    'pressure': 1021.7,
#    'cloudcover': 26.6,
#    'visibility': 14.4,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:14:42',
#    'sunriseEpoch': 1579965282,
#    'sunset': '17:25:35',
#    'sunsetEpoch': 1580001935,
#    'moonphase': 0.0,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['72593023233',
#     '74505823277',
#     'KMRY',
#     'KWVI',
#     'KSNS',
#     '72491523259'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-26',
#    'datetimeEpoch': 1580025600,
#    'tempmax': 15.1,
#    'tempmin': 11.1,
#    'temp': 13.9,
#    'feelslikemax': 15.1,
#    'feelslikemin': 11.1,
#    'feelslike': 13.9,
#    'dew': 11.6,
#    'humidity': 86.66,
#    'precip': 3.32,
#    'precipprob': None,
#    'precipcover': 41.67,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 14.7,
#    'winddir': 230.0,
#    'pressure': 1025.1,
#    'cloudcover': 77.9,
#    'visibility': 13.6,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:14:05',
#    'sunriseEpoch': 1580051645,
#    'sunset': '17:26:39',
#    'sunsetEpoch': 1580088399,
#    'moonphase': 0.01,
#    'conditions': 'Rain, Overcast',
#    'icon': 'rain',
#    'stations': ['72593023233',
#     '74505823277',
#     'KMRY',
#     'KWVI',
#     'KSNS',
#     '72491523259'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-27',
#    'datetimeEpoch': 1580112000,
#    'tempmax': 15.1,
#    'tempmin': 6.7,
#    'temp': 11.5,
#    'feelslikemax': 15.1,
#    'feelslikemin': 5.5,
#    'feelslike': 11.2,
#    'dew': 8.2,
#    'humidity': 80.88,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 12.8,
#    'winddir': 233.5,
#    'pressure': 1030.0,
#    'cloudcover': 23.1,
#    'visibility': 15.8,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:13:26',
#    'sunriseEpoch': 1580138006,
#    'sunset': '17:27:44',
#    'sunsetEpoch': 1580174864,
#    'moonphase': 0.03,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['72593023233',
#     '74505823277',
#     'KMRY',
#     'KWVI',
#     'KSNS',
#     '72491523259'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-28',
#    'datetimeEpoch': 1580198400,
#    'tempmax': 16.7,
#    'tempmin': 9.2,
#    'temp': 12.8,
#    'feelslikemax': 16.7,
#    'feelslikemin': 7.1,
#    'feelslike': 12.5,
#    'dew': 8.9,
#    'humidity': 78.44,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 14.6,
#    'winddir': 198.1,
#    'pressure': 1028.7,
#    'cloudcover': 47.5,
#    'visibility': 15.8,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:12:46',
#    'sunriseEpoch': 1580224366,
#    'sunset': '17:28:49',
#    'sunsetEpoch': 1580261329,
#    'moonphase': 0.06,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['72593023233',
#     '74505823277',
#     'KMRY',
#     'KWVI',
#     'KSNS',
#     '72491523259'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-29',
#    'datetimeEpoch': 1580284800,
#    'tempmax': 16.1,
#    'tempmin': 7.0,
#    'temp': 11.6,
#    'feelslikemax': 16.1,
#    'feelslikemin': 4.5,
#    'feelslike': 11.1,
#    'dew': 7.8,
#    'humidity': 78.62,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 16.2,
#    'winddir': 186.2,
#    'pressure': 1025.3,
#    'cloudcover': 11.6,
#    'visibility': 14.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:12:03',
#    'sunriseEpoch': 1580310723,
#    'sunset': '17:29:53',
#    'sunsetEpoch': 1580347793,
#    'moonphase': 0.09,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['72593023233',
#     '74505823277',
#     'KMRY',
#     'KWVI',
#     'KSNS',
#     '72491523259'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-30',
#    'datetimeEpoch': 1580371200,
#    'tempmax': 16.1,
#    'tempmin': 7.7,
#    'temp': 11.7,
#    'feelslikemax': 16.1,
#    'feelslikemin': 5.7,
#    'feelslike': 11.5,
#    'dew': 9.8,
#    'humidity': 87.96,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 14.4,
#    'winddir': 206.0,
#    'pressure': 1025.5,
#    'cloudcover': 40.7,
#    'visibility': 10.9,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:11:19',
#    'sunriseEpoch': 1580397079,
#    'sunset': '17:30:58',
#    'sunsetEpoch': 1580434258,
#    'moonphase': 0.13,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['72593023233',
#     '74505823277',
#     'KMRY',
#     'KWVI',
#     'KSNS',
#     '72491523259'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-31',
#    'datetimeEpoch': 1580457600,
#    'tempmax': 21.9,
#    'tempmin': 8.3,
#    'temp': 13.1,
#    'feelslikemax': 21.9,
#    'feelslikemin': 7.9,
#    'feelslike': 13.1,
#    'dew': 9.4,
#    'humidity': 79.39,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 13.2,
#    'winddir': 166.6,
#    'pressure': 1026.5,
#    'cloudcover': 3.7,
#    'visibility': 15.1,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:10:33',
#    'sunriseEpoch': 1580483433,
#    'sunset': '17:32:03',
#    'sunsetEpoch': 1580520723,
#    'moonphase': 0.18,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['72593023233',
#     '74505823277',
#     'KMRY',
#     'KWVI',
#     'KSNS',
#     '72491523259'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-01',
#    'datetimeEpoch': 1580544000,
#    'tempmax': 18.1,
#    'tempmin': 7.4,
#    'temp': 12.1,
#    'feelslikemax': 18.1,
#    'feelslikemin': 6.4,
#    'feelslike': 11.7,
#    'dew': 8.9,
#    'humidity': 81.82,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 13.0,
#    'winddir': 203.5,
#    'pressure': 1025.2,
#    'cloudcover': 16.5,
#    'visibility': 12.4,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:09:46',
#    'sunriseEpoch': 1580569786,
#    'sunset': '17:33:08',
#    'sunsetEpoch': 1580607188,
#    'moonphase': 0.22,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['72593023233',
#     '74505823277',
#     'KMRY',
#     'KWVI',
#     'KSNS',
#     '72491523259'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-02',
#    'datetimeEpoch': 1580630400,
#    'tempmax': 13.6,
#    'tempmin': 9.2,
#    'temp': 11.5,
#    'feelslikemax': 13.6,
#    'feelslikemin': 6.1,
#    'feelslike': 11.2,
#    'dew': 6.1,
#    'humidity': 71.22,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 61.7,
#    'windspeed': 37.9,
#    'winddir': 275.9,
#    'pressure': 1021.6,
#    'cloudcover': 59.1,
#    'visibility': 13.7,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:08:57',
#    'sunriseEpoch': 1580656137,
#    'sunset': '17:34:13',
#    'sunsetEpoch': 1580693653,
#    'moonphase': 0.27,
#    'conditions': 'Partially cloudy',
#    'icon': 'wind',
#    'stations': ['72593023233',
#     '74505823277',
#     'KMRY',
#     'KWVI',
#     'KSNS',
#     '72491523259'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-03',
#    'datetimeEpoch': 1580716800,
#    'tempmax': 12.9,
#    'tempmin': 3.3,
#    'temp': 9.2,
#    'feelslikemax': 12.9,
#    'feelslikemin': 1.9,
#    'feelslike': 8.5,
#    'dew': -0.9,
#    'humidity': 51.61,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 40.7,
#    'windspeed': 24.9,
#    'winddir': 273.8,
#    'pressure': 1021.4,
#    'cloudcover': 3.9,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:08:07',
#    'sunriseEpoch': 1580742487,
#    'sunset': '17:35:17',
#    'sunsetEpoch': 1580780117,
#    'moonphase': 0.32,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['72593023233',
#     '74505823277',
#     'KMRY',
#     'KWVI',
#     'KSNS',
#     '72491523259'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-04',
#    'datetimeEpoch': 1580803200,
#    'tempmax': 13.3,
#    'tempmin': 1.5,
#    'temp': 7.6,
#    'feelslikemax': 13.3,
#    'feelslikemin': -1.7,
#    'feelslike': 6.2,
#    'dew': -5.6,
#    'humidity': 40.84,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 27.7,
#    'windspeed': 14.4,
#    'winddir': 159.6,
#    'pressure': 1024.9,
#    'cloudcover': 0.0,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:07:15',
#    'sunriseEpoch': 1580828835,
#    'sunset': '17:36:22',
#    'sunsetEpoch': 1580866582,
#    'moonphase': 0.37,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['72593023233',
#     '74505823277',
#     'KMRY',
#     'KWVI',
#     'KSNS',
#     '72491523259'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-05',
#    'datetimeEpoch': 1580889600,
#    'tempmax': 14.4,
#    'tempmin': 3.3,
#    'temp': 9.4,
#    'feelslikemax': 14.4,
#    'feelslikemin': 1.3,
#    'feelslike': 8.8,
#    'dew': -0.8,
#    'humidity': 50.58,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 11.1,
#    'winddir': 183.6,
#    'pressure': 1025.1,
#    'cloudcover': 0.0,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:06:21',
#    'sunriseEpoch': 1580915181,
#    'sunset': '17:37:26',
#    'sunsetEpoch': 1580953046,
#    'moonphase': 0.41,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['72593023233',
#     '74505823277',
#     'KMRY',
#     'KWVI',
#     'KSNS',
#     '72491523259'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-06',
#    'datetimeEpoch': 1580976000,
#    'tempmax': 15.7,
#    'tempmin': 5.4,
#    'temp': 10.1,
#    'feelslikemax': 15.7,
#    'feelslikemin': 3.8,
#    'feelslike': 9.6,
#    'dew': 5.0,
#    'humidity': 72.03,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 10.3,
#    'winddir': 199.6,
#    'pressure': 1022.4,
#    'cloudcover': 0.6,
#    'visibility': 15.9,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:05:26',
#    'sunriseEpoch': 1581001526,
#    'sunset': '17:38:31',
#    'sunsetEpoch': 1581039511,
#    'moonphase': 0.45,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['72593023233',
#     '74505823277',
#     'KMRY',
#     'KWVI',
#     'KSNS',
#     '72491523259'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-07',
#    'datetimeEpoch': 1581062400,
#    'tempmax': 14.6,
#    'tempmin': 5.5,
#    'temp': 10.1,
#    'feelslikemax': 14.6,
#    'feelslikemin': 4.4,
#    'feelslike': 9.9,
#    'dew': 6.8,
#    'humidity': 80.54,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 11.2,
#    'winddir': 186.3,
#    'pressure': 1021.4,
#    'cloudcover': 25.9,
#    'visibility': 11.9,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:04:29',
#    'sunriseEpoch': 1581087869,
#    'sunset': '17:39:35',
#    'sunsetEpoch': 1581125975,
#    'moonphase': 0.48,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['72593023233',
#     '74505823277',
#     'KMRY',
#     'KWVI',
#     'KSNS',
#     '72491523259'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-08',
#    'datetimeEpoch': 1581148800,
#    'tempmax': 13.4,
#    'tempmin': 7.7,
#    'temp': 11.0,
#    'feelslikemax': 13.4,
#    'feelslikemin': 7.1,
#    'feelslike': 10.8,
#    'dew': 7.3,
#    'humidity': 78.81,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 31.7,
#    'windspeed': 21.8,
#    'winddir': 239.4,
#    'pressure': 1019.4,
#    'cloudcover': 60.8,
#    'visibility': 13.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:03:31',
#    'sunriseEpoch': 1581174211,
#    'sunset': '17:40:39',
#    'sunsetEpoch': 1581212439,
#    'moonphase': 0.5,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['72593023233',
#     '74505823277',
#     'KMRY',
#     'KWVI',
#     'KSNS',
#     '72491523259'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-09',
#    'datetimeEpoch': 1581235200,
#    'tempmax': 19.3,
#    'tempmin': 4.6,
#    'temp': 12.4,
#    'feelslikemax': 19.3,
#    'feelslikemin': 1.7,
#    'feelslike': 11.9,
#    'dew': -0.7,
#    'humidity': 48.81,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 54.8,
#    'windspeed': 36.8,
#    'winddir': 193.9,
#    'pressure': 1015.3,
#    'cloudcover': 3.9,
#    'visibility': 15.4,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:02:32',
#    'sunriseEpoch': 1581260552,
#    'sunset': '17:41:42',
#    'sunsetEpoch': 1581298902,
#    'moonphase': 0.5,
#    'conditions': 'Clear',
#    'icon': 'wind',
#    'stations': ['72593023233',
#     '74505823277',
#     'KMRY',
#     'KWVI',
#     'KSNS',
#     '72491523259'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-10',
#    'datetimeEpoch': 1581321600,
#    'tempmax': 19.8,
#    'tempmin': 4.5,
#    'temp': 11.9,
#    'feelslikemax': 19.8,
#    'feelslikemin': 2.3,
#    'feelslike': 11.1,
#    'dew': -2.2,
#    'humidity': 40.34,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 27.7,
#    'windspeed': 18.8,
#    'winddir': 152.9,
#    'pressure': 1017.4,
#    'cloudcover': 0.0,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:01:31',
#    'sunriseEpoch': 1581346891,
#    'sunset': '17:42:46',
#    'sunsetEpoch': 1581385366,
#    'moonphase': 0.52,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['72593023233',
#     '74505823277',
#     'KMRY',
#     'KWVI',
#     'KSNS',
#     '72491523259'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-11',
#    'datetimeEpoch': 1581408000,
#    'tempmax': 21.7,
#    'tempmin': 6.0,
#    'temp': 13.3,
#    'feelslikemax': 21.7,
#    'feelslikemin': 4.0,
#    'feelslike': 12.9,
#    'dew': -0.3,
#    'humidity': 43.0,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 14.4,
#    'winddir': 136.9,
#    'pressure': 1018.7,
#    'cloudcover': 0.0,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:00:29',
#    'sunriseEpoch': 1581433229,
#    'sunset': '17:43:49',
#    'sunsetEpoch': 1581471829,
#    'moonphase': 0.53,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['72593023233',
#     '74505823277',
#     'KMRY',
#     'KWVI',
#     'KSNS',
#     '72491523259'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-12',
#    'datetimeEpoch': 1581494400,
#    'tempmax': 18.2,
#    'tempmin': 5.9,
#    'temp': 11.0,
#    'feelslikemax': 18.2,
#    'feelslikemin': 3.6,
#    'feelslike': 10.4,
#    'dew': 4.4,
#    'humidity': 65.09,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 18.5,
#    'winddir': 173.3,
#    'pressure': 1018.8,
#    'cloudcover': 8.5,
#    'visibility': 15.9,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:59:26',
#    'sunriseEpoch': 1581519566,
#    'sunset': '17:44:52',
#    'sunsetEpoch': 1581558292,
#    'moonphase': 0.57,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['72593023233',
#     '74505823277',
#     'KMRY',
#     'KWVI',
#     'KSNS',
#     '72491523259'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-13',
#    'datetimeEpoch': 1581580800,
#    'tempmax': 13.4,
#    'tempmin': 9.3,
#    'temp': 10.9,
#    'feelslikemax': 13.4,
#    'feelslikemin': 8.0,
#    'feelslike': 10.7,
#    'dew': 7.2,
#    'humidity': 78.3,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 14.8,
#    'winddir': 184.3,
#    'pressure': 1020.3,
#    'cloudcover': 80.0,
#    'visibility': 14.6,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:58:21',
#    'sunriseEpoch': 1581605901,
#    'sunset': '17:45:55',
#    'sunsetEpoch': 1581644755,
#    'moonphase': 0.62,
#    'conditions': 'Overcast',
#    'icon': 'cloudy',
#    'stations': ['72593023233',
#     '74505823277',
#     'KMRY',
#     'KWVI',
#     'KSNS',
#     '72491523259'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-14',
#    'datetimeEpoch': 1581667200,
#    'tempmax': 13.6,
#    'tempmin': 7.9,
#    'temp': 10.8,
#    'feelslikemax': 13.6,
#    'feelslikemin': 6.3,
#    'feelslike': 10.3,
#    'dew': 6.7,
#    'humidity': 76.1,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 13.9,
#    'winddir': 141.2,
#    'pressure': 1020.8,
#    'cloudcover': 51.1,
#    'visibility': 14.8,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:57:15',
#    'sunriseEpoch': 1581692235,
#    'sunset': '17:46:57',
#    'sunsetEpoch': 1581731217,
#    'moonphase': 0.67,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['72593023233',
#     '74505823277',
#     'KMRY',
#     'KWVI',
#     'KSNS',
#     '72491523259'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-15',
#    'datetimeEpoch': 1581753600,
#    'tempmax': 14.6,
#    'tempmin': 5.5,
#    'temp': 10.2,
#    'feelslikemax': 14.6,
#    'feelslikemin': 3.9,
#    'feelslike': 9.7,
#    'dew': 6.3,
#    'humidity': 77.46,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 16.7,
#    'winddir': 198.1,
#    'pressure': 1024.0,
#    'cloudcover': 0.0,
#    'visibility': 15.4,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:56:08',
#    'sunriseEpoch': 1581778568,
#    'sunset': '17:47:59',
#    'sunsetEpoch': 1581817679,
#    'moonphase': 0.73,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['72593023233',
#     '74505823277',
#     'KMRY',
#     'KWVI',
#     'KSNS',
#     '72491523259'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-16',
#    'datetimeEpoch': 1581840000,
#    'tempmax': 15.1,
#    'tempmin': 7.2,
#    'temp': 11.6,
#    'feelslikemax': 15.1,
#    'feelslikemin': 5.6,
#    'feelslike': 11.4,
#    'dew': 7.5,
#    'humidity': 76.47,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 18.3,
#    'winddir': 243.2,
#    'pressure': 1024.3,
#    'cloudcover': 30.0,
#    'visibility': 15.6,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:55:00',
#    'sunriseEpoch': 1581864900,
#    'sunset': '17:49:01',
#    'sunsetEpoch': 1581904141,
#    'moonphase': 0.78,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['72593023233',
#     '74505823277',
#     'KMRY',
#     'KWVI',
#     'KSNS',
#     '72491523259'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-17',
#    'datetimeEpoch': 1581926400,
#    'tempmax': 17.3,
#    'tempmin': 7.1,
#    'temp': 11.9,
#    'feelslikemax': 17.3,
#    'feelslikemin': 5.9,
#    'feelslike': 11.6,
#    'dew': 6.9,
#    'humidity': 72.44,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 13.8,
#    'winddir': 196.6,
#    'pressure': 1019.7,
#    'cloudcover': 10.5,
#    'visibility': 15.8,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:53:51',
#    'sunriseEpoch': 1581951231,
#    'sunset': '17:50:02',
#    'sunsetEpoch': 1581990602,
#    'moonphase': 0.84,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['72593023233',
#     '74505823277',
#     'KMRY',
#     'KWVI',
#     'KSNS',
#     '72491523259'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-18',
#    'datetimeEpoch': 1582012800,
#    'tempmax': 17.7,
#    'tempmin': 7.0,
#    'temp': 12.0,
#    'feelslikemax': 17.7,
#    'feelslikemin': 4.9,
#    'feelslike': 11.8,
#    'dew': 2.9,
#    'humidity': 55.3,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 15.9,
#    'winddir': 201.5,
#    'pressure': 1018.0,
#    'cloudcover': 1.0,
#    'visibility': 15.1,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:52:41',
#    'sunriseEpoch': 1582037561,
#    'sunset': '17:51:04',
#    'sunsetEpoch': 1582077064,
#    'moonphase': 0.88,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['72593023233',
#     '74505823277',
#     'KMRY',
#     'KWVI',
#     'KSNS',
#     '72491523259'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-19',
#    'datetimeEpoch': 1582099200,
#    'tempmax': 15.9,
#    'tempmin': 4.9,
#    'temp': 10.2,
#    'feelslikemax': 15.9,
#    'feelslikemin': 2.9,
#    'feelslike': 9.6,
#    'dew': 5.6,
#    'humidity': 74.26,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 14.9,
#    'winddir': 189.0,
#    'pressure': 1020.5,
#    'cloudcover': 17.4,
#    'visibility': 15.8,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:51:29',
#    'sunriseEpoch': 1582123889,
#    'sunset': '17:52:04',
#    'sunsetEpoch': 1582163524,
#    'moonphase': 0.93,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['72593023233',
#     '74505823277',
#     'KMRY',
#     'KWVI',
#     'KSNS',
#     '72491523259'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-20',
#    'datetimeEpoch': 1582185600,
#    'tempmax': 18.6,
#    'tempmin': 5.1,
#    'temp': 11.3,
#    'feelslikemax': 18.6,
#    'feelslikemin': 2.4,
#    'feelslike': 10.7,
#    'dew': 4.2,
#    'humidity': 63.85,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 12.6,
#    'winddir': 181.6,
#    'pressure': 1020.6,
#    'cloudcover': 1.4,
#    'visibility': 15.8,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:50:17',
#    'sunriseEpoch': 1582210217,
#    'sunset': '17:53:05',
#    'sunsetEpoch': 1582249985,
#    'moonphase': 0.96,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['72593023233',
#     '74505823277',
#     'KMRY',
#     'KWVI',
#     'KSNS',
#     '72491523259'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-21',
#    'datetimeEpoch': 1582272000,
#    'tempmax': 22.6,
#    'tempmin': 7.5,
#    'temp': 14.2,
#    'feelslikemax': 22.6,
#    'feelslikemin': 6.3,
#    'feelslike': 13.9,
#    'dew': 4.9,
#    'humidity': 55.15,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 13.0,
#    'winddir': 167.5,
#    'pressure': 1017.4,
#    'cloudcover': 20.0,
#    'visibility': 15.9,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:49:03',
#    'sunriseEpoch': 1582296543,
#    'sunset': '17:54:05',
#    'sunsetEpoch': 1582336445,
#    'moonphase': 0.98,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['72593023233',
#     '74505823277',
#     'KMRY',
#     'KWVI',
#     'KSNS',
#     '72491523259'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-22',
#    'datetimeEpoch': 1582358400,
#    'tempmax': 15.5,
#    'tempmin': 10.2,
#    'temp': 12.6,
#    'feelslikemax': 15.5,
#    'feelslikemin': 10.2,
#    'feelslike': 12.7,
#    'dew': 8.0,
#    'humidity': 73.74,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 31.7,
#    'windspeed': 21.4,
#    'winddir': 214.8,
#    'pressure': 1019.0,
#    'cloudcover': 64.5,
#    'visibility': 14.4,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:47:49',
#    'sunriseEpoch': 1582382869,
#    'sunset': '17:55:05',
#    'sunsetEpoch': 1582422905,
#    'moonphase': 1.0,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['72593023233',
#     '74505823277',
#     'KMRY',
#     'KWVI',
#     'KSNS',
#     '72491523259'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-23',
#    'datetimeEpoch': 1582444800,
#    'tempmax': 13.4,
#    'tempmin': 10.6,
#    'temp': 12.0,
#    'feelslikemax': 13.4,
#    'feelslikemin': 10.6,
#    'feelslike': 12.0,
#    'dew': 8.2,
#    'humidity': 77.95,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 33.5,
#    'windspeed': 17.8,
#    'winddir': 265.6,
#    'pressure': 1028.5,
#    'cloudcover': 84.0,
#    'visibility': 15.4,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:46:33',
#    'sunriseEpoch': 1582469193,
#    'sunset': '17:56:04',
#    'sunsetEpoch': 1582509364,
#    'moonphase': 1.0,
#    'conditions': 'Overcast',
#    'icon': 'cloudy',
#    'stations': ['72593023233',
#     '74505823277',
#     'KMRY',
#     'KWVI',
#     'KSNS',
#     '72491523259'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-24',
#    'datetimeEpoch': 1582531200,
#    'tempmax': 16.9,
#    'tempmin': 6.6,
#    'temp': 11.6,
#    'feelslikemax': 16.9,
#    'feelslikemin': 4.6,
#    'feelslike': 11.2,
#    'dew': 7.1,
#    'humidity': 74.96,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 13.7,
#    'winddir': 225.3,
#    'pressure': 1028.2,
#    'cloudcover': 10.4,
#    'visibility': 15.4,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:45:17',
#    'sunriseEpoch': 1582555517,
#    'sunset': '17:57:04',
#    'sunsetEpoch': 1582595824,
#    'moonphase': 0.0,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['72593023233',
#     '74505823277',
#     'KMRY',
#     'KWVI',
#     'KSNS',
#     '72491523259'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-25',
#    'datetimeEpoch': 1582617600,
# ...
#     'KMRY',
#     'KWVI',
#     'KSNS',
#     '72491523259'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-15',
#    'datetimeEpoch': 1608019200,
#    'tempmax': 14.0,
#    'tempmin': 4.9,
#    'temp': 8.7,
#    'feelslikemax': 14.0,
#    'feelslikemin': 3.2,
#    'feelslike': 7.9,
#    'dew': 4.8,
#    'humidity': 77.35,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 12.0,
#    'winddir': 181.7,
#    'pressure': 1027.5,
#    'cloudcover': 14.5,
#    'visibility': 15.8,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:13:09',
#    'sunriseEpoch': 1608045189,
#    'sunset': '16:53:13',
#    'sunsetEpoch': 1608079993,
#    'moonphase': 0.0,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['72593023233',
#     '74505823277',
#     'KMRY',
#     'KWVI',
#     'KSNS',
#     '72491523259'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-16',
#    'datetimeEpoch': 1608105600,
#    'tempmax': 17.3,
#    'tempmin': 4.4,
#    'temp': 10.4,
#    'feelslikemax': 17.3,
#    'feelslikemin': 2.5,
#    'feelslike': 10.1,
#    'dew': 4.8,
#    'humidity': 70.2,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 11.4,
#    'winddir': 174.8,
#    'pressure': 1023.4,
#    'cloudcover': 11.6,
#    'visibility': 15.6,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:13:48',
#    'sunriseEpoch': 1608131628,
#    'sunset': '16:53:34',
#    'sunsetEpoch': 1608166414,
#    'moonphase': 0.02,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['72593023233',
#     '74505823277',
#     'KMRY',
#     'KWVI',
#     'KSNS',
#     '72491523259'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-17',
#    'datetimeEpoch': 1608192000,
#    'tempmax': 13.6,
#    'tempmin': 6.8,
#    'temp': 11.7,
#    'feelslikemax': 13.6,
#    'feelslikemin': 5.4,
#    'feelslike': 11.5,
#    'dew': 9.0,
#    'humidity': 83.89,
#    'precip': 6.25,
#    'precipprob': None,
#    'precipcover': 33.33,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 48.1,
#    'windspeed': 28.6,
#    'winddir': 246.7,
#    'pressure': 1020.0,
#    'cloudcover': 61.6,
#    'visibility': 13.9,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:14:24',
#    'sunriseEpoch': 1608218064,
#    'sunset': '16:53:57',
#    'sunsetEpoch': 1608252837,
#    'moonphase': 0.05,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['72593023233',
#     '74505823277',
#     'KMRY',
#     'KWVI',
#     'KSNS',
#     '72491523259'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-18',
#    'datetimeEpoch': 1608278400,
#    'tempmax': 15.7,
#    'tempmin': 4.8,
#    'temp': 9.1,
#    'feelslikemax': 15.7,
#    'feelslikemin': 1.4,
#    'feelslike': 8.0,
#    'dew': 4.3,
#    'humidity': 74.4,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 15.6,
#    'winddir': 168.0,
#    'pressure': 1026.5,
#    'cloudcover': 0.3,
#    'visibility': 15.9,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:14:59',
#    'sunriseEpoch': 1608304499,
#    'sunset': '16:54:21',
#    'sunsetEpoch': 1608339261,
#    'moonphase': 0.09,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['72593023233',
#     '74505823277',
#     'KMRY',
#     'KWVI',
#     'KSNS',
#     '72491523259'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-19',
#    'datetimeEpoch': 1608364800,
#    'tempmax': 15.3,
#    'tempmin': 2.9,
#    'temp': 8.4,
#    'feelslikemax': 15.3,
#    'feelslikemin': 1.1,
#    'feelslike': 7.6,
#    'dew': 2.8,
#    'humidity': 69.03,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 14.7,
#    'winddir': 170.0,
#    'pressure': 1028.8,
#    'cloudcover': 0.0,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:15:33',
#    'sunriseEpoch': 1608390933,
#    'sunset': '16:54:48',
#    'sunsetEpoch': 1608425688,
#    'moonphase': 0.13,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['72593023233',
#     '74505823277',
#     'KMRY',
#     'KWVI',
#     'KSNS',
#     '72491523259'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-20',
#    'datetimeEpoch': 1608451200,
#    'tempmax': 20.0,
#    'tempmin': 2.9,
#    'temp': 8.7,
#    'feelslikemax': 20.0,
#    'feelslikemin': 0.0,
#    'feelslike': 7.8,
#    'dew': 2.7,
#    'humidity': 69.3,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 13.9,
#    'winddir': 133.5,
#    'pressure': 1025.0,
#    'cloudcover': 0.0,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:16:05',
#    'sunriseEpoch': 1608477365,
#    'sunset': '16:55:16',
#    'sunsetEpoch': 1608512116,
#    'moonphase': 0.18,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['72593023233',
#     '74505823277',
#     'KMRY',
#     'KWVI',
#     'KSNS',
#     '72491523259'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-21',
#    'datetimeEpoch': 1608537600,
#    'tempmax': 15.3,
#    'tempmin': 1.6,
#    'temp': 8.4,
#    'feelslikemax': 15.3,
#    'feelslikemin': -1.6,
#    'feelslike': 7.7,
#    'dew': 3.2,
#    'humidity': 71.59,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 44.6,
#    'windspeed': 12.5,
#    'winddir': 174.9,
#    'pressure': 1018.9,
#    'cloudcover': 0.0,
#    'visibility': 15.9,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:16:35',
#    'sunriseEpoch': 1608563795,
#    'sunset': '16:55:46',
#    'sunsetEpoch': 1608598546,
#    'moonphase': 0.23,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['72593023233',
#     '74505823277',
#     'KMRY',
#     'KWVI',
#     'KSNS',
#     '72491523259'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-22',
#    'datetimeEpoch': 1608624000,
#    'tempmax': 15.6,
#    'tempmin': 6.6,
#    'temp': 10.4,
#    'feelslikemax': 15.6,
#    'feelslikemin': 4.8,
#    'feelslike': 9.8,
#    'dew': 6.5,
#    'humidity': 77.35,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 17.3,
#    'winddir': 187.7,
#    'pressure': 1022.0,
#    'cloudcover': 17.6,
#    'visibility': 15.9,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:17:04',
#    'sunriseEpoch': 1608650224,
#    'sunset': '16:56:18',
#    'sunsetEpoch': 1608684978,
#    'moonphase': 0.28,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['72593023233',
#     '74505823277',
#     'KMRY',
#     'KWVI',
#     'KSNS',
#     '72491523259'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-23',
#    'datetimeEpoch': 1608710400,
#    'tempmax': 15.8,
#    'tempmin': 3.8,
#    'temp': 9.2,
#    'feelslikemax': 15.8,
#    'feelslikemin': 1.0,
#    'feelslike': 8.0,
#    'dew': 1.7,
#    'humidity': 61.58,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 17.2,
#    'winddir': 89.0,
#    'pressure': 1023.5,
#    'cloudcover': 0.0,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:17:31',
#    'sunriseEpoch': 1608736651,
#    'sunset': '16:56:51',
#    'sunsetEpoch': 1608771411,
#    'moonphase': 0.32,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['72593023233',
#     '74505823277',
#     'KMRY',
#     'KWVI',
#     'KSNS',
#     '72491523259'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-24',
#    'datetimeEpoch': 1608796800,
#    'tempmax': 16.9,
#    'tempmin': 7.1,
#    'temp': 11.2,
#    'feelslikemax': 16.9,
#    'feelslikemin': 5.8,
#    'feelslike': 10.5,
#    'dew': 0.2,
#    'humidity': 47.71,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 11.4,
#    'winddir': 151.2,
#    'pressure': 1023.9,
#    'cloudcover': 22.5,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:17:56',
#    'sunriseEpoch': 1608823076,
#    'sunset': '16:57:26',
#    'sunsetEpoch': 1608857846,
#    'moonphase': 0.37,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['72593023233',
#     '74505823277',
#     'KMRY',
#     'KWVI',
#     'KSNS',
#     '72491523259'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-25',
#    'datetimeEpoch': 1608883200,
#    'tempmax': 17.0,
#    'tempmin': 7.2,
#    'temp': 12.8,
#    'feelslikemax': 17.0,
#    'feelslikemin': 5.0,
#    'feelslike': 12.2,
#    'dew': 4.5,
#    'humidity': 58.43,
#    'precip': 1.31,
#    'precipprob': None,
#    'precipcover': 20.83,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 33.5,
#    'windspeed': 20.4,
#    'winddir': 148.6,
#    'pressure': 1021.3,
#    'cloudcover': 64.5,
#    'visibility': 15.7,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:18:19',
#    'sunriseEpoch': 1608909499,
#    'sunset': '16:58:03',
#    'sunsetEpoch': 1608944283,
#    'moonphase': 0.4,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['72593023233',
#     '74505823277',
#     'KMRY',
#     'KWVI',
#     'KSNS',
#     '72491523259'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-26',
#    'datetimeEpoch': 1608969600,
#    'tempmax': 14.7,
#    'tempmin': 8.0,
#    'temp': 12.4,
#    'feelslikemax': 14.7,
#    'feelslikemin': 6.2,
#    'feelslike': 12.3,
#    'dew': 9.5,
#    'humidity': 82.37,
#    'precip': 0.03,
#    'precipprob': None,
#    'precipcover': 4.17,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 37.1,
#    'windspeed': 14.1,
#    'winddir': 245.5,
#    'pressure': 1024.1,
#    'cloudcover': 33.3,
#    'visibility': 15.9,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:18:40',
#    'sunriseEpoch': 1608995920,
#    'sunset': '16:58:41',
#    'sunsetEpoch': 1609030721,
#    'moonphase': 0.44,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['72593023233',
#     '74505823277',
#     'KMRY',
#     'KWVI',
#     'KSNS',
#     '72491523259'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-27',
#    'datetimeEpoch': 1609056000,
#    'tempmax': 14.0,
#    'tempmin': 6.7,
#    'temp': 10.2,
#    'feelslikemax': 14.0,
#    'feelslikemin': 5.5,
#    'feelslike': 9.8,
#    'dew': 6.5,
#    'humidity': 78.78,
#    'precip': 0.45,
#    'precipprob': None,
#    'precipcover': 4.17,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 40.2,
#    'windspeed': 23.6,
#    'winddir': 149.3,
#    'pressure': 1014.1,
#    'cloudcover': 31.0,
#    'visibility': 15.5,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:19:00',
#    'sunriseEpoch': 1609082340,
#    'sunset': '16:59:21',
#    'sunsetEpoch': 1609117161,
#    'moonphase': 0.47,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['72593023233',
#     '74505823277',
#     'KMRY',
#     'KWVI',
#     'KSNS',
#     '72491523259'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-28',
#    'datetimeEpoch': 1609142400,
#    'tempmax': 13.4,
#    'tempmin': 7.3,
#    'temp': 9.7,
#    'feelslikemax': 13.4,
#    'feelslikemin': 4.9,
#    'feelslike': 9.0,
#    'dew': 6.8,
#    'humidity': 82.9,
#    'precip': 3.39,
#    'precipprob': None,
#    'precipcover': 25.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 33.5,
#    'windspeed': 14.5,
#    'winddir': 171.8,
#    'pressure': 1010.9,
#    'cloudcover': 57.1,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:19:17',
#    'sunriseEpoch': 1609168757,
#    'sunset': '17:00:03',
#    'sunsetEpoch': 1609203603,
#    'moonphase': 0.49,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['72593023233',
#     '74505823277',
#     'KMRY',
#     'KWVI',
#     'KSNS',
#     '72491523259'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-29',
#    'datetimeEpoch': 1609228800,
#    'tempmax': 15.6,
#    'tempmin': 4.2,
#    'temp': 8.8,
#    'feelslikemax': 15.6,
#    'feelslikemin': 2.0,
#    'feelslike': 7.7,
#    'dew': 4.6,
#    'humidity': 77.18,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 14.9,
#    'winddir': 176.5,
#    'pressure': 1024.6,
#    'cloudcover': 0.1,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:19:33',
#    'sunriseEpoch': 1609255173,
#    'sunset': '17:00:45',
#    'sunsetEpoch': 1609290045,
#    'moonphase': 0.5,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['72593023233',
#     '74505823277',
#     'KMRY',
#     'KWVI',
#     'KSNS',
#     '72491523259'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-30',
#    'datetimeEpoch': 1609315200,
#    'tempmax': 12.3,
#    'tempmin': 2.2,
#    'temp': 8.2,
#    'feelslikemax': 12.3,
#    'feelslikemin': -0.2,
#    'feelslike': 7.3,
#    'dew': 3.6,
#    'humidity': 73.65,
#    'precip': 0.15,
#    'precipprob': None,
#    'precipcover': 4.17,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 14.8,
#    'winddir': 193.4,
#    'pressure': 1027.9,
#    'cloudcover': 21.6,
#    'visibility': 15.5,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:19:47',
#    'sunriseEpoch': 1609341587,
#    'sunset': '17:01:30',
#    'sunsetEpoch': 1609376490,
#    'moonphase': 0.5,
#    'conditions': 'Rain',
#    'icon': 'rain',
#    'stations': ['72593023233',
#     '74505823277',
#     'KMRY',
#     'KWVI',
#     'KSNS',
#     '72491523259'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-31',
#    'datetimeEpoch': 1609401600,
#    'tempmax': 12.8,
#    'tempmin': 6.6,
#    'temp': 9.8,
#    'feelslikemax': 12.8,
#    'feelslikemin': 5.7,
#    'feelslike': 9.5,
#    'dew': 7.2,
#    'humidity': 84.13,
#    'precip': 0.92,
#    'precipprob': None,
#    'precipcover': 12.5,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 37.1,
#    'windspeed': 20.5,
#    'winddir': 194.8,
#    'pressure': 1022.8,
#    'cloudcover': 23.2,
#    'visibility': 15.3,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:19:59',
#    'sunriseEpoch': 1609427999,
#    'sunset': '17:02:15',
#    'sunsetEpoch': 1609462935,
#    'moonphase': 0.51,
#    'conditions': 'Rain',
#    'icon': 'rain',
#    'stations': ['72593023233',
#     '74505823277',
#     'KMRY',
#     'KWVI',
#     'KSNS',
#     '72491523259'],
#    'source': 'obs',
#    'hours': None}],
#  'stations': {'72593023233': {'distance': 28177.0,
#    'latitude': 36.664,
#    'longitude': -121.608,
#    'useCount': 0,
#    'id': '72593023233',
#    'name': 'SALINAS AIRPORT, CA US',
#    'quality': 100,
#    'contribution': 0.0},
#   '74505823277': {'distance': 37076.0,
#    'latitude': 36.936,
#    'longitude': -121.789,
#    'useCount': 0,
#    'id': '74505823277',
#    'name': 'WATSONVILLE MUNICIPAL AIRPORT, CA US',
#    'quality': 99,
#    'contribution': 0.0},
#   'KMRY': {'distance': 7533.0,
#    'latitude': 36.58,
#    'longitude': -121.85,
#    'useCount': 0,
#    'id': 'KMRY',
#    'name': 'MONTEREY PNINSLA, CA',
#    'quality': 98,
#    'contribution': 0.0},
#   'KWVI': {'distance': 37493.0,
#    'latitude': 36.94,
#    'longitude': -121.79,
#    'useCount': 0,
#    'id': 'KWVI',
#    'name': 'KWVI',
#    'quality': 100,
#    'contribution': 0.0},
#   'KSNS': {'distance': 29009.0,
#    'latitude': 36.67,
#    'longitude': -121.6,
#    'useCount': 0,
#    'id': 'KSNS',
#    'name': 'KSNS',
#    'quality': 99,
#    'contribution': 0.0},
#   '72491523259': {'distance': 7439.0,
#    'latitude': 36.588,
#    'longitude': -121.845,
#    'useCount': 0,
#    'id': '72491523259',
#    'name': 'MONTEREY PENINSUL AIRPORT, CA US',
#    'quality': 97,
#    'contribution': 0.0}}}

# %%
#3. We create empty lists to transfer the data
temperature = []
temp_max = []
temp_min = []
humidity = []
precip = []
snow = []
windspeed = []
conditions = []
date = []
city = []

# %%
#4. We loop thropugh the API and extract the info we need
for x in range(366):
    temperature.append(response["days"][x]["temp"])
    temp_max.append(response["days"][x]["tempmax"])
    temp_min.append(response["days"][x]["tempmin"])
    humidity.append(response["days"][x]["humidity"])
    precip.append(response["days"][x]["precip"])
    snow.append(response["days"][x]["snow"])
    windspeed.append(response["days"][x]["windspeed"])
    conditions.append(response["days"][x]["conditions"])
    date.append(response["days"][x]["datetime"])
    city.append("Pacific Grove, CA")

# %%
print(len(temperature),len(temp_max),len(temp_min),len(humidity),len(precip),len(snow),len(windspeed),len(conditions),len(date),len(city))
# Out:
# 366 366 366 366 366 366 366 366 366 366

# %%
#5. We create a dataframe based on the lists
New_df = pd.DataFrame(
    {'City': city,
     'Date': date,
     'Temperature': temperature,
     'temp_max': temp_max,
     'temp_min':temp_min,
     'humidity':humidity,
     'precip':precip,
     'snow':snow,
     'windspeed':windspeed,
     'conditions': conditions
    })

# %%
New_df
# Out:
#             City        Date  Temperature  temp_max  temp_min  humidity  \
# 0    Oakland, CA  2020-01-01         11.1      14.3       8.2     86.01
# 1    Oakland, CA  2020-01-02         10.5      15.4       6.9     83.51
# 2    Oakland, CA  2020-01-03         10.2      15.2       5.4     77.15
# 3    Oakland, CA  2020-01-04         11.2      15.3       8.3     82.47
# 4    Oakland, CA  2020-01-05         10.0      14.3       4.8     77.22
# ..           ...         ...          ...       ...       ...       ...
# 361  Oakland, CA  2020-12-27         11.2      16.0       7.9     70.44
# 362  Oakland, CA  2020-12-28         11.3      15.0       8.0     70.21
# 363  Oakland, CA  2020-12-29          9.4      15.4       4.6     68.06
# 364  Oakland, CA  2020-12-30          9.4      13.5       4.3     70.72
# 365  Oakland, CA  2020-12-31         11.1      14.2       8.0     74.07
#
#      precip  snow  windspeed              conditions
# 0      0.00   0.0       18.9        Partially cloudy
# 1      0.00   0.0       11.8        Partially cloudy
# 2      0.00   0.0       15.6        Partially cloudy
# 3      0.24   0.0       17.1  Rain, Partially cloudy
# 4      0.00   0.0       15.0                   Clear
# ..      ...   ...        ...                     ...
# 361    0.00   0.0       19.9        Partially cloudy
# 362    2.41   0.0       18.8          Rain, Overcast
# 363    0.00   0.0       11.0        Partially cloudy
# 364    0.56   0.0       18.7  Rain, Partially cloudy
# 365    2.59   0.0       20.5  Rain, Partially cloudy
#
# [366 rows x 10 columns]

# %%
#6. We add new city dataframe to original dataframe including cities already evaluated 

frames = [Final_df,New_df]

# %%
Final_df = pd.concat(frames)

# %%
Final_df
# Out:
#              City        Date  Temperature  temp_max  temp_min  humidity  \
# 0    Montreal, QC  2020-01-01          0.2       1.1      -0.8     87.84
# 1    Montreal, QC  2020-01-02          0.9       2.6      -1.0     78.70
# 2    Montreal, QC  2020-01-03          4.8       5.8       2.8     74.88
# 3    Montreal, QC  2020-01-04          0.5       3.2      -1.9     78.79
# 4    Montreal, QC  2020-01-05         -5.3      -1.8      -9.9     69.09
# ..            ...         ...          ...       ...       ...       ...
# 361   Oakland, CA  2020-12-27         11.2      16.0       7.9     70.44
# 362   Oakland, CA  2020-12-28         11.3      15.0       8.0     70.21
# 363   Oakland, CA  2020-12-29          9.4      15.4       4.6     68.06
# 364   Oakland, CA  2020-12-30          9.4      13.5       4.3     70.72
# 365   Oakland, CA  2020-12-31         11.1      14.2       8.0     74.07
#
#      precip  snow  windspeed              conditions
# 0      5.71  0.00        7.9                    Rain
# 1      0.00  0.00        7.7                   Clear
# 2      0.00  0.00        7.6                   Clear
# 3      2.27  0.00       11.2                    Rain
# 4      0.76  3.88       13.1                    Snow
# ..      ...   ...        ...                     ...
# 361    0.00  0.00       19.9        Partially cloudy
# 362    2.41  0.00       18.8          Rain, Overcast
# 363    0.00  0.00       11.0        Partially cloudy
# 364    0.56  0.00       18.7  Rain, Partially cloudy
# 365    2.59  0.00       20.5  Rain, Partially cloudy
#
# [8418 rows x 10 columns]

# %%
#7.Update to csv by converting df to csv
Final_df.to_csv("Temperature_Dataset1.csv", index=False)

# %%
#8. Will need to import CSV with temp for cities already evaluated every time this document is open again for the 1st time. 
#Name dataframe: Final_df

file_path = os.path.join("Temperature_Dataset1.csv")
Final_df = pd.read_csv(file_path)
Final_df
# Out:
#               City        Date  Temperature  temp_max  temp_min  humidity  \
# 0     Montreal, QC  2020-01-01          0.2       1.1      -0.8     87.84
# 1     Montreal, QC  2020-01-02          0.9       2.6      -1.0     78.70
# 2     Montreal, QC  2020-01-03          4.8       5.8       2.8     74.88
# 3     Montreal, QC  2020-01-04          0.5       3.2      -1.9     78.79
# 4     Montreal, QC  2020-01-05         -5.3      -1.8      -9.9     69.09
# ...            ...         ...          ...       ...       ...       ...
# 8413   Oakland, CA  2020-12-27         11.2      16.0       7.9     70.44
# 8414   Oakland, CA  2020-12-28         11.3      15.0       8.0     70.21
# 8415   Oakland, CA  2020-12-29          9.4      15.4       4.6     68.06
# 8416   Oakland, CA  2020-12-30          9.4      13.5       4.3     70.72
# 8417   Oakland, CA  2020-12-31         11.1      14.2       8.0     74.07
#
#       precip  snow  windspeed              conditions
# 0       5.71  0.00        7.9                    Rain
# 1       0.00  0.00        7.7                   Clear
# 2       0.00  0.00        7.6                   Clear
# 3       2.27  0.00       11.2                    Rain
# 4       0.76  3.88       13.1                    Snow
# ...      ...   ...        ...                     ...
# 8413    0.00  0.00       19.9        Partially cloudy
# 8414    2.41  0.00       18.8          Rain, Overcast
# 8415    0.00  0.00       11.0        Partially cloudy
# 8416    0.56  0.00       18.7  Rain, Partially cloudy
# 8417    2.59  0.00       20.5  Rain, Partially cloudy
#
# [8418 rows x 10 columns]
