# %%
# 1.Importing dependencies

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import os

# %%
#2. We add url. Each city will have a new url

url2 = "https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/Nashville/2020-1-1/2020-12-31?unitGroup=metric&key=SRX784Y4XEDTND44NFLHKK42Z&include=obs"

# %%
response = requests.get(url2).json()

# %%
response
# Out:
# {'queryCost': 366,
#  'latitude': 36.1678,
#  'longitude': -86.7782,
#  'resolvedAddress': 'Nashville, TN, United States',
#  'address': 'Nashville',
#  'timezone': 'America/Chicago',
#  'tzoffset': -6.0,
#  'days': [{'datetime': '2020-01-01',
#    'datetimeEpoch': 1577858400,
#    'tempmax': 11.1,
#    'tempmin': 0.8,
#    'temp': 6.0,
#    'feelslikemax': 11.1,
#    'feelslikemin': -1.6,
#    'feelslike': 4.3,
#    'dew': -4.6,
#    'humidity': 48.21,
#    'precip': 0.06,
#    'precipprob': None,
#    'precipcover': 4.17,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 19.7,
#    'winddir': 201.3,
#    'pressure': 1016.3,
#    'cloudcover': 41.4,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:58:13',
#    'sunriseEpoch': 1577883493,
#    'sunset': '16:43:01',
#    'sunsetEpoch': 1577918581,
#    'moonphase': 0.17,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['72327013897', 'KBNA', 'KMQY', '72327313827', '72077599999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-02',
#    'datetimeEpoch': 1577944800,
#    'tempmax': 12.1,
#    'tempmin': 7.8,
#    'temp': 10.4,
#    'feelslikemax': 12.1,
#    'feelslikemin': 5.0,
#    'feelslike': 9.4,
#    'dew': 5.3,
#    'humidity': 74.23,
#    'precip': 29.83,
#    'precipprob': None,
#    'precipcover': 75.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 40.7,
#    'windspeed': 29.4,
#    'winddir': 160.0,
#    'pressure': 1010.4,
#    'cloudcover': 88.7,
#    'visibility': 11.3,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:58:23',
#    'sunriseEpoch': 1577969903,
#    'sunset': '16:43:48',
#    'sunsetEpoch': 1578005028,
#    'moonphase': 0.22,
#    'conditions': 'Rain, Overcast',
#    'icon': 'rain',
#    'stations': ['72327013897',
#     'KBNA',
#     'KMQY',
#     '72327313827',
#     '72077599999',
#     'K1M5'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-03',
#    'datetimeEpoch': 1578031200,
#    'tempmax': 14.3,
#    'tempmin': 11.6,
#    'temp': 13.0,
#    'feelslikemax': 14.3,
#    'feelslikemin': 11.6,
#    'feelslike': 13.0,
#    'dew': 11.5,
#    'humidity': 90.45,
#    'precip': 10.32,
#    'precipprob': None,
#    'precipcover': 87.5,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 12.2,
#    'winddir': 207.0,
#    'pressure': 1009.1,
#    'cloudcover': 80.2,
#    'visibility': 12.4,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:58:31',
#    'sunriseEpoch': 1578056311,
#    'sunset': '16:44:36',
#    'sunsetEpoch': 1578091476,
#    'moonphase': 0.26,
#    'conditions': 'Rain, Overcast',
#    'icon': 'rain',
#    'stations': ['72327013897',
#     'KBNA',
#     'KMQY',
#     '72327313827',
#     'K1M5',
#     '72077599999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-04',
#    'datetimeEpoch': 1578117600,
#    'tempmax': 12.7,
#    'tempmin': 3.3,
#    'temp': 6.1,
#    'feelslikemax': 12.7,
#    'feelslikemin': -0.1,
#    'feelslike': 3.3,
#    'dew': 0.9,
#    'humidity': 70.03,
#    'precip': 0.88,
#    'precipprob': None,
#    'precipcover': 20.83,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 43.8,
#    'windspeed': 25.6,
#    'winddir': 299.1,
#    'pressure': 1018.5,
#    'cloudcover': 85.8,
#    'visibility': 15.4,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:58:38',
#    'sunriseEpoch': 1578142718,
#    'sunset': '16:45:25',
#    'sunsetEpoch': 1578177925,
#    'moonphase': 0.31,
#    'conditions': 'Rain, Overcast',
#    'icon': 'rain',
#    'stations': ['72327013897',
#     'KBNA',
#     'KMQY',
#     '72327313827',
#     'K1M5',
#     '72077599999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-05',
#    'datetimeEpoch': 1578204000,
#    'tempmax': 12.8,
#    'tempmin': -1.8,
#    'temp': 5.7,
#    'feelslikemax': 12.8,
#    'feelslikemin': -5.2,
#    'feelslike': 4.6,
#    'dew': -1.7,
#    'humidity': 62.11,
#    'precip': 0.33,
#    'precipprob': None,
#    'precipcover': 25.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 35.3,
#    'windspeed': 23.1,
#    'winddir': 201.4,
#    'pressure': 1024.8,
#    'cloudcover': 0.1,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:58:42',
#    'sunriseEpoch': 1578229122,
#    'sunset': '16:46:16',
#    'sunsetEpoch': 1578264376,
#    'moonphase': 0.36,
#    'conditions': 'Rain',
#    'icon': 'rain',
#    'stations': ['72327013897',
#     'KBNA',
#     'KMQY',
#     '72327313827',
#     'K1M5',
#     '72077599999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-06',
#    'datetimeEpoch': 1578290400,
#    'tempmax': 12.3,
#    'tempmin': 0.2,
#    'temp': 7.0,
#    'feelslikemax': 12.3,
#    'feelslikemin': 0.2,
#    'feelslike': 6.5,
#    'dew': -1.5,
#    'humidity': 58.59,
#    'precip': 0.7,
#    'precipprob': None,
#    'precipcover': 29.17,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 10.9,
#    'winddir': 85.0,
#    'pressure': 1021.4,
#    'cloudcover': 34.6,
#    'visibility': 15.8,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:58:44',
#    'sunriseEpoch': 1578315524,
#    'sunset': '16:47:07',
#    'sunsetEpoch': 1578350827,
#    'moonphase': 0.4,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['72327013897',
#     'KBNA',
#     'KMQY',
#     '72327313827',
#     'K1M5',
#     '72077599999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-07',
#    'datetimeEpoch': 1578376800,
#    'tempmax': 12.1,
#    'tempmin': 2.6,
#    'temp': 7.2,
#    'feelslikemax': 12.1,
#    'feelslikemin': 0.2,
#    'feelslike': 5.8,
#    'dew': -1.8,
#    'humidity': 56.77,
#    'precip': 0.92,
#    'precipprob': None,
#    'precipcover': 16.67,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 36.7,
#    'windspeed': 20.6,
#    'winddir': 260.2,
#    'pressure': 1020.6,
#    'cloudcover': 35.1,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:58:44',
#    'sunriseEpoch': 1578401924,
#    'sunset': '16:48:00',
#    'sunsetEpoch': 1578437280,
#    'moonphase': 0.44,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['72327013897',
#     'KBNA',
#     'KMQY',
#     '72327313827',
#     'K1M5',
#     '72077599999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-08',
#    'datetimeEpoch': 1578463200,
#    'tempmax': 14.8,
#    'tempmin': 1.7,
#    'temp': 7.7,
#    'feelslikemax': 14.8,
#    'feelslikemin': -1.1,
#    'feelslike': 6.6,
#    'dew': -3.4,
#    'humidity': 47.49,
#    'precip': 0.17,
#    'precipprob': None,
#    'precipcover': 12.5,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 9.9,
#    'winddir': 173.2,
#    'pressure': 1028.7,
#    'cloudcover': 4.0,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:58:42',
#    'sunriseEpoch': 1578488322,
#    'sunset': '16:48:54',
#    'sunsetEpoch': 1578523734,
#    'moonphase': 0.47,
#    'conditions': 'Rain',
#    'icon': 'rain',
#    'stations': ['72327013897',
#     'KBNA',
#     'KMQY',
#     '72327313827',
#     'K1M5',
#     '72077599999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-09',
#    'datetimeEpoch': 1578549600,
#    'tempmax': 16.1,
#    'tempmin': 2.8,
#    'temp': 10.4,
#    'feelslikemax': 16.1,
#    'feelslikemin': 0.4,
#    'feelslike': 9.8,
#    'dew': -2.4,
#    'humidity': 43.23,
#    'precip': 0.11,
#    'precipprob': None,
#    'precipcover': 8.33,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 54.3,
#    'windspeed': 36.8,
#    'winddir': 156.8,
#    'pressure': 1027.7,
#    'cloudcover': 55.4,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:58:39',
#    'sunriseEpoch': 1578574719,
#    'sunset': '16:49:48',
#    'sunsetEpoch': 1578610188,
#    'moonphase': 0.49,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['72327013897',
#     'KBNA',
#     'KMQY',
#     '72327313827',
#     'K1M5',
#     '72077599999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-10',
#    'datetimeEpoch': 1578636000,
#    'tempmax': 19.8,
#    'tempmin': 15.0,
#    'temp': 16.7,
#    'feelslikemax': 19.8,
#    'feelslikemin': 15.0,
#    'feelslike': 16.7,
#    'dew': 10.0,
#    'humidity': 65.01,
#    'precip': 1.5,
#    'precipprob': None,
#    'precipcover': 25.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 56.2,
#    'windspeed': 37.8,
#    'winddir': 169.1,
#    'pressure': 1022.5,
#    'cloudcover': 75.9,
#    'visibility': 15.9,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:58:33',
#    'sunriseEpoch': 1578661113,
#    'sunset': '16:50:44',
#    'sunsetEpoch': 1578696644,
#    'moonphase': 0.5,
#    'conditions': 'Rain, Overcast',
#    'icon': 'rain',
#    'stations': ['72327013897',
#     'KBNA',
#     'KMQY',
#     '72327313827',
#     'K1M5',
#     '72077599999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-11',
#    'datetimeEpoch': 1578722400,
#    'tempmax': 21.6,
#    'tempmin': 8.4,
#    'temp': 16.4,
#    'feelslikemax': 21.6,
#    'feelslikemin': 5.7,
#    'feelslike': 16.0,
#    'dew': 13.0,
#    'humidity': 80.6,
#    'precip': 29.46,
#    'precipprob': None,
#    'precipcover': 62.5,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 80.6,
#    'windspeed': 47.3,
#    'winddir': 189.8,
#    'pressure': 1011.2,
#    'cloudcover': 81.4,
#    'visibility': 12.9,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:58:25',
#    'sunriseEpoch': 1578747505,
#    'sunset': '16:51:40',
#    'sunsetEpoch': 1578783100,
#    'moonphase': 0.51,
#    'conditions': 'Rain, Overcast',
#    'icon': 'rain',
#    'stations': ['72327013897',
#     'KBNA',
#     'KMQY',
#     '72327313827',
#     'K1M5',
#     '72077599999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-12',
#    'datetimeEpoch': 1578808800,
#    'tempmax': 11.2,
#    'tempmin': 4.1,
#    'temp': 7.6,
#    'feelslikemax': 11.2,
#    'feelslikemin': 3.2,
#    'feelslike': 6.8,
#    'dew': 3.7,
#    'humidity': 76.72,
#    'precip': 0.06,
#    'precipprob': None,
#    'precipcover': 4.17,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 20.5,
#    'windspeed': 14.5,
#    'winddir': 195.1,
#    'pressure': 1024.8,
#    'cloudcover': 76.6,
#    'visibility': 15.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:58:16',
#    'sunriseEpoch': 1578833896,
#    'sunset': '16:52:37',
#    'sunsetEpoch': 1578869557,
#    'moonphase': 0.52,
#    'conditions': 'Rain, Overcast',
#    'icon': 'rain',
#    'stations': ['72327013897',
#     'KBNA',
#     'KMQY',
#     '72327313827',
#     'K1M5',
#     '72077599999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-13',
#    'datetimeEpoch': 1578895200,
#    'tempmax': 13.8,
#    'tempmin': 3.2,
#    'temp': 8.6,
#    'feelslikemax': 13.8,
#    'feelslikemin': 1.4,
#    'feelslike': 8.3,
#    'dew': 4.8,
#    'humidity': 77.79,
#    'precip': 0.06,
#    'precipprob': None,
#    'precipcover': 4.17,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 8.8,
#    'winddir': 94.1,
#    'pressure': 1026.2,
#    'cloudcover': 81.5,
#    'visibility': 15.1,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:58:04',
#    'sunriseEpoch': 1578920284,
#    'sunset': '16:53:35',
#    'sunsetEpoch': 1578956015,
#    'moonphase': 0.55,
#    'conditions': 'Rain, Overcast',
#    'icon': 'rain',
#    'stations': ['72327013897',
#     'KBNA',
#     'KMQY',
#     '72327313827',
#     'K1M5',
#     '72077599999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-14',
#    'datetimeEpoch': 1578981600,
#    'tempmax': 16.7,
#    'tempmin': 11.1,
#    'temp': 14.4,
#    'feelslikemax': 16.7,
#    'feelslikemin': 11.1,
#    'feelslike': 14.4,
#    'dew': 11.3,
#    'humidity': 81.91,
#    'precip': 16.09,
#    'precipprob': None,
#    'precipcover': 33.33,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 11.1,
#    'winddir': 175.8,
#    'pressure': 1021.7,
#    'cloudcover': 82.0,
#    'visibility': 13.5,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:57:50',
#    'sunriseEpoch': 1579006670,
#    'sunset': '16:54:34',
#    'sunsetEpoch': 1579042474,
#    'moonphase': 0.59,
#    'conditions': 'Rain, Overcast',
#    'icon': 'rain',
#    'stations': ['72327013897',
#     'KBNA',
#     'KMQY',
#     '72327313827',
#     'K1M5',
#     '72077599999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-15',
#    'datetimeEpoch': 1579068000,
#    'tempmax': 20.6,
#    'tempmin': 13.8,
#    'temp': 17.1,
#    'feelslikemax': 20.6,
#    'feelslikemin': 13.8,
#    'feelslike': 17.1,
#    'dew': 14.5,
#    'humidity': 84.92,
#    'precip': 1.14,
#    'precipprob': None,
#    'precipcover': 33.33,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 33.5,
#    'windspeed': 21.7,
#    'winddir': 195.3,
#    'pressure': 1019.9,
#    'cloudcover': 87.5,
#    'visibility': 13.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:57:35',
#    'sunriseEpoch': 1579093055,
#    'sunset': '16:55:33',
#    'sunsetEpoch': 1579128933,
#    'moonphase': 0.64,
#    'conditions': 'Rain, Overcast',
#    'icon': 'rain',
#    'stations': ['72327013897',
#     'KBNA',
#     'KMQY',
#     '72327313827',
#     'K1M5',
#     '72077599999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-16',
#    'datetimeEpoch': 1579154400,
#    'tempmax': 13.2,
#    'tempmin': 1.7,
#    'temp': 8.1,
#    'feelslikemax': 13.2,
#    'feelslikemin': -3.3,
#    'feelslike': 5.7,
#    'dew': 0.9,
#    'humidity': 61.66,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 4.17,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 38.9,
#    'windspeed': 25.3,
#    'winddir': 252.4,
#    'pressure': 1033.3,
#    'cloudcover': 63.6,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:57:17',
#    'sunriseEpoch': 1579179437,
#    'sunset': '16:56:33',
#    'sunsetEpoch': 1579215393,
#    'moonphase': 0.69,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['72327013897',
#     'KBNA',
#     'KMQY',
#     '72327313827',
#     'K1M5',
#     '72077599999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-17',
#    'datetimeEpoch': 1579240800,
#    'tempmax': 11.1,
#    'tempmin': 1.1,
#    'temp': 4.4,
#    'feelslikemax': 11.1,
#    'feelslikemin': -3.2,
#    'feelslike': 1.3,
#    'dew': -5.6,
#    'humidity': 48.88,
#    'precip': 0.06,
#    'precipprob': None,
#    'precipcover': 4.17,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 41.9,
#    'windspeed': 25.8,
#    'winddir': 77.5,
#    'pressure': 1033.4,
#    'cloudcover': 91.0,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:56:58',
#    'sunriseEpoch': 1579265818,
#    'sunset': '16:57:34',
#    'sunsetEpoch': 1579301854,
#    'moonphase': 0.75,
#    'conditions': 'Rain, Overcast',
#    'icon': 'rain',
#    'stations': ['72327013897',
#     'KBNA',
#     'KMQY',
#     '72327313827',
#     'K1M5',
#     '72077599999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-18',
#    'datetimeEpoch': 1579327200,
#    'tempmax': 13.7,
#    'tempmin': 6.0,
#    'temp': 10.6,
#    'feelslikemax': 13.7,
#    'feelslikemin': 3.0,
#    'feelslike': 9.4,
#    'dew': 3.2,
#    'humidity': 63.26,
#    'precip': 5.14,
#    'precipprob': None,
#    'precipcover': 29.17,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 65.2,
#    'windspeed': 38.7,
#    'winddir': 210.2,
#    'pressure': 1020.2,
#    'cloudcover': 67.0,
#    'visibility': 15.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:56:36',
#    'sunriseEpoch': 1579352196,
#    'sunset': '16:58:35',
#    'sunsetEpoch': 1579388315,
#    'moonphase': 0.81,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['72327013897',
#     'KBNA',
#     'KMQY',
#     '72327313827',
#     'K1M5',
#     '72077599999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-19',
#    'datetimeEpoch': 1579413600,
#    'tempmax': 4.3,
#    'tempmin': -5.0,
#    'temp': 0.1,
#    'feelslikemax': 0.5,
#    'feelslikemin': -11.8,
#    'feelslike': -4.8,
#    'dew': -10.3,
#    'humidity': 46.14,
#    'precip': 0.28,
#    'precipprob': None,
#    'precipcover': 12.5,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 47.9,
#    'windspeed': 29.0,
#    'winddir': 304.2,
#    'pressure': 1027.4,
#    'cloudcover': 26.9,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:56:13',
#    'sunriseEpoch': 1579438573,
#    'sunset': '16:59:36',
#    'sunsetEpoch': 1579474776,
#    'moonphase': 0.86,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['72327013897',
#     'KBNA',
#     'KMQY',
#     '72327313827',
#     'K1M5',
#     '72077599999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-20',
#    'datetimeEpoch': 1579500000,
#    'tempmax': -3.9,
#    'tempmin': -6.7,
#    'temp': -5.2,
#    'feelslikemax': -8.8,
#    'feelslikemin': -13.7,
#    'feelslike': -11.0,
#    'dew': -10.8,
#    'humidity': 64.83,
#    'precip': 0.34,
#    'precipprob': None,
#    'precipcover': 25.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 24.1,
#    'windspeed': 23.8,
#    'winddir': 252.0,
#    'pressure': 1034.7,
#    'cloudcover': 97.3,
#    'visibility': 14.1,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:55:48',
#    'sunriseEpoch': 1579524948,
#    'sunset': '17:00:38',
#    'sunsetEpoch': 1579561238,
#    'moonphase': 0.91,
#    'conditions': 'Snow, Overcast',
#    'icon': 'snow',
#    'stations': ['72327013897',
#     'KBNA',
#     'KMQY',
#     '72327313827',
#     'K1M5',
#     '72077599999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-21',
#    'datetimeEpoch': 1579586400,
#    'tempmax': 2.2,
#    'tempmin': -4.4,
#    'temp': -2.1,
#    'feelslikemax': -1.0,
#    'feelslikemin': -10.5,
#    'feelslike': -6.6,
#    'dew': -10.0,
#    'humidity': 55.46,
#    'precip': 2.04,
#    'precipprob': None,
#    'precipcover': 25.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 33.5,
#    'windspeed': 20.1,
#    'winddir': 157.3,
#    'pressure': 1035.5,
#    'cloudcover': 49.9,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:55:21',
#    'sunriseEpoch': 1579611321,
#    'sunset': '17:01:40',
#    'sunsetEpoch': 1579647700,
#    'moonphase': 0.95,
#    'conditions': 'Snow, Partially cloudy',
#    'icon': 'snow',
#    'stations': ['72327013897',
#     'KBNA',
#     'KMQY',
#     '72327313827',
#     'K1M5',
#     '72077599999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-22',
#    'datetimeEpoch': 1579672800,
#    'tempmax': 8.2,
#    'tempmin': -6.4,
#    'temp': 1.1,
#    'feelslikemax': 6.9,
#    'feelslikemin': -8.5,
#    'feelslike': 0.1,
#    'dew': -9.1,
#    'humidity': 51.16,
#    'precip': 3.88,
#    'precipprob': None,
#    'precipcover': 58.33,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 12.7,
#    'winddir': 113.0,
#    'pressure': 1027.7,
#    'cloudcover': 52.2,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:54:52',
#    'sunriseEpoch': 1579697692,
#    'sunset': '17:02:43',
#    'sunsetEpoch': 1579734163,
#    'moonphase': 0.98,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['72327013897',
#     'KBNA',
#     'KMQY',
#     '72327313827',
#     'K1M5',
#     '72077599999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-23',
#    'datetimeEpoch': 1579759200,
#    'tempmax': 9.1,
#    'tempmin': 3.4,
#    'temp': 6.1,
#    'feelslikemax': 6.5,
#    'feelslikemin': 1.7,
#    'feelslike': 4.4,
#    'dew': -0.8,
#    'humidity': 64.26,
#    'precip': 16.74,
#    'precipprob': None,
#    'precipcover': 50.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 29.5,
#    'windspeed': 17.6,
#    'winddir': 113.2,
#    'pressure': 1019.2,
#    'cloudcover': 86.0,
#    'visibility': 13.4,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:54:21',
#    'sunriseEpoch': 1579784061,
#    'sunset': '17:03:46',
#    'sunsetEpoch': 1579820626,
#    'moonphase': 0.99,
#    'conditions': 'Rain, Overcast',
#    'icon': 'rain',
#    'stations': ['72327013897',
#     'KBNA',
#     'KMQY',
#     '72327313827',
#     'K1M5',
#     '72077599999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-24',
#    'datetimeEpoch': 1579845600,
#    'tempmax': 11.6,
#    'tempmin': 4.3,
#    'temp': 7.9,
#    'feelslikemax': 11.6,
#    'feelslikemin': 0.9,
#    'feelslike': 5.8,
#    'dew': 4.0,
#    'humidity': 77.31,
#    'precip': 4.44,
#    'precipprob': None,
#    'precipcover': 100.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 38.9,
#    'windspeed': 21.0,
#    'winddir': 220.0,
#    'pressure': 1013.3,
#    'cloudcover': 80.8,
#    'visibility': 14.3,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:53:49',
#    'sunriseEpoch': 1579870429,
#    'sunset': '17:04:49',
#    'sunsetEpoch': 1579907089,
#    'moonphase': 1.0,
#    'conditions': 'Rain, Overcast',
#    'icon': 'rain',
#    'stations': ['72327013897',
#     'KBNA',
#     'KMQY',
#     '72327313827',
#     'K1M5',
#     '72077599999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-25',
#    'datetimeEpoch': 1579932000,
#    'tempmax': 4.3,
#    'tempmin': 0.4,
#    'temp': 3.5,
#    'feelslikemax': 2.0,
#    'feelslikemin': -1.1,
#    'feelslike': 0.9,
#    'dew': -1.6,
#    'humidity': 69.79,
#    'precip': 1.04,
#    'precipprob': None,
#    'precipcover': 79.17,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 27.7,
#    'windspeed': 18.0,
#    'winddir': 254.2,
#    'pressure': 1019.5,
#    'cloudcover': 87.7,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:53:15',
#    'sunriseEpoch': 1579956795,
#    'sunset': '17:05:52',
#    'sunsetEpoch': 1579993552,
#    'moonphase': 0.0,
#    'conditions': 'Rain, Overcast',
#    'icon': 'rain',
#    'stations': ['72327013897',
#     'KBNA',
#     'KMQY',
#     '72327313827',
#     'K1M5',
#     '72077599999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-26',
#    'datetimeEpoch': 1580018400,
#    'tempmax': 9.8,
#    'tempmin': -1.3,
#    'temp': 4.9,
#    'feelslikemax': 8.2,
#    'feelslikemin': -3.9,
#    'feelslike': 2.7,
#    'dew': 0.7,
#    'humidity': 74.84,
#    'precip': 0.13,
#    'precipprob': None,
#    'precipcover': 12.5,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 14.6,
#    'winddir': 188.1,
#    'pressure': 1017.8,
#    'cloudcover': 86.3,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:52:38',
#    'sunriseEpoch': 1580043158,
#    'sunset': '17:06:56',
#    'sunsetEpoch': 1580080016,
#    'moonphase': 0.01,
#    'conditions': 'Rain, Overcast',
#    'icon': 'rain',
#    'stations': ['72327013897',
#     'KBNA',
#     'KMQY',
#     '72327313827',
#     'K1M5',
#     '72077599999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-27',
#    'datetimeEpoch': 1580104800,
#    'tempmax': 14.3,
#    'tempmin': 4.0,
#    'temp': 9.2,
#    'feelslikemax': 14.3,
#    'feelslikemin': 0.9,
#    'feelslike': 8.1,
#    'dew': 3.7,
#    'humidity': 70.77,
#    'precip': 1.95,
#    'precipprob': None,
#    'precipcover': 33.33,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 33.5,
#    'windspeed': 18.3,
#    'winddir': 286.0,
#    'pressure': 1014.7,
#    'cloudcover': 61.1,
#    'visibility': 13.9,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:52:01',
#    'sunriseEpoch': 1580129521,
#    'sunset': '17:08:00',
#    'sunsetEpoch': 1580166480,
#    'moonphase': 0.03,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['72327013897',
#     'KBNA',
#     'KMQY',
#     '72327313827',
#     'K1M5',
#     '72077599999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-28',
#    'datetimeEpoch': 1580191200,
#    'tempmax': 7.8,
#    'tempmin': 0.6,
#    'temp': 3.2,
#    'feelslikemax': 7.8,
#    'feelslikemin': -2.3,
#    'feelslike': 1.2,
#    'dew': -0.6,
#    'humidity': 76.97,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 20.5,
#    'windspeed': 14.6,
#    'winddir': 106.9,
#    'pressure': 1019.0,
#    'cloudcover': 69.8,
#    'visibility': 9.4,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:51:21',
#    'sunriseEpoch': 1580215881,
#    'sunset': '17:09:03',
#    'sunsetEpoch': 1580252943,
#    'moonphase': 0.06,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['72327013897',
#     'KBNA',
#     'KMQY',
#     '72327313827',
#     'K1M5',
#     '72077599999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-29',
#    'datetimeEpoch': 1580277600,
#    'tempmax': 8.3,
#    'tempmin': 3.3,
#    'temp': 5.6,
#    'feelslikemax': 7.5,
#    'feelslikemin': 0.5,
#    'feelslike': 3.5,
#    'dew': 1.6,
#    'humidity': 75.85,
#    'precip': 0.01,
#    'precipprob': None,
#    'precipcover': 4.17,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 14.8,
#    'winddir': 64.5,
#    'pressure': 1018.4,
#    'cloudcover': 88.6,
#    'visibility': 14.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:50:40',
#    'sunriseEpoch': 1580302240,
#    'sunset': '17:10:07',
#    'sunsetEpoch': 1580339407,
#    'moonphase': 0.09,
#    'conditions': 'Rain, Overcast',
#    'icon': 'rain',
#    'stations': ['72327013897',
#     'KBNA',
#     'KMQY',
#     '72327313827',
#     'K1M5',
#     '72077599999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-30',
#    'datetimeEpoch': 1580364000,
#    'tempmax': 9.3,
#    'tempmin': 4.1,
#    'temp': 6.5,
#    'feelslikemax': 9.3,
#    'feelslikemin': 1.8,
#    'feelslike': 5.1,
#    'dew': 1.9,
#    'humidity': 72.84,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 12.5,
#    'winddir': 105.1,
#    'pressure': 1020.9,
#    'cloudcover': 86.6,
#    'visibility': 15.3,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:49:57',
#    'sunriseEpoch': 1580388597,
#    'sunset': '17:11:11',
#    'sunsetEpoch': 1580425871,
#    'moonphase': 0.13,
#    'conditions': 'Overcast',
#    'icon': 'cloudy',
#    'stations': ['72327013897',
#     'KBNA',
#     'KMQY',
#     '72327313827',
#     'K1M5',
#     '72077599999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-31',
#    'datetimeEpoch': 1580450400,
#    'tempmax': 9.4,
#    'tempmin': 6.1,
#    'temp': 8.0,
#    'feelslikemax': 9.3,
#    'feelslikemin': 4.7,
#    'feelslike': 7.4,
#    'dew': 4.7,
#    'humidity': 79.87,
#    'precip': 0.38,
#    'precipprob': None,
#    'precipcover': 33.33,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 10.5,
#    'winddir': 108.6,
#    'pressure': 1019.7,
#    'cloudcover': 80.1,
#    'visibility': 12.3,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:49:12',
#    'sunriseEpoch': 1580474952,
#    'sunset': '17:12:15',
#    'sunsetEpoch': 1580512335,
#    'moonphase': 0.18,
#    'conditions': 'Rain, Overcast',
#    'icon': 'rain',
#    'stations': ['72327013897',
#     'KBNA',
#     'KMQY',
#     '72327313827',
#     'K1M5',
#     '72077599999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-01',
#    'datetimeEpoch': 1580536800,
#    'tempmax': 8.9,
#    'tempmin': 2.1,
#    'temp': 7.2,
#    'feelslikemax': 8.2,
#    'feelslikemin': -0.5,
#    'feelslike': 5.7,
#    'dew': 2.8,
#    'humidity': 74.92,
#    'precip': 3.18,
#    'precipprob': None,
#    'precipcover': 29.17,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 13.5,
#    'winddir': 277.1,
#    'pressure': 1017.3,
#    'cloudcover': 62.5,
#    'visibility': 12.9,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:48:26',
#    'sunriseEpoch': 1580561306,
#    'sunset': '17:13:19',
#    'sunsetEpoch': 1580598799,
#    'moonphase': 0.22,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['72327013897',
#     'KBNA',
#     'KMQY',
#     '72327313827',
#     '72077599999',
#     'K1M5'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-02',
#    'datetimeEpoch': 1580623200,
#    'tempmax': 21.1,
#    'tempmin': 1.5,
#    'temp': 11.3,
#    'feelslikemax': 21.1,
#    'feelslikemin': -2.0,
#    'feelslike': 10.3,
#    'dew': -0.2,
#    'humidity': 49.75,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 36.6,
#    'windspeed': 25.4,
#    'winddir': 207.3,
#    'pressure': 1013.8,
#    'cloudcover': 23.5,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:47:38',
#    'sunriseEpoch': 1580647658,
#    'sunset': '17:14:23',
#    'sunsetEpoch': 1580685263,
#    'moonphase': 0.27,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['72327013897',
#     'KBNA',
#     'KMQY',
#     '72327313827',
#     'K1M5',
#     '72077599999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-03',
#    'datetimeEpoch': 1580709600,
#    'tempmax': 21.6,
#    'tempmin': 9.9,
#    'temp': 16.4,
#    'feelslikemax': 21.6,
#    'feelslikemin': 8.3,
#    'feelslike': 16.3,
#    'dew': 2.8,
#    'humidity': 41.41,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 51.6,
#    'windspeed': 24.3,
#    'winddir': 191.8,
#    'pressure': 1013.1,
#    'cloudcover': 65.3,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:46:49',
#    'sunriseEpoch': 1580734009,
#    'sunset': '17:15:26',
#    'sunsetEpoch': 1580771726,
#    'moonphase': 0.32,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['72327013897',
#     'KBNA',
#     'KMQY',
#     '72327313827',
#     'K1M5',
#     '72077599999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-04',
#    'datetimeEpoch': 1580796000,
#    'tempmax': 18.2,
#    'tempmin': 13.8,
#    'temp': 15.9,
#    'feelslikemax': 18.2,
#    'feelslikemin': 13.8,
#    'feelslike': 15.9,
#    'dew': 12.4,
#    'humidity': 80.66,
#    'precip': 16.59,
#    'precipprob': None,
#    'precipcover': 83.33,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 50.0,
#    'windspeed': 27.7,
#    'winddir': 202.2,
#    'pressure': 1011.3,
#    'cloudcover': 84.0,
#    'visibility': 13.7,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:45:58',
#    'sunriseEpoch': 1580820358,
#    'sunset': '17:16:30',
#    'sunsetEpoch': 1580858190,
#    'moonphase': 0.37,
#    'conditions': 'Rain, Overcast',
#    'icon': 'rain',
#    'stations': ['72327013897',
#     'KBNA',
#     'KMQY',
#     '72327313827',
#     'K1M5',
#     '72077599999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-05',
#    'datetimeEpoch': 1580882400,
#    'tempmax': 14.3,
#    'tempmin': 8.3,
#    'temp': 10.2,
#    'feelslikemax': 14.3,
#    'feelslikemin': 6.0,
#    'feelslike': 9.4,
#    'dew': 8.5,
#    'humidity': 89.48,
#    'precip': 24.31,
#    'precipprob': None,
#    'precipcover': 87.5,
#    'preciptype': None,
#    'snow': 1.88,
#    'snowdepth': 1.88,
#    'windgust': 24.1,
#    'windspeed': 17.4,
#    'winddir': 183.8,
#    'pressure': 1007.9,
#    'cloudcover': 93.1,
#    'visibility': 9.1,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:45:05',
#    'sunriseEpoch': 1580906705,
#    'sunset': '17:17:33',
#    'sunsetEpoch': 1580944653,
#    'moonphase': 0.41,
#    'conditions': 'Snow, Overcast',
#    'icon': 'snow',
#    'stations': ['72327013897',
#     'KBNA',
#     'KMQY',
#     '72327313827',
#     'K1M5',
#     '72077599999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-06',
#    'datetimeEpoch': 1580968800,
#    'tempmax': 9.0,
#    'tempmin': 1.0,
#    'temp': 4.6,
#    'feelslikemax': 7.0,
#    'feelslikemin': -2.1,
#    'feelslike': 1.7,
#    'dew': 2.3,
#    'humidity': 85.05,
#    'precip': 5.98,
#    'precipprob': None,
#    'precipcover': 100.0,
#    'preciptype': None,
#    'snow': 1.13,
#    'snowdepth': 3.0,
#    'windgust': 35.7,
#    'windspeed': 18.0,
#    'winddir': 286.2,
#    'pressure': 1000.1,
#    'cloudcover': 94.1,
#    'visibility': 10.3,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:44:11',
#    'sunriseEpoch': 1580993051,
#    'sunset': '17:18:37',
#    'sunsetEpoch': 1581031117,
#    'moonphase': 0.45,
#    'conditions': 'Snow, Overcast',
#    'icon': 'snow',
#    'stations': ['72327013897',
#     'KBNA',
#     'KMQY',
#     '72327313827',
#     'K1M5',
#     '72077599999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-07',
#    'datetimeEpoch': 1581055200,
#    'tempmax': 2.1,
#    'tempmin': -1.1,
#    'temp': 0.3,
#    'feelslikemax': -0.3,
#    'feelslikemin': -5.6,
#    'feelslike': -3.6,
#    'dew': -3.9,
#    'humidity': 73.99,
#    'precip': 3.33,
#    'precipprob': None,
#    'precipcover': 79.17,
#    'preciptype': None,
#    'snow': 1.92,
#    'snowdepth': 1.92,
#    'windgust': 33.5,
#    'windspeed': 18.4,
#    'winddir': 256.6,
#    'pressure': 1011.7,
#    'cloudcover': 77.6,
#    'visibility': 12.9,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:43:16',
#    'sunriseEpoch': 1581079396,
#    'sunset': '17:19:40',
#    'sunsetEpoch': 1581117580,
#    'moonphase': 0.48,
#    'conditions': 'Snow, Overcast',
#    'icon': 'snow',
#    'stations': ['72327013897',
#     'KBNA',
#     'KMQY',
#     '72327313827',
#     'K1M5',
#     '72077599999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-08',
#    'datetimeEpoch': 1581141600,
#    'tempmax': 10.9,
#    'tempmin': -1.2,
#    'temp': 4.1,
#    'feelslikemax': 10.9,
#    'feelslikemin': -3.3,
#    'feelslike': 2.6,
#    'dew': -3.9,
#    'humidity': 59.09,
#    'precip': 0.66,
#    'precipprob': None,
#    'precipcover': 50.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.67,
#    'windgust': 33.5,
#    'windspeed': 20.4,
#    'winddir': 203.0,
#    'pressure': 1023.3,
#    'cloudcover': 49.1,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:42:19',
#    'sunriseEpoch': 1581165739,
#    'sunset': '17:20:43',
#    'sunsetEpoch': 1581204043,
#    'moonphase': 0.5,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['72327013897',
#     'KBNA',
#     'KMQY',
#     '72327313827',
#     'K1M5',
#     '72077599999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-09',
#    'datetimeEpoch': 1581228000,
#    'tempmax': 17.8,
#    'tempmin': -1.4,
#    'temp': 8.6,
#    'feelslikemax': 17.8,
#    'feelslikemin': -3.1,
#    'feelslike': 7.9,
#    'dew': -0.4,
#    'humidity': 56.91,
#    'precip': 0.52,
#    'precipprob': None,
#    'precipcover': 20.83,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 56.7,
#    'windspeed': 37.1,
#    'winddir': 156.9,
#    'pressure': 1025.3,
#    'cloudcover': 56.5,
#    'visibility': 15.9,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:41:21',
#    'sunriseEpoch': 1581252081,
#    'sunset': '17:21:45',
#    'sunsetEpoch': 1581290505,
#    'moonphase': 0.5,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['72327013897',
#     'KBNA',
#     'KMQY',
#     '72327313827',
#     'K1M5',
#     '72077599999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-10',
#    'datetimeEpoch': 1581314400,
#    'tempmax': 13.8,
#    'tempmin': 9.6,
#    'temp': 12.0,
#    'feelslikemax': 13.8,
#    'feelslikemin': 7.1,
#    'feelslike': 11.8,
#    'dew': 9.3,
#    'humidity': 84.08,
#    'precip': 29.23,
#    'precipprob': None,
#    'precipcover': 100.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 56.6,
#    'windspeed': 35.5,
#    'winddir': 173.4,
#    'pressure': 1017.6,
#    'cloudcover': 88.9,
#    'visibility': 8.7,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:40:21',
#    'sunriseEpoch': 1581338421,
#    'sunset': '17:22:48',
#    'sunsetEpoch': 1581376968,
#    'moonphase': 0.52,
#    'conditions': 'Rain, Overcast',
#    'icon': 'rain',
#    'stations': ['72327013897',
#     'KBNA',
#     'KMQY',
#     '72327313827',
#     'K1M5',
#     '72077599999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-11',
#    'datetimeEpoch': 1581400800,
#    'tempmax': 9.4,
#    'tempmin': 5.0,
#    'temp': 6.9,
#    'feelslikemax': 7.4,
#    'feelslikemin': 2.2,
#    'feelslike': 4.3,
#    'dew': 3.7,
#    'humidity': 80.68,
#    'precip': 16.67,
#    'precipprob': None,
#    'precipcover': 100.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 29.5,
#    'windspeed': 22.0,
#    'winddir': 303.5,
#    'pressure': 1019.6,
#    'cloudcover': 89.3,
#    'visibility': 13.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:39:21',
#    'sunriseEpoch': 1581424761,
#    'sunset': '17:23:50',
#    'sunsetEpoch': 1581463430,
#    'moonphase': 0.53,
#    'conditions': 'Rain, Overcast',
#    'icon': 'rain',
#    'stations': ['72327013897',
#     'KBNA',
#     'KMQY',
#     '72327313827',
#     'K1M5',
#     '72077599999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-12',
#    'datetimeEpoch': 1581487200,
#    'tempmax': 12.4,
#    'tempmin': 4.3,
#    'temp': 7.4,
#    'feelslikemax': 12.4,
#    'feelslikemin': 1.1,
#    'feelslike': 6.1,
#    'dew': 5.3,
#    'humidity': 86.43,
#    'precip': 32.03,
#    'precipprob': None,
#    'precipcover': 100.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 61.9,
#    'windspeed': 16.4,
#    'winddir': 146.0,
#    'pressure': 1013.5,
#    'cloudcover': 83.2,
#    'visibility': 7.4,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:38:18',
#    'sunriseEpoch': 1581511098,
#    'sunset': '17:24:52',
#    'sunsetEpoch': 1581549892,
#    'moonphase': 0.57,
#    'conditions': 'Rain, Overcast',
#    'icon': 'rain',
#    'stations': ['72327013897',
#     'KBNA',
#     'KMQY',
#     '72327313827',
#     'K1M5',
#     '72077599999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-13',
#    'datetimeEpoch': 1581573600,
#    'tempmax': 10.6,
#    'tempmin': -2.2,
#    'temp': 5.2,
#    'feelslikemax': 10.6,
#    'feelslikemin': -7.1,
#    'feelslike': 1.7,
#    'dew': 1.2,
#    'humidity': 75.96,
#    'precip': 10.59,
#    'precipprob': None,
#    'precipcover': 95.83,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 42.1,
#    'windspeed': 27.5,
#    'winddir': 314.6,
#    'pressure': 1018.2,
#    'cloudcover': 90.5,
#    'visibility': 14.5,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:37:15',
#    'sunriseEpoch': 1581597435,
#    'sunset': '17:25:53',
#    'sunsetEpoch': 1581636353,
#    'moonphase': 0.62,
#    'conditions': 'Rain, Overcast',
#    'icon': 'rain',
#    'stations': ['72327013897',
#     'KBNA',
#     'KMQY',
#     '72327313827',
#     'K1M5',
#     '72077599999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-14',
#    'datetimeEpoch': 1581660000,
#    'tempmax': 1.0,
#    'tempmin': -6.6,
#    'temp': -3.2,
#    'feelslikemax': -0.7,
#    'feelslikemin': -13.1,
#    'feelslike': -7.9,
#    'dew': -10.8,
#    'humidity': 56.78,
#    'precip': 3.25,
#    'precipprob': None,
#    'precipcover': 70.83,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 27.0,
#    'windspeed': 20.4,
#    'winddir': 143.4,
#    'pressure': 1033.7,
#    'cloudcover': 41.2,
#    'visibility': 15.9,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:36:10',
#    'sunriseEpoch': 1581683770,
#    'sunset': '17:26:55',
#    'sunsetEpoch': 1581722815,
#    'moonphase': 0.67,
#    'conditions': 'Snow, Partially cloudy',
#    'icon': 'snow',
#    'stations': ['72327013897',
#     'KBNA',
#     'KMQY',
#     '72327313827',
#     'K1M5',
#     '72077599999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-15',
#    'datetimeEpoch': 1581746400,
#    'tempmax': 11.7,
#    'tempmin': -7.9,
#    'temp': 2.7,
#    'feelslikemax': 11.7,
#    'feelslikemin': -11.0,
#    'feelslike': 1.1,
#    'dew': -7.1,
#    'humidity': 52.6,
#    'precip': 2.15,
#    'precipprob': None,
#    'precipcover': 25.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 35.8,
#    'windspeed': 21.7,
#    'winddir': 116.9,
#    'pressure': 1028.6,
#    'cloudcover': 52.1,
#    'visibility': 15.9,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:35:05',
#    'sunriseEpoch': 1581770105,
#    'sunset': '17:27:56',
#    'sunsetEpoch': 1581809276,
#    'moonphase': 0.73,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['72327013897',
#     'KBNA',
#     'KMQY',
#     '72327313827',
#     'K1M5',
#     '72077599999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-16',
#    'datetimeEpoch': 1581832800,
#    'tempmax': 15.5,
#    'tempmin': 6.7,
#    'temp': 10.5,
#    'feelslikemax': 15.5,
#    'feelslikemin': 4.8,
#    'feelslike': 9.8,
#    'dew': 0.1,
#    'humidity': 49.36,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 27.6,
#    'windspeed': 16.2,
#    'winddir': 170.5,
#    'pressure': 1020.0,
#    'cloudcover': 74.2,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:33:58',
#    'sunriseEpoch': 1581856438,
#    'sunset': '17:28:56',
#    'sunsetEpoch': 1581895736,
#    'moonphase': 0.78,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['72327013897',
#     'KBNA',
#     'KMQY',
#     '72327313827',
#     'K1M5',
#     '72077599999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-17',
#    'datetimeEpoch': 1581919200,
#    'tempmax': 20.5,
#    'tempmin': 4.3,
#    'temp': 12.0,
#    'feelslikemax': 20.5,
#    'feelslikemin': 2.7,
#    'feelslike': 11.8,
#    'dew': 5.0,
#    'humidity': 64.57,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 48.2,
#    'windspeed': 32.0,
#    'winddir': 146.5,
#    'pressure': 1017.1,
#    'cloudcover': 69.5,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:32:50',
#    'sunriseEpoch': 1581942770,
#    'sunset': '17:29:57',
#    'sunsetEpoch': 1581982197,
#    'moonphase': 0.84,
#    'conditions': 'Partially cloudy',
#    'icon': 'wind',
#    'stations': ['72327013897',
#     'KBNA',
#     'KMQY',
#     '72327313827',
#     'K1M5',
#     '72077599999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-18',
#    'datetimeEpoch': 1582005600,
#    'tempmax': 15.5,
#    'tempmin': 6.1,
#    'temp': 11.7,
#    'feelslikemax': 15.5,
#    'feelslikemin': 2.6,
#    'feelslike': 10.8,
#    'dew': 9.0,
#    'humidity': 83.68,
#    'precip': 9.34,
#    'precipprob': None,
#    'precipcover': 62.5,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 41.5,
#    'windspeed': 25.5,
#    'winddir': 240.4,
#    'pressure': 1018.8,
#    'cloudcover': 88.8,
#    'visibility': 12.9,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:31:40',
#    'sunriseEpoch': 1582029100,
#    'sunset': '17:30:57',
#    'sunsetEpoch': 1582068657,
#    'moonphase': 0.88,
#    'conditions': 'Rain, Overcast',
#    'icon': 'rain',
#    'stations': ['72327013897',
#     'KBNA',
#     'KMQY',
#     '72327313827',
#     'K1M5',
#     '72077599999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-19',
#    'datetimeEpoch': 1582092000,
#    'tempmax': 11.7,
#    'tempmin': 2.9,
#    'temp': 6.5,
#    'feelslikemax': 11.7,
#    'feelslikemin': -1.8,
#    'feelslike': 3.6,
#    'dew': -1.9,
#    'humidity': 57.8,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 35.3,
#    'windspeed': 23.6,
#    'winddir': 65.5,
#    'pressure': 1029.5,
#    'cloudcover': 66.2,
#    'visibility': 14.6,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:30:30',
#    'sunriseEpoch': 1582115430,
#    'sunset': '17:31:57',
#    'sunsetEpoch': 1582155117,
#    'moonphase': 0.93,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['72327013897',
#     'KBNA',
#     'KMQY',
#     '72327313827',
#     'K1M5',
#     '72077599999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-20',
#    'datetimeEpoch': 1582178400,
#    'tempmax': 6.1,
#    'tempmin': 0.0,
#    'temp': 3.6,
#    'feelslikemax': 3.2,
#    'feelslikemin': -5.6,
#    'feelslike': -0.4,
#    'dew': -3.2,
#    'humidity': 62.28,
#    'precip': 4.04,
#    'precipprob': None,
#    'precipcover': 29.17,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 46.4,
#    'windspeed': 28.1,
#    'winddir': 116.1,
#    'pressure': 1031.0,
#    'cloudcover': 74.0,
#    'visibility': 13.1,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:29:19',
#    'sunriseEpoch': 1582201759,
#    'sunset': '17:32:56',
#    'sunsetEpoch': 1582241576,
#    'moonphase': 0.96,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['72327013897',
#     'KBNA',
#     'KMQY',
#     '72327313827',
#     'K1M5',
#     '72077599999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-21',
#    'datetimeEpoch': 1582264800,
#    'tempmax': 6.0,
#    'tempmin': -5.0,
#    'temp': 0.0,
#    'feelslikemax': 4.3,
#    'feelslikemin': -11.2,
#    'feelslike': -3.8,
#    'dew': -10.4,
#    'humidity': 47.66,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 37.1,
#    'windspeed': 20.4,
#    'winddir': 86.9,
#    'pressure': 1036.6,
#    'cloudcover': 0.1,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:28:06',
#    'sunriseEpoch': 1582288086,
#    'sunset': '17:33:55',
#    'sunsetEpoch': 1582328035,
#    'moonphase': 0.98,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['72327013897',
#     'KBNA',
#     'KMQY',
#     '72327313827',
#     'K1M5',
#     '72077599999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-22',
#    'datetimeEpoch': 1582351200,
#    'tempmax': 11.7,
#    'tempmin': -5.8,
#    'temp': 2.9,
#    'feelslikemax': 11.7,
#    'feelslikemin': -9.2,
#    'feelslike': 1.8,
#    'dew': -7.3,
#    'humidity': 52.95,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 9.9,
#    'winddir': 167.2,
#    'pressure': 1030.5,
#    'cloudcover': 39.5,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:26:53',
#    'sunriseEpoch': 1582374413,
#    'sunset': '17:34:54',
#    'sunsetEpoch': 1582414494,
#    'moonphase': 1.0,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['72327013897',
#     'KBNA',
#     'KMQY',
#     '72327313827',
#     'K1M5',
#     '72077599999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-23',
#    'datetimeEpoch': 1582437600,
#    'tempmax': 13.3,
#    'tempmin': 0.9,
#    'temp': 7.4,
#    'feelslikemax': 13.3,
#    'feelslikemin': -1.3,
#    'feelslike': 6.1,
#    'dew': -0.8,
#    'humidity': 57.68,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 31.7,
#    'windspeed': 19.9,
#    'winddir': 196.1,
#    'pressure': 1022.8,
#    'cloudcover': 82.3,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:25:39',
#    'sunriseEpoch': 1582460739,
#    'sunset': '17:35:52',
#    'sunsetEpoch': 1582500952,
#    'moonphase': 1.0,
#    'conditions': 'Overcast',
#    'icon': 'cloudy',
#    'stations': ['72327013897',
#     'KBNA',
#     'KMQY',
#     '72327313827',
#     'K1M5',
#     '72077599999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-24',
#    'datetimeEpoch': 1582524000,
#    'tempmax': 12.1,
#    'tempmin': 6.6,
#    'temp': 9.2,
#    'feelslikemax': 12.1,
#    'feelslikemin': 3.1,
#    'feelslike': 7.8,
#    'dew': 6.7,
#    'humidity': 84.45,
#    'precip': 15.34,
#    'precipprob': None,
#    'precipcover': 75.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 44.7,
#    'windspeed': 27.5,
#    'winddir': 167.2,
#    'pressure': 1011.2,
#    'cloudcover': 96.3,
#    'visibility': 13.8,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:24:24',
#    'sunriseEpoch': 1582547064,
#    'sunset': '17:36:50',
#    'sunsetEpoch': 1582587410,
#    'moonphase': 0.0,
#    'conditions': 'Rain, Overcast',
#    'icon': 'rain',
#    'stations': ['72327013897',
#     'KBNA',
#     'KMQY',
#     '72327313827',
# ...
#   {'datetime': '2020-12-15',
#    'datetimeEpoch': 1608012000,
#    'tempmax': 7.9,
#    'tempmin': -0.8,
#    'temp': 4.0,
#    'feelslikemax': 7.1,
#    'feelslikemin': -5.2,
#    'feelslike': 1.4,
#    'dew': -1.3,
#    'humidity': 68.55,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 16.4,
#    'winddir': 66.4,
#    'pressure': 1021.2,
#    'cloudcover': 85.5,
#    'visibility': 15.9,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:51:18',
#    'sunriseEpoch': 1608036678,
#    'sunset': '16:33:52',
#    'sunsetEpoch': 1608071632,
#    'moonphase': 0.0,
#    'conditions': 'Overcast',
#    'icon': 'cloudy',
#    'stations': ['72327013897',
#     'KBNA',
#     'KMQY',
#     '72327313827',
#     'K1M5',
#     '72077599999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-16',
#    'datetimeEpoch': 1608098400,
#    'tempmax': 6.6,
#    'tempmin': 1.6,
#    'temp': 4.6,
#    'feelslikemax': 6.6,
#    'feelslikemin': -2.9,
#    'feelslike': 2.5,
#    'dew': 2.2,
#    'humidity': 84.81,
#    'precip': 4.27,
#    'precipprob': None,
#    'precipcover': 45.83,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 20.5,
#    'windspeed': 18.0,
#    'winddir': 225.6,
#    'pressure': 1014.8,
#    'cloudcover': 99.3,
#    'visibility': 9.3,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:51:56',
#    'sunriseEpoch': 1608123116,
#    'sunset': '16:34:12',
#    'sunsetEpoch': 1608158052,
#    'moonphase': 0.02,
#    'conditions': 'Rain, Overcast',
#    'icon': 'rain',
#    'stations': ['72327013897',
#     'KBNA',
#     'KMQY',
#     '72327313827',
#     'K1M5',
#     '72077599999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-17',
#    'datetimeEpoch': 1608184800,
#    'tempmax': 3.8,
#    'tempmin': -2.5,
#    'temp': 0.7,
#    'feelslikemax': 1.4,
#    'feelslikemin': -5.2,
#    'feelslike': -2.1,
#    'dew': -5.3,
#    'humidity': 65.27,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 18.4,
#    'windspeed': 18.4,
#    'winddir': 245.6,
#    'pressure': 1023.2,
#    'cloudcover': 45.9,
#    'visibility': 15.7,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:52:33',
#    'sunriseEpoch': 1608209553,
#    'sunset': '16:34:35',
#    'sunsetEpoch': 1608244475,
#    'moonphase': 0.05,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['72327013897',
#     'KBNA',
#     'KMQY',
#     '72327313827',
#     'K1M5',
#     '72077599999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-18',
#    'datetimeEpoch': 1608271200,
#    'tempmax': 7.1,
#    'tempmin': -4.6,
#    'temp': 0.8,
#    'feelslikemax': 5.6,
#    'feelslikemin': -5.8,
#    'feelslike': -0.1,
#    'dew': -4.5,
#    'humidity': 69.73,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 10.8,
#    'winddir': 78.8,
#    'pressure': 1029.5,
#    'cloudcover': 36.9,
#    'visibility': 14.1,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:53:08',
#    'sunriseEpoch': 1608295988,
#    'sunset': '16:34:59',
#    'sunsetEpoch': 1608330899,
#    'moonphase': 0.09,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['72327013897',
#     'KBNA',
#     'KMQY',
#     '72327313827',
#     'K1M5',
#     '72077599999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-19',
#    'datetimeEpoch': 1608357600,
#    'tempmax': 10.6,
#    'tempmin': -1.3,
#    'temp': 5.0,
#    'feelslikemax': 10.6,
#    'feelslikemin': -3.8,
#    'feelslike': 3.5,
#    'dew': -0.8,
#    'humidity': 68.05,
#    'precip': 6.27,
#    'precipprob': None,
#    'precipcover': 25.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 35.3,
#    'windspeed': 23.0,
#    'winddir': 152.0,
#    'pressure': 1023.6,
#    'cloudcover': 89.5,
#    'visibility': 15.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:53:42',
#    'sunriseEpoch': 1608382422,
#    'sunset': '16:35:26',
#    'sunsetEpoch': 1608417326,
#    'moonphase': 0.13,
#    'conditions': 'Rain, Overcast',
#    'icon': 'rain',
#    'stations': ['72327013897',
#     'KBNA',
#     'KMQY',
#     '72327313827',
#     'K1M5',
#     '72077599999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-20',
#    'datetimeEpoch': 1608444000,
#    'tempmax': 9.8,
#    'tempmin': 0.5,
#    'temp': 6.3,
#    'feelslikemax': 9.7,
#    'feelslikemin': -1.8,
#    'feelslike': 5.3,
#    'dew': 3.9,
#    'humidity': 85.4,
#    'precip': 3.61,
#    'precipprob': None,
#    'precipcover': 20.83,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 11.0,
#    'winddir': 186.6,
#    'pressure': 1017.4,
#    'cloudcover': 71.1,
#    'visibility': 11.1,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:54:14',
#    'sunriseEpoch': 1608468854,
#    'sunset': '16:35:54',
#    'sunsetEpoch': 1608503754,
#    'moonphase': 0.18,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['72327013897',
#     'KBNA',
#     'KMQY',
#     '72327313827',
#     'K1M5',
#     '72077599999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-21',
#    'datetimeEpoch': 1608530400,
#    'tempmax': 15.6,
#    'tempmin': 0.4,
#    'temp': 8.2,
#    'feelslikemax': 15.6,
#    'feelslikemin': -2.5,
#    'feelslike': 7.1,
#    'dew': 1.8,
#    'humidity': 67.29,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 47.9,
#    'windspeed': 24.3,
#    'winddir': 230.6,
#    'pressure': 1016.6,
#    'cloudcover': 43.0,
#    'visibility': 13.3,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:54:44',
#    'sunriseEpoch': 1608555284,
#    'sunset': '16:36:24',
#    'sunsetEpoch': 1608590184,
#    'moonphase': 0.23,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['72327013897',
#     'KBNA',
#     'KMQY',
#     '72327313827',
#     'K1M5',
#     '72077599999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-22',
#    'datetimeEpoch': 1608616800,
#    'tempmax': 12.8,
#    'tempmin': 3.0,
#    'temp': 8.2,
#    'feelslikemax': 12.8,
#    'feelslikemin': 0.7,
#    'feelslike': 7.1,
#    'dew': -2.8,
#    'humidity': 47.16,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 27.7,
#    'windspeed': 14.6,
#    'winddir': 162.3,
#    'pressure': 1024.0,
#    'cloudcover': 4.0,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:55:13',
#    'sunriseEpoch': 1608641713,
#    'sunset': '16:36:55',
#    'sunsetEpoch': 1608676615,
#    'moonphase': 0.28,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['72327013897',
#     'KBNA',
#     'KMQY',
#     '72327313827',
#     'K1M5',
#     '72077599999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-23',
#    'datetimeEpoch': 1608703200,
#    'tempmax': 16.1,
#    'tempmin': 1.9,
#    'temp': 10.1,
#    'feelslikemax': 16.1,
#    'feelslikemin': -0.3,
#    'feelslike': 9.0,
#    'dew': -0.4,
#    'humidity': 50.78,
#    'precip': 11.12,
#    'precipprob': None,
#    'precipcover': 16.67,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 59.9,
#    'windspeed': 37.5,
#    'winddir': 159.6,
#    'pressure': 1016.7,
#    'cloudcover': 76.8,
#    'visibility': 15.3,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:55:40',
#    'sunriseEpoch': 1608728140,
#    'sunset': '16:37:28',
#    'sunsetEpoch': 1608763048,
#    'moonphase': 0.32,
#    'conditions': 'Rain, Overcast',
#    'icon': 'rain',
#    'stations': ['72327013897',
#     'KBNA',
#     'KMQY',
#     '72327313827',
#     'K1M5',
#     '72077599999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-24',
#    'datetimeEpoch': 1608789600,
#    'tempmax': 9.9,
#    'tempmin': -3.8,
#    'temp': 2.6,
#    'feelslikemax': 8.6,
#    'feelslikemin': -9.7,
#    'feelslike': -1.7,
#    'dew': -3.7,
#    'humidity': 64.63,
#    'precip': 8.65,
#    'precipprob': None,
#    'precipcover': 25.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 49.7,
#    'windspeed': 32.7,
#    'winddir': 288.1,
#    'pressure': 1012.1,
#    'cloudcover': 97.0,
#    'visibility': 14.8,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:56:05',
#    'sunriseEpoch': 1608814565,
#    'sunset': '16:38:03',
#    'sunsetEpoch': 1608849483,
#    'moonphase': 0.37,
#    'conditions': 'Rain, Overcast',
#    'icon': 'rain',
#    'stations': ['72327013897',
#     'KBNA',
#     'KMQY',
#     '72327313827',
#     'K1M5',
#     '72077599999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-25',
#    'datetimeEpoch': 1608876000,
#    'tempmax': -3.3,
#    'tempmin': -7.8,
#    'temp': -5.8,
#    'feelslikemax': -8.6,
#    'feelslikemin': -13.7,
#    'feelslike': -10.9,
#    'dew': -14.1,
#    'humidity': 52.58,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 35.3,
#    'windspeed': 22.2,
#    'winddir': 260.8,
#    'pressure': 1019.9,
#    'cloudcover': 51.8,
#    'visibility': 15.7,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:56:29',
#    'sunriseEpoch': 1608900989,
#    'sunset': '16:38:40',
#    'sunsetEpoch': 1608935920,
#    'moonphase': 0.4,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['72327013897',
#     'KBNA',
#     'KMQY',
#     '72327313827',
#     'K1M5',
#     '72077599999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-26',
#    'datetimeEpoch': 1608962400,
#    'tempmax': 10.5,
#    'tempmin': -8.3,
#    'temp': 0.4,
#    'feelslikemax': 10.5,
#    'feelslikemin': -13.6,
#    'feelslike': -2.7,
#    'dew': -8.4,
#    'humidity': 54.31,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 27.7,
#    'windspeed': 19.7,
#    'winddir': 170.2,
#    'pressure': 1020.9,
#    'cloudcover': 11.5,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:56:51',
#    'sunriseEpoch': 1608987411,
#    'sunset': '16:39:18',
#    'sunsetEpoch': 1609022358,
#    'moonphase': 0.44,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['72327013897',
#     'KBNA',
#     'KMQY',
#     '72327313827',
#     'K1M5',
#     '72077599999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-27',
#    'datetimeEpoch': 1609048800,
#    'tempmax': 16.1,
#    'tempmin': 0.0,
#    'temp': 8.2,
#    'feelslikemax': 16.1,
#    'feelslikemin': -2.6,
#    'feelslike': 7.6,
#    'dew': -3.0,
#    'humidity': 47.81,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 59.0,
#    'windspeed': 35.2,
#    'winddir': 148.5,
#    'pressure': 1018.5,
#    'cloudcover': 47.4,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:57:10',
#    'sunriseEpoch': 1609073830,
#    'sunset': '16:39:57',
#    'sunsetEpoch': 1609108797,
#    'moonphase': 0.47,
#    'conditions': 'Partially cloudy',
#    'icon': 'wind',
#    'stations': ['72327013897',
#     'KBNA',
#     'KMQY',
#     '72327313827',
#     'K1M5',
#     '72077599999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-28',
#    'datetimeEpoch': 1609135200,
#    'tempmax': 13.2,
#    'tempmin': 1.4,
#    'temp': 8.9,
#    'feelslikemax': 13.2,
#    'feelslikemin': -1.8,
#    'feelslike': 7.9,
#    'dew': 0.6,
#    'humidity': 57.02,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 51.9,
#    'windspeed': 35.1,
#    'winddir': 239.3,
#    'pressure': 1025.4,
#    'cloudcover': 75.0,
#    'visibility': 15.9,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:57:28',
#    'sunriseEpoch': 1609160248,
#    'sunset': '16:40:38',
#    'sunsetEpoch': 1609195238,
#    'moonphase': 0.49,
#    'conditions': 'Partially cloudy',
#    'icon': 'wind',
#    'stations': ['72327013897',
#     'KBNA',
#     'KMQY',
#     '72327313827',
#     'K1M5',
#     '72077599999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-29',
#    'datetimeEpoch': 1609221600,
#    'tempmax': 10.1,
#    'tempmin': -2.3,
#    'temp': 3.3,
#    'feelslikemax': 10.1,
#    'feelslikemin': -5.9,
#    'feelslike': 1.1,
#    'dew': -2.5,
#    'humidity': 67.55,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 14.3,
#    'winddir': 86.3,
#    'pressure': 1029.6,
#    'cloudcover': 45.9,
#    'visibility': 13.9,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:57:45',
#    'sunriseEpoch': 1609246665,
#    'sunset': '16:41:21',
#    'sunsetEpoch': 1609281681,
#    'moonphase': 0.5,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['72327013897',
#     'KBNA',
#     'KMQY',
#     '72327313827',
#     'K1M5',
#     '72077599999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-30',
#    'datetimeEpoch': 1609308000,
#    'tempmax': 19.3,
#    'tempmin': 1.8,
#    'temp': 13.3,
#    'feelslikemax': 19.3,
#    'feelslikemin': -1.8,
#    'feelslike': 12.5,
#    'dew': 6.1,
#    'humidity': 63.07,
#    'precip': 3.0,
#    'precipprob': None,
#    'precipcover': 12.5,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 61.3,
#    'windspeed': 38.2,
#    'winddir': 170.8,
#    'pressure': 1019.4,
#    'cloudcover': 68.2,
#    'visibility': 15.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:57:59',
#    'sunriseEpoch': 1609333079,
#    'sunset': '16:42:05',
#    'sunsetEpoch': 1609368125,
#    'moonphase': 0.5,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['72327013897',
#     'KBNA',
#     'KMQY',
#     '72327313827',
#     'K1M5',
#     '72077599999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-31',
#    'datetimeEpoch': 1609394400,
#    'tempmax': 7.9,
#    'tempmin': 3.9,
#    'temp': 5.3,
#    'feelslikemax': 6.0,
#    'feelslikemin': 0.2,
#    'feelslike': 2.5,
#    'dew': 3.9,
#    'humidity': 90.34,
#    'precip': 22.4,
#    'precipprob': None,
#    'precipcover': 58.33,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 40.3,
#    'windspeed': 28.0,
#    'winddir': 128.9,
#    'pressure': 1020.8,
#    'cloudcover': 98.1,
#    'visibility': 12.2,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:58:11',
#    'sunriseEpoch': 1609419491,
#    'sunset': '16:42:50',
#    'sunsetEpoch': 1609454570,
#    'moonphase': 0.51,
#    'conditions': 'Rain, Overcast',
#    'icon': 'rain',
#    'stations': ['72327013897',
#     'KBNA',
#     'KMQY',
#     '72327313827',
#     'K1M5',
#     '72077599999'],
#    'source': 'obs',
#    'hours': None}],
#  'stations': {'72327013897': {'distance': 9677.0,
#    'latitude': 36.119,
#    'longitude': -86.689,
#    'useCount': 0,
#    'id': '72327013897',
#    'name': 'NASHVILLE INTERNATIONAL AIRPORT, TN US',
#    'quality': 100,
#    'contribution': 0.0},
#   'KBNA': {'distance': 9779.0,
#    'latitude': 36.13,
#    'longitude': -86.68,
#    'useCount': 0,
#    'id': 'KBNA',
#    'name': 'KBNA',
#    'quality': 100,
#    'contribution': 0.0},
#   'KMQY': {'distance': 28463.0,
#    'latitude': 36.02,
#    'longitude': -86.52,
#    'useCount': 0,
#    'id': 'KMQY',
#    'name': 'KMQY',
#    'quality': 100,
#    'contribution': 0.0},
#   '72327313827': {'distance': 29196.0,
#    'latitude': 36.009,
#    'longitude': -86.52,
#    'useCount': 0,
#    'id': '72327313827',
#    'name': 'SMYRNA AIRPORT, TN US',
#    'quality': 100,
#    'contribution': 0.0},
#   '72077599999': {'distance': 73596.0,
#    'latitude': 35.507,
#    'longitude': -86.804,
#    'useCount': 0,
#    'id': '72077599999',
#    'name': 'ELLINGTON, TN US',
#    'quality': 100,
#    'contribution': 0.0},
#   'K1M5': {'distance': 55036.0,
#    'latitude': 36.6,
#    'longitude': -86.48,
#    'useCount': 0,
#    'id': 'K1M5',
#    'name': 'K1M5',
#    'quality': 99,
#    'contribution': 0.0}}}

# %%
#3. We create empty lists to transfer the data
temperature = []
temp_max = []
temp_min = []
humidity = []
precip = []
snow = []
windspeed = []
conditions = []
date = []
city = []

# %%
#4. We loop thropugh the API and extract the info we need
for x in range(366):
    temperature.append(response["days"][x]["temp"])
    temp_max.append(response["days"][x]["tempmax"])
    temp_min.append(response["days"][x]["tempmin"])
    humidity.append(response["days"][x]["humidity"])
    precip.append(response["days"][x]["precip"])
    snow.append(response["days"][x]["snow"])
    windspeed.append(response["days"][x]["windspeed"])
    conditions.append(response["days"][x]["conditions"])
    date.append(response["days"][x]["datetime"])
    city.append("Nashville, TN")

# %%
print(len(temperature),len(temp_max),len(temp_min),len(humidity),len(precip),len(snow),len(windspeed),len(conditions),len(date),len(city))
# Out:
# 366 366 366 366 366 366 366 366 366 366

# %%
#5. We create a dataframe based on the lists
New_df = pd.DataFrame(
    {'City': city,
     'Date': date,
     'Temperature': temperature,
     'temp_max': temp_max,
     'temp_min':temp_min,
     'humidity':humidity,
     'precip':precip,
     'snow':snow,
     'windspeed':windspeed,
     'conditions': conditions
    })

# %%
New_df
# Out:
#               City        Date  Temperature  temp_max  temp_min  humidity  \
# 0    Nashville, TN  2020-01-01          6.0      11.1       0.8     48.21
# 1    Nashville, TN  2020-01-02         10.4      12.1       7.8     74.23
# 2    Nashville, TN  2020-01-03         13.0      14.3      11.6     90.45
# 3    Nashville, TN  2020-01-04          6.1      12.7       3.3     70.03
# 4    Nashville, TN  2020-01-05          5.7      12.8      -1.8     62.11
# ..             ...         ...          ...       ...       ...       ...
# 361  Nashville, TN  2020-12-27          8.2      16.1       0.0     47.81
# 362  Nashville, TN  2020-12-28          8.9      13.2       1.4     57.02
# 363  Nashville, TN  2020-12-29          3.3      10.1      -2.3     67.55
# 364  Nashville, TN  2020-12-30         13.3      19.3       1.8     63.07
# 365  Nashville, TN  2020-12-31          5.3       7.9       3.9     90.34
#
#      precip  snow  windspeed              conditions
# 0      0.06   0.0       19.7  Rain, Partially cloudy
# 1     29.83   0.0       29.4          Rain, Overcast
# 2     10.32   0.0       12.2          Rain, Overcast
# 3      0.88   0.0       25.6          Rain, Overcast
# 4      0.33   0.0       23.1                    Rain
# ..      ...   ...        ...                     ...
# 361    0.00   0.0       35.2        Partially cloudy
# 362    0.00   0.0       35.1        Partially cloudy
# 363    0.00   0.0       14.3        Partially cloudy
# 364    3.00   0.0       38.2  Rain, Partially cloudy
# 365   22.40   0.0       28.0          Rain, Overcast
#
# [366 rows x 10 columns]

# %%
#6. We add new city dataframe to original dataframe including cities already evaluated 

frames = [Final_df,New_df]

# %%
Final_df = pd.concat(frames)

# %%
Final_df
# Out:
#               City        Date  Temperature  temp_max  temp_min  humidity  \
# 0     Montreal, QC  2020-01-01          0.2       1.1      -0.8     87.84
# 1     Montreal, QC  2020-01-02          0.9       2.6      -1.0     78.70
# 2     Montreal, QC  2020-01-03          4.8       5.8       2.8     74.88
# 3     Montreal, QC  2020-01-04          0.5       3.2      -1.9     78.79
# 4     Montreal, QC  2020-01-05         -5.3      -1.8      -9.9     69.09
# ..             ...         ...          ...       ...       ...       ...
# 361  Nashville, TN  2020-12-27          8.2      16.1       0.0     47.81
# 362  Nashville, TN  2020-12-28          8.9      13.2       1.4     57.02
# 363  Nashville, TN  2020-12-29          3.3      10.1      -2.3     67.55
# 364  Nashville, TN  2020-12-30         13.3      19.3       1.8     63.07
# 365  Nashville, TN  2020-12-31          5.3       7.9       3.9     90.34
#
#      precip  snow  windspeed              conditions
# 0      5.71  0.00        7.9                    Rain
# 1      0.00  0.00        7.7                   Clear
# 2      0.00  0.00        7.6                   Clear
# 3      2.27  0.00       11.2                    Rain
# 4      0.76  3.88       13.1                    Snow
# ..      ...   ...        ...                     ...
# 361    0.00  0.00       35.2        Partially cloudy
# 362    0.00  0.00       35.1        Partially cloudy
# 363    0.00  0.00       14.3        Partially cloudy
# 364    3.00  0.00       38.2  Rain, Partially cloudy
# 365   22.40  0.00       28.0          Rain, Overcast
#
# [7320 rows x 10 columns]

# %%
#7.Update to csv by converting df to csv
Final_df.to_csv("Temperature_Dataset1.csv", index=False)

# %%
#8. Will need to import CSV with temp for cities already evaluated every time this document is open again for the 1st time. 
#Name dataframe: Final_df

file_path = os.path.join("Temperature_Dataset1.csv")
Final_df = pd.read_csv(file_path)
Final_df
# Out:
#                City        Date  Temperature  temp_max  temp_min  humidity  \
# 0      Montreal, QC  2020-01-01          0.2       1.1      -0.8     87.84
# 1      Montreal, QC  2020-01-02          0.9       2.6      -1.0     78.70
# 2      Montreal, QC  2020-01-03          4.8       5.8       2.8     74.88
# 3      Montreal, QC  2020-01-04          0.5       3.2      -1.9     78.79
# 4      Montreal, QC  2020-01-05         -5.3      -1.8      -9.9     69.09
# ...             ...         ...          ...       ...       ...       ...
# 7315  Nashville, TN  2020-12-27          8.2      16.1       0.0     47.81
# 7316  Nashville, TN  2020-12-28          8.9      13.2       1.4     57.02
# 7317  Nashville, TN  2020-12-29          3.3      10.1      -2.3     67.55
# 7318  Nashville, TN  2020-12-30         13.3      19.3       1.8     63.07
# 7319  Nashville, TN  2020-12-31          5.3       7.9       3.9     90.34
#
#       precip  snow  windspeed              conditions
# 0       5.71  0.00        7.9                    Rain
# 1       0.00  0.00        7.7                   Clear
# 2       0.00  0.00        7.6                   Clear
# 3       2.27  0.00       11.2                    Rain
# 4       0.76  3.88       13.1                    Snow
# ...      ...   ...        ...                     ...
# 7315    0.00  0.00       35.2        Partially cloudy
# 7316    0.00  0.00       35.1        Partially cloudy
# 7317    0.00  0.00       14.3        Partially cloudy
# 7318    3.00  0.00       38.2  Rain, Partially cloudy
# 7319   22.40  0.00       28.0          Rain, Overcast
#
# [7320 rows x 10 columns]
