# %%
# 1.Importing dependencies

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import os

# %%
#2. We add url. Each city will have a new url

url2 = "https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/Chicago/2020-1-1/2020-12-31?unitGroup=metric&key=SRX784Y4XEDTND44NFLHKK42Z&include=obs"

# %%
response = requests.get(url2).json()

# %%
response
# Out:
# {'queryCost': 366,
#  'latitude': 42.3668,
#  'longitude': -71.106,
#  'resolvedAddress': 'Cambridge, MA, United States',
#  'address': 'cambridge massachusetts',
#  'timezone': 'America/New_York',
#  'tzoffset': -5.0,
#  'days': [{'datetime': '2020-01-01',
#    'datetimeEpoch': 1577854800,
#    'tempmax': 5.5,
#    'tempmin': 2.1,
#    'temp': 3.7,
#    'feelslikemax': 1.7,
#    'feelslikemin': -2.8,
#    'feelslike': -0.9,
#    'dew': -4.3,
#    'humidity': 56.05,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.35,
#    'windgust': 55.4,
#    'windspeed': 32.0,
#    'winddir': 266.0,
#    'pressure': 1003.1,
#    'cloudcover': 39.2,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:13:45',
#    'sunriseEpoch': 1577880825,
#    'sunset': '16:22:05',
#    'sunsetEpoch': 1577913725,
#    'moonphase': 0.17,
#    'conditions': 'Partially cloudy',
#    'icon': 'wind',
#    'stations': ['KOWD',
#     '72509854704',
#     'KBED',
#     'KBOS',
#     '72509014739',
#     '72505914702'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-02',
#    'datetimeEpoch': 1577941200,
#    'tempmax': 8.8,
#    'tempmin': 0.8,
#    'temp': 4.7,
#    'feelslikemax': 5.5,
#    'feelslikemin': -3.3,
#    'feelslike': 1.0,
#    'dew': -4.7,
#    'humidity': 50.92,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 42.5,
#    'windspeed': 25.4,
#    'winddir': 230.4,
#    'pressure': 1010.8,
#    'cloudcover': 56.3,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:13:50',
#    'sunriseEpoch': 1577967230,
#    'sunset': '16:22:57',
#    'sunsetEpoch': 1578000177,
#    'moonphase': 0.22,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['KOWD',
#     '72509854704',
#     'KBED',
#     'KBOS',
#     '72509014739',
#     '72505914702'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-03',
#    'datetimeEpoch': 1578027600,
#    'tempmax': 10.5,
#    'tempmin': 6.5,
#    'temp': 8.5,
#    'feelslikemax': 10.5,
#    'feelslikemin': 3.6,
#    'feelslike': 6.8,
#    'dew': 0.5,
#    'humidity': 57.23,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 21.7,
#    'winddir': 242.2,
#    'pressure': 1008.3,
#    'cloudcover': 79.1,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:13:53',
#    'sunriseEpoch': 1578053633,
#    'sunset': '16:23:51',
#    'sunsetEpoch': 1578086631,
#    'moonphase': 0.26,
#    'conditions': 'Overcast',
#    'icon': 'cloudy',
#    'stations': ['KOWD',
#     '72509854704',
#     'KBED',
#     'KBOS',
#     '72509014739',
#     '72505914702'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-04',
#    'datetimeEpoch': 1578114000,
#    'tempmax': 8.5,
#    'tempmin': 4.9,
#    'temp': 7.1,
#    'feelslikemax': 8.1,
#    'feelslikemin': 1.2,
#    'feelslike': 5.8,
#    'dew': 3.7,
#    'humidity': 79.41,
#    'precip': 3.14,
#    'precipprob': None,
#    'precipcover': 33.33,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 17.7,
#    'winddir': 161.8,
#    'pressure': 1004.1,
#    'cloudcover': 82.5,
#    'visibility': 8.2,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:13:53',
#    'sunriseEpoch': 1578140033,
#    'sunset': '16:24:47',
#    'sunsetEpoch': 1578173087,
#    'moonphase': 0.31,
#    'conditions': 'Rain, Overcast',
#    'icon': 'rain',
#    'stations': ['KOWD',
#     '72509854704',
#     'KBED',
#     'KBOS',
#     '72509014739',
#     '72505914702'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-05',
#    'datetimeEpoch': 1578200400,
#    'tempmax': 4.3,
#    'tempmin': 0.2,
#    'temp': 2.8,
#    'feelslikemax': 0.6,
#    'feelslikemin': -4.0,
#    'feelslike': -2.2,
#    'dew': -4.6,
#    'humidity': 59.96,
#    'precip': 2.94,
#    'precipprob': None,
#    'precipcover': 29.17,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 65.8,
#    'windspeed': 40.0,
#    'winddir': 308.7,
#    'pressure': 1004.3,
#    'cloudcover': 58.8,
#    'visibility': 14.8,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:13:51',
#    'sunriseEpoch': 1578226431,
#    'sunset': '16:25:44',
#    'sunsetEpoch': 1578259544,
#    'moonphase': 0.36,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['KOWD',
#     '72509854704',
#     'KBED',
#     'KBOS',
#     '72509014739',
#     '72505914702'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-06',
#    'datetimeEpoch': 1578286800,
#    'tempmax': 3.5,
#    'tempmin': -3.1,
#    'temp': 0.4,
#    'feelslikemax': 0.3,
#    'feelslikemin': -5.2,
#    'feelslike': -2.2,
#    'dew': -6.4,
#    'humidity': 60.66,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 48.1,
#    'windspeed': 23.8,
#    'winddir': 180.3,
#    'pressure': 1013.3,
#    'cloudcover': 44.9,
#    'visibility': 15.7,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:13:46',
#    'sunriseEpoch': 1578312826,
#    'sunset': '16:26:42',
#    'sunsetEpoch': 1578346002,
#    'moonphase': 0.4,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['KOWD',
#     '72509854704',
#     'KBED',
#     'KBOS',
#     '72509014739',
#     '72505914702'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-07',
#    'datetimeEpoch': 1578373200,
#    'tempmax': 5.6,
#    'tempmin': 0.5,
#    'temp': 3.0,
#    'feelslikemax': 4.3,
#    'feelslikemin': -4.0,
#    'feelslike': -0.3,
#    'dew': -6.3,
#    'humidity': 51.06,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 35.3,
#    'windspeed': 22.3,
#    'winddir': 191.3,
#    'pressure': 1015.5,
#    'cloudcover': 54.8,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:13:39',
#    'sunriseEpoch': 1578399219,
#    'sunset': '16:27:42',
#    'sunsetEpoch': 1578432462,
#    'moonphase': 0.44,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['KOWD',
#     '72509854704',
#     'KBED',
#     'KBOS',
#     '72509014739',
#     '72505914702'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-08',
#    'datetimeEpoch': 1578459600,
#    'tempmax': 6.5,
#    'tempmin': -0.8,
#    'temp': 2.7,
#    'feelslikemax': 2.9,
#    'feelslikemin': -7.6,
#    'feelslike': -1.6,
#    'dew': -5.7,
#    'humidity': 56.45,
#    'precip': 0.54,
#    'precipprob': None,
#    'precipcover': 8.33,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 64.8,
#    'windspeed': 38.0,
#    'winddir': 241.0,
#    'pressure': 1011.1,
#    'cloudcover': 58.3,
#    'visibility': 15.2,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:13:30',
#    'sunriseEpoch': 1578485610,
#    'sunset': '16:28:44',
#    'sunsetEpoch': 1578518924,
#    'moonphase': 0.47,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['KOWD',
#     '72509854704',
#     'KBED',
#     'KBOS',
#     '72509014739',
#     '72505914702'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-09',
#    'datetimeEpoch': 1578546000,
#    'tempmax': 0.5,
#    'tempmin': -5.2,
#    'temp': -2.5,
#    'feelslikemax': -2.4,
#    'feelslikemin': -13.6,
#    'feelslike': -8.0,
#    'dew': -16.1,
#    'humidity': 34.63,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 56.9,
#    'windspeed': 34.8,
#    'winddir': 272.3,
#    'pressure': 1035.4,
#    'cloudcover': 21.7,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:13:18',
#    'sunriseEpoch': 1578571998,
#    'sunset': '16:29:47',
#    'sunsetEpoch': 1578605387,
#    'moonphase': 0.49,
#    'conditions': 'Clear',
#    'icon': 'wind',
#    'stations': ['KOWD',
#     '72509854704',
#     'KBED',
#     'KBOS',
#     '72509014739',
#     '72505914702'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-10',
#    'datetimeEpoch': 1578632400,
#    'tempmax': 11.5,
#    'tempmin': -2.2,
#    'temp': 5.6,
#    'feelslikemax': 11.5,
#    'feelslikemin': -6.7,
#    'feelslike': 2.8,
#    'dew': -1.6,
#    'humidity': 60.11,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 55.1,
#    'windspeed': 34.4,
#    'winddir': 221.0,
#    'pressure': 1032.8,
#    'cloudcover': 71.6,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:13:04',
#    'sunriseEpoch': 1578658384,
#    'sunset': '16:30:51',
#    'sunsetEpoch': 1578691851,
#    'moonphase': 0.5,
#    'conditions': 'Partially cloudy',
#    'icon': 'wind',
#    'stations': ['KOWD',
#     '72509854704',
#     'KBED',
#     'KBOS',
#     '72509014739',
#     '72505914702'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-11',
#    'datetimeEpoch': 1578718800,
#    'tempmax': 20.7,
#    'tempmin': 9.5,
#    'temp': 15.3,
#    'feelslikemax': 20.7,
#    'feelslikemin': 7.6,
#    'feelslike': 15.0,
#    'dew': 8.9,
#    'humidity': 66.7,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 72.4,
#    'windspeed': 50.7,
#    'winddir': 207.9,
#    'pressure': 1021.5,
#    'cloudcover': 57.1,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:12:47',
#    'sunriseEpoch': 1578744767,
#    'sunset': '16:31:56',
#    'sunsetEpoch': 1578778316,
#    'moonphase': 0.51,
#    'conditions': 'Partially cloudy',
#    'icon': 'wind',
#    'stations': ['KOWD',
#     '72509854704',
#     'KBED',
#     'KBOS',
#     '72509014739',
#     '72505914702'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-12',
#    'datetimeEpoch': 1578805200,
#    'tempmax': 22.8,
#    'tempmin': 5.2,
#    'temp': 16.7,
#    'feelslikemax': 22.8,
#    'feelslikemin': 1.4,
#    'feelslike': 16.3,
#    'dew': 7.8,
#    'humidity': 57.79,
#    'precip': 0.77,
#    'precipprob': None,
#    'precipcover': 16.67,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 66.4,
#    'windspeed': 46.4,
#    'winddir': 257.7,
#    'pressure': 1014.8,
#    'cloudcover': 62.4,
#    'visibility': 15.5,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:12:28',
#    'sunriseEpoch': 1578831148,
#    'sunset': '16:33:03',
#    'sunsetEpoch': 1578864783,
#    'moonphase': 0.52,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['KOWD',
#     '72509854704',
#     'KBED',
#     'KBOS',
#     '72509014739',
#     '72505914702'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-13',
#    'datetimeEpoch': 1578891600,
#    'tempmax': 5.6,
#    'tempmin': 2.1,
#    'temp': 3.6,
#    'feelslikemax': 4.0,
#    'feelslikemin': -2.2,
#    'feelslike': 0.5,
#    'dew': -1.0,
#    'humidity': 72.14,
#    'precip': 0.27,
#    'precipprob': None,
#    'precipcover': 4.17,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 27.7,
#    'windspeed': 23.8,
#    'winddir': 119.4,
#    'pressure': 1030.8,
#    'cloudcover': 90.8,
#    'visibility': 13.2,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:12:07',
#    'sunriseEpoch': 1578917527,
#    'sunset': '16:34:10',
#    'sunsetEpoch': 1578951250,
#    'moonphase': 0.55,
#    'conditions': 'Rain, Overcast',
#    'icon': 'rain',
#    'stations': ['KOWD',
#     '72509854704',
#     'KBED',
#     'KBOS',
#     '72509014739',
#     '72505914702'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-14',
#    'datetimeEpoch': 1578978000,
#    'tempmax': 5.6,
#    'tempmin': 2.7,
#    'temp': 4.2,
#    'feelslikemax': 4.8,
#    'feelslikemin': -0.1,
#    'feelslike': 2.2,
#    'dew': 0.4,
#    'humidity': 76.63,
#    'precip': 0.06,
#    'precipprob': None,
#    'precipcover': 4.17,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 11.7,
#    'winddir': 183.3,
#    'pressure': 1025.8,
#    'cloudcover': 78.3,
#    'visibility': 14.5,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:11:44',
#    'sunriseEpoch': 1579003904,
#    'sunset': '16:35:19',
#    'sunsetEpoch': 1579037719,
#    'moonphase': 0.59,
#    'conditions': 'Rain, Overcast',
#    'icon': 'rain',
#    'stations': ['KOWD',
#     '72509854704',
#     'KBED',
#     'KBOS',
#     '72509014739',
#     '72505914702'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-15',
#    'datetimeEpoch': 1579064400,
#    'tempmax': 10.0,
#    'tempmin': 3.8,
#    'temp': 6.9,
#    'feelslikemax': 7.4,
#    'feelslikemin': 1.5,
#    'feelslike': 4.8,
#    'dew': -0.5,
#    'humidity': 61.39,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 33.5,
#    'windspeed': 21.4,
#    'winddir': 241.2,
#    'pressure': 1018.9,
#    'cloudcover': 52.2,
#    'visibility': 14.8,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:11:18',
#    'sunriseEpoch': 1579090278,
#    'sunset': '16:36:29',
#    'sunsetEpoch': 1579124189,
#    'moonphase': 0.64,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['KOWD',
#     '72509854704',
#     'KBED',
#     'KBOS',
#     '72509014739',
#     '72505914702'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-16',
#    'datetimeEpoch': 1579150800,
#    'tempmax': 8.1,
#    'tempmin': -0.2,
#    'temp': 4.1,
#    'feelslikemax': 4.3,
#    'feelslikemin': -7.0,
#    'feelslike': 0.3,
#    'dew': -3.1,
#    'humidity': 60.95,
#    'precip': 2.78,
#    'precipprob': None,
#    'precipcover': 33.33,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 69.2,
#    'windspeed': 42.3,
#    'winddir': 245.7,
#    'pressure': 1011.0,
#    'cloudcover': 63.1,
#    'visibility': 14.5,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:10:50',
#    'sunriseEpoch': 1579176650,
#    'sunset': '16:37:39',
#    'sunsetEpoch': 1579210659,
#    'moonphase': 0.69,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['KOWD',
#     '72509854704',
#     'KBED',
#     'KBOS',
#     '72509014739',
#     '72505914702'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-17',
#    'datetimeEpoch': 1579237200,
#    'tempmax': -1.3,
#    'tempmin': -9.0,
#    'temp': -6.1,
#    'feelslikemax': -7.9,
#    'feelslikemin': -19.0,
#    'feelslike': -14.5,
#    'dew': -20.1,
#    'humidity': 33.18,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 61.0,
#    'windspeed': 45.1,
#    'winddir': 317.7,
#    'pressure': 1030.7,
#    'cloudcover': 15.9,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:10:19',
#    'sunriseEpoch': 1579263019,
#    'sunset': '16:38:51',
#    'sunsetEpoch': 1579297131,
#    'moonphase': 0.75,
#    'conditions': 'Clear',
#    'icon': 'wind',
#    'stations': ['KOWD',
#     '72509854704',
#     'KBED',
#     'KBOS',
#     '72509014739',
#     '72505914702'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-18',
#    'datetimeEpoch': 1579323600,
#    'tempmax': -0.8,
#    'tempmin': -10.2,
#    'temp': -6.8,
#    'feelslikemax': -4.9,
#    'feelslikemin': -18.2,
#    'feelslike': -12.1,
#    'dew': -16.7,
#    'humidity': 46.8,
#    'precip': 6.11,
#    'precipprob': None,
#    'precipcover': 20.83,
#    'preciptype': None,
#    'snow': 5.51,
#    'snowdepth': 5.51,
#    'windgust': 35.3,
#    'windspeed': 21.3,
#    'winddir': 223.6,
#    'pressure': 1028.8,
#    'cloudcover': 62.5,
#    'visibility': 12.6,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:09:47',
#    'sunriseEpoch': 1579349387,
#    'sunset': '16:40:03',
#    'sunsetEpoch': 1579383603,
#    'moonphase': 0.81,
#    'conditions': 'Snow, Partially cloudy',
#    'icon': 'snow',
#    'stations': ['KOWD',
#     '72509854704',
#     'KBED',
#     'KBOS',
#     '72509014739',
#     '72505914702'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-19',
#    'datetimeEpoch': 1579410000,
#    'tempmax': 6.7,
#    'tempmin': -4.2,
#    'temp': 1.0,
#    'feelslikemax': 2.5,
#    'feelslikemin': -9.0,
#    'feelslike': -3.5,
#    'dew': -6.1,
#    'humidity': 62.18,
#    'precip': 1.25,
#    'precipprob': None,
#    'precipcover': 8.33,
#    'preciptype': None,
#    'snow': 3.31,
#    'snowdepth': 8.82,
#    'windgust': 50.1,
#    'windspeed': 35.5,
#    'winddir': 275.7,
#    'pressure': 1005.4,
#    'cloudcover': 67.4,
#    'visibility': 12.8,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:09:12',
#    'sunriseEpoch': 1579435752,
#    'sunset': '16:41:17',
#    'sunsetEpoch': 1579470077,
#    'moonphase': 0.86,
#    'conditions': 'Snow, Partially cloudy',
#    'icon': 'snow',
#    'stations': ['KOWD',
#     '72509854704',
#     'KBED',
#     'KBOS',
#     '72509014739',
#     '72505914702'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-20',
#    'datetimeEpoch': 1579496400,
#    'tempmax': -1.2,
#    'tempmin': -7.4,
#    'temp': -4.7,
#    'feelslikemax': -6.2,
#    'feelslikemin': -15.5,
#    'feelslike': -11.4,
#    'dew': -16.8,
#    'humidity': 39.55,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 7.61,
#    'windgust': 48.1,
#    'windspeed': 32.6,
#    'winddir': 311.6,
#    'pressure': 1020.8,
#    'cloudcover': 32.8,
#    'visibility': 15.9,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:08:35',
#    'sunriseEpoch': 1579522115,
#    'sunset': '16:42:30',
#    'sunsetEpoch': 1579556550,
#    'moonphase': 0.91,
#    'conditions': 'Partially cloudy',
#    'icon': 'wind',
#    'stations': ['KOWD',
#     '72509854704',
#     'KBED',
#     'KBOS',
#     '72509014739',
#     '72505914702'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-21',
#    'datetimeEpoch': 1579582800,
#    'tempmax': -2.3,
#    'tempmin': -9.0,
#    'temp': -5.7,
#    'feelslikemax': -4.4,
#    'feelslikemin': -14.5,
#    'feelslike': -9.9,
#    'dew': -17.3,
#    'humidity': 39.92,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.43,
#    'snowdepth': 7.44,
#    'windgust': 35.3,
#    'windspeed': 22.1,
#    'winddir': 259.7,
#    'pressure': 1029.2,
#    'cloudcover': 22.6,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:07:56',
#    'sunriseEpoch': 1579608476,
#    'sunset': '16:43:45',
#    'sunsetEpoch': 1579643025,
#    'moonphase': 0.95,
#    'conditions': 'Snow',
#    'icon': 'snow',
#    'stations': ['KOWD',
#     '72509854704',
#     'KBED',
#     'KBOS',
#     '72509014739',
#     '72505914702'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-22',
#    'datetimeEpoch': 1579669200,
#    'tempmax': 3.7,
#    'tempmin': -7.6,
#    'temp': -2.0,
#    'feelslikemax': 1.1,
#    'feelslikemin': -10.4,
#    'feelslike': -4.0,
#    'dew': -11.2,
#    'humidity': 49.8,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 6.56,
#    'windgust': None,
#    'windspeed': 11.9,
#    'winddir': 231.0,
#    'pressure': 1029.9,
#    'cloudcover': 23.8,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:07:15',
#    'sunriseEpoch': 1579694835,
#    'sunset': '16:45:00',
#    'sunsetEpoch': 1579729500,
#    'moonphase': 0.98,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['KOWD',
#     '72509854704',
#     'KBED',
#     'KBOS',
#     '72509014739',
#     '72505914702'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-23',
#    'datetimeEpoch': 1579755600,
#    'tempmax': 9.2,
#    'tempmin': -4.4,
#    'temp': 2.2,
#    'feelslikemax': 7.4,
#    'feelslikemin': -8.3,
#    'feelslike': -0.5,
#    'dew': -9.5,
#    'humidity': 44.9,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 5.69,
#    'windgust': None,
#    'windspeed': 18.0,
#    'winddir': 235.1,
#    'pressure': 1027.8,
#    'cloudcover': 50.8,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:06:32',
#    'sunriseEpoch': 1579781192,
#    'sunset': '16:46:16',
#    'sunsetEpoch': 1579815976,
#    'moonphase': 0.99,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['KOWD',
#     '72509854704',
#     'KBED',
#     'KBOS',
#     '72509014739',
#     '72505914702'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-24',
#    'datetimeEpoch': 1579842000,
#    'tempmax': 8.8,
#    'tempmin': 0.7,
#    'temp': 4.1,
#    'feelslikemax': 6.7,
#    'feelslikemin': -1.8,
#    'feelslike': 2.1,
#    'dew': -3.3,
#    'humidity': 59.83,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 4.79,
#    'windgust': None,
#    'windspeed': 19.4,
#    'winddir': 140.0,
#    'pressure': 1029.1,
#    'cloudcover': 63.5,
#    'visibility': 15.5,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:05:46',
#    'sunriseEpoch': 1579867546,
#    'sunset': '16:47:32',
#    'sunsetEpoch': 1579902452,
#    'moonphase': 1.0,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['KOWD',
#     '72509854704',
#     'KBED',
#     'KBOS',
#     '72509014739',
#     '72505914702'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-25',
#    'datetimeEpoch': 1579928400,
#    'tempmax': 9.3,
#    'tempmin': 3.5,
#    'temp': 6.3,
#    'feelslikemax': 7.2,
#    'feelslikemin': 0.4,
#    'feelslike': 2.8,
#    'dew': 2.8,
#    'humidity': 78.4,
#    'precip': 17.06,
#    'precipprob': None,
#    'precipcover': 25.0,
#    'preciptype': None,
#    'snow': 1.02,
#    'snowdepth': 2.81,
#    'windgust': 54.3,
#    'windspeed': 32.6,
#    'winddir': 80.3,
#    'pressure': 1020.4,
#    'cloudcover': 98.7,
#    'visibility': 12.2,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:04:59',
#    'sunriseEpoch': 1579953899,
#    'sunset': '16:48:49',
#    'sunsetEpoch': 1579988929,
#    'moonphase': 0.0,
#    'conditions': 'Snow, Overcast',
#    'icon': 'snow',
#    'stations': ['KOWD',
#     '72509854704',
#     'KBED',
#     'KBOS',
#     '72509014739',
#     '72505914702'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-26',
#    'datetimeEpoch': 1580014800,
#    'tempmax': 10.0,
#    'tempmin': 4.8,
#    'temp': 7.5,
#    'feelslikemax': 7.7,
#    'feelslikemin': 1.1,
#    'feelslike': 4.5,
#    'dew': 0.8,
#    'humidity': 63.68,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.94,
#    'windgust': 47.0,
#    'windspeed': 34.0,
#    'winddir': 250.9,
#    'pressure': 1004.9,
#    'cloudcover': 58.5,
#    'visibility': 15.3,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:04:09',
#    'sunriseEpoch': 1580040249,
#    'sunset': '16:50:06',
#    'sunsetEpoch': 1580075406,
#    'moonphase': 0.01,
#    'conditions': 'Partially cloudy',
#    'icon': 'wind',
#    'stations': ['KOWD',
#     '72509854704',
#     'KBED',
#     'KBOS',
#     '72509014739',
#     '72505914702'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-27',
#    'datetimeEpoch': 1580101200,
#    'tempmax': 8.3,
#    'tempmin': 3.6,
#    'temp': 5.7,
#    'feelslikemax': 4.9,
#    'feelslikemin': -0.6,
#    'feelslike': 2.2,
#    'dew': -2.7,
#    'humidity': 55.42,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 37.1,
#    'windspeed': 25.3,
#    'winddir': 256.9,
#    'pressure': 1002.5,
#    'cloudcover': 73.4,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:03:18',
#    'sunriseEpoch': 1580126598,
#    'sunset': '16:51:23',
#    'sunsetEpoch': 1580161883,
#    'moonphase': 0.03,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['KOWD',
#     '72509854704',
#     'KBED',
#     'KBOS',
#     '72509014739',
#     '72505914702'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-28',
#    'datetimeEpoch': 1580187600,
#    'tempmax': 5.4,
#    'tempmin': 2.0,
#    'temp': 4.2,
#    'feelslikemax': 1.9,
#    'feelslikemin': -3.1,
#    'feelslike': 0.2,
#    'dew': -5.1,
#    'humidity': 51.2,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 38.9,
#    'windspeed': 25.4,
#    'winddir': 316.6,
#    'pressure': 1007.0,
#    'cloudcover': 74.9,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:02:25',
#    'sunriseEpoch': 1580212945,
#    'sunset': '16:52:41',
#    'sunsetEpoch': 1580248361,
#    'moonphase': 0.06,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['KOWD',
#     '72509854704',
#     'KBED',
#     'KBOS',
#     '72509014739',
#     '72505914702'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-29',
#    'datetimeEpoch': 1580274000,
#    'tempmax': 6.0,
#    'tempmin': -1.4,
#    'temp': 2.0,
#    'feelslikemax': 3.2,
#    'feelslikemin': -5.9,
#    'feelslike': -2.2,
#    'dew': -11.1,
#    'humidity': 38.73,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 35.3,
#    'windspeed': 24.9,
#    'winddir': 328.5,
#    'pressure': 1016.3,
#    'cloudcover': 42.4,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:01:29',
#    'sunriseEpoch': 1580299289,
#    'sunset': '16:53:59',
#    'sunsetEpoch': 1580334839,
#    'moonphase': 0.09,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['KOWD',
#     '72509854704',
#     'KBED',
#     'KBOS',
#     '72509014739',
#     '72505914702'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-30',
#    'datetimeEpoch': 1580360400,
#    'tempmax': 0.5,
#    'tempmin': -6.0,
#    'temp': -2.0,
#    'feelslikemax': 0.5,
#    'feelslikemin': -10.8,
#    'feelslike': -5.7,
#    'dew': -12.9,
#    'humidity': 43.96,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 18.2,
#    'winddir': 218.5,
#    'pressure': 1026.3,
#    'cloudcover': 27.9,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:00:32',
#    'sunriseEpoch': 1580385632,
#    'sunset': '16:55:17',
#    'sunsetEpoch': 1580421317,
#    'moonphase': 0.13,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['KOWD',
#     '72509854704',
#     'KBED',
#     'KBOS',
#     '72509014739',
#     '72505914702'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-31',
#    'datetimeEpoch': 1580446800,
#    'tempmax': 7.9,
#    'tempmin': -2.7,
#    'temp': 2.2,
#    'feelslikemax': 5.1,
#    'feelslikemin': -7.2,
#    'feelslike': -1.0,
#    'dew': -6.8,
#    'humidity': 52.5,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 21.2,
#    'winddir': 233.0,
#    'pressure': 1025.9,
#    'cloudcover': 53.0,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:59:33',
#    'sunriseEpoch': 1580471973,
#    'sunset': '16:56:35',
#    'sunsetEpoch': 1580507795,
#    'moonphase': 0.18,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['KOWD',
#     '72509854704',
#     'KBED',
#     'KBOS',
#     '72509014739',
#     '72505914702'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-01',
#    'datetimeEpoch': 1580533200,
#    'tempmax': 4.5,
#    'tempmin': 1.1,
#    'temp': 3.1,
#    'feelslikemax': 4.0,
#    'feelslikemin': -0.9,
#    'feelslike': 1.6,
#    'dew': -0.3,
#    'humidity': 78.51,
#    'precip': 0.46,
#    'precipprob': None,
#    'precipcover': 8.33,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 9.8,
#    'winddir': 186.2,
#    'pressure': 1013.2,
#    'cloudcover': 90.5,
#    'visibility': 14.1,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:58:33',
#    'sunriseEpoch': 1580558313,
#    'sunset': '16:57:54',
#    'sunsetEpoch': 1580594274,
#    'moonphase': 0.22,
#    'conditions': 'Rain, Overcast',
#    'icon': 'rain',
#    'stations': ['KOWD',
#     '72509854704',
#     'KBED',
#     'KBOS',
#     '72509014739',
#     '72505914702'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-02',
#    'datetimeEpoch': 1580619600,
#    'tempmax': 5.6,
#    'tempmin': 2.4,
#    'temp': 3.9,
#    'feelslikemax': 4.3,
#    'feelslikemin': 0.0,
#    'feelslike': 1.5,
#    'dew': -3.9,
#    'humidity': 58.13,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 16.5,
#    'winddir': 290.1,
#    'pressure': 999.8,
#    'cloudcover': 85.9,
#    'visibility': 15.1,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:57:30',
#    'sunriseEpoch': 1580644650,
#    'sunset': '16:59:12',
#    'sunsetEpoch': 1580680752,
#    'moonphase': 0.27,
#    'conditions': 'Overcast',
#    'icon': 'cloudy',
#    'stations': ['KOWD',
#     '72509854704',
#     'KBED',
#     'KBOS',
#     '72509014739',
#     '72505914702'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-03',
#    'datetimeEpoch': 1580706000,
#    'tempmax': 9.1,
#    'tempmin': 0.6,
#    'temp': 4.9,
#    'feelslikemax': 6.5,
#    'feelslikemin': -2.4,
#    'feelslike': 2.1,
#    'dew': -3.4,
#    'humidity': 55.64,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 38.9,
#    'windspeed': 23.7,
#    'winddir': 269.9,
#    'pressure': 1007.2,
#    'cloudcover': 45.7,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:56:26',
#    'sunriseEpoch': 1580730986,
#    'sunset': '17:00:31',
#    'sunsetEpoch': 1580767231,
#    'moonphase': 0.32,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['KOWD',
#     '72509854704',
#     'KBED',
#     'KBOS',
#     '72509014739',
#     '72505914702'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-04',
#    'datetimeEpoch': 1580792400,
#    'tempmax': 8.4,
#    'tempmin': 1.5,
#    'temp': 4.9,
#    'feelslikemax': 7.7,
#    'feelslikemin': -1.0,
#    'feelslike': 4.1,
#    'dew': -0.4,
#    'humidity': 68.52,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 13.4,
#    'winddir': 106.1,
#    'pressure': 1009.9,
#    'cloudcover': 66.9,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:55:20',
#    'sunriseEpoch': 1580817320,
#    'sunset': '17:01:50',
#    'sunsetEpoch': 1580853710,
#    'moonphase': 0.37,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['KOWD',
#     '72509854704',
#     'KBED',
#     'KBOS',
#     '72509014739',
#     '72505914702'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-05',
#    'datetimeEpoch': 1580878800,
#    'tempmax': 5.9,
#    'tempmin': 0.6,
#    'temp': 4.1,
#    'feelslikemax': 5.9,
#    'feelslikemin': -2.7,
#    'feelslike': 2.1,
#    'dew': -4.4,
#    'humidity': 55.7,
#    'precip': 1.47,
#    'precipprob': None,
#    'precipcover': 20.83,
#    'preciptype': None,
#    'snow': 0.63,
#    'snowdepth': 0.63,
#    'windgust': 27.7,
#    'windspeed': 19.2,
#    'winddir': 132.8,
#    'pressure': 1015.3,
#    'cloudcover': 74.7,
#    'visibility': 15.9,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:54:12',
#    'sunriseEpoch': 1580903652,
#    'sunset': '17:03:08',
#    'sunsetEpoch': 1580940188,
#    'moonphase': 0.41,
#    'conditions': 'Snow, Partially cloudy',
#    'icon': 'snow',
#    'stations': ['KOWD',
#     '72509854704',
#     'KBED',
#     'KBOS',
#     '72509014739',
#     '72505914702'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-06',
#    'datetimeEpoch': 1580965200,
#    'tempmax': 4.8,
#    'tempmin': 0.2,
#    'temp': 3.1,
#    'feelslikemax': 1.3,
#    'feelslikemin': -3.6,
#    'feelslike': -0.9,
#    'dew': -0.3,
#    'humidity': 79.17,
#    'precip': 11.13,
#    'precipprob': None,
#    'precipcover': 62.5,
#    'preciptype': None,
#    'snow': 0.38,
#    'snowdepth': 1.0,
#    'windgust': None,
#    'windspeed': 29.1,
#    'winddir': 69.1,
#    'pressure': 1007.1,
#    'cloudcover': 86.7,
#    'visibility': 6.1,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:53:03',
#    'sunriseEpoch': 1580989983,
#    'sunset': '17:04:27',
#    'sunsetEpoch': 1581026667,
#    'moonphase': 0.45,
#    'conditions': 'Snow, Overcast',
#    'icon': 'snow',
#    'stations': ['KOWD',
#     '72509854704',
#     'KBED',
#     'KBOS',
#     '72509014739',
#     '72505914702'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-07',
#    'datetimeEpoch': 1581051600,
#    'tempmax': 11.6,
#    'tempmin': -0.8,
#    'temp': 3.5,
#    'feelslikemax': 11.6,
#    'feelslikemin': -7.8,
#    'feelslike': -0.4,
#    'dew': -0.3,
#    'humidity': 77.09,
#    'precip': 7.13,
#    'precipprob': None,
#    'precipcover': 54.17,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.33,
#    'windgust': 85.5,
#    'windspeed': 60.1,
#    'winddir': 197.6,
#    'pressure': 987.9,
#    'cloudcover': 87.7,
#    'visibility': 8.3,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:51:52',
#    'sunriseEpoch': 1581076312,
#    'sunset': '17:05:46',
#    'sunsetEpoch': 1581113146,
#    'moonphase': 0.48,
#    'conditions': 'Rain, Overcast',
#    'icon': 'rain',
#    'stations': ['KOWD',
#     '72509854704',
#     'KBED',
#     'KBOS',
#     '72509014739',
#     '72505914702'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-08',
#    'datetimeEpoch': 1581138000,
#    'tempmax': 2.6,
#    'tempmin': -3.6,
#    'temp': -1.2,
#    'feelslikemax': -2.2,
#    'feelslikemin': -10.5,
#    'feelslike': -7.5,
#    'dew': -12.1,
#    'humidity': 43.78,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 55.1,
#    'windspeed': 35.5,
#    'winddir': 284.6,
#    'pressure': 1017.4,
#    'cloudcover': 38.3,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:50:40',
#    'sunriseEpoch': 1581162640,
#    'sunset': '17:07:04',
#    'sunsetEpoch': 1581199624,
#    'moonphase': 0.5,
#    'conditions': 'Partially cloudy',
#    'icon': 'wind',
#    'stations': ['KOWD',
#     '72509854704',
#     'KBED',
#     'KBOS',
#     '72509014739',
#     '72505914702'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-09',
#    'datetimeEpoch': 1581224400,
#    'tempmax': 3.2,
#    'tempmin': -7.2,
#    'temp': -2.0,
#    'feelslikemax': -0.8,
#    'feelslikemin': -11.0,
#    'feelslike': -5.3,
#    'dew': -9.3,
#    'humidity': 57.56,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 22.1,
#    'winddir': 193.7,
#    'pressure': 1033.6,
#    'cloudcover': 53.9,
#    'visibility': 15.9,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:49:26',
#    'sunriseEpoch': 1581248966,
#    'sunset': '17:08:23',
#    'sunsetEpoch': 1581286103,
#    'moonphase': 0.5,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['KOWD',
#     '72509854704',
#     'KBED',
#     'KBOS',
#     '72509014739',
#     '72505914702'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-10',
#    'datetimeEpoch': 1581310800,
#    'tempmax': 8.3,
#    'tempmin': 3.3,
#    'temp': 6.5,
#    'feelslikemax': 5.9,
#    'feelslikemin': -0.9,
#    'feelslike': 3.2,
#    'dew': 2.2,
#    'humidity': 73.79,
#    'precip': 4.27,
#    'precipprob': None,
#    'precipcover': 41.67,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 50.0,
#    'windspeed': 32.7,
#    'winddir': 213.6,
#    'pressure': 1021.0,
#    'cloudcover': 70.2,
#    'visibility': 15.6,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:48:11',
#    'sunriseEpoch': 1581335291,
#    'sunset': '17:09:41',
#    'sunsetEpoch': 1581372581,
#    'moonphase': 0.52,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['KOWD',
#     '72509854704',
#     'KBED',
#     'KBOS',
#     '72509014739',
#     '72505914702'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-11',
#    'datetimeEpoch': 1581397200,
#    'tempmax': 6.4,
#    'tempmin': 4.3,
#    'temp': 5.2,
#    'feelslikemax': 6.3,
#    'feelslikemin': 1.2,
#    'feelslike': 3.3,
#    'dew': 2.6,
#    'humidity': 83.65,
#    'precip': 4.52,
#    'precipprob': None,
#    'precipcover': 45.83,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 35.3,
#    'windspeed': 16.6,
#    'winddir': 150.2,
#    'pressure': 1013.8,
#    'cloudcover': 79.9,
#    'visibility': 5.4,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:46:54',
#    'sunriseEpoch': 1581421614,
#    'sunset': '17:10:59',
#    'sunsetEpoch': 1581459059,
#    'moonphase': 0.53,
#    'conditions': 'Rain, Overcast',
#    'icon': 'rain',
#    'stations': ['KOWD',
#     '72509854704',
#     'KBED',
#     'KBOS',
#     '72509014739',
#     '72505914702'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-12',
#    'datetimeEpoch': 1581483600,
#    'tempmax': 7.1,
#    'tempmin': 3.1,
#    'temp': 5.0,
#    'feelslikemax': 4.1,
#    'feelslikemin': -1.5,
#    'feelslike': 1.5,
#    'dew': -5.1,
#    'humidity': 49.32,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 1.25,
#    'snowdepth': 1.25,
#    'windgust': 38.9,
#    'windspeed': 22.5,
#    'winddir': 257.8,
#    'pressure': 1017.4,
#    'cloudcover': 51.0,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:45:36',
#    'sunriseEpoch': 1581507936,
#    'sunset': '17:12:17',
#    'sunsetEpoch': 1581545537,
#    'moonphase': 0.57,
#    'conditions': 'Snow, Partially cloudy',
#    'icon': 'snow',
#    'stations': ['KOWD',
#     '72509854704',
#     'KBED',
#     'KBOS',
#     '72509014739',
#     '72505914702'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-13',
#    'datetimeEpoch': 1581570000,
#    'tempmax': 4.9,
#    'tempmin': 1.6,
#    'temp': 3.5,
#    'feelslikemax': 4.2,
#    'feelslikemin': -1.7,
#    'feelslike': 1.3,
#    'dew': 0.4,
#    'humidity': 81.02,
#    'precip': 12.74,
#    'precipprob': None,
#    'precipcover': 54.17,
#    'preciptype': None,
#    'snow': 0.75,
#    'snowdepth': 2.0,
#    'windgust': 44.7,
#    'windspeed': 36.8,
#    'winddir': 194.8,
#    'pressure': 1006.8,
#    'cloudcover': 80.3,
#    'visibility': 10.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:44:17',
#    'sunriseEpoch': 1581594257,
#    'sunset': '17:13:35',
#    'sunsetEpoch': 1581632015,
#    'moonphase': 0.62,
#    'conditions': 'Snow, Overcast',
#    'icon': 'snow',
#    'stations': ['KOWD',
#     '72509854704',
#     'KBED',
#     'KBOS',
#     '72509014739',
#     '72505914702'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-14',
#    'datetimeEpoch': 1581656400,
#    'tempmax': 4.0,
#    'tempmin': -9.5,
#    'temp': -2.4,
#    'feelslikemax': 0.9,
#    'feelslikemin': -17.5,
#    'feelslike': -8.6,
#    'dew': -12.9,
#    'humidity': 46.65,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.67,
#    'windgust': 48.8,
#    'windspeed': 32.3,
#    'winddir': 317.8,
#    'pressure': 1022.6,
#    'cloudcover': 28.8,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:42:56',
#    'sunriseEpoch': 1581680576,
#    'sunset': '17:14:53',
#    'sunsetEpoch': 1581718493,
#    'moonphase': 0.67,
#    'conditions': 'Partially cloudy',
#    'icon': 'wind',
#    'stations': ['KOWD',
#     '72509854704',
#     'KBED',
#     'KBOS',
#     '72509014739',
#     '72505914702'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-15',
#    'datetimeEpoch': 1581742800,
#    'tempmax': -0.8,
#    'tempmin': -11.6,
#    'temp': -6.3,
#    'feelslikemax': -5.7,
#    'feelslikemin': -18.6,
#    'feelslike': -11.5,
#    'dew': -17.9,
#    'humidity': 40.15,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 41.5,
#    'windspeed': 24.1,
#    'winddir': 263.4,
#    'pressure': 1033.9,
#    'cloudcover': 27.2,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:41:34',
#    'sunriseEpoch': 1581766894,
#    'sunset': '17:16:10',
#    'sunsetEpoch': 1581804970,
#    'moonphase': 0.73,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['KOWD',
#     '72509854704',
#     'KBED',
#     'KBOS',
#     '72509014739',
#     '72505914702'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-16',
#    'datetimeEpoch': 1581829200,
#    'tempmax': 7.4,
#    'tempmin': -2.0,
#    'temp': 3.1,
#    'feelslikemax': 6.1,
#    'feelslikemin': -8.9,
#    'feelslike': -0.8,
#    'dew': -6.8,
#    'humidity': 48.61,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 49.3,
#    'windspeed': 28.9,
#    'winddir': 238.2,
#    'pressure': 1020.6,
#    'cloudcover': 74.0,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:40:11',
#    'sunriseEpoch': 1581853211,
#    'sunset': '17:17:27',
#    'sunsetEpoch': 1581891447,
#    'moonphase': 0.78,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['KOWD',
#     '72509854704',
#     'KBED',
#     'KBOS',
#     '72509014739',
#     '72505914702'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-17',
#    'datetimeEpoch': 1581915600,
#    'tempmax': 8.7,
#    'tempmin': -0.2,
#    'temp': 4.2,
#    'feelslikemax': 6.0,
#    'feelslikemin': -3.3,
#    'feelslike': 1.4,
#    'dew': -7.4,
#    'humidity': 44.59,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 37.1,
#    'windspeed': 21.4,
#    'winddir': 240.3,
#    'pressure': 1023.5,
#    'cloudcover': 31.6,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:38:46',
#    'sunriseEpoch': 1581939526,
#    'sunset': '17:18:44',
#    'sunsetEpoch': 1581977924,
#    'moonphase': 0.84,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['KOWD',
#     '72509854704',
#     'KBED',
#     'KBOS',
#     '72509014739',
#     '72505914702'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-18',
#    'datetimeEpoch': 1582002000,
#    'tempmax': 5.5,
#    'tempmin': -0.8,
#    'temp': 3.1,
#    'feelslikemax': 3.4,
#    'feelslikemin': -4.2,
#    'feelslike': -0.4,
#    'dew': -3.0,
#    'humidity': 65.54,
#    'precip': 11.01,
#    'precipprob': None,
#    'precipcover': 41.67,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 31.7,
#    'windspeed': 24.5,
#    'winddir': 158.4,
#    'pressure': 1025.6,
#    'cloudcover': 64.3,
#    'visibility': 11.7,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:37:21',
#    'sunriseEpoch': 1582025841,
#    'sunset': '17:20:01',
#    'sunsetEpoch': 1582064401,
#    'moonphase': 0.88,
#    'conditions': 'Rain, Partially cloudy',
#    'icon': 'rain',
#    'stations': ['KOWD',
#     '72509854704',
#     'KBED',
#     'KBOS',
#     '72509014739',
#     '72505914702'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-19',
#    'datetimeEpoch': 1582088400,
#    'tempmax': 7.6,
#    'tempmin': 0.8,
#    'temp': 5.1,
#    'feelslikemax': 3.1,
#    'feelslikemin': -4.1,
#    'feelslike': 1.0,
#    'dew': -6.8,
#    'humidity': 45.62,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 63.7,
#    'windspeed': 41.3,
#    'winddir': 278.3,
#    'pressure': 1019.1,
#    'cloudcover': 43.5,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:35:54',
#    'sunriseEpoch': 1582112154,
#    'sunset': '17:21:17',
#    'sunsetEpoch': 1582150877,
#    'moonphase': 0.93,
#    'conditions': 'Partially cloudy',
#    'icon': 'wind',
#    'stations': ['KOWD',
#     '72509854704',
#     'KBED',
#     'KBOS',
#     '72509014739',
#     '72505914702'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-20',
#    'datetimeEpoch': 1582174800,
#    'tempmax': 1.9,
#    'tempmin': -4.9,
#    'temp': -1.1,
#    'feelslikemax': -2.6,
#    'feelslikemin': -9.6,
#    'feelslike': -6.0,
#    'dew': -14.6,
#    'humidity': 35.3,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 35.5,
#    'windspeed': 24.1,
#    'winddir': 284.2,
#    'pressure': 1029.0,
#    'cloudcover': 34.8,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:34:26',
#    'sunriseEpoch': 1582198466,
#    'sunset': '17:22:33',
#    'sunsetEpoch': 1582237353,
#    'moonphase': 0.96,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['KOWD',
#     '72509854704',
#     'KBED',
#     'KBOS',
#     '72509014739',
#     '72505914702'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-21',
#    'datetimeEpoch': 1582261200,
#    'tempmax': 0.5,
#    'tempmin': -8.6,
#    'temp': -3.7,
#    'feelslikemax': -3.5,
#    'feelslikemin': -15.0,
#    'feelslike': -8.9,
#    'dew': -17.5,
#    'humidity': 34.25,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 35.3,
#    'windspeed': 25.5,
#    'winddir': 258.2,
#    'pressure': 1029.9,
#    'cloudcover': 10.8,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:32:57',
#    'sunriseEpoch': 1582284777,
#    'sunset': '17:23:49',
#    'sunsetEpoch': 1582323829,
#    'moonphase': 0.98,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['KOWD',
#     '72509854704',
#     'KBED',
#     'KBOS',
#     '72509014739',
#     '72505914702'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-22',
#    'datetimeEpoch': 1582347600,
#    'tempmax': 8.8,
#    'tempmin': -2.1,
#    'temp': 3.3,
#    'feelslikemax': 5.7,
#    'feelslikemin': -8.1,
#    'feelslike': -0.7,
#    'dew': -12.2,
#    'humidity': 31.83,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 35.3,
#    'windspeed': 22.2,
#    'winddir': 254.5,
#    'pressure': 1021.2,
#    'cloudcover': 15.9,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:31:27',
#    'sunriseEpoch': 1582371087,
#    'sunset': '17:25:05',
#    'sunsetEpoch': 1582410305,
#    'moonphase': 1.0,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['KOWD',
#     '72509854704',
#     'KBED',
#     'KBOS',
#     '72509014739',
#     '72505914702'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-23',
#    'datetimeEpoch': 1582434000,
#    'tempmax': 13.7,
#    'tempmin': 0.3,
#    'temp': 6.3,
#    'feelslikemax': 13.7,
#    'feelslikemin': -3.5,
#    'feelslike': 4.3,
#    'dew': -7.4,
#    'humidity': 38.79,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 32.9,
#    'windspeed': 22.3,
#    'winddir': 243.5,
#    'pressure': 1019.7,
#    'cloudcover': 15.4,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:29:56',
#    'sunriseEpoch': 1582457396,
#    'sunset': '17:26:20',
#    'sunsetEpoch': 1582496780,
#    'moonphase': 1.0,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['KOWD',
#     '72509854704',
#     'KBED',
#     'KBOS',
#     '72509014739',
#     '72505914702'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-24',
#    'datetimeEpoch': 1582520400,
#    'tempmax': 17.8,
#    'tempmin': 1.0,
#    'temp': 8.9,
#    'feelslikemax': 17.8,
#    'feelslikemin': -0.9,
#    'feelslike': 7.8,
#    'dew': -4.2,
#    'humidity': 42.37,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 40.7,
#    'windspeed': 26.7,
#    'winddir': 198.0,
#    'pressure': 1016.1,
#    'cloudcover': 32.3,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '06:28:25',
#    'sunriseEpoch': 1582543705,
#    'sunset': '17:27:35',
#    'sunsetEpoch': 1582583255,
# ...
#    'tempmax': 2.3,
#    'tempmin': -4.3,
#    'temp': -0.2,
#    'feelslikemax': -2.6,
#    'feelslikemin': -9.5,
#    'feelslike': -5.6,
#    'dew': -11.7,
#    'humidity': 43.64,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 41.2,
#    'windspeed': 28.1,
#    'winddir': 294.0,
#    'pressure': 1021.1,
#    'cloudcover': 29.4,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:07:06',
#    'sunriseEpoch': 1608034026,
#    'sunset': '16:12:38',
#    'sunsetEpoch': 1608066758,
#    'moonphase': 0.0,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['KOWD',
#     '72509854704',
#     'KBED',
#     'KBOS',
#     '72509014739',
#     '72505914702'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-16',
#    'datetimeEpoch': 1608094800,
#    'tempmax': -1.4,
#    'tempmin': -8.8,
#    'temp': -5.1,
#    'feelslikemax': -8.2,
#    'feelslikemin': -14.7,
#    'feelslike': -11.1,
#    'dew': -13.1,
#    'humidity': 53.76,
#    'precip': 0.16,
#    'precipprob': None,
#    'precipcover': 4.17,
#    'preciptype': None,
#    'snow': 16.7,
#    'snowdepth': 16.7,
#    'windgust': 53.6,
#    'windspeed': 37.1,
#    'winddir': 164.7,
#    'pressure': 1030.5,
#    'cloudcover': 73.7,
#    'visibility': 15.3,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:07:47',
#    'sunriseEpoch': 1608120467,
#    'sunset': '16:12:56',
#    'sunsetEpoch': 1608153176,
#    'moonphase': 0.02,
#    'conditions': 'Snow, Partially cloudy',
#    'icon': 'snow',
#    'stations': ['KOWD',
#     '72509854704',
#     'KBED',
#     'KBOS',
#     '72509014739',
#     '72505914702'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-17',
#    'datetimeEpoch': 1608181200,
#    'tempmax': -0.6,
#    'tempmin': -6.1,
#    'temp': -3.9,
#    'feelslikemax': -8.6,
#    'feelslikemin': -15.1,
#    'feelslike': -11.9,
#    'dew': -5.9,
#    'humidity': 86.74,
#    'precip': 8.16,
#    'precipprob': None,
#    'precipcover': 54.17,
#    'preciptype': None,
#    'snow': 12.08,
#    'snowdepth': 28.78,
#    'windgust': 71.4,
#    'windspeed': 51.7,
#    'winddir': 179.8,
#    'pressure': 1015.8,
#    'cloudcover': 82.7,
#    'visibility': 5.1,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:08:26',
#    'sunriseEpoch': 1608206906,
#    'sunset': '16:13:16',
#    'sunsetEpoch': 1608239596,
#    'moonphase': 0.05,
#    'conditions': 'Snow, Overcast',
#    'icon': 'snow',
#    'stations': ['KOWD',
#     '72509854704',
#     'KBED',
#     'KBOS',
#     '72509014739',
#     '72505914702'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-18',
#    'datetimeEpoch': 1608267600,
#    'tempmax': -1.4,
#    'tempmin': -6.8,
#    'temp': -3.8,
#    'feelslikemax': -6.1,
#    'feelslikemin': -12.4,
#    'feelslike': -9.1,
#    'dew': -10.4,
#    'humidity': 60.59,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 1.24,
#    'snowdepth': 30.02,
#    'windgust': 29.5,
#    'windspeed': 20.4,
#    'winddir': 335.9,
#    'pressure': 1023.4,
#    'cloudcover': 69.7,
#    'visibility': 15.9,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:09:03',
#    'sunriseEpoch': 1608293343,
#    'sunset': '16:13:39',
#    'sunsetEpoch': 1608326019,
#    'moonphase': 0.09,
#    'conditions': 'Snow, Partially cloudy',
#    'icon': 'snow',
#    'stations': ['KOWD',
#     '72509854704',
#     'KBED',
#     'KBOS',
#     '72509014739',
#     '72505914702'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-19',
#    'datetimeEpoch': 1608354000,
#    'tempmax': -1.4,
#    'tempmin': -9.7,
#    'temp': -5.3,
#    'feelslikemax': -1.4,
#    'feelslikemin': -14.6,
#    'feelslike': -8.8,
#    'dew': -9.9,
#    'humidity': 70.3,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.12,
#    'snowdepth': 29.68,
#    'windgust': None,
#    'windspeed': 13.3,
#    'winddir': 244.0,
#    'pressure': 1028.1,
#    'cloudcover': 50.6,
#    'visibility': 15.9,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:09:38',
#    'sunriseEpoch': 1608379778,
#    'sunset': '16:14:04',
#    'sunsetEpoch': 1608412444,
#    'moonphase': 0.13,
#    'conditions': 'Snow, Partially cloudy',
#    'icon': 'snow',
#    'stations': ['KOWD',
#     '72509854704',
#     'KBED',
#     'KBOS',
#     '72509014739',
#     '72505914702'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-20',
#    'datetimeEpoch': 1608440400,
#    'tempmax': 1.9,
#    'tempmin': -4.1,
#    'temp': -1.3,
#    'feelslikemax': 1.6,
#    'feelslikemin': -7.8,
#    'feelslike': -3.1,
#    'dew': -4.3,
#    'humidity': 80.59,
#    'precip': 0.88,
#    'precipprob': None,
#    'precipcover': 16.67,
#    'preciptype': None,
#    'snow': 13.58,
#    'snowdepth': 26.17,
#    'windgust': None,
#    'windspeed': 10.4,
#    'winddir': 180.0,
#    'pressure': 1021.9,
#    'cloudcover': 86.6,
#    'visibility': 14.7,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:10:11',
#    'sunriseEpoch': 1608466211,
#    'sunset': '16:14:32',
#    'sunsetEpoch': 1608498872,
#    'moonphase': 0.18,
#    'conditions': 'Snow, Overcast',
#    'icon': 'snow',
#    'stations': ['KOWD',
#     '72509854704',
#     'KBED',
#     'KBOS',
#     '72509014739',
#     '72505914702'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-21',
#    'datetimeEpoch': 1608526800,
#    'tempmax': 2.3,
#    'tempmin': -2.9,
#    'temp': 0.4,
#    'feelslikemax': 1.6,
#    'feelslikemin': -5.5,
#    'feelslike': -1.7,
#    'dew': -1.4,
#    'humidity': 88.21,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 2.42,
#    'snowdepth': 22.19,
#    'windgust': None,
#    'windspeed': 14.5,
#    'winddir': 258.0,
#    'pressure': 1009.8,
#    'cloudcover': 87.8,
#    'visibility': 8.4,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:10:41',
#    'sunriseEpoch': 1608552641,
#    'sunset': '16:15:01',
#    'sunsetEpoch': 1608585301,
#    'moonphase': 0.23,
#    'conditions': 'Snow, Overcast',
#    'icon': 'snow',
#    'stations': ['KOWD',
#     '72509854704',
#     'KBED',
#     'KBOS',
#     '72509014739',
#     '72505914702'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-22',
#    'datetimeEpoch': 1608613200,
#    'tempmax': 6.8,
#    'tempmin': 0.2,
#    'temp': 3.3,
#    'feelslikemax': 3.0,
#    'feelslikemin': -3.3,
#    'feelslike': -0.5,
#    'dew': -3.0,
#    'humidity': 63.94,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 21.0,
#    'windgust': 44.6,
#    'windspeed': 29.9,
#    'winddir': 277.0,
#    'pressure': 1006.8,
#    'cloudcover': 55.0,
#    'visibility': 15.8,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:11:10',
#    'sunriseEpoch': 1608639070,
#    'sunset': '16:15:33',
#    'sunsetEpoch': 1608671733,
#    'moonphase': 0.28,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['KOWD',
#     '72509854704',
#     'KBED',
#     'KBOS',
#     '72509014739',
#     '72505914702'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-23',
#    'datetimeEpoch': 1608699600,
#    'tempmax': 3.5,
#    'tempmin': -1.0,
#    'temp': 1.1,
#    'feelslikemax': 1.8,
#    'feelslikemin': -5.7,
#    'feelslike': -2.9,
#    'dew': -7.1,
#    'humidity': 55.15,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 19.13,
#    'windgust': 42.5,
#    'windspeed': 25.7,
#    'winddir': 246.2,
#    'pressure': 1025.9,
#    'cloudcover': 35.3,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:11:36',
#    'sunriseEpoch': 1608725496,
#    'sunset': '16:16:07',
#    'sunsetEpoch': 1608758167,
#    'moonphase': 0.32,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['KOWD',
#     '72509854704',
#     'KBED',
#     'KBOS',
#     '72509014739',
#     '72505914702'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-24',
#    'datetimeEpoch': 1608786000,
#    'tempmax': 11.6,
#    'tempmin': -1.9,
#    'temp': 6.0,
#    'feelslikemax': 11.6,
#    'feelslikemin': -5.9,
#    'feelslike': 3.3,
#    'dew': 3.8,
#    'humidity': 85.87,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 17.06,
#    'windgust': 50.3,
#    'windspeed': 35.6,
#    'winddir': 160.0,
#    'pressure': 1023.1,
#    'cloudcover': 85.5,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:12:00',
#    'sunriseEpoch': 1608811920,
#    'sunset': '16:16:44',
#    'sunsetEpoch': 1608844604,
#    'moonphase': 0.37,
#    'conditions': 'Overcast',
#    'icon': 'wind',
#    'stations': ['KOWD',
#     '72509854704',
#     'KBED',
#     'KBOS',
#     '72509014739',
#     '72505914702'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-25',
#    'datetimeEpoch': 1608872400,
#    'tempmax': 15.0,
#    'tempmin': 6.2,
#    'temp': 11.7,
#    'feelslikemax': 15.0,
#    'feelslikemin': 1.5,
#    'feelslike': 10.7,
#    'dew': 10.1,
#    'humidity': 89.92,
#    'precip': 40.38,
#    'precipprob': None,
#    'precipcover': 70.83,
#    'preciptype': None,
#    'snow': 0.96,
#    'snowdepth': 5.45,
#    'windgust': 69.3,
#    'windspeed': 45.7,
#    'winddir': 166.0,
#    'pressure': 1004.8,
#    'cloudcover': 98.7,
#    'visibility': 10.5,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:12:22',
#    'sunriseEpoch': 1608898342,
#    'sunset': '16:17:22',
#    'sunsetEpoch': 1608931042,
#    'moonphase': 0.4,
#    'conditions': 'Snow, Overcast',
#    'icon': 'snow',
#    'stations': ['KOWD',
#     '72509854704',
#     'KBED',
#     'KBOS',
#     '72509014739',
#     '72505914702'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-26',
#    'datetimeEpoch': 1608958800,
#    'tempmax': 4.4,
#    'tempmin': -1.7,
#    'temp': 0.2,
#    'feelslikemax': -1.4,
#    'feelslikemin': -7.4,
#    'feelslike': -5.7,
#    'dew': -7.7,
#    'humidity': 55.45,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.33,
#    'windgust': 56.2,
#    'windspeed': 38.3,
#    'winddir': 236.4,
#    'pressure': 1007.9,
#    'cloudcover': 55.0,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:12:41',
#    'sunriseEpoch': 1608984761,
#    'sunset': '16:18:02',
#    'sunsetEpoch': 1609017482,
#    'moonphase': 0.44,
#    'conditions': 'Partially cloudy',
#    'icon': 'wind',
#    'stations': ['KOWD',
#     '72509854704',
#     'KBED',
#     'KBOS',
#     '72509014739',
#     '72505914702'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-27',
#    'datetimeEpoch': 1609045200,
#    'tempmax': 3.4,
#    'tempmin': -4.0,
#    'temp': -0.6,
#    'feelslikemax': 0.0,
#    'feelslikemin': -9.2,
#    'feelslike': -4.7,
#    'dew': -7.6,
#    'humidity': 59.4,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 21.6,
#    'winddir': 237.7,
#    'pressure': 1023.3,
#    'cloudcover': 26.1,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:12:59',
#    'sunriseEpoch': 1609071179,
#    'sunset': '16:18:45',
#    'sunsetEpoch': 1609103925,
#    'moonphase': 0.47,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['KOWD',
#     '72509854704',
#     'KBED',
#     'KBOS',
#     '72509014739',
#     '72505914702'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-28',
#    'datetimeEpoch': 1609131600,
#    'tempmax': 9.5,
#    'tempmin': -2.5,
#    'temp': 3.7,
#    'feelslikemax': 6.5,
#    'feelslikemin': -5.5,
#    'feelslike': 0.9,
#    'dew': 0.1,
#    'humidity': 77.68,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 42.6,
#    'windspeed': 27.5,
#    'winddir': 188.4,
#    'pressure': 1021.9,
#    'cloudcover': 70.5,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:13:14',
#    'sunriseEpoch': 1609157594,
#    'sunset': '16:19:29',
#    'sunsetEpoch': 1609190369,
#    'moonphase': 0.49,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['KOWD',
#     '72509854704',
#     'KBED',
#     'KBOS',
#     '72509014739',
#     '72505914702'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-29',
#    'datetimeEpoch': 1609218000,
#    'tempmax': 5.5,
#    'tempmin': -4.0,
#    'temp': 0.9,
#    'feelslikemax': 1.4,
#    'feelslikemin': -9.3,
#    'feelslike': -4.4,
#    'dew': -11.4,
#    'humidity': 40.73,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 59.7,
#    'windspeed': 37.3,
#    'winddir': 296.4,
#    'pressure': 1024.7,
#    'cloudcover': 30.7,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:13:26',
#    'sunriseEpoch': 1609244006,
#    'sunset': '16:20:15',
#    'sunsetEpoch': 1609276815,
#    'moonphase': 0.5,
#    'conditions': 'Partially cloudy',
#    'icon': 'wind',
#    'stations': ['KOWD',
#     '72509854704',
#     'KBED',
#     'KBOS',
#     '72509014739',
#     '72505914702'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-30',
#    'datetimeEpoch': 1609304400,
#    'tempmax': 4.4,
#    'tempmin': -4.8,
#    'temp': -0.7,
#    'feelslikemax': -0.2,
#    'feelslikemin': -10.8,
#    'feelslike': -5.4,
#    'dew': -9.9,
#    'humidity': 50.95,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 42.5,
#    'windspeed': 31.0,
#    'winddir': 241.2,
#    'pressure': 1026.9,
#    'cloudcover': 66.4,
#    'visibility': 16.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:13:36',
#    'sunriseEpoch': 1609330416,
#    'sunset': '16:21:03',
#    'sunsetEpoch': 1609363263,
#    'moonphase': 0.5,
#    'conditions': 'Partially cloudy',
#    'icon': 'wind',
#    'stations': ['KOWD',
#     '72509854704',
#     'KBED',
#     'KBOS',
#     '72509014739',
#     '72505914702'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-31',
#    'datetimeEpoch': 1609390800,
#    'tempmax': 7.2,
#    'tempmin': 0.0,
#    'temp': 4.8,
#    'feelslikemax': 3.7,
#    'feelslikemin': -4.0,
#    'feelslike': 0.9,
#    'dew': -0.9,
#    'humidity': 67.2,
#    'precip': 2.56,
#    'precipprob': None,
#    'precipcover': 16.67,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 52.6,
#    'windspeed': 34.0,
#    'winddir': 265.2,
#    'pressure': 1018.9,
#    'cloudcover': 75.6,
#    'visibility': 15.8,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:13:44',
#    'sunriseEpoch': 1609416824,
#    'sunset': '16:21:53',
#    'sunsetEpoch': 1609449713,
#    'moonphase': 0.51,
#    'conditions': 'Rain, Overcast',
#    'icon': 'rain',
#    'stations': ['KOWD',
#     '72509854704',
#     'KBED',
#     'KBOS',
#     '72509014739',
#     '72505914702'],
#    'source': 'obs',
#    'hours': None}],
#  'stations': {'KOWD': {'distance': 21452.0,
#    'latitude': 42.18,
#    'longitude': -71.17,
#    'useCount': 0,
#    'id': 'KOWD',
#    'name': 'KOWD',
#    'quality': 100,
#    'contribution': 0.0},
#   '72509854704': {'distance': 20368.0,
#    'latitude': 42.191,
#    'longitude': -71.174,
#    'useCount': 0,
#    'id': '72509854704',
#    'name': 'NORWOOD MEMORIAL AIRPORT, MA US',
#    'quality': 100,
#    'contribution': 0.0},
#   'KBED': {'distance': 19651.0,
#    'latitude': 42.47,
#    'longitude': -71.3,
#    'useCount': 0,
#    'id': 'KBED',
#    'name': 'KBED',
#    'quality': 100,
#    'contribution': 0.0},
#   'KBOS': {'distance': 6261.0,
#    'latitude': 42.37,
#    'longitude': -71.03,
#    'useCount': 0,
#    'id': 'KBOS',
#    'name': 'KBOS',
#    'quality': 100,
#    'contribution': 0.0},
#   '72509014739': {'distance': 7951.0,
#    'latitude': 42.361,
#    'longitude': -71.01,
#    'useCount': 0,
#    'id': '72509014739',
#    'name': 'BOSTON, MA US',
#    'quality': 100,
#    'contribution': 0.0},
#   '72505914702': {'distance': 18951.0,
#    'latitude': 42.47,
#    'longitude': -71.289,
#    'useCount': 0,
#    'id': '72505914702',
#    'name': 'BEDFORD HANSCOM FIELD, MA US',
#    'quality': 100,
#    'contribution': 0.0}}}

# %%
#3. We create empty lists to transfer the data
temperature = []
date = []
city = []

# %%
#4. We loop thropugh the API and extract the info we need
for x in range(366):
    temperature.append(response["days"][x]["temp"])
    date.append(response["days"][x]["datetime"])
    city.append("Cambridge, MA")

# %%
len(city)
# Out:
# 366

# %%
len(date)
# Out:
# 366

# %%
len (temperature)
# Out:
# 366

# %%
#5. We create a dataframe based on the lists
New_df = pd.DataFrame(
    {'City': city,
     'Date': date,
     'Temperature': temperature
    })

# %%
New_df
# Out:
#               City        Date  Temperature
# 0    Cambridge, MA  2020-01-01          3.7
# 1    Cambridge, MA  2020-01-02          4.7
# 2    Cambridge, MA  2020-01-03          8.5
# 3    Cambridge, MA  2020-01-04          7.1
# 4    Cambridge, MA  2020-01-05          2.8
# ..             ...         ...          ...
# 361  Cambridge, MA  2020-12-27         -0.6
# 362  Cambridge, MA  2020-12-28          3.7
# 363  Cambridge, MA  2020-12-29          0.9
# 364  Cambridge, MA  2020-12-30         -0.7
# 365  Cambridge, MA  2020-12-31          4.8
#
# [366 rows x 3 columns]

# %%
#6. We add new city dataframe to original dataframe including cities already evaluated 

frames = [Final_df,New_df]

# %%
Final_df = pd.concat(frames)

# %%
Final_df
# Out:
#               City        Date  Temperature
# 0    Asheville, NC  2020-01-01          3.8
# 1    Asheville, NC  2020-01-02          3.8
# 2    Asheville, NC  2020-01-03         10.8
# 3    Asheville, NC  2020-01-04          8.2
# 4    Asheville, NC  2020-01-05          1.9
# ..             ...         ...          ...
# 361  Cambridge, MA  2020-12-27         -0.6
# 362  Cambridge, MA  2020-12-28          3.7
# 363  Cambridge, MA  2020-12-29          0.9
# 364  Cambridge, MA  2020-12-30         -0.7
# 365  Cambridge, MA  2020-12-31          4.8
#
# [1830 rows x 3 columns]

# %%
#7.Update to csv by converting df to csv
Final_df.to_csv("Temperature_Dataset2.csv", index=False)

# %%
#8. Will need to import CSV with temp for cities already evaluated every time this document is open again for the 1st time. 
#Name dataframe: Final_df

file_path = os.path.join("Temperature_Dataset1.csv")
Final_df = pd.read_csv(file_path)
Final_df
# Out:
#                City        Date  Temperature
# 0     Asheville, NC  2020-01-01          3.8
# 1     Asheville, NC  2020-01-02          3.8
# 2     Asheville, NC  2020-01-03         10.8
# 3     Asheville, NC  2020-01-04          8.2
# 4     Asheville, NC  2020-01-05          1.9
# ...             ...         ...          ...
# 1825  Cambridge, MA  2020-12-27         -0.6
# 1826  Cambridge, MA  2020-12-28          3.7
# 1827  Cambridge, MA  2020-12-29          0.9
# 1828  Cambridge, MA  2020-12-30         -0.7
# 1829  Cambridge, MA  2020-12-31          4.8
#
# [1830 rows x 3 columns]
