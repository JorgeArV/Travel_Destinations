# %%
# 1.Importing dependencies

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import os

# %%
#2. We add url. Each city will have a new url

url2 = "https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/Vancouver/2020-1-1/2020-12-31?unitGroup=metric&key=SRX784Y4XEDTND44NFLHKK42Z&include=obs"

# %%
response = requests.get(url2).json()

# %%
response
# Out:
# {'queryCost': 366,
#  'latitude': 49.2604,
#  'longitude': -123.113,
#  'resolvedAddress': 'Vancouver, BC, Canada',
#  'address': 'Vancouver',
#  'timezone': 'America/Vancouver',
#  'tzoffset': -8.0,
#  'days': [{'datetime': '2020-01-01',
#    'datetimeEpoch': 1577865600,
#    'tempmax': 11.7,
#    'tempmin': 6.9,
#    'temp': 8.7,
#    'feelslikemax': 11.7,
#    'feelslikemin': 3.2,
#    'feelslike': 7.9,
#    'dew': 5.9,
#    'humidity': 83.01,
#    'precip': 15.61,
#    'precipprob': None,
#    'precipcover': 75.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 56.3,
#    'windspeed': 23.3,
#    'winddir': 284.4,
#    'pressure': 1005.4,
#    'cloudcover': 0.0,
#    'visibility': 1005.7,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '08:07:45',
#    'sunriseEpoch': 1577894865,
#    'sunset': '16:24:19',
#    'sunsetEpoch': 1577924659,
#    'moonphase': 0.17,
#    'conditions': 'Rain',
#    'icon': 'rain',
#    'stations': ['71608099999',
#     'CWWA',
#     '71775099999',
#     '71784099999',
#     '71037099999',
#     '71201099999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-02',
#    'datetimeEpoch': 1577952000,
#    'tempmax': 6.7,
#    'tempmin': 3.5,
#    'temp': 4.9,
#    'feelslikemax': 6.4,
#    'feelslikemin': 0.0,
#    'feelslike': 3.3,
#    'dew': 2.0,
#    'humidity': 82.61,
#    'precip': 46.27,
#    'precipprob': None,
#    'precipcover': 91.67,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 59.0,
#    'windspeed': 22.6,
#    'winddir': 170.8,
#    'pressure': 1016.2,
#    'cloudcover': 0.0,
#    'visibility': 1016.4,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '08:07:42',
#    'sunriseEpoch': 1577981262,
#    'sunset': '16:25:19',
#    'sunsetEpoch': 1578011119,
#    'moonphase': 0.22,
#    'conditions': 'Rain',
#    'icon': 'rain',
#    'stations': ['71608099999',
#     'CWWA',
#     '71775099999',
#     '71784099999',
#     '71037099999',
#     '71201099999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-03',
#    'datetimeEpoch': 1578038400,
#    'tempmax': 10.4,
#    'tempmin': 5.4,
#    'temp': 8.4,
#    'feelslikemax': 10.4,
#    'feelslikemin': 2.1,
#    'feelslike': 6.8,
#    'dew': 6.4,
#    'humidity': 87.36,
#    'precip': 93.65,
#    'precipprob': None,
#    'precipcover': 100.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 77.8,
#    'windspeed': 29.3,
#    'winddir': 159.6,
#    'pressure': 1007.1,
#    'cloudcover': 0.0,
#    'visibility': 1007.4,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '08:07:35',
#    'sunriseEpoch': 1578067655,
#    'sunset': '16:26:22',
#    'sunsetEpoch': 1578097582,
#    'moonphase': 0.26,
#    'conditions': 'Rain',
#    'icon': 'rain',
#    'stations': ['71608099999',
#     'CWWA',
#     '71775099999',
#     '71784099999',
#     '71037099999',
#     '71201099999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-04',
#    'datetimeEpoch': 1578124800,
#    'tempmax': 8.3,
#    'tempmin': 5.5,
#    'temp': 6.9,
#    'feelslikemax': 8.1,
#    'feelslikemin': 3.4,
#    'feelslike': 5.6,
#    'dew': 2.9,
#    'humidity': 76.41,
#    'precip': 50.59,
#    'precipprob': None,
#    'precipcover': 91.67,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 63.0,
#    'windspeed': 16.7,
#    'winddir': 238.0,
#    'pressure': 1018.7,
#    'cloudcover': 0.0,
#    'visibility': 1018.9,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '08:07:26',
#    'sunriseEpoch': 1578154046,
#    'sunset': '16:27:28',
#    'sunsetEpoch': 1578184048,
#    'moonphase': 0.31,
#    'conditions': 'Rain',
#    'icon': 'rain',
#    'stations': ['71608099999',
#     'CWWA',
#     '71775099999',
#     '71784099999',
#     '71037099999',
#     '71201099999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-05',
#    'datetimeEpoch': 1578211200,
#    'tempmax': 7.1,
#    'tempmin': 4.0,
#    'temp': 6.0,
#    'feelslikemax': 7.1,
#    'feelslikemin': 2.3,
#    'feelslike': 4.4,
#    'dew': 3.3,
#    'humidity': 83.73,
#    'precip': 105.73,
#    'precipprob': None,
#    'precipcover': 87.5,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 72.0,
#    'windspeed': 26.2,
#    'winddir': 151.5,
#    'pressure': 1021.0,
#    'cloudcover': 0.0,
#    'visibility': 1021.3,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '08:07:13',
#    'sunriseEpoch': 1578240433,
#    'sunset': '16:28:35',
#    'sunsetEpoch': 1578270515,
#    'moonphase': 0.36,
#    'conditions': 'Rain',
#    'icon': 'rain',
#    'stations': ['71608099999',
#     'CWWA',
#     '71775099999',
#     '71784099999',
#     '71037099999',
#     '71201099999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-06',
#    'datetimeEpoch': 1578297600,
#    'tempmax': 5.5,
#    'tempmin': 4.0,
#    'temp': 4.6,
#    'feelslikemax': 5.5,
#    'feelslikemin': 0.7,
#    'feelslike': 3.7,
#    'dew': 3.8,
#    'humidity': 94.86,
#    'precip': 20.64,
#    'precipprob': None,
#    'precipcover': 91.67,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 37.1,
#    'windspeed': 13.5,
#    'winddir': 81.3,
#    'pressure': 1018.5,
#    'cloudcover': 0.0,
#    'visibility': 1018.5,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '08:06:57',
#    'sunriseEpoch': 1578326817,
#    'sunset': '16:29:45',
#    'sunsetEpoch': 1578356985,
#    'moonphase': 0.4,
#    'conditions': 'Rain',
#    'icon': 'rain',
#    'stations': ['71608099999',
#     'CWWA',
#     '71775099999',
#     '71784099999',
#     '71037099999',
#     '71201099999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-07',
#    'datetimeEpoch': 1578384000,
#    'tempmax': 9.4,
#    'tempmin': 5.7,
#    'temp': 8.0,
#    'feelslikemax': 9.2,
#    'feelslikemin': 3.3,
#    'feelslike': 6.8,
#    'dew': 7.2,
#    'humidity': 94.66,
#    'precip': 65.79,
#    'precipprob': None,
#    'precipcover': 100.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 57.2,
#    'windspeed': 21.4,
#    'winddir': 154.6,
#    'pressure': 1006.2,
#    'cloudcover': 0.0,
#    'visibility': 1006.3,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '08:06:38',
#    'sunriseEpoch': 1578413198,
#    'sunset': '16:30:57',
#    'sunsetEpoch': 1578443457,
#    'moonphase': 0.44,
#    'conditions': 'Rain',
#    'icon': 'rain',
#    'stations': ['71608099999',
#     'CWWA',
#     '71775099999',
#     '71784099999',
#     '71037099999',
#     '71201099999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-08',
#    'datetimeEpoch': 1578470400,
#    'tempmax': 6.9,
#    'tempmin': 0.6,
#    'temp': 4.3,
#    'feelslikemax': 6.5,
#    'feelslikemin': 0.2,
#    'feelslike': 2.3,
#    'dew': -0.3,
#    'humidity': 72.36,
#    'precip': 65.94,
#    'precipprob': None,
#    'precipcover': 75.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 63.0,
#    'windspeed': 21.6,
#    'winddir': 225.0,
#    'pressure': 1008.7,
#    'cloudcover': 0.0,
#    'visibility': 1009.1,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '08:06:17',
#    'sunriseEpoch': 1578499577,
#    'sunset': '16:32:10',
#    'sunsetEpoch': 1578529930,
#    'moonphase': 0.47,
#    'conditions': 'Rain',
#    'icon': 'rain',
#    'stations': ['71608099999',
#     'CWWA',
#     '71775099999',
#     '71784099999',
#     '71037099999',
#     '71201099999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-09',
#    'datetimeEpoch': 1578556800,
#    'tempmax': 6.2,
#    'tempmin': 0.3,
#    'temp': 2.9,
#    'feelslikemax': 6.2,
#    'feelslikemin': -0.6,
#    'feelslike': 2.2,
#    'dew': 0.1,
#    'humidity': 82.38,
#    'precip': 5.9,
#    'precipprob': None,
#    'precipcover': 20.83,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 35.3,
#    'windspeed': 11.4,
#    'winddir': 147.7,
#    'pressure': 1019.9,
#    'cloudcover': 0.0,
#    'visibility': 1020.1,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '08:05:52',
#    'sunriseEpoch': 1578585952,
#    'sunset': '16:33:26',
#    'sunsetEpoch': 1578616406,
#    'moonphase': 0.49,
#    'conditions': 'Rain',
#    'icon': 'rain',
#    'stations': ['71608099999',
#     'CWWA',
#     '71775099999',
#     '71784099999',
#     '71037099999',
#     '71201099999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-10',
#    'datetimeEpoch': 1578643200,
#    'tempmax': 4.7,
#    'tempmin': 0.2,
#    'temp': 2.5,
#    'feelslikemax': 3.1,
#    'feelslikemin': -4.4,
#    'feelslike': -1.5,
#    'dew': 1.7,
#    'humidity': 94.32,
#    'precip': 84.09,
#    'precipprob': None,
#    'precipcover': 100.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 63.0,
#    'windspeed': 23.7,
#    'winddir': 95.9,
#    'pressure': 1007.0,
#    'cloudcover': 0.0,
#    'visibility': 1007.2,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '08:05:25',
#    'sunriseEpoch': 1578672325,
#    'sunset': '16:34:44',
#    'sunsetEpoch': 1578702884,
#    'moonphase': 0.5,
#    'conditions': 'Rain',
#    'icon': 'rain',
#    'stations': ['71608099999',
#     'CWWA',
#     '71775099999',
#     '71784099999',
#     '71037099999',
#     '71201099999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-11',
#    'datetimeEpoch': 1578729600,
#    'tempmax': 5.9,
#    'tempmin': 1.3,
#    'temp': 4.2,
#    'feelslikemax': 3.9,
#    'feelslikemin': -2.0,
#    'feelslike': 1.6,
#    'dew': 1.1,
#    'humidity': 81.82,
#    'precip': 39.06,
#    'precipprob': None,
#    'precipcover': 79.17,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 68.4,
#    'windspeed': 26.7,
#    'winddir': 213.8,
#    'pressure': 1006.1,
#    'cloudcover': 0.0,
#    'visibility': 1007.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '08:04:54',
#    'sunriseEpoch': 1578758694,
#    'sunset': '16:36:03',
#    'sunsetEpoch': 1578789363,
#    'moonphase': 0.51,
#    'conditions': 'Rain',
#    'icon': 'rain',
#    'stations': ['71608099999',
#     'CWWA',
#     '71775099999',
#     '71784099999',
#     '71037099999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-12',
#    'datetimeEpoch': 1578816000,
#    'tempmax': 3.3,
#    'tempmin': -2.6,
#    'temp': 1.4,
#    'feelslikemax': 3.3,
#    'feelslikemin': -5.7,
#    'feelslike': -1.9,
#    'dew': 0.5,
#    'humidity': 93.88,
#    'precip': 34.46,
#    'precipprob': None,
#    'precipcover': 95.83,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 61.2,
#    'windspeed': 21.5,
#    'winddir': 144.5,
#    'pressure': 999.9,
#    'cloudcover': 0.0,
#    'visibility': 1000.1,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '08:04:21',
#    'sunriseEpoch': 1578845061,
#    'sunset': '16:37:24',
#    'sunsetEpoch': 1578875844,
#    'moonphase': 0.52,
#    'conditions': 'Rain',
#    'icon': 'rain',
#    'stations': ['71608099999',
#     'CWWA',
#     '71775099999',
#     '71784099999',
#     '71037099999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-13',
#    'datetimeEpoch': 1578902400,
#    'tempmax': -3.0,
#    'tempmin': -6.0,
#    'temp': -5.1,
#    'feelslikemax': -4.8,
#    'feelslikemin': -9.6,
#    'feelslike': -6.6,
#    'dew': -6.8,
#    'humidity': 87.91,
#    'precip': 0.5,
#    'precipprob': None,
#    'precipcover': 8.33,
#    'preciptype': None,
#    'snow': 1.0,
#    'snowdepth': 1.0,
#    'windgust': None,
#    'windspeed': 9.8,
#    'winddir': 81.2,
#    'pressure': 1011.5,
#    'cloudcover': 0.0,
#    'visibility': 1011.3,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '08:03:45',
#    'sunriseEpoch': 1578931425,
#    'sunset': '16:38:47',
#    'sunsetEpoch': 1578962327,
#    'moonphase': 0.55,
#    'conditions': 'Snow',
#    'icon': 'snow',
#    'stations': ['71608099999',
#     'CWWA',
#     '71775099999',
#     '71784099999',
#     '71037099999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-14',
#    'datetimeEpoch': 1578988800,
#    'tempmax': -4.0,
#    'tempmin': -7.3,
#    'temp': -6.3,
#    'feelslikemax': -4.0,
#    'feelslikemin': -11.1,
#    'feelslike': -8.3,
#    'dew': -8.3,
#    'humidity': 85.88,
#    'precip': 1.72,
#    'precipprob': None,
#    'precipcover': 20.83,
#    'preciptype': None,
#    'snow': 9.08,
#    'snowdepth': 9.93,
#    'windgust': None,
#    'windspeed': 7.8,
#    'winddir': 84.2,
#    'pressure': 1013.7,
#    'cloudcover': 0.0,
#    'visibility': 1013.8,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '08:03:06',
#    'sunriseEpoch': 1579017786,
#    'sunset': '16:40:11',
#    'sunsetEpoch': 1579048811,
#    'moonphase': 0.59,
#    'conditions': 'Snow',
#    'icon': 'snow',
#    'stations': ['71608099999',
#     'CWWA',
#     '71775099999',
#     '71784099999',
#     '71037099999',
#     '71201099999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-15',
#    'datetimeEpoch': 1579075200,
#    'tempmax': 4.4,
#    'tempmin': -6.0,
#    'temp': -2.3,
#    'feelslikemax': -0.2,
#    'feelslikemin': -7.9,
#    'feelslike': -5.1,
#    'dew': -3.6,
#    'humidity': 91.48,
#    'precip': 26.86,
#    'precipprob': None,
#    'precipcover': 83.33,
#    'preciptype': None,
#    'snow': 6.9,
#    'snowdepth': 16.83,
#    'windgust': 55.7,
#    'windspeed': 28.1,
#    'winddir': 66.1,
#    'pressure': 1004.9,
#    'cloudcover': 0.0,
#    'visibility': 1004.9,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '08:02:24',
#    'sunriseEpoch': 1579104144,
#    'sunset': '16:41:37',
#    'sunsetEpoch': 1579135297,
#    'moonphase': 0.64,
#    'conditions': 'Snow',
#    'icon': 'snow',
#    'stations': ['71608099999',
#     'CWWA',
#     '71775099999',
#     '71784099999',
#     '71037099999',
#     '71201099999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-16',
#    'datetimeEpoch': 1579161600,
#    'tempmax': 4.6,
#    'tempmin': 0.0,
#    'temp': 2.3,
#    'feelslikemax': 4.3,
#    'feelslikemin': -2.2,
#    'feelslike': 0.3,
#    'dew': -0.5,
#    'humidity': 81.93,
#    'precip': 35.42,
#    'precipprob': None,
#    'precipcover': 75.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 14.33,
#    'windgust': 61.2,
#    'windspeed': 27.2,
#    'winddir': 102.5,
#    'pressure': 1003.0,
#    'cloudcover': 0.0,
#    'visibility': 1003.3,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '08:01:39',
#    'sunriseEpoch': 1579190499,
#    'sunset': '16:43:04',
#    'sunsetEpoch': 1579221784,
#    'moonphase': 0.69,
#    'conditions': 'Rain',
#    'icon': 'rain',
#    'stations': ['71608099999',
#     'CWWA',
#     '71775099999',
#     '71784099999',
#     '71037099999',
#     '71201099999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-17',
#    'datetimeEpoch': 1579248000,
#    'tempmax': 5.3,
#    'tempmin': 0.0,
#    'temp': 2.2,
#    'feelslikemax': 5.3,
#    'feelslikemin': -2.8,
#    'feelslike': 0.7,
#    'dew': -0.6,
#    'humidity': 82.61,
#    'precip': 3.0,
#    'precipprob': None,
#    'precipcover': 41.67,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 10.33,
#    'windgust': 40.7,
#    'windspeed': 14.3,
#    'winddir': 98.0,
#    'pressure': 1018.8,
#    'cloudcover': 0.0,
#    'visibility': 1018.8,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '08:00:52',
#    'sunriseEpoch': 1579276852,
#    'sunset': '16:44:32',
#    'sunsetEpoch': 1579308272,
#    'moonphase': 0.75,
#    'conditions': 'Rain',
#    'icon': 'rain',
#    'stations': ['71608099999',
#     'CWWA',
#     '71775099999',
#     '71784099999',
#     '71037099999',
#     '71201099999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-18',
#    'datetimeEpoch': 1579334400,
#    'tempmax': 5.8,
#    'tempmin': 3.3,
#    'temp': 4.7,
#    'feelslikemax': 5.8,
#    'feelslikemin': -0.6,
#    'feelslike': 2.6,
#    'dew': 3.3,
#    'humidity': 90.73,
#    'precip': 20.82,
#    'precipprob': None,
#    'precipcover': 100.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 9.0,
#    'windgust': 61.2,
#    'windspeed': 18.8,
#    'winddir': 95.7,
#    'pressure': 1019.0,
#    'cloudcover': 0.0,
#    'visibility': 1018.9,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '08:00:02',
#    'sunriseEpoch': 1579363202,
#    'sunset': '16:46:02',
#    'sunsetEpoch': 1579394762,
#    'moonphase': 0.81,
#    'conditions': 'Rain',
#    'icon': 'rain',
#    'stations': ['71608099999',
#     'CWWA',
#     '71775099999',
#     '71784099999',
#     '71037099999',
#     '71201099999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-19',
#    'datetimeEpoch': 1579420800,
#    'tempmax': 7.7,
#    'tempmin': 5.6,
#    'temp': 6.8,
#    'feelslikemax': 7.7,
#    'feelslikemin': 3.5,
#    'feelslike': 6.0,
#    'dew': 5.9,
#    'humidity': 93.75,
#    'precip': 12.35,
#    'precipprob': None,
#    'precipcover': 66.67,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 50.0,
#    'windspeed': 13.1,
#    'winddir': 104.1,
#    'pressure': 1020.3,
#    'cloudcover': 0.0,
#    'visibility': 1020.3,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:59:10',
#    'sunriseEpoch': 1579449550,
#    'sunset': '16:47:33',
#    'sunsetEpoch': 1579481253,
#    'moonphase': 0.86,
#    'conditions': 'Rain',
#    'icon': 'rain',
#    'stations': ['71608099999',
#     'CWWA',
#     '71775099999',
#     '71784099999',
#     '71037099999',
#     '71201099999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-20',
#    'datetimeEpoch': 1579507200,
#    'tempmax': 8.4,
#    'tempmin': 6.8,
#    'temp': 7.6,
#    'feelslikemax': 8.2,
#    'feelslikemin': 5.0,
#    'feelslike': 6.8,
#    'dew': 6.3,
#    'humidity': 91.51,
#    'precip': 10.52,
#    'precipprob': None,
#    'precipcover': 66.67,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 46.1,
#    'windspeed': 13.1,
#    'winddir': 107.7,
#    'pressure': 1010.8,
#    'cloudcover': 0.0,
#    'visibility': 1010.9,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:58:15',
#    'sunriseEpoch': 1579535895,
#    'sunset': '16:49:05',
#    'sunsetEpoch': 1579567745,
#    'moonphase': 0.91,
#    'conditions': 'Rain',
#    'icon': 'rain',
#    'stations': ['71608099999',
#     'CWWA',
#     '71775099999',
#     '71784099999',
#     '71037099999',
#     '71201099999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-21',
#    'datetimeEpoch': 1579593600,
#    'tempmax': 9.4,
#    'tempmin': 6.3,
#    'temp': 7.8,
#    'feelslikemax': 9.4,
#    'feelslikemin': 4.6,
#    'feelslike': 6.5,
#    'dew': 5.7,
#    'humidity': 86.39,
#    'precip': 27.74,
#    'precipprob': None,
#    'precipcover': 79.17,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 64.8,
#    'windspeed': 18.7,
#    'winddir': 133.0,
#    'pressure': 1003.6,
#    'cloudcover': 0.0,
#    'visibility': 1003.8,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:57:17',
#    'sunriseEpoch': 1579622237,
#    'sunset': '16:50:38',
#    'sunsetEpoch': 1579654238,
#    'moonphase': 0.95,
#    'conditions': 'Rain',
#    'icon': 'rain',
#    'stations': ['71608099999',
#     'CWWA',
#     '71775099999',
#     '71784099999',
#     '71037099999',
#     '71201099999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-22',
#    'datetimeEpoch': 1579680000,
#    'tempmax': 7.3,
#    'tempmin': 5.5,
#    'temp': 6.3,
#    'feelslikemax': 7.2,
#    'feelslikemin': 3.7,
#    'feelslike': 5.1,
#    'dew': 5.3,
#    'humidity': 93.51,
#    'precip': 20.9,
#    'precipprob': None,
#    'precipcover': 91.67,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 46.1,
#    'windspeed': 14.4,
#    'winddir': 92.7,
#    'pressure': 1013.8,
#    'cloudcover': 0.0,
#    'visibility': 1013.9,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:56:17',
#    'sunriseEpoch': 1579708577,
#    'sunset': '16:52:11',
#    'sunsetEpoch': 1579740731,
#    'moonphase': 0.98,
#    'conditions': 'Rain',
#    'icon': 'rain',
#    'stations': ['71608099999',
#     'CWWA',
#     '71775099999',
#     '71784099999',
#     '71037099999',
#     '71201099999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-23',
#    'datetimeEpoch': 1579766400,
#    'tempmax': 9.7,
#    'tempmin': 6.4,
#    'temp': 8.1,
#    'feelslikemax': 9.7,
#    'feelslikemin': 3.9,
#    'feelslike': 6.6,
#    'dew': 7.7,
#    'humidity': 97.02,
#    'precip': 34.38,
#    'precipprob': None,
#    'precipcover': 100.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 59.0,
#    'windspeed': 18.1,
#    'winddir': 98.3,
#    'pressure': 1010.5,
#    'cloudcover': 0.0,
#    'visibility': 1010.7,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:55:14',
#    'sunriseEpoch': 1579794914,
#    'sunset': '16:53:46',
#    'sunsetEpoch': 1579827226,
#    'moonphase': 0.99,
#    'conditions': 'Rain',
#    'icon': 'rain',
#    'stations': ['71608099999',
#     'CWWA',
#     '71775099999',
#     '71784099999',
#     '71037099999',
#     '71201099999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-24',
#    'datetimeEpoch': 1579852800,
#    'tempmax': 9.9,
#    'tempmin': 7.1,
#    'temp': 8.4,
#    'feelslikemax': 9.6,
#    'feelslikemin': 5.3,
#    'feelslike': 7.4,
#    'dew': 7.5,
#    'humidity': 93.61,
#    'precip': 19.21,
#    'precipprob': None,
#    'precipcover': 100.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 51.8,
#    'windspeed': 13.6,
#    'winddir': 123.6,
#    'pressure': 1010.8,
#    'cloudcover': 0.0,
#    'visibility': 1011.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:54:10',
#    'sunriseEpoch': 1579881250,
#    'sunset': '16:55:22',
#    'sunsetEpoch': 1579913722,
#    'moonphase': 1.0,
#    'conditions': 'Rain',
#    'icon': 'rain',
#    'stations': ['71608099999',
#     'CWWA',
#     '71775099999',
#     '71784099999',
#     '71037099999',
#     '71201099999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-25',
#    'datetimeEpoch': 1579939200,
#    'tempmax': 8.2,
#    'tempmin': 6.7,
#    'temp': 7.3,
#    'feelslikemax': 8.2,
#    'feelslikemin': 5.7,
#    'feelslike': 6.9,
#    'dew': 6.3,
#    'humidity': 93.53,
#    'precip': 6.63,
#    'precipprob': None,
#    'precipcover': 41.67,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 9.1,
#    'winddir': 78.5,
#    'pressure': 1013.9,
#    'cloudcover': 0.0,
#    'visibility': 1014.1,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:53:02',
#    'sunriseEpoch': 1579967582,
#    'sunset': '16:56:58',
#    'sunsetEpoch': 1580000218,
#    'moonphase': 0.0,
#    'conditions': 'Rain',
#    'icon': 'rain',
#    'stations': ['71608099999',
#     'CWWA',
#     '71775099999',
#     '71784099999',
#     '71037099999',
#     '71201099999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-26',
#    'datetimeEpoch': 1580025600,
#    'tempmax': 10.8,
#    'tempmin': 6.5,
#    'temp': 8.3,
#    'feelslikemax': 10.8,
#    'feelslikemin': 4.6,
#    'feelslike': 7.1,
#    'dew': 6.4,
#    'humidity': 87.7,
#    'precip': 18.28,
#    'precipprob': None,
#    'precipcover': 79.17,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 57.2,
#    'windspeed': 19.1,
#    'winddir': 110.9,
#    'pressure': 1011.0,
#    'cloudcover': 0.0,
#    'visibility': 1011.3,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:51:53',
#    'sunriseEpoch': 1580053913,
#    'sunset': '16:58:35',
#    'sunsetEpoch': 1580086715,
#    'moonphase': 0.01,
#    'conditions': 'Rain',
#    'icon': 'rain',
#    'stations': ['71608099999',
#     'CWWA',
#     '71775099999',
#     '71784099999',
#     '71037099999',
#     '71201099999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-27',
#    'datetimeEpoch': 1580112000,
#    'tempmax': 8.6,
#    'tempmin': 5.1,
#    'temp': 7.1,
#    'feelslikemax': 8.3,
#    'feelslikemin': 3.6,
#    'feelslike': 5.8,
#    'dew': 5.2,
#    'humidity': 87.77,
#    'precip': 8.85,
#    'precipprob': None,
#    'precipcover': 87.5,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 55.4,
#    'windspeed': 14.5,
#    'winddir': 144.3,
#    'pressure': 1016.2,
#    'cloudcover': 0.0,
#    'visibility': 1016.2,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:50:41',
#    'sunriseEpoch': 1580140241,
#    'sunset': '17:00:13',
#    'sunsetEpoch': 1580173213,
#    'moonphase': 0.03,
#    'conditions': 'Rain',
#    'icon': 'rain',
#    'stations': ['71608099999',
#     'CWWA',
#     '71775099999',
#     '71784099999',
#     '71037099999',
#     '71201099999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-28',
#    'datetimeEpoch': 1580198400,
#    'tempmax': 9.0,
#    'tempmin': 5.9,
#    'temp': 7.2,
#    'feelslikemax': 8.8,
#    'feelslikemin': 3.3,
#    'feelslike': 6.7,
#    'dew': 5.6,
#    'humidity': 89.76,
#    'precip': 3.15,
#    'precipprob': None,
#    'precipcover': 37.5,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 31.3,
#    'windspeed': 13.1,
#    'winddir': 124.2,
#    'pressure': 1015.7,
#    'cloudcover': 0.0,
#    'visibility': 1015.9,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:49:27',
#    'sunriseEpoch': 1580226567,
#    'sunset': '17:01:51',
#    'sunsetEpoch': 1580259711,
#    'moonphase': 0.06,
#    'conditions': 'Rain',
#    'icon': 'rain',
#    'stations': ['71608099999',
#     'CWWA',
#     '71775099999',
#     '71784099999',
#     '71037099999',
#     '71201099999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-29',
#    'datetimeEpoch': 1580284800,
#    'tempmax': 8.7,
#    'tempmin': 5.8,
#    'temp': 7.5,
#    'feelslikemax': 8.7,
#    'feelslikemin': 4.6,
#    'feelslike': 6.3,
#    'dew': 6.4,
#    'humidity': 92.92,
#    'precip': 20.28,
#    'precipprob': None,
#    'precipcover': 54.17,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 53.6,
#    'windspeed': 17.1,
#    'winddir': 120.5,
#    'pressure': 1018.9,
#    'cloudcover': 0.0,
#    'visibility': 1019.1,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:48:11',
#    'sunriseEpoch': 1580312891,
#    'sunset': '17:03:30',
#    'sunsetEpoch': 1580346210,
#    'moonphase': 0.09,
#    'conditions': 'Rain',
#    'icon': 'rain',
#    'stations': ['71608099999',
#     'CWWA',
#     '71775099999',
#     '71784099999',
#     '71037099999',
#     '71201099999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-30',
#    'datetimeEpoch': 1580371200,
#    'tempmax': 8.3,
#    'tempmin': 5.6,
#    'temp': 6.6,
#    'feelslikemax': 7.7,
#    'feelslikemin': 3.6,
#    'feelslike': 5.6,
#    'dew': 4.8,
#    'humidity': 88.55,
#    'precip': 7.56,
#    'precipprob': None,
#    'precipcover': 41.67,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 50.0,
#    'windspeed': 14.3,
#    'winddir': 107.1,
#    'pressure': 1021.3,
#    'cloudcover': 0.0,
#    'visibility': 1021.4,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:46:53',
#    'sunriseEpoch': 1580399213,
#    'sunset': '17:05:09',
#    'sunsetEpoch': 1580432709,
#    'moonphase': 0.13,
#    'conditions': 'Rain',
#    'icon': 'rain',
#    'stations': ['71608099999',
#     'CWWA',
#     '71775099999',
#     '71784099999',
#     '71037099999',
#     '71201099999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-01-31',
#    'datetimeEpoch': 1580457600,
#    'tempmax': 11.0,
#    'tempmin': 6.1,
#    'temp': 8.4,
#    'feelslikemax': 11.0,
#    'feelslikemin': 4.0,
#    'feelslike': 7.5,
#    'dew': 7.9,
#    'humidity': 96.98,
#    'precip': 61.65,
#    'precipprob': None,
#    'precipcover': 100.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 57.2,
#    'windspeed': 16.0,
#    'winddir': 123.8,
#    'pressure': 1012.5,
#    'cloudcover': 0.0,
#    'visibility': 1012.6,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:45:33',
#    'sunriseEpoch': 1580485533,
#    'sunset': '17:06:48',
#    'sunsetEpoch': 1580519208,
#    'moonphase': 0.18,
#    'conditions': 'Rain',
#    'icon': 'rain',
#    'stations': ['71608099999',
#     'CWWA',
#     '71775099999',
#     '71784099999',
#     '71037099999',
#     '71201099999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-01',
#    'datetimeEpoch': 1580544000,
#    'tempmax': 10.9,
#    'tempmin': 2.4,
#    'temp': 7.9,
#    'feelslikemax': 10.9,
#    'feelslikemin': 1.6,
#    'feelslike': 6.7,
#    'dew': 3.5,
#    'humidity': 75.0,
#    'precip': 23.7,
#    'precipprob': None,
#    'precipcover': 87.5,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 57.2,
#    'windspeed': 26.3,
#    'winddir': 301.8,
#    'pressure': 1014.4,
#    'cloudcover': 0.0,
#    'visibility': 1014.6,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:44:10',
#    'sunriseEpoch': 1580571850,
#    'sunset': '17:08:28',
#    'sunsetEpoch': 1580605708,
#    'moonphase': 0.22,
#    'conditions': 'Rain',
#    'icon': 'rain',
#    'stations': ['71608099999',
#     'CWWA',
#     '71775099999',
#     '71784099999',
#     '71037099999',
#     '71201099999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-02',
#    'datetimeEpoch': 1580630400,
#    'tempmax': 5.2,
#    'tempmin': 1.6,
#    'temp': 3.2,
#    'feelslikemax': 5.0,
#    'feelslikemin': -0.7,
#    'feelslike': 1.8,
#    'dew': 1.0,
#    'humidity': 85.55,
#    'precip': 7.21,
#    'precipprob': None,
#    'precipcover': 58.33,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 40.7,
#    'windspeed': 13.0,
#    'winddir': 122.8,
#    'pressure': 1022.2,
#    'cloudcover': 0.0,
#    'visibility': 1022.4,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:42:46',
#    'sunriseEpoch': 1580658166,
#    'sunset': '17:10:09',
#    'sunsetEpoch': 1580692209,
#    'moonphase': 0.27,
#    'conditions': 'Rain',
#    'icon': 'rain',
#    'stations': ['71608099999',
#     'CWWA',
#     '71775099999',
#     '71784099999',
#     '71037099999',
#     '71201099999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-03',
#    'datetimeEpoch': 1580716800,
#    'tempmax': 4.3,
#    'tempmin': 1.4,
#    'temp': 2.5,
#    'feelslikemax': 4.3,
#    'feelslikemin': 0.0,
#    'feelslike': 2.1,
#    'dew': 0.1,
#    'humidity': 84.67,
#    'precip': 0.2,
#    'precipprob': None,
#    'precipcover': 8.33,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 35.3,
#    'windspeed': 8.3,
#    'winddir': 161.8,
#    'pressure': 1026.7,
#    'cloudcover': 0.0,
#    'visibility': 1027.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:41:20',
#    'sunriseEpoch': 1580744480,
#    'sunset': '17:11:49',
#    'sunsetEpoch': 1580778709,
#    'moonphase': 0.32,
#    'conditions': 'Rain',
#    'icon': 'rain',
#    'stations': ['71608099999',
#     'CWWA',
#     '71775099999',
#     '71784099999',
#     '71037099999',
#     '71201099999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-04',
#    'datetimeEpoch': 1580803200,
#    'tempmax': 2.5,
#    'tempmin': 0.7,
#    'temp': 1.8,
#    'feelslikemax': 2.5,
#    'feelslikemin': -2.2,
#    'feelslike': 0.1,
#    'dew': 0.7,
#    'humidity': 92.91,
#    'precip': 9.42,
#    'precipprob': None,
#    'precipcover': 75.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 48.2,
#    'windspeed': 14.2,
#    'winddir': 87.6,
#    'pressure': 1027.1,
#    'cloudcover': 0.0,
#    'visibility': 1027.2,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:39:52',
#    'sunriseEpoch': 1580830792,
#    'sunset': '17:13:30',
#    'sunsetEpoch': 1580865210,
#    'moonphase': 0.37,
#    'conditions': 'Rain',
#    'icon': 'rain',
#    'stations': ['71608099999',
#     'CWWA',
#     '71775099999',
#     '71784099999',
#     '71037099999',
#     '71201099999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-05',
#    'datetimeEpoch': 1580889600,
#    'tempmax': 5.0,
#    'tempmin': 2.6,
#    'temp': 3.9,
#    'feelslikemax': 5.0,
#    'feelslikemin': 1.3,
#    'feelslike': 3.8,
#    'dew': 3.3,
#    'humidity': 96.19,
#    'precip': 13.35,
#    'precipprob': None,
#    'precipcover': 75.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 5.4,
#    'winddir': 170.3,
#    'pressure': 1017.5,
#    'cloudcover': 0.0,
#    'visibility': 1017.5,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:38:22',
#    'sunriseEpoch': 1580917102,
#    'sunset': '17:15:10',
#    'sunsetEpoch': 1580951710,
#    'moonphase': 0.41,
#    'conditions': 'Rain',
#    'icon': 'rain',
#    'stations': ['71608099999',
#     'CWWA',
#     '71775099999',
#     '71784099999',
#     '71037099999',
#     '71201099999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-06',
#    'datetimeEpoch': 1580976000,
#    'tempmax': 5.0,
#    'tempmin': 2.6,
#    'temp': 4.3,
#    'feelslikemax': 5.0,
#    'feelslikemin': 2.6,
#    'feelslike': 4.2,
#    'dew': 3.6,
#    'humidity': 95.13,
#    'precip': 7.36,
#    'precipprob': None,
#    'precipcover': 29.17,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 6.3,
#    'winddir': 193.9,
#    'pressure': 1017.1,
#    'cloudcover': 0.0,
#    'visibility': 1017.2,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:36:51',
#    'sunriseEpoch': 1581003411,
#    'sunset': '17:16:51',
#    'sunsetEpoch': 1581038211,
#    'moonphase': 0.45,
#    'conditions': 'Rain',
#    'icon': 'rain',
#    'stations': ['71608099999',
#     'CWWA',
#     '71775099999',
#     '71784099999',
#     '71037099999',
#     '71201099999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-07',
#    'datetimeEpoch': 1581062400,
#    'tempmax': 7.6,
#    'tempmin': 3.6,
#    'temp': 5.3,
#    'feelslikemax': 7.3,
#    'feelslikemin': 2.3,
#    'feelslike': 4.1,
#    'dew': 4.3,
#    'humidity': 93.8,
#    'precip': 3.87,
#    'precipprob': None,
#    'precipcover': 41.67,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 53.6,
#    'windspeed': 16.4,
#    'winddir': 126.7,
#    'pressure': 1011.4,
#    'cloudcover': 0.0,
#    'visibility': 1011.5,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:35:18',
#    'sunriseEpoch': 1581089718,
#    'sunset': '17:18:32',
#    'sunsetEpoch': 1581124712,
#    'moonphase': 0.48,
#    'conditions': 'Rain',
#    'icon': 'rain',
#    'stations': ['71608099999',
#     'CWWA',
#     '71775099999',
#     '71784099999',
#     '71037099999',
#     '71201099999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-08',
#    'datetimeEpoch': 1581148800,
#    'tempmax': 7.9,
#    'tempmin': 2.5,
#    'temp': 5.0,
#    'feelslikemax': 7.9,
#    'feelslikemin': 1.0,
#    'feelslike': 4.4,
#    'dew': 2.8,
#    'humidity': 86.06,
#    'precip': 4.43,
#    'precipprob': None,
#    'precipcover': 12.5,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 40.7,
#    'windspeed': 8.9,
#    'winddir': 103.4,
#    'pressure': 1017.8,
#    'cloudcover': 0.0,
#    'visibility': 1017.9,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:33:43',
#    'sunriseEpoch': 1581176023,
#    'sunset': '17:20:13',
#    'sunsetEpoch': 1581211213,
#    'moonphase': 0.5,
#    'conditions': 'Rain',
#    'icon': 'rain',
#    'stations': ['71608099999',
#     'CWWA',
#     '71775099999',
#     '71784099999',
#     '71037099999',
#     '71201099999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-09',
#    'datetimeEpoch': 1581235200,
#    'tempmax': 5.9,
#    'tempmin': 0.8,
#    'temp': 3.5,
#    'feelslikemax': 5.8,
#    'feelslikemin': 0.8,
#    'feelslike': 3.4,
#    'dew': 0.9,
#    'humidity': 83.06,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 5.8,
#    'winddir': 159.8,
#    'pressure': 1032.2,
#    'cloudcover': 0.0,
#    'visibility': 1032.4,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:32:06',
#    'sunriseEpoch': 1581262326,
#    'sunset': '17:21:54',
#    'sunsetEpoch': 1581297714,
#    'moonphase': 0.5,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['71608099999',
#     'CWWA',
#     '71775099999',
#     '71784099999',
#     '71037099999',
#     '71201099999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-10',
#    'datetimeEpoch': 1581321600,
#    'tempmax': 6.8,
#    'tempmin': 1.8,
#    'temp': 4.5,
#    'feelslikemax': 6.3,
#    'feelslikemin': 1.8,
#    'feelslike': 4.4,
#    'dew': 1.4,
#    'humidity': 80.51,
#    'precip': 0.1,
#    'precipprob': None,
#    'precipcover': 4.17,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 6.1,
#    'winddir': 171.5,
#    'pressure': 1031.7,
#    'cloudcover': 0.0,
#    'visibility': 1031.8,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:30:28',
#    'sunriseEpoch': 1581348628,
#    'sunset': '17:23:35',
#    'sunsetEpoch': 1581384215,
#    'moonphase': 0.52,
#    'conditions': 'Rain',
#    'icon': 'rain',
#    'stations': ['71608099999',
#     'CWWA',
#     '71775099999',
#     '71784099999',
#     '71037099999',
#     '71201099999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-11',
#    'datetimeEpoch': 1581408000,
#    'tempmax': 10.2,
#    'tempmin': 3.5,
#    'temp': 6.1,
#    'feelslikemax': 10.2,
#    'feelslikemin': 1.9,
#    'feelslike': 5.4,
#    'dew': 4.1,
#    'humidity': 86.95,
#    'precip': 1.2,
#    'precipprob': None,
#    'precipcover': 20.83,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 31.3,
#    'windspeed': 9.7,
#    'winddir': 119.0,
#    'pressure': 1024.6,
#    'cloudcover': 0.0,
#    'visibility': 1024.9,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:28:49',
#    'sunriseEpoch': 1581434929,
#    'sunset': '17:25:16',
#    'sunsetEpoch': 1581470716,
#    'moonphase': 0.53,
#    'conditions': 'Rain',
#    'icon': 'rain',
#    'stations': ['71608099999',
#     'CWWA',
#     '71775099999',
#     '71784099999',
#     '71037099999',
#     '71201099999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-12',
#    'datetimeEpoch': 1581494400,
#    'tempmax': 7.6,
#    'tempmin': 4.6,
#    'temp': 6.3,
#    'feelslikemax': 7.6,
#    'feelslikemin': 4.6,
#    'feelslike': 6.2,
#    'dew': 3.9,
#    'humidity': 85.2,
#    'precip': 0.6,
#    'precipprob': None,
#    'precipcover': 8.33,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 4.9,
#    'winddir': 222.3,
#    'pressure': 1025.0,
#    'cloudcover': 0.0,
#    'visibility': 1025.2,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:27:08',
#    'sunriseEpoch': 1581521228,
#    'sunset': '17:26:57',
#    'sunsetEpoch': 1581557217,
#    'moonphase': 0.57,
#    'conditions': 'Rain',
#    'icon': 'rain',
#    'stations': ['71608099999',
#     'CWWA',
#     '71775099999',
#     '71784099999',
#     '71037099999',
#     '71201099999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-13',
#    'datetimeEpoch': 1581580800,
#    'tempmax': 7.2,
#    'tempmin': 5.1,
#    'temp': 5.9,
#    'feelslikemax': 7.1,
#    'feelslikemin': 2.8,
#    'feelslike': 5.0,
#    'dew': 4.1,
#    'humidity': 88.69,
#    'precip': 2.43,
#    'precipprob': None,
#    'precipcover': 20.83,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 44.3,
#    'windspeed': 12.3,
#    'winddir': 156.1,
#    'pressure': 1013.3,
#    'cloudcover': 0.0,
#    'visibility': 1013.5,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:25:25',
#    'sunriseEpoch': 1581607525,
#    'sunset': '17:28:38',
#    'sunsetEpoch': 1581643718,
#    'moonphase': 0.62,
#    'conditions': 'Rain',
#    'icon': 'rain',
#    'stations': ['71608099999',
#     'CWWA',
#     '71775099999',
#     '71784099999',
#     '71037099999',
#     '71201099999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-14',
#    'datetimeEpoch': 1581667200,
#    'tempmax': 8.8,
#    'tempmin': 3.2,
#    'temp': 5.9,
#    'feelslikemax': 8.7,
#    'feelslikemin': 0.9,
#    'feelslike': 5.1,
#    'dew': 3.0,
#    'humidity': 82.28,
#    'precip': 0.8,
#    'precipprob': None,
#    'precipcover': 12.5,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 38.9,
#    'windspeed': 14.9,
#    'winddir': 210.1,
#    'pressure': 1017.0,
#    'cloudcover': 0.0,
#    'visibility': 1017.1,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:23:41',
#    'sunriseEpoch': 1581693821,
#    'sunset': '17:30:19',
#    'sunsetEpoch': 1581730219,
#    'moonphase': 0.67,
#    'conditions': 'Rain',
#    'icon': 'rain',
#    'stations': ['71608099999',
#     'CWWA',
#     '71775099999',
#     '71784099999',
#     '71037099999',
#     '71201099999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-15',
#    'datetimeEpoch': 1581753600,
#    'tempmax': 6.1,
#    'tempmin': 4.3,
#    'temp': 5.2,
#    'feelslikemax': 6.1,
#    'feelslikemin': 1.6,
#    'feelslike': 3.9,
#    'dew': 4.2,
#    'humidity': 93.46,
#    'precip': 15.16,
#    'precipprob': None,
#    'precipcover': 62.5,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 38.9,
#    'windspeed': 14.2,
#    'winddir': 127.3,
#    'pressure': 1015.9,
#    'cloudcover': 0.0,
#    'visibility': 1016.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:21:56',
#    'sunriseEpoch': 1581780116,
#    'sunset': '17:31:59',
#    'sunsetEpoch': 1581816719,
#    'moonphase': 0.73,
#    'conditions': 'Rain',
#    'icon': 'rain',
#    'stations': ['71608099999',
#     'CWWA',
#     '71775099999',
#     '71784099999',
#     '71037099999',
#     '71201099999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-16',
#    'datetimeEpoch': 1581840000,
#    'tempmax': 6.9,
#    'tempmin': 3.3,
#    'temp': 5.1,
#    'feelslikemax': 6.9,
#    'feelslikemin': 0.7,
#    'feelslike': 3.8,
#    'dew': 2.5,
#    'humidity': 83.82,
#    'precip': 0.3,
#    'precipprob': None,
#    'precipcover': 12.5,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 43.6,
#    'windspeed': 17.4,
#    'winddir': 274.8,
#    'pressure': 1019.4,
#    'cloudcover': 0.0,
#    'visibility': 1019.7,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:20:10',
#    'sunriseEpoch': 1581866410,
#    'sunset': '17:33:40',
#    'sunsetEpoch': 1581903220,
#    'moonphase': 0.78,
#    'conditions': 'Rain',
#    'icon': 'rain',
#    'stations': ['71608099999',
#     'CWWA',
#     '71775099999',
#     '71784099999',
#     '71037099999',
#     '71201099999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-17',
#    'datetimeEpoch': 1581926400,
#    'tempmax': 6.2,
#    'tempmin': 1.4,
#    'temp': 3.6,
#    'feelslikemax': 6.1,
#    'feelslikemin': -0.3,
#    'feelslike': 3.1,
#    'dew': 0.7,
#    'humidity': 82.06,
#    'precip': 0.2,
#    'precipprob': None,
#    'precipcover': 8.33,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 40.7,
#    'windspeed': 9.5,
#    'winddir': 130.8,
#    'pressure': 1028.0,
#    'cloudcover': 0.0,
#    'visibility': 1028.1,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:18:22',
#    'sunriseEpoch': 1581952702,
#    'sunset': '17:35:20',
#    'sunsetEpoch': 1581989720,
#    'moonphase': 0.84,
#    'conditions': 'Rain',
#    'icon': 'rain',
#    'stations': ['71608099999',
#     'CWWA',
#     '71775099999',
#     '71784099999',
#     '71037099999',
#     '71201099999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-18',
#    'datetimeEpoch': 1582012800,
#    'tempmax': 6.6,
#    'tempmin': 0.3,
#    'temp': 3.8,
#    'feelslikemax': 6.2,
#    'feelslikemin': 0.3,
#    'feelslike': 3.4,
#    'dew': -0.3,
#    'humidity': 74.86,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 31.3,
#    'windspeed': 10.5,
#    'winddir': 135.2,
#    'pressure': 1029.7,
#    'cloudcover': 0.0,
#    'visibility': 1029.9,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:16:33',
#    'sunriseEpoch': 1582038993,
#    'sunset': '17:37:00',
#    'sunsetEpoch': 1582076220,
#    'moonphase': 0.88,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['71608099999',
#     'CWWA',
#     '71775099999',
#     '71784099999',
#     '71037099999',
#     '71201099999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-19',
#    'datetimeEpoch': 1582099200,
#    'tempmax': 7.7,
#    'tempmin': 0.2,
#    'temp': 3.9,
#    'feelslikemax': 7.7,
#    'feelslikemin': 0.2,
#    'feelslike': 3.8,
#    'dew': 0.1,
#    'humidity': 77.19,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 7.3,
#    'winddir': 125.8,
#    'pressure': 1026.7,
#    'cloudcover': 0.0,
#    'visibility': 1026.8,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:14:43',
#    'sunriseEpoch': 1582125283,
#    'sunset': '17:38:39',
#    'sunsetEpoch': 1582162719,
#    'moonphase': 0.93,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['71608099999',
#     'CWWA',
#     '71775099999',
#     '71784099999',
#     '71037099999',
#     '71201099999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-20',
#    'datetimeEpoch': 1582185600,
#    'tempmax': 9.2,
#    'tempmin': 1.3,
#    'temp': 4.8,
#    'feelslikemax': 8.6,
#    'feelslikemin': 1.3,
#    'feelslike': 4.7,
#    'dew': 1.1,
#    'humidity': 77.66,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 9.7,
#    'winddir': 148.1,
#    'pressure': 1024.5,
#    'cloudcover': 0.0,
#    'visibility': 1024.8,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:12:51',
#    'sunriseEpoch': 1582211571,
#    'sunset': '17:40:19',
#    'sunsetEpoch': 1582249219,
#    'moonphase': 0.96,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['71608099999',
#     'CWWA',
#     '71775099999',
#     '71784099999',
#     '71037099999',
#     '71201099999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-21',
#    'datetimeEpoch': 1582272000,
#    'tempmax': 11.0,
#    'tempmin': 2.4,
#    'temp': 6.6,
#    'feelslikemax': 11.0,
#    'feelslikemin': 2.4,
#    'feelslike': 6.4,
#    'dew': 1.4,
#    'humidity': 70.31,
#    'precip': 0.5,
#    'precipprob': None,
#    'precipcover': 4.17,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 7.0,
#    'winddir': 108.9,
#    'pressure': 1021.5,
#    'cloudcover': 0.0,
#    'visibility': 1021.6,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:10:59',
#    'sunriseEpoch': 1582297859,
#    'sunset': '17:41:58',
#    'sunsetEpoch': 1582335718,
#    'moonphase': 0.98,
#    'conditions': 'Rain',
#    'icon': 'rain',
#    'stations': ['71608099999',
#     'CWWA',
#     '71775099999',
#     '71784099999',
#     '71037099999',
#     '71201099999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-22',
#    'datetimeEpoch': 1582358400,
#    'tempmax': 7.6,
#    'tempmin': 4.3,
#    'temp': 5.7,
#    'feelslikemax': 7.6,
#    'feelslikemin': 2.2,
#    'feelslike': 4.9,
#    'dew': 4.0,
#    'humidity': 88.96,
#    'precip': 12.05,
#    'precipprob': None,
#    'precipcover': 33.33,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 46.1,
#    'windspeed': 12.7,
#    'winddir': 119.5,
#    'pressure': 1019.3,
#    'cloudcover': 0.0,
#    'visibility': 1019.5,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:09:06',
#    'sunriseEpoch': 1582384146,
#    'sunset': '17:43:37',
#    'sunsetEpoch': 1582422217,
#    'moonphase': 1.0,
#    'conditions': 'Rain',
#    'icon': 'rain',
#    'stations': ['71608099999',
#     'CWWA',
#     '71775099999',
#     '71784099999',
#     '71037099999',
#     '71201099999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-23',
#    'datetimeEpoch': 1582444800,
#    'tempmax': 8.1,
#    'tempmin': 4.1,
#    'temp': 6.0,
#    'feelslikemax': 7.7,
#    'feelslikemin': 1.3,
#    'feelslike': 4.3,
#    'dew': 4.0,
#    'humidity': 86.63,
#    'precip': 15.53,
#    'precipprob': None,
#    'precipcover': 58.33,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 66.6,
#    'windspeed': 23.6,
#    'winddir': 207.0,
#    'pressure': 1012.1,
#    'cloudcover': 0.0,
#    'visibility': 1012.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:07:11',
#    'sunriseEpoch': 1582470431,
#    'sunset': '17:45:16',
#    'sunsetEpoch': 1582508716,
#    'moonphase': 1.0,
#    'conditions': 'Rain',
#    'icon': 'rain',
#    'stations': ['71608099999',
#     'CWWA',
#     '71775099999',
#     '71784099999',
#     '71037099999',
#     '71201099999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-02-24',
#    'datetimeEpoch': 1582531200,
#    'tempmax': 7.6,
#    'tempmin': 4.7,
#    'temp': 5.9,
#    'feelslikemax': 7.6,
#    'feelslikemin': 1.6,
#    'feelslike': 4.4,
#    'dew': 0.0,
#    'humidity': 66.24,
#    'precip': 0.9,
#    'precipprob': None,
#    'precipcover': 20.83,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 55.4,
#    'windspeed': 22.3,
#    'winddir': 262.2,
#    'pressure': 1032.5,
#    'cloudcover': 0.0,
#    'visibility': 1032.8,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '07:05:16',
#    'sunriseEpoch': 1582556716,
#    'sunset': '17:46:54',
#    'sunsetEpoch': 1582595214,
#    'moonphase': 0.0,
#    'conditions': 'Rain',
#    'icon': 'rain',
#    'stations': ['71608099999',
#     'CWWA',
#     '71775099999',
#     '71784099999',
#     '71037099999',
#     '71201099999'],
#    'source': 'obs',
# ...
#    'moonphase': 1.0,
#    'conditions': 'Rain',
#    'icon': 'rain',
#    'stations': ['71608099999',
#     'CWWA',
#     '71775099999',
#     '71784099999',
#     '71037099999',
#     '71201099999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-15',
#    'datetimeEpoch': 1608019200,
#    'tempmax': 7.9,
#    'tempmin': 5.5,
#    'temp': 6.9,
#    'feelslikemax': 7.9,
#    'feelslikemin': 1.7,
#    'feelslike': 5.3,
#    'dew': 6.0,
#    'humidity': 93.97,
#    'precip': 17.65,
#    'precipprob': None,
#    'precipcover': 62.5,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 68.4,
#    'windspeed': 19.6,
#    'winddir': 185.8,
#    'pressure': 1014.0,
#    'cloudcover': 0.0,
#    'visibility': 1014.3,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '08:01:41',
#    'sunriseEpoch': 1608048101,
#    'sunset': '16:14:14',
#    'sunsetEpoch': 1608077654,
#    'moonphase': 0.0,
#    'conditions': 'Rain',
#    'icon': 'rain',
#    'stations': ['71608099999',
#     'CWWA',
#     '71775099999',
#     '71784099999',
#     '71037099999',
#     '71201099999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-16',
#    'datetimeEpoch': 1608105600,
#    'tempmax': 9.1,
#    'tempmin': 6.7,
#    'temp': 7.7,
#    'feelslikemax': 8.7,
#    'feelslikemin': 3.4,
#    'feelslike': 6.1,
#    'dew': 6.7,
#    'humidity': 93.28,
#    'precip': 11.93,
#    'precipprob': None,
#    'precipcover': 50.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 55.4,
#    'windspeed': 19.8,
#    'winddir': 91.3,
#    'pressure': 1008.0,
#    'cloudcover': 0.0,
#    'visibility': 1008.1,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '08:02:25',
#    'sunriseEpoch': 1608134545,
#    'sunset': '16:14:29',
#    'sunsetEpoch': 1608164069,
#    'moonphase': 0.02,
#    'conditions': 'Rain',
#    'icon': 'rain',
#    'stations': ['71608099999',
#     'CWWA',
#     '71775099999',
#     '71784099999',
#     '71037099999',
#     '71201099999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-17',
#    'datetimeEpoch': 1608192000,
#    'tempmax': 8.2,
#    'tempmin': 5.8,
#    'temp': 6.8,
#    'feelslikemax': 7.8,
#    'feelslikemin': 4.8,
#    'feelslike': 6.2,
#    'dew': 5.7,
#    'humidity': 92.5,
#    'precip': 14.79,
#    'precipprob': None,
#    'precipcover': 66.67,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 55.4,
#    'windspeed': 11.6,
#    'winddir': 148.3,
#    'pressure': 1009.5,
#    'cloudcover': 0.0,
#    'visibility': 1009.4,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '08:03:07',
#    'sunriseEpoch': 1608220987,
#    'sunset': '16:14:47',
#    'sunsetEpoch': 1608250487,
#    'moonphase': 0.05,
#    'conditions': 'Rain',
#    'icon': 'rain',
#    'stations': ['71608099999',
#     'CWWA',
#     '71775099999',
#     '71784099999',
#     '71037099999',
#     '71201099999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-18',
#    'datetimeEpoch': 1608278400,
#    'tempmax': 8.9,
#    'tempmin': 5.6,
#    'temp': 7.1,
#    'feelslikemax': 8.9,
#    'feelslikemin': 3.1,
#    'feelslike': 5.4,
#    'dew': 6.4,
#    'humidity': 95.55,
#    'precip': 51.04,
#    'precipprob': None,
#    'precipcover': 100.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 79.6,
#    'windspeed': 23.2,
#    'winddir': 109.2,
#    'pressure': 1015.0,
#    'cloudcover': 0.0,
#    'visibility': 1015.0,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '08:03:46',
#    'sunriseEpoch': 1608307426,
#    'sunset': '16:15:08',
#    'sunsetEpoch': 1608336908,
#    'moonphase': 0.09,
#    'conditions': 'Rain',
#    'icon': 'rain',
#    'stations': ['71608099999',
#     'CWWA',
#     '71775099999',
#     '71784099999',
#     '71037099999',
#     '71201099999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-19',
#    'datetimeEpoch': 1608364800,
#    'tempmax': 8.4,
#    'tempmin': 4.9,
#    'temp': 6.9,
#    'feelslikemax': 8.1,
#    'feelslikemin': 3.3,
#    'feelslike': 5.4,
#    'dew': 5.9,
#    'humidity': 93.24,
#    'precip': 28.37,
#    'precipprob': None,
#    'precipcover': 50.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 61.2,
#    'windspeed': 20.8,
#    'winddir': 146.9,
#    'pressure': 1015.7,
#    'cloudcover': 0.0,
#    'visibility': 1015.9,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '08:04:22',
#    'sunriseEpoch': 1608393862,
#    'sunset': '16:15:32',
#    'sunsetEpoch': 1608423332,
#    'moonphase': 0.13,
#    'conditions': 'Rain',
#    'icon': 'rain',
#    'stations': ['71608099999',
#     'CWWA',
#     '71775099999',
#     '71784099999',
#     '71037099999',
#     '71201099999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-20',
#    'datetimeEpoch': 1608451200,
#    'tempmax': 9.3,
#    'tempmin': 5.5,
#    'temp': 7.2,
#    'feelslikemax': 8.8,
#    'feelslikemin': 5.0,
#    'feelslike': 6.7,
#    'dew': 6.5,
#    'humidity': 95.36,
#    'precip': 0.95,
#    'precipprob': None,
#    'precipcover': 8.33,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 46.1,
#    'windspeed': 12.1,
#    'winddir': 202.8,
#    'pressure': 1016.5,
#    'cloudcover': 0.0,
#    'visibility': 1016.7,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '08:04:56',
#    'sunriseEpoch': 1608480296,
#    'sunset': '16:15:59',
#    'sunsetEpoch': 1608509759,
#    'moonphase': 0.18,
#    'conditions': 'Rain',
#    'icon': 'rain',
#    'stations': ['71608099999',
#     'CWWA',
#     '71775099999',
#     '71784099999',
#     '71037099999',
#     '71201099999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-21',
#    'datetimeEpoch': 1608537600,
#    'tempmax': 6.1,
#    'tempmin': 1.9,
#    'temp': 3.9,
#    'feelslikemax': 6.1,
#    'feelslikemin': -1.6,
#    'feelslike': 2.8,
#    'dew': 3.3,
#    'humidity': 96.1,
#    'precip': 37.36,
#    'precipprob': None,
#    'precipcover': 70.83,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 35.3,
#    'windspeed': 17.0,
#    'winddir': 100.5,
#    'pressure': 1007.5,
#    'cloudcover': 0.0,
#    'visibility': 1007.5,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '08:05:26',
#    'sunriseEpoch': 1608566726,
#    'sunset': '16:16:29',
#    'sunsetEpoch': 1608596189,
#    'moonphase': 0.23,
#    'conditions': 'Rain',
#    'icon': 'rain',
#    'stations': ['71608099999',
#     'CWWA',
#     '71775099999',
#     '71784099999',
#     '71037099999',
#     '71201099999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-22',
#    'datetimeEpoch': 1608624000,
#    'tempmax': 6.1,
#    'tempmin': 1.0,
#    'temp': 3.1,
#    'feelslikemax': 5.9,
#    'feelslikemin': -0.2,
#    'feelslike': 2.7,
#    'dew': 1.9,
#    'humidity': 92.1,
#    'precip': 2.6,
#    'precipprob': None,
#    'precipcover': 12.5,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 7.1,
#    'winddir': 128.3,
#    'pressure': 1024.4,
#    'cloudcover': 0.0,
#    'visibility': 1024.8,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '08:05:54',
#    'sunriseEpoch': 1608653154,
#    'sunset': '16:17:02',
#    'sunsetEpoch': 1608682622,
#    'moonphase': 0.28,
#    'conditions': 'Rain',
#    'icon': 'rain',
#    'stations': ['71608099999', '71775099999', '71037099999', '71201099999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-23',
#    'datetimeEpoch': 1608710400,
#    'tempmax': 5.9,
#    'tempmin': 0.8,
#    'temp': 2.9,
#    'feelslikemax': 5.9,
#    'feelslikemin': -0.2,
#    'feelslike': 2.6,
#    'dew': 1.0,
#    'humidity': 87.5,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': None,
#    'windspeed': 7.0,
#    'winddir': 126.3,
#    'pressure': 1032.1,
#    'cloudcover': 0.0,
#    'visibility': 1032.4,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '08:06:18',
#    'sunriseEpoch': 1608739578,
#    'sunset': '16:17:38',
#    'sunsetEpoch': 1608769058,
#    'moonphase': 0.32,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['71608099999', '71775099999', '71037099999', '71201099999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-24',
#    'datetimeEpoch': 1608796800,
#    'tempmax': 5.2,
#    'tempmin': -0.5,
#    'temp': 2.3,
#    'feelslikemax': 5.2,
#    'feelslikemin': -3.0,
#    'feelslike': 1.6,
#    'dew': 1.4,
#    'humidity': 93.7,
#    'precip': 0.0,
#    'precipprob': None,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 38.9,
#    'windspeed': 9.1,
#    'winddir': 142.3,
#    'pressure': 1020.0,
#    'cloudcover': 0.0,
#    'visibility': 1020.3,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '08:06:40',
#    'sunriseEpoch': 1608826000,
#    'sunset': '16:18:16',
#    'sunsetEpoch': 1608855496,
#    'moonphase': 0.37,
#    'conditions': 'Clear',
#    'icon': 'clear-day',
#    'stations': ['71608099999', '71775099999', '71037099999', '71201099999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-25',
#    'datetimeEpoch': 1608883200,
#    'tempmax': 7.9,
#    'tempmin': 2.7,
#    'temp': 5.7,
#    'feelslikemax': 7.5,
#    'feelslikemin': 2.5,
#    'feelslike': 4.9,
#    'dew': 4.5,
#    'humidity': 91.54,
#    'precip': 11.37,
#    'precipprob': None,
#    'precipcover': 37.5,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 37.1,
#    'windspeed': 15.0,
#    'winddir': 140.0,
#    'pressure': 1007.2,
#    'cloudcover': 0.0,
#    'visibility': 1007.5,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '08:06:58',
#    'sunriseEpoch': 1608912418,
#    'sunset': '16:18:58',
#    'sunsetEpoch': 1608941938,
#    'moonphase': 0.4,
#    'conditions': 'Rain',
#    'icon': 'rain',
#    'stations': ['71608099999', '71775099999', '71037099999', '71201099999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-26',
#    'datetimeEpoch': 1608969600,
#    'tempmax': 8.0,
#    'tempmin': 6.1,
#    'temp': 7.1,
#    'feelslikemax': 8.0,
#    'feelslikemin': 2.8,
#    'feelslike': 5.0,
#    'dew': 5.7,
#    'humidity': 90.78,
#    'precip': 13.83,
#    'precipprob': None,
#    'precipcover': 58.33,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 59.0,
#    'windspeed': 27.8,
#    'winddir': 144.4,
#    'pressure': 1009.6,
#    'cloudcover': 0.0,
#    'visibility': 1010.2,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '08:07:14',
#    'sunriseEpoch': 1608998834,
#    'sunset': '16:19:43',
#    'sunsetEpoch': 1609028383,
#    'moonphase': 0.44,
#    'conditions': 'Rain',
#    'icon': 'rain',
#    'stations': ['71608099999', '71775099999', '71037099999', '71201099999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-27',
#    'datetimeEpoch': 1609056000,
#    'tempmax': 7.0,
#    'tempmin': 5.9,
#    'temp': 6.5,
#    'feelslikemax': 6.9,
#    'feelslikemin': 3.0,
#    'feelslike': 5.5,
#    'dew': 5.6,
#    'humidity': 94.24,
#    'precip': 8.89,
#    'precipprob': None,
#    'precipcover': 62.5,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 42.5,
#    'windspeed': 21.3,
#    'winddir': 114.1,
#    'pressure': 1018.4,
#    'cloudcover': 0.0,
#    'visibility': 1018.8,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '08:07:27',
#    'sunriseEpoch': 1609085247,
#    'sunset': '16:20:30',
#    'sunsetEpoch': 1609114830,
#    'moonphase': 0.47,
#    'conditions': 'Rain',
#    'icon': 'rain',
#    'stations': ['71608099999', '71775099999', '71037099999', '71201099999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-28',
#    'datetimeEpoch': 1609142400,
#    'tempmax': 6.8,
#    'tempmin': 4.7,
#    'temp': 5.9,
#    'feelslikemax': 6.6,
#    'feelslikemin': 3.0,
#    'feelslike': 4.9,
#    'dew': 4.9,
#    'humidity': 93.81,
#    'precip': 3.79,
#    'precipprob': None,
#    'precipcover': 12.5,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 31.3,
#    'windspeed': 18.3,
#    'winddir': 237.2,
#    'pressure': 1020.2,
#    'cloudcover': 0.0,
#    'visibility': 1020.6,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '08:07:36',
#    'sunriseEpoch': 1609171656,
#    'sunset': '16:21:20',
#    'sunsetEpoch': 1609201280,
#    'moonphase': 0.49,
#    'conditions': 'Rain',
#    'icon': 'rain',
#    'stations': ['71608099999',
#     '71775099999',
#     '71784099999',
#     '71037099999',
#     '71201099999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-29',
#    'datetimeEpoch': 1609228800,
#    'tempmax': 5.5,
#    'tempmin': 3.5,
#    'temp': 4.6,
#    'feelslikemax': 5.5,
#    'feelslikemin': 0.4,
#    'feelslike': 3.6,
#    'dew': 3.6,
#    'humidity': 92.87,
#    'precip': 11.89,
#    'precipprob': None,
#    'precipcover': 41.67,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 37.1,
#    'windspeed': 13.4,
#    'winddir': 108.9,
#    'pressure': 1023.2,
#    'cloudcover': 0.0,
#    'visibility': 1023.5,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '08:07:43',
#    'sunriseEpoch': 1609258063,
#    'sunset': '16:22:12',
#    'sunsetEpoch': 1609287732,
#    'moonphase': 0.5,
#    'conditions': 'Rain',
#    'icon': 'rain',
#    'stations': ['71608099999',
#     'CWWA',
#     '71775099999',
#     '71784099999',
#     '71037099999',
#     '71201099999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-30',
#    'datetimeEpoch': 1609315200,
#    'tempmax': 6.0,
#    'tempmin': 4.0,
#    'temp': 5.0,
#    'feelslikemax': 4.4,
#    'feelslikemin': 0.2,
#    'feelslike': 1.5,
#    'dew': 3.9,
#    'humidity': 92.34,
#    'precip': 56.31,
#    'precipprob': None,
#    'precipcover': 100.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 61.2,
#    'windspeed': 21.8,
#    'winddir': 93.7,
#    'pressure': 1009.2,
#    'cloudcover': 0.0,
#    'visibility': 1009.5,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '08:07:46',
#    'sunriseEpoch': 1609344466,
#    'sunset': '16:23:07',
#    'sunsetEpoch': 1609374187,
#    'moonphase': 0.5,
#    'conditions': 'Rain',
#    'icon': 'rain',
#    'stations': ['71608099999',
#     'CWWA',
#     '71775099999',
#     '71784099999',
#     '71037099999',
#     '71201099999'],
#    'source': 'obs',
#    'hours': None},
#   {'datetime': '2020-12-31',
#    'datetimeEpoch': 1609401600,
#    'tempmax': 7.1,
#    'tempmin': 4.5,
#    'temp': 6.1,
#    'feelslikemax': 6.7,
#    'feelslikemin': 3.5,
#    'feelslike': 5.0,
#    'dew': 5.4,
#    'humidity': 95.42,
#    'precip': 26.92,
#    'precipprob': None,
#    'precipcover': 66.67,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 50.0,
#    'windspeed': 19.4,
#    'winddir': 121.8,
#    'pressure': 1014.1,
#    'cloudcover': 0.0,
#    'visibility': 1014.7,
#    'solarradiation': None,
#    'solarenergy': None,
#    'sunrise': '08:07:46',
#    'sunriseEpoch': 1609430866,
#    'sunset': '16:24:05',
#    'sunsetEpoch': 1609460645,
#    'moonphase': 0.51,
#    'conditions': 'Rain',
#    'icon': 'rain',
#    'stations': ['71608099999',
#     'CWWA',
#     '71775099999',
#     '71784099999',
#     '71037099999'],
#    'source': 'obs',
#    'hours': None}],
#  'stations': {'71608099999': {'distance': 9978.0,
#    'latitude': 49.183,
#    'longitude': -123.183,
#    'useCount': 0,
#    'id': '71608099999',
#    'name': 'VANCOUVER SEA ISLAND CCG, CA',
#    'quality': 100,
#    'contribution': 0.0},
#   'CWWA': {'distance': 11097.0,
#    'latitude': 49.35,
#    'longitude': -123.18,
#    'useCount': 0,
#    'id': 'CWWA',
#    'name': 'CWWA',
#    'quality': 97,
#    'contribution': 0.0},
#   '71775099999': {'distance': 31973.0,
#    'latitude': 49.2,
#    'longitude': -122.683,
#    'useCount': 0,
#    'id': '71775099999',
#    'name': 'PITT MEADOWS CAMPBELL SCIENTIFIC BC, CA',
#    'quality': 100,
#    'contribution': 0.0},
#   '71784099999': {'distance': 11805.0,
#    'latitude': 49.35,
#    'longitude': -123.2,
#    'useCount': 0,
#    'id': '71784099999',
#    'name': 'WEST VANCOUVER AUT, CA',
#    'quality': 98,
#    'contribution': 0.0},
#   '71037099999': {'distance': 13502.0,
#    'latitude': 49.33,
#    'longitude': -123.265,
#    'useCount': 0,
#    'id': '71037099999',
#    'name': 'POINT ATKINSON, CA',
#    'quality': 100,
#    'contribution': 0.0},
#   '71201099999': {'distance': 2566.0,
#    'latitude': 49.283,
#    'longitude': -123.117,
#    'useCount': 0,
#    'id': '71201099999',
#    'name': 'VANCOUVER HARBOUR CS BC, CA',
#    'quality': 99,
#    'contribution': 0.0}}}

# %%
#3. We create empty lists to transfer the data
temperature = []
temp_max = []
temp_min = []
humidity = []
precip = []
snow = []
windspeed = []
conditions = []
date = []
city = []

# %%
#4. We loop thropugh the API and extract the info we need
for x in range(366):
    temperature.append(response["days"][x]["temp"])
    temp_max.append(response["days"][x]["tempmax"])
    temp_min.append(response["days"][x]["tempmin"])
    humidity.append(response["days"][x]["humidity"])
    precip.append(response["days"][x]["precip"])
    snow.append(response["days"][x]["snow"])
    windspeed.append(response["days"][x]["windspeed"])
    conditions.append(response["days"][x]["conditions"])
    date.append(response["days"][x]["datetime"])
    city.append("Toronto, ON")

# %%
print(len(temperature),len(temp_max),len(temp_min),len(humidity),len(precip),len(snow),len(windspeed),len(conditions),len(date),len(city))
# Out:
# 366 366 366 366 366 366 366 366 366 366

# %%
#5. We create a dataframe based on the lists
New_df = pd.DataFrame(
    {'City': city,
     'Date': date,
     'Temperature': temperature,
     'temp_max': temp_max,
     'temp_min':temp_min,
     'humidity':humidity,
     'precip':precip,
     'snow':snow,
     'windspeed':windspeed,
     'conditions': conditions
    })

# %%
New_df
# Out:
#             City        Date  Temperature  temp_max  temp_min  humidity  \
# 0    Toronto, ON  2020-01-01         -0.2       0.5      -0.9     68.41
# 1    Toronto, ON  2020-01-02          4.2       5.8       0.2     70.62
# 2    Toronto, ON  2020-01-03          6.0       7.2       4.3     71.65
# 3    Toronto, ON  2020-01-04          2.0       3.9       0.7     75.03
# 4    Toronto, ON  2020-01-05          0.5       1.8      -0.9     69.74
# ..           ...         ...          ...       ...       ...       ...
# 361  Toronto, ON  2020-12-27         -0.1       2.7      -2.4     73.19
# 362  Toronto, ON  2020-12-28          2.6       5.1      -0.9     73.53
# 363  Toronto, ON  2020-12-29         -2.2      -0.7      -4.0     58.88
# 364  Toronto, ON  2020-12-30          1.7       5.5      -2.1     79.01
# 365  Toronto, ON  2020-12-31          0.7       3.2      -0.8     66.38
#
#      precip  snow  windspeed conditions
# 0      0.24  0.83       37.0       Snow
# 1      0.20  0.60       31.5       Snow
# 2      0.00  1.87       23.9       Snow
# 3      2.01  1.13       29.3       Snow
# 4      5.33  3.61       29.3       Snow
# ..      ...   ...        ...        ...
# 361    0.36  0.00       33.2       Snow
# 362    7.20  0.00       48.1       Rain
# 363    0.00  0.57       24.4       Snow
# 364    7.51  0.37       40.4       Snow
# 365    1.40  0.00       33.5       Rain
#
# [366 rows x 10 columns]

# %%
#6. We add new city dataframe to original dataframe including cities already evaluated 

frames = [Final_df,New_df]

# %%
Final_df = pd.concat(frames)

# %%
Final_df
# Out:
#              City        Date  Temperature  temp_max  temp_min  humidity  \
# 0    Montreal, QC  2020-01-01          0.2       1.1      -0.8     87.84
# 1    Montreal, QC  2020-01-02          0.9       2.6      -1.0     78.70
# 2    Montreal, QC  2020-01-03          4.8       5.8       2.8     74.88
# 3    Montreal, QC  2020-01-04          0.5       3.2      -1.9     78.79
# 4    Montreal, QC  2020-01-05         -5.3      -1.8      -9.9     69.09
# ..            ...         ...          ...       ...       ...       ...
# 361   Toronto, ON  2020-12-27         -0.1       2.7      -2.4     73.19
# 362   Toronto, ON  2020-12-28          2.6       5.1      -0.9     73.53
# 363   Toronto, ON  2020-12-29         -2.2      -0.7      -4.0     58.88
# 364   Toronto, ON  2020-12-30          1.7       5.5      -2.1     79.01
# 365   Toronto, ON  2020-12-31          0.7       3.2      -0.8     66.38
#
#      precip  snow  windspeed conditions
# 0      5.71  0.00        7.9       Rain
# 1      0.00  0.00        7.7      Clear
# 2      0.00  0.00        7.6      Clear
# 3      2.27  0.00       11.2       Rain
# 4      0.76  3.88       13.1       Snow
# ..      ...   ...        ...        ...
# 361    0.36  0.00       33.2       Snow
# 362    7.20  0.00       48.1       Rain
# 363    0.00  0.57       24.4       Snow
# 364    7.51  0.37       40.4       Snow
# 365    1.40  0.00       33.5       Rain
#
# [1830 rows x 10 columns]

# %%
#7.Update to csv by converting df to csv
Final_df.to_csv("Temperature_Dataset1.csv", index=False)

# %%
#8. Will need to import CSV with temp for cities already evaluated every time this document is open again for the 1st time. 
#Name dataframe: Final_df

file_path = os.path.join("Temperature_Dataset1.csv")
Final_df = pd.read_csv(file_path)
Final_df
# Out:
#               City        Date  Temperature  temp_max  temp_min  humidity  \
# 0     Montreal, QC  2020-01-01          0.2       1.1      -0.8     87.84
# 1     Montreal, QC  2020-01-02          0.9       2.6      -1.0     78.70
# 2     Montreal, QC  2020-01-03          4.8       5.8       2.8     74.88
# 3     Montreal, QC  2020-01-04          0.5       3.2      -1.9     78.79
# 4     Montreal, QC  2020-01-05         -5.3      -1.8      -9.9     69.09
# ...            ...         ...          ...       ...       ...       ...
# 1825   Toronto, ON  2020-12-27         -0.1       2.7      -2.4     73.19
# 1826   Toronto, ON  2020-12-28          2.6       5.1      -0.9     73.53
# 1827   Toronto, ON  2020-12-29         -2.2      -0.7      -4.0     58.88
# 1828   Toronto, ON  2020-12-30          1.7       5.5      -2.1     79.01
# 1829   Toronto, ON  2020-12-31          0.7       3.2      -0.8     66.38
#
#       precip  snow  windspeed conditions
# 0       5.71  0.00        7.9       Rain
# 1       0.00  0.00        7.7      Clear
# 2       0.00  0.00        7.6      Clear
# 3       2.27  0.00       11.2       Rain
# 4       0.76  3.88       13.1       Snow
# ...      ...   ...        ...        ...
# 1825    0.36  0.00       33.2       Snow
# 1826    7.20  0.00       48.1       Rain
# 1827    0.00  0.57       24.4       Snow
# 1828    7.51  0.37       40.4       Snow
# 1829    1.40  0.00       33.5       Rain
#
# [1830 rows x 10 columns]
