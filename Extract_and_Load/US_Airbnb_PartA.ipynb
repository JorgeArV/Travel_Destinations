# %%
import pandas as pd

# %%
Asheville = pd.read_csv('../Resources/Asheville.csv')

# %%
Asheville.rename(columns = {
    'host_name':'Host Name',
    'neighbourhood_cleansed': 'Neighbourhood',
    'latitude': 'Latitude',
    'longitude': 'Longitude',
    'property_type': 'Property Type',
    'room_type': 'Room Type',
    'price': 'Price',
    'minimum_nights': 'Minimum Nights',
    'availability_365': 'Availability 365',
    'review_scores_rating': 'Reviews Scores Rating'}, inplace = True)
Asheville.head()
# Out:
#        id                          listing_url       scrape_id last_scraped  \
# 0  108061  https://www.airbnb.com/rooms/108061  20210217171651   2021-02-18
# 1  155305  https://www.airbnb.com/rooms/155305  20210217171651   2021-02-18
# 2  156805  https://www.airbnb.com/rooms/156805  20210217171651   2021-02-19
# 3  156926  https://www.airbnb.com/rooms/156926  20210217171651   2021-02-18
# 4  160594  https://www.airbnb.com/rooms/160594  20210217171651   2021-02-17
#
#                                                 name  \
# 0  Walk to stores/parks/downtown. Fenced yard/Pet...
# 1                 Cottage! BonPaul + Sharky's Hostel
# 2                  Private Room "Ader" at BPS Hostel
# 3             Mixed Dorm "Top Bunk #1" at BPS Hostel
# 4                                Historic Grove Park
#
#                                          description  \
# 0  Walk to town in ten minutes! Monthly rental in...
# 1  <b>The space</b><br />Private cottage located ...
# ...

# %%
Asheville["City"] = "Ashville,NC"

# %%
Asheville = Asheville[['City','Host Name','Neighbourhood','Latitude','Longitude','Property Type','Room Type','Price','Minimum Nights','Availability 365','Reviews Scores Rating']]
Asheville.head()
# Out:
#           City  Host Name  Neighbourhood  Latitude  Longitude  \
# 0  Ashville,NC       Lisa          28801  35.60670  -82.55563
# 1  Ashville,NC    BonPaul          28806  35.57864  -82.59578
# 2  Ashville,NC    BonPaul          28806  35.57864  -82.59578
# 3  Ashville,NC    BonPaul          28806  35.57864  -82.59578
# 4  Ashville,NC  Elizabeth          28801  35.61442  -82.54127
#
#            Property Type        Room Type    Price  Minimum Nights  \
# 0       Entire apartment  Entire home/apt   $82.00              30
# 1      Entire guesthouse  Entire home/apt   $90.00               1
# 2  Private room in house     Private room   $66.00               1
# 3  Shared room in hostel      Shared room   $31.00               1
# 4  Private room in house     Private room  $125.00              30
#
#    Availability 365  Reviews Scores Rating
# 0               242                   90.0
# 1               310                   91.0
# 2                16                   90.0
# ...

# %%
Austin = pd.read_csv('../Resources/Austin.csv')

# %%
Austin.rename(columns = {
    'host_name':'Host Name',
    'neighbourhood_cleansed': 'Neighbourhood',
    'latitude': 'Latitude',
    'longitude': 'Longitude',
    'property_type': 'Property Type',
    'room_type': 'Room Type',
    'price': 'Price',
    'minimum_nights': 'Minimum Nights',
    'availability_365': 'Availability 365',
    'review_scores_rating': 'Reviews Scores Rating'}, inplace = True)
Austin.head()
# Out:
#      id                        listing_url       scrape_id last_scraped  \
# 0  2265  https://www.airbnb.com/rooms/2265  20210210181232   2021-02-12
# 1  5245  https://www.airbnb.com/rooms/5245  20210210181232   2021-02-12
# 2  5456  https://www.airbnb.com/rooms/5456  20210210181232   2021-02-12
# 3  5636  https://www.airbnb.com/rooms/5636  20210210181232   2021-02-12
# 4  5769  https://www.airbnb.com/rooms/5769  20210210181232   2021-02-13
#
#                                                 name  \
# 0   Zen-East in the Heart of Austin (monthly rental)
# 1  Eco friendly, Colorful, Clean, Cozy monthly share
# 2          Walk to 6th, Rainey St and Convention Ctr
# 3         Soco, Barton Springs Private Guest Cottage
# 4                                     NW Austin Room
#
#                                          description  \
# 0  Zen East is situated in a vibrant & diverse mu...
# 1  Situated in a vibrant & diverse multicultural ...
# ...

# %%
Austin["City"] = "Austin,TX"

# %%
Austin = Austin[['City','Host Name','Neighbourhood','Latitude','Longitude','Property Type','Room Type','Price','Minimum Nights','Availability 365','Reviews Scores Rating']]
Austin.head()
# Out:
#         City  Host Name  Neighbourhood  Latitude  Longitude  \
# 0  Austin,TX      Paddy          78702  30.27750  -97.71398
# 1  Austin,TX      Paddy          78702  30.27577  -97.71379
# 2  Austin,TX     Sylvia          78702  30.26112  -97.73448
# 3  Austin,TX      Peggy          78704  30.24630  -97.76361
# 4  Austin,TX  Elizabeth          78729  30.45697  -97.78422
#
#            Property Type        Room Type    Price  Minimum Nights  \
# 0           Entire house  Entire home/apt  $200.00               7
# 1  Private room in house     Private room  $114.00              30
# 2      Entire guesthouse  Entire home/apt  $104.00               2
# 3      Entire guesthouse  Entire home/apt   $46.00              30
# 4  Private room in house     Private room   $39.00               1
#
#    Availability 365  Reviews Scores Rating
# 0               131                   93.0
# 1                 0                   91.0
# 2               354                   97.0
# ...

# %%
Boston = pd.read_csv('../Resources/Boston.csv')

# %%
Boston.rename(columns = {
    'host_name':'Host Name',
    'neighbourhood_cleansed': 'Neighbourhood',
    'latitude': 'Latitude',
    'longitude': 'Longitude',
    'property_type': 'Property Type',
    'room_type': 'Room Type',
    'price': 'Price',
    'minimum_nights': 'Minimum Nights',
    'availability_365': 'Availability 365',
    'review_scores_rating': 'Reviews Scores Rating'}, inplace = True)
Boston.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0   3781   https://www.airbnb.com/rooms/3781  20210219004231   2021-02-20
# 1   6695   https://www.airbnb.com/rooms/6695  20210219004231   2021-02-19
# 2  10813  https://www.airbnb.com/rooms/10813  20210219004231   2021-02-19
# 3  10986  https://www.airbnb.com/rooms/10986  20210219004231   2021-02-20
# 4  13247  https://www.airbnb.com/rooms/13247  20210219004231   2021-02-19
#
#                                                 name  \
# 0                          HARBORSIDE-Walk to subway
# 1                     $99 Special!! Home Away! Condo
# 2  Back Bay Apt-blocks to subway, Newbury St, The...
# 3  North End (Waterfront area)  CLOSE TO MGH & SU...
# 4                          Back Bay studio apartment
#
#                                          description  \
# 0  Fully separate apartment in a two apartment bu...
# 1  Comfortable,  Fully Equipped private apartment...
# ...

# %%
Boston["City"] = "Boston,MA"

# %%
Boston = Boston[['City','Host Name','Neighbourhood','Latitude','Longitude','Property Type','Room Type','Price','Minimum Nights','Availability 365','Reviews Scores Rating']]
Boston.head()
# Out:
#         City Host Name Neighbourhood  Latitude  Longitude       Property Type  \
# 0  Boston,MA     Frank   East Boston  42.36413  -71.02991    Entire apartment
# 1  Boston,MA     Terry       Roxbury  42.32994  -71.09351  Entire condominium
# 2  Boston,MA  Michelle      Back Bay  42.35061  -71.08787    Entire apartment
# 3  Boston,MA  Michelle     North End  42.36352  -71.05075  Entire condominium
# 4  Boston,MA     Susan      Back Bay  42.35164  -71.08752     Entire home/apt
#
#          Room Type    Price  Minimum Nights  Availability 365  \
# 0  Entire home/apt  $125.00              29               224
# 1  Entire home/apt  $169.00              29                 0
# 2  Entire home/apt   $70.00              29               364
# 3  Entire home/apt   $73.00              29               364
# 4  Entire home/apt   $75.00              91                 0
#
#    Reviews Scores Rating
# 0                   99.0
# 1                   96.0
# 2                   99.0
# ...

# %%
BrowardCounty = pd.read_csv('../Resources/Broward County.csv')
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (67) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
BrowardCounty.rename(columns = {
    'host_name':'Host Name',
    'neighbourhood_cleansed': 'Neighbourhood',
    'latitude': 'Latitude',
    'longitude': 'Longitude',
    'property_type': 'Property Type',
    'room_type': 'Room Type',
    'price': 'Price',
    'minimum_nights': 'Minimum Nights',
    'availability_365': 'Availability 365',
    'review_scores_rating': 'Reviews Scores Rating'}, inplace = True)
BrowardCounty.head()
# Out:
#        id                          listing_url       scrape_id last_scraped  \
# 0   57818   https://www.airbnb.com/rooms/57818  20210223032208   2021-02-23
# 1   69824   https://www.airbnb.com/rooms/69824  20210223032208   2021-02-24
# 2   83449   https://www.airbnb.com/rooms/83449  20210223032208   2021-02-25
# 3  105411  https://www.airbnb.com/rooms/105411  20210223032208   2021-02-25
# 4  129061  https://www.airbnb.com/rooms/129061  20210223032208   2021-02-24
#
#                                   name  \
# 0    Private house close to the beach!
# 1            2 bd/2ba Oceanfront Condo
# 2        MARY POP APTS 2/1 APT SLEEP 5
# 3                 House in the Ranches
# 4  MIAMI - LUXURY APARTMENT OVER BEACH
#
#                                          description  \
# 0  Beautifully private duplex that allows you to ...
# 1  <b>The space</b><br />Beautiful and meticulous...
# 2  MARY POP APARTMENTS 1&2 BEDROOM SUITES ACCOMMO...
# ...

# %%
BrowardCounty["City"] = "Broward County,FL"

# %%
BrowardCounty = BrowardCounty[['City','Host Name','Neighbourhood','Latitude','Longitude','Property Type','Room Type','Price','Minimum Nights','Availability 365','Reviews Scores Rating']]
BrowardCounty.head()
# Out:
#                 City                  Host Name      Neighbourhood  Latitude  \
# 0  Broward County,FL                     VonJon          Hollywood  26.01670
# 1  Broward County,FL                      Tracy   Hallandale Beach  25.97840
# 2  Broward County,FL  Jon,  Mary Pop Apartments        Dania Beach  26.03392
# 3  Broward County,FL                      Sonia  Southwest Ranches  26.04678
# 4  Broward County,FL                     Bianca          Hollywood  25.99332
#
#    Longitude     Property Type        Room Type    Price  Minimum Nights  \
# 0  -80.12437      Entire house  Entire home/apt  $125.00               2
# 1  -80.12028  Entire apartment  Entire home/apt  $140.00              30
# 2  -80.14201  Entire apartment  Entire home/apt  $125.00               7
# 3  -80.36809  Entire apartment  Entire home/apt  $235.00               4
# 4  -80.11887  Entire apartment  Entire home/apt  $250.00              20
#
#    Availability 365  Reviews Scores Rating
# ...

# %%
Cambridge = pd.read_csv('../Resources/Cambridge.csv')

# %%
Cambridge.rename(columns = {
    'host_name':'Host Name',
    'neighbourhood_cleansed': 'Neighbourhood',
    'latitude': 'Latitude',
    'longitude': 'Longitude',
    'property_type': 'Property Type',
    'room_type': 'Room Type',
    'price': 'Price',
    'minimum_nights': 'Minimum Nights',
    'availability_365': 'Availability 365',
    'review_scores_rating': 'Reviews Scores Rating'}, inplace = True)
Cambridge.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0   8521   https://www.airbnb.com/rooms/8521  20210225210417   2021-02-27
# 1  11169  https://www.airbnb.com/rooms/11169  20210225210417   2021-02-26
# 2  11945  https://www.airbnb.com/rooms/11945  20210225210417   2021-02-26
# 3  19581  https://www.airbnb.com/rooms/19581  20210225210417   2021-02-26
# 4  22006  https://www.airbnb.com/rooms/22006  20210225210417   2021-02-26
#
#                                                name  \
# 0  SunsplashedSerenity walk to Harvard & Fresh Pond
# 1   Lovely Studio Room: Thu-Mons, Near Universities
# 2                  Near Harvard: Safe & Lovely Room
# 3                          Furnished suite, Windsor
# 4                  B & B near Harvard's Quad Houses
#
#                                          description  \
# 0  An elegant, sun-splashed, 2 bedroom (+2offices...
# 1  Large sunny room which comfortably fits a coup...
# ...

# %%
Cambridge["City"] = "Cambridge,MA"

# %%
Cambridge = Cambridge[['City','Host Name','Neighbourhood','Latitude','Longitude','Property Type','Room Type','Price','Minimum Nights','Availability 365','Reviews Scores Rating']]
Cambridge.head()
# Out:
#            City       Host Name      Neighbourhood  Latitude  Longitude  \
# 0  Cambridge,MA           Janet     West Cambridge  42.38329  -71.13617
# 1  Cambridge,MA            Judy    North Cambridge  42.39469  -71.13223
# 2  Cambridge,MA            Judy    North Cambridge  42.39454  -71.13431
# 3  Cambridge,MA  Marc And Patty           The Port  42.36276  -71.09765
# 4  Cambridge,MA            Blue  Neighborhood Nine  42.38670  -71.12387
#
#                        Property Type        Room Type    Price  \
# 0                   Entire apartment  Entire home/apt  $150.00
# 1              Private room in house     Private room  $112.00
# 2        Private room in condominium     Private room   $82.00
# 3  Private room in bed and breakfast     Private room   $98.00
# 4  Private room in bed and breakfast     Private room  $110.00
#
#    Minimum Nights  Availability 365  Reviews Scores Rating
# 0               2                57                   94.0
# ...

# %%
Chicago = pd.read_csv('../Resources/Chicago.csv')

# %%
Chicago.rename(columns = {
    'host_name':'Host Name',
    'neighbourhood_cleansed': 'Neighbourhood',
    'latitude': 'Latitude',
    'longitude': 'Longitude',
    'property_type': 'Property Type',
    'room_type': 'Room Type',
    'price': 'Price',
    'minimum_nights': 'Minimum Nights',
    'availability_365': 'Availability 365',
    'review_scores_rating': 'Reviews Scores Rating'}, inplace = True)
Chicago.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0   2384   https://www.airbnb.com/rooms/2384  20210217171619   2021-02-19
# 1   4505   https://www.airbnb.com/rooms/4505  20210217171619   2021-02-19
# 2   7126   https://www.airbnb.com/rooms/7126  20210217171619   2021-02-19
# 3   9811   https://www.airbnb.com/rooms/9811  20210217171619   2021-02-19
# 4  10945  https://www.airbnb.com/rooms/10945  20210217171619   2021-02-19
#
#                                                 name  \
# 0  Hyde Park - Walk to UChicago, 10 min to McCormick
# 1  394 Great Reviews. 127 y/o House. 40 yds to tr...
# 2                Tiny Studio Apartment 94 Walk Score
# 3                      Barbara's Hideaway - Old Town
# 4                              The Biddle House (#1)
#
#                                          description  \
# 0  Visiting The University of Chicago or attendin...
# 1  We have been closed for quite a while and will...
# ...

# %%
Chicago["City"] = "Chicago,IL"

# %%
Chicago = Chicago[['City','Host Name','Neighbourhood','Latitude','Longitude','Property Type','Room Type','Price','Minimum Nights','Availability 365','Reviews Scores Rating']]
Chicago.head()
# Out:
#          City         Host Name   Neighbourhood  Latitude  Longitude  \
# 0  Chicago,IL           Rebecca       Hyde Park  41.78790  -87.58780
# 1  Chicago,IL  Craig & Kathleen  South Lawndale  41.85495  -87.69696
# 2  Chicago,IL             Sarah       West Town  41.90289  -87.68182
# 3  Chicago,IL       At Home Inn    Lincoln Park  41.91769  -87.63788
# 4  Chicago,IL       At Home Inn    Lincoln Park  41.91183  -87.64000
#
#                  Property Type        Room Type    Price  Minimum Nights  \
# 0  Private room in condominium     Private room   $65.00               2
# 1             Entire apartment  Entire home/apt  $117.00               2
# 2             Entire apartment  Entire home/apt   $70.00               2
# 3             Entire apartment  Entire home/apt   $95.00               4
# 4             Entire apartment  Entire home/apt  $125.00               4
#
#    Availability 365  Reviews Scores Rating
# 0               355                  100.0
# ...

# %%
ClarkCounty = pd.read_csv('../Resources/Clark County.csv')

# %%
ClarkCounty.rename(columns = {
    'host_name':'Host Name',
    'neighbourhood_cleansed': 'Neighbourhood',
    'latitude': 'Latitude',
    'longitude': 'Longitude',
    'property_type': 'Property Type',
    'room_type': 'Room Type',
    'price': 'Price',
    'minimum_nights': 'Minimum Nights',
    'availability_365': 'Availability 365',
    'review_scores_rating': 'Reviews Scores Rating'}, inplace = True)
ClarkCounty.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0  31388  https://www.airbnb.com/rooms/31388  20210220051957   2021-02-21
# 1  41656  https://www.airbnb.com/rooms/41656  20210220051957   2021-02-20
# 2  44495  https://www.airbnb.com/rooms/44495  20210220051957   2021-02-22
# 3  44701  https://www.airbnb.com/rooms/44701  20210220051957   2021-02-21
# 4  61643  https://www.airbnb.com/rooms/61643  20210220051957   2021-02-22
#
#                                                 name  \
# 0                      Las Vegas MGM Signature Condo
# 1               #TOP Floor 2BR/3BA Penthouse @MGMSig
# 2   Bedroom with private bath in Southwest Las Vegas
# 3  Jan1-8, 2022 for CES, 1 block from Strip, Slee...
# 4                   2BR/2BA Strip View@MGM Signature
#
#                                          description  \
# 0  This place is perfect in all respects: Excelle...
# 1  °º¤ø,¸¸,ø¤º° 38TH Floor º¤ø,¸¸,ø¤º°`°º¤ø<br />...
# ...

# %%
ClarkCounty["City"] = "Clark County,NV"

# %%
ClarkCounty = ClarkCounty[['City','Host Name','Neighbourhood','Latitude','Longitude','Property Type','Room Type','Price','Minimum Nights','Availability 365','Reviews Scores Rating']]
ClarkCounty.head()
# Out:
#               City  Host Name         Neighbourhood  Latitude  Longitude  \
# 0  Clark County,NV        Kim  Unincorporated Areas  36.10520 -115.16777
# 1  Clark County,NV       Paul  Unincorporated Areas  36.10592 -115.16506
# 2  Clark County,NV     Lenore  Unincorporated Areas  36.01160 -115.29714
# 3  Clark County,NV  Christine  Unincorporated Areas  36.11697 -115.16397
# 4  Clark County,NV       Paul  Unincorporated Areas  36.10641 -115.16691
#
#            Property Type        Room Type    Price  Minimum Nights  \
# 0  Private room in house     Private room  $240.00               2
# 1       Entire apartment  Entire home/apt  $294.00               3
# 2  Private room in house     Private room   $35.00               2
# 3       Entire apartment  Entire home/apt  $350.00               7
# 4       Entire apartment  Entire home/apt  $226.00               3
#
#    Availability 365  Reviews Scores Rating
# 0               362                   97.0
# ...

# %%
Columbus = pd.read_csv('../Resources/Columbus.csv')

# %%
Columbus.rename(columns = {
    'host_name':'Host Name',
    'neighbourhood_cleansed': 'Neighbourhood',
    'latitude': 'Latitude',
    'longitude': 'Longitude',
    'property_type': 'Property Type',
    'room_type': 'Room Type',
    'price': 'Price',
    'minimum_nights': 'Minimum Nights',
    'availability_365': 'Availability 365',
    'review_scores_rating': 'Reviews Scores Rating'}, inplace = True)
Columbus.head()
# Out:
#        id                          listing_url       scrape_id last_scraped  \
# 0   90676   https://www.airbnb.com/rooms/90676  20210223032229   2021-02-23
# 1  543140  https://www.airbnb.com/rooms/543140  20210223032229   2021-02-23
# 2  591101  https://www.airbnb.com/rooms/591101  20210223032229   2021-02-23
# 3  681145  https://www.airbnb.com/rooms/681145  20210223032229   2021-02-23
# 4  923248  https://www.airbnb.com/rooms/923248  20210223032229   2021-02-27
#
#                                                name  \
# 0                  Short North - Italianate Cottage
# 1                Private queen bedroom 1 - N.Campus
# 2   The Bellows' Studio Loft  (3rd floor apartment)
# 3  2 bed/Safe/Quiet/Clean/Ample Parking/OSU/Laundry
# 4  1 Single Bed in a Shared Coed Dorm at the Hostel
#
#                                          description  \
# 0  Just steps from High Street and all the action...
# 1  Private, second-floor queen bed with desk, ple...
# ...

# %%
Columbus["City"] = "Columbus,OH"

# %%
Columbus = ClarkCounty[['City','Host Name','Neighbourhood','Latitude','Longitude','Property Type','Room Type','Price','Minimum Nights','Availability 365','Reviews Scores Rating']]
Columbus.head()
# Out:
#               City  Host Name         Neighbourhood  Latitude  Longitude  \
# 0  Clark County,NV        Kim  Unincorporated Areas  36.10520 -115.16777
# 1  Clark County,NV       Paul  Unincorporated Areas  36.10592 -115.16506
# 2  Clark County,NV     Lenore  Unincorporated Areas  36.01160 -115.29714
# 3  Clark County,NV  Christine  Unincorporated Areas  36.11697 -115.16397
# 4  Clark County,NV       Paul  Unincorporated Areas  36.10641 -115.16691
#
#            Property Type        Room Type    Price  Minimum Nights  \
# 0  Private room in house     Private room  $240.00               2
# 1       Entire apartment  Entire home/apt  $294.00               3
# 2  Private room in house     Private room   $35.00               2
# 3       Entire apartment  Entire home/apt  $350.00               7
# 4       Entire apartment  Entire home/apt  $226.00               3
#
#    Availability 365  Reviews Scores Rating
# 0               362                   97.0
# ...

# %%
Dallas = pd.read_csv('../Resources/Dallas.csv')

# %%
Dallas.rename(columns = {
    'host_name':'Host Name',
    'neighbourhood_cleansed': 'Neighbourhood',
    'latitude': 'Latitude',
    'longitude': 'Longitude',
    'property_type': 'Property Type',
    'room_type': 'Room Type',
    'price': 'Price',
    'minimum_nights': 'Minimum Nights',
    'availability_365': 'Availability 365',
    'review_scores_rating': 'Reviews Scores Rating'}, inplace = True)
Dallas.head()
# Out:
#        id                          listing_url       scrape_id last_scraped  \
# 0   61878   https://www.airbnb.com/rooms/61878  20210221235909   2021-02-22
# 1  247794  https://www.airbnb.com/rooms/247794  20210221235909   2021-02-22
# 2  270936  https://www.airbnb.com/rooms/270936  20210221235909   2021-02-22
# 3  776810  https://www.airbnb.com/rooms/776810  20210221235909   2021-02-22
# 4  795703  https://www.airbnb.com/rooms/795703  20210221235909   2021-02-22
#
#                                                name  \
# 0                     MODERN LIVING AND FURNISHINGS
# 1                      Private Room in North Dallas
# 2  1BR 1BA Oaklawn Condo Close to Downtown & Uptown
# 3                             Goldies Bohemian Loft
# 4          Amazing location walk to Downtown Dallas
#
#                                          description  \
# 0  Close to downtown and Uptown.  Fast and conven...
# 1  Visiting Dallas?  Come and stay with us in a l...
# ...

# %%
Dallas["City"] = "Dallas,TX"

# %%
Dallas = Dallas[['City','Host Name','Neighbourhood','Latitude','Longitude','Property Type','Room Type','Price','Minimum Nights','Availability 365','Reviews Scores Rating']]
Dallas.head()
# Out:
#         City  Host Name Neighbourhood  Latitude  Longitude  \
# 0  Dallas,TX       Rita    District 2  32.81829  -96.81893
# 1  Dallas,TX  J. Yuriko   District 10  32.88846  -96.71016
# 2  Dallas,TX     Robert   District 14  32.81442  -96.81548
# 3  Dallas,TX       Eric    District 2  32.81304  -96.81540
# 4  Dallas,TX   Michelle   District 14  32.80158  -96.81117
#
#            Property Type        Room Type    Price  Minimum Nights  \
# 0     Entire condominium  Entire home/apt   $71.00              30
# 1  Private room in house     Private room   $57.00               2
# 2     Entire condominium  Entire home/apt   $75.00              30
# 3            Entire loft  Entire home/apt   $75.00               5
# 4     Entire condominium  Entire home/apt  $169.00              30
#
#    Availability 365  Reviews Scores Rating
# 0               324                   95.0
# 1               327                    NaN
# 2                68                   99.0
# ...

# %%
Denver = pd.read_csv('../Resources/Denver.csv')

# %%
Denver.rename(columns = {
    'host_name':'Host Name',
    'neighbourhood_cleansed': 'Neighbourhood',
    'latitude': 'Latitude',
    'longitude': 'Longitude',
    'property_type': 'Property Type',
    'room_type': 'Room Type',
    'price': 'Price',
    'minimum_nights': 'Minimum Nights',
    'availability_365': 'Availability 365',
    'review_scores_rating': 'Reviews Scores Rating'}, inplace = True)
Denver.head()
# Out:
#     id                       listing_url       scrape_id last_scraped  \
# 0  177  https://www.airbnb.com/rooms/177  20210226174216   2021-02-28
# 1  360  https://www.airbnb.com/rooms/360  20210226174216   2021-02-28
# 2  364  https://www.airbnb.com/rooms/364  20210226174216   2021-02-27
# 3  590  https://www.airbnb.com/rooms/590  20210226174216   2021-02-28
# 4  592  https://www.airbnb.com/rooms/592  20210226174216   2021-02-28
#
#                                                 name  \
# 0   Tiny Home in the Heart of the City- ECO FRIENDLY
# 1  Sit in the Peaceful Garden of the Chickadee Co...
# 2                Lodo / RiNo LOFT  via airport train
# 3                  Comfortable  - and a great value!
# 4                                            private
#
#                                          description  \
# 0  160 sq ft + 80 sq ft loft for sleeping, Sleeps...
# 1  Enjoy the famous Colorado weather and unplug i...
# 2  Modern 1,000 square foot loft in the heart of ...
# ...

# %%
Denver["City"] = "Denver,CO"

# %%
Denver = Denver[['City','Host Name','Neighbourhood','Latitude','Longitude','Property Type','Room Type','Price','Minimum Nights','Availability 365','Reviews Scores Rating']]
Denver.head()
# Out:
#         City            Host Name             Neighbourhood  Latitude  \
# 0  Denver,CO                  Joe  Washington Virginia Vale  39.69753
# 1  Denver,CO  Jennifer & Giovanni                  Highland  39.76703
# 2  Denver,CO                Jason               Five Points  39.76551
# 3  Denver,CO                 Jill           North Park Hill  39.75361
# 4  Denver,CO                 Jill           North Park Hill  39.75438
#
#    Longitude          Property Type        Room Type    Price  Minimum Nights  \
# 0 -104.92588      Entire guesthouse  Entire home/apt   $68.00               1
# 1 -105.00256      Entire guesthouse  Entire home/apt  $134.00               3
# 2 -104.97902            Entire loft  Entire home/apt  $179.00             185
# 3 -104.91237  Private room in house     Private room   $54.00               1
# 4 -104.91156  Private room in house     Private room   $45.00              29
#
#    Availability 365  Reviews Scores Rating
# ...

# %%
Hawaii = pd.read_csv('../Resources/Hawaii.csv')

# %%
Hawaii.rename(columns = {
    'host_name':'Host Name',
    'neighbourhood_cleansed': 'Neighbourhood',
    'latitude': 'Latitude',
    'longitude': 'Longitude',
    'property_type': 'Property Type',
    'room_type': 'Room Type',
    'price': 'Price',
    'minimum_nights': 'Minimum Nights',
    'availability_365': 'Availability 365',
    'review_scores_rating': 'Reviews Scores Rating'}, inplace = True)
Hawaii.head()
# Out:
#      id                        listing_url       scrape_id last_scraped  \
# 0  5269  https://www.airbnb.com/rooms/5269  20210210181214   2021-02-14
# 1  5387  https://www.airbnb.com/rooms/5387  20210210181214   2021-02-14
# 2  5389  https://www.airbnb.com/rooms/5389  20210210181214   2021-02-13
# 3  5434  https://www.airbnb.com/rooms/5434  20210210181214   2021-02-13
# 4  7896  https://www.airbnb.com/rooms/7896  20210210181214   2021-02-13
#
#                                                name  \
# 0         Upcountry Hospitality in the 'Auwai Suite
# 1               Hale Koa Studio & 1 Bedroom Units!!
# 2                                     Keauhou Villa
# 3  Kauai  Ocean View 3 Story Tiki Tower Princeville
# 4        Beachfront Maui Sunset Condo, Kihei/Wailea
#
#                                          description  \
# 0  The 'Auwai Suite is a lovely, self-contained a...
# 1  This Wonderful Spacious Studio apt/flat is in ...
# ...

# %%
Hawaii["City"] = "Hawaii,HI"

# %%
Hawaii = Hawaii[['City','Host Name','Neighbourhood','Latitude','Longitude','Property Type','Room Type','Price','Minimum Nights','Availability 365','Reviews Scores Rating']]
Hawaii.head()
# Out:
#         City  Host Name      Neighbourhood  Latitude  Longitude  \
# 0  Hawaii,HI  Lea & Pat       South Kohala  20.02740 -155.70200
# 1  Hawaii,HI     Edward         South Kona  19.43119 -155.88079
# 2  Hawaii,HI     Edward         North Kona  19.56413 -155.96347
# 3  Hawaii,HI      Ahlea  North Shore Kauai  22.21972 -159.46958
# 4  Hawaii,HI   Caroline       Kihei-Makena  20.75470 -156.45666
#
#         Property Type        Room Type    Price  Minimum Nights  \
# 0    Entire apartment  Entire home/apt  $150.00               3
# 1    Entire apartment  Entire home/apt   $85.00               5
# 2        Entire house  Entire home/apt  $239.00               6
# 3        Entire house  Entire home/apt  $295.00               2
# 4  Entire condominium  Entire home/apt  $212.00               4
#
#    Availability 365  Reviews Scores Rating
# 0               281                   88.0
# 1               272                   93.0
# 2               203                   97.0
# ...

# %%
Jersey = pd.read_csv('../Resources/Jersey City.csv')

# %%
Jersey.rename(columns = {
    'host_name':'Host Name',
    'neighbourhood_cleansed': 'Neighbourhood',
    'latitude': 'Latitude',
    'longitude': 'Longitude',
    'property_type': 'Property Type',
    'room_type': 'Room Type',
    'price': 'Price',
    'minimum_nights': 'Minimum Nights',
    'availability_365': 'Availability 365',
    'review_scores_rating': 'Reviews Scores Rating'}, inplace = True)
Jersey.head()
# Out:
#        id                          listing_url       scrape_id last_scraped  \
# 0   40669   https://www.airbnb.com/rooms/40669  20210221060108   2021-02-23
# 1   63282   https://www.airbnb.com/rooms/63282  20210221060108   2021-02-21
# 2  146144  https://www.airbnb.com/rooms/146144  20210221060108   2021-02-21
# 3  215768  https://www.airbnb.com/rooms/215768  20210221060108   2021-02-23
# 4  269266  https://www.airbnb.com/rooms/269266  20210221060108   2021-02-23
#
#                                            name  \
# 0                          Skyy’s Lounge / Cozy
# 1           2bed/2bath,furnished,doorman, by NY
# 2                                   Shared Room
# 3           Minutes to Manhattan & Jersey Shore
# 4  Modern private 2 bedrooms apt minutes to NYC
#
#                                          description  \
# 0  <b>The space</b><br />Skyy’s Lounge ....Everyt...
# 1  <b>The space</b><br />MINIMUM STAY OF 5 MONTHS...
# ...

# %%
Jersey["City"] = "Jersey City,NJ"

# %%
Jersey = Jersey[['City','Host Name','Neighbourhood','Latitude','Longitude','Property Type','Room Type','Price','Minimum Nights','Availability 365','Reviews Scores Rating']]
Jersey.head()
# Out:
#              City  Host Name                                Neighbourhood  \
# 0  Jersey City,NJ       Skyy      Ward C (councilmember Richard Boggiano)
# 1  Jersey City,NJ        Gil       Ward B (councilmember Mira Prinz-Arey)
# 2  Jersey City,NJ   Patricia         Ward E (councilmember James Solomon)
# 3  Jersey City,NJ  Charlaine  Ward F (councilmember Jermaine D. Robinson)
# 4  Jersey City,NJ      Magda  Ward F (councilmember Jermaine D. Robinson)
#
#    Latitude  Longitude                Property Type        Room Type  \
# 0  40.73742  -74.05255  Private room in condominium     Private room
# 1  40.72813  -74.07037             Entire apartment  Entire home/apt
# 2  40.71077  -74.03833     Shared room in apartment      Shared room
# 3  40.71663  -74.05799                 Entire house  Entire home/apt
# 4  40.71266  -74.06329             Entire apartment  Entire home/apt
#
#        Price  Minimum Nights  Availability 365  Reviews Scores Rating
# ...

# %%
LA = pd.read_csv('../Resources/Los Angeles.csv')

# %%
LA.rename(columns = {
    'host_name':'Host Name',
    'neighbourhood_cleansed': 'Neighbourhood',
    'latitude': 'Latitude',
    'longitude': 'Longitude',
    'property_type': 'Property Type',
    'room_type': 'Room Type',
    'price': 'Price',
    'minimum_nights': 'Minimum Nights',
    'availability_365': 'Availability 365',
    'review_scores_rating': 'Reviews Scores Rating'}, inplace = True)
LA.head()
# Out:
#      id                        listing_url       scrape_id last_scraped  \
# 0   109   https://www.airbnb.com/rooms/109  20210207181900   2021-02-09
# 1  2708  https://www.airbnb.com/rooms/2708  20210207181900   2021-02-09
# 2  2732  https://www.airbnb.com/rooms/2732  20210207181900   2021-02-09
# 3  2864  https://www.airbnb.com/rooms/2864  20210207181900   2021-02-09
# 4  5728  https://www.airbnb.com/rooms/5728  20210207181900   2021-02-10
#
#                                                 name  \
# 0  Amazing bright elegant condo park front *UPGRA...
# 1  Runyon Canyon  | Beau Furn Mir Mini-Suite Fire...
# 2                              Zen Life at the Beach
# 3             * Beautiful Master Suite/Jacuzzi Tub/*
# 4    Tiny Home in Artistic Oasis near Venice and LAX
#
#                                          description  \
# 0  *** Unit upgraded with new bamboo flooring, br...
# 1  Run Runyon Canyon<br /><br />Beautifully Furni...
# ...

# %%
LA["City"] = "Los Angeles,CA"

# %%
LA = LA[['City','Host Name','Neighbourhood','Latitude','Longitude','Property Type','Room Type','Price','Minimum Nights','Availability 365','Reviews Scores Rating']]
LA.head()
# Out:
#              City       Host Name Neighbourhood  Latitude  Longitude  \
# 0  Los Angeles,CA           Paolo   Culver City  33.98209 -118.38494
# 1  Los Angeles,CA           Chas.     Hollywood  34.09768 -118.34602
# 2  Los Angeles,CA  Yoga Priestess  Santa Monica  34.00475 -118.48127
# 3  Los Angeles,CA       Bernadine    Bellflower  33.87619 -118.11397
# 4  Los Angeles,CA           Sanni       Del Rey  33.98750 -118.43200
#
#                 Property Type        Room Type    Price  Minimum Nights  \
# 0          Entire condominium  Entire home/apt  $115.00              30
# 1   Private room in apartment     Private room   $71.00              30
# 2   Private room in apartment     Private room  $155.00               1
# 3            Entire apartment  Entire home/apt   $50.00              30
# 4  Private room in tiny house     Private room   $42.00              30
#
#    Availability 365  Reviews Scores Rating
# 0                 0                   80.0
# ...

# %%
Nashville = pd.read_csv('../Resources/Nashville.csv')

# %%
Nashville.rename(columns = {
    'host_name':'Host Name',
    'neighbourhood_cleansed': 'Neighbourhood',
    'latitude': 'Latitude',
    'longitude': 'Longitude',
    'property_type': 'Property Type',
    'room_type': 'Room Type',
    'price': 'Price',
    'minimum_nights': 'Minimum Nights',
    'availability_365': 'Availability 365',
    'review_scores_rating': 'Reviews Scores Rating'}, inplace = True)
Nashville.head()
# Out:
#        id                          listing_url       scrape_id last_scraped  \
# 0    6422    https://www.airbnb.com/rooms/6422  20210219004252   2021-02-20
# 1   25613   https://www.airbnb.com/rooms/25613  20210219004252   2021-02-20
# 2  136015  https://www.airbnb.com/rooms/136015  20210219004252   2021-02-20
# 3  258817  https://www.airbnb.com/rooms/258817  20210219004252   2021-02-20
# 4  289242  https://www.airbnb.com/rooms/289242  20210219004252   2021-02-20
#
#                                              name  \
# 0                                 Nashville Charm
# 1  Room in Historic East Nashville Craftsman Home
# 2               Apart. on the Ridge near Opryland
# 3         ButterflyRoom-private bath- open Jan 26
# 4     MorningstarHouse, monthly room- open Feb  2
#
#                                          description  \
# 0  30 day or more rental during COVID. Show COVID...
# 1  Serve up some sweet sounds on the piano and wi...
# ...

# %%
Nashville["City"] = "Nashville,TN"

# %%
Nashville = Nashville[['City','Host Name','Neighbourhood','Latitude','Longitude','Property Type','Room Type','Price','Minimum Nights','Availability 365','Reviews Scores Rating']]
Nashville.head()
# Out:
#            City       Host Name Neighbourhood  Latitude  Longitude  \
# 0  Nashville,TN         Michele    District 6  36.17315  -86.73581
# 1  Nashville,TN            Nell    District 6  36.17826  -86.74162
# 2  Nashville,TN  Dave And Peggy   District 15  36.19464  -86.67195
# 3  Nashville,TN           Diana   District 12  36.16249  -86.58988
# 4  Nashville,TN           Diana   District 12  36.16102  -86.59207
#
#            Property Type        Room Type    Price  Minimum Nights  \
# 0  Private room in house     Private room   $40.00              30
# 1  Private room in house     Private room   $75.00               2
# 2       Entire apartment  Entire home/apt  $103.00              30
# 3  Private room in house     Private room   $27.00              30
# 4  Private room in house     Private room   $24.00              30
#
#    Availability 365  Reviews Scores Rating
# 0               267                   99.0
# 1                63                   97.0
# ...

# %%
NewOrleans = pd.read_csv('../Resources/New Orleans.csv')

# %%
NewOrleans.rename(columns = {
    'host_name':'Host Name',
    'neighbourhood_cleansed': 'Neighbourhood',
    'latitude': 'Latitude',
    'longitude': 'Longitude',
    'property_type': 'Property Type',
    'room_type': 'Room Type',
    'price': 'Price',
    'minimum_nights': 'Minimum Nights',
    'availability_365': 'Availability 365',
    'review_scores_rating': 'Reviews Scores Rating'}, inplace = True)
NewOrleans.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0  10291  https://www.airbnb.com/rooms/10291  20210208155348   2021-02-10
# 1  19091  https://www.airbnb.com/rooms/19091  20210208155348   2021-02-09
# 2  26834  https://www.airbnb.com/rooms/26834  20210208155348   2021-02-09
# 3  71624  https://www.airbnb.com/rooms/71624  20210208155348   2021-02-09
# 4  74498  https://www.airbnb.com/rooms/74498  20210208155348   2021-02-09
#
#                                   name  \
# 0        Spacious Cottage in Mid-City!
# 1       Fully Furnished Cozy Apartment
# 2     Maison Mandeville in the Marigny
# 3   Ravenwood Manor (Historic Bywater)
# 4  Maison Marais 1: Large Local Living
#
#                                          description  \
# 0  <b>The space</b><br />Spacious house located i...
# 1  CITY OF NEW ORLEANS STR LICENSE PERMIT NUMBER:...
# 2  <b>The space</b><br />Charming shotgun apartme...
# 3  You are in for a very unique stay in a neighbo...
# ...

# %%
NewOrleans["City"] = "New Orleans,LA"

# %%
NewOrleans = NewOrleans[['City','Host Name','Neighbourhood','Latitude','Longitude','Property Type','Room Type','Price','Minimum Nights','Availability 365','Reviews Scores Rating']]
NewOrleans.head()
# Out:
#              City Host Name Neighbourhood  Latitude  Longitude  \
# 0  New Orleans,LA      Jill       Navarre  29.98666  -90.10928
# 1  New Orleans,LA      John    Hollygrove  29.96317  -90.11888
# 2  New Orleans,LA    Rachel       Marigny  29.96557  -90.05531
# 3  New Orleans,LA     Susan       Bywater  29.96335  -90.04245
# 4  New Orleans,LA   Georgia       Marigny  29.96860  -90.05251
#
#       Property Type        Room Type    Price  Minimum Nights  \
# 0    Entire cottage  Entire home/apt  $264.00               2
# 1  Entire apartment  Entire home/apt   $61.00               1
# 2      Entire house  Entire home/apt  $106.00               3
# 3  Entire apartment  Entire home/apt  $130.00               3
# 4  Entire apartment  Entire home/apt  $158.00               3
#
#    Availability 365  Reviews Scores Rating
# 0                 1                   97.0
# 1               299                   98.0
# 2                51                   99.0
# ...

# %%
PartA = pd.concat([Asheville, Austin ,Boston, BrowardCounty, Cambridge, Chicago, ClarkCounty, Columbus, Dallas, Denver, Hawaii, Jersey, LA, Nashville, NewOrleans])
PartA.head(20)
# Out:
#            City   Host Name Neighbourhood  Latitude  Longitude  \
# 0   Ashville,NC        Lisa         28801  35.60670  -82.55563
# 1   Ashville,NC     BonPaul         28806  35.57864  -82.59578
# 2   Ashville,NC     BonPaul         28806  35.57864  -82.59578
# 3   Ashville,NC     BonPaul         28806  35.57864  -82.59578
# 4   Ashville,NC   Elizabeth         28801  35.61442  -82.54127
# 5   Ashville,NC       Kevin         28804  35.61856  -82.55276
# 6   Ashville,NC     Susanne         28806  35.58345  -82.59713
# 7   Ashville,NC       Annie         28805  35.59635  -82.50655
# 8   Ashville,NC       Julia         28805  35.61929  -82.48114
# 9   Ashville,NC      Debbie         28803  35.55537  -82.53539
# 10  Ashville,NC       Gayle         28804  35.64453  -82.52586
# 11  Ashville,NC       Milan         28803  35.49111  -82.48438
# 12  Ashville,NC       Heidi         28801  35.60182  -82.56174
# 13  Ashville,NC     Camille         28803  35.56118  -82.57784
# ...

# %%
PartA.to_csv('USAirbnb.csv')
