# %% [markdown]
# #Decision Tree Test - exploring data

# %%
#Initial test: Creating a decision tree. Decision tree just uses max and min temp as x values (for now), to predict a city

# %%
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
import pandas as pd
import os

# %%
df = pd.read_csv(os.path.join("Temperature_Dataset1.csv"))

# %%
df
# Out:
#                  City        Date  Temperature  temp_max  temp_min  humidity  \
# 0        Montreal, QC  2020-01-01          0.2       1.1      -0.8     87.84
# 1        Montreal, QC  2020-01-02          0.9       2.6      -1.0     78.70
# 2        Montreal, QC  2020-01-03          4.8       5.8       2.8     74.88
# 3        Montreal, QC  2020-01-04          0.5       3.2      -1.9     78.79
# 4        Montreal, QC  2020-01-05         -5.3      -1.8      -9.9     69.09
# ...               ...         ...          ...       ...       ...       ...
# 12805  Washington, DC  2020-12-27          1.0       5.6      -3.6     60.64
# 12806  Washington, DC  2020-12-28          6.1      11.3       1.6     64.95
# 12807  Washington, DC  2020-12-29          3.8       6.2       0.3     46.13
# 12808  Washington, DC  2020-12-30          3.8       7.8      -0.3     52.82
# 12809  Washington, DC  2020-12-31          8.1      12.8       4.4     70.87
#
#        precip  snow  windspeed        conditions
# 0        5.71  0.00        7.9              Rain
# 1        0.00  0.00        7.7             Clear
# 2        0.00  0.00        7.6             Clear
# 3        2.27  0.00       11.2              Rain
# 4        0.76  3.88       13.1              Snow
# ...       ...   ...        ...               ...
# 12805    0.00  0.00       17.2  Partially cloudy
# 12806    0.00  0.00       19.5  Partially cloudy
# 12807    0.00  0.00       32.7  Partially cloudy
# 12808    0.00  0.00       29.0          Overcast
# 12809    0.00  0.00       28.8          Overcast
#
# [12810 rows x 10 columns]

# %%
y = df["City"]

# %%
X= df[["temp_max", "temp_min"]]

# %%
X.shape, y.shape
# Out:
# ((12810, 2), (12810,))

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model = DecisionTreeClassifier()
model.fit(X_train, y_train)
model.score(X_test, y_test)
# Out:
# 0.10739931314392757

# %%
predictions = model.predict(X_test)

# %%
predictions
# Out:
# array(['New Brunswick, NB', 'Washington, DC', 'New Brunswick, NB', ...,
#        'Los Angeles, CA', 'San Francisco, CA', 'Cambridge, MA'],
#       dtype=object)

# %%
# Out:
# 772                  Ottawa, ON
# 10196             San Diego, CA
# 385           New Brunswick, NB
# 4269                Chicago, IL
# 8                  Montreal, QC
#                   ...
# 10423         San Francisco, CA
# 11170    Santa Clara County, CA
# 957                  Ottawa, ON
# 2110              Vancouver, BC
# 8544          Pacific Grove, CA
# Name: City, Length: 3203, dtype: object

# %%
data_point = [[-2, 8]]

model.predict(data_point)
# Out:
# array(['Vancouver, BC'], dtype=object)

# %% [markdown]
# # Let's reduce dataset to Dec. 20 - Dec. 29 to see if model score increases (Only Max. and Min. temp)

# %%
# 1.We find the variable types of each column - We need to change date to a date-time variable
df.dtypes
# Out:
# City                   object
# Date                   object
# Temperature           float64
# temp_max              float64
# temp_min              float64
# humidity              float64
# precip                float64
# snow                  float64
# windspeed             float64
# conditions             object
# Time_stamp     datetime64[ns]
# dtype: object

# %%
# We create a column with date as a datetime
df['Time_stamp'] = pd.to_datetime(df['Date'].str.strip(), format='%Y/%m/%d')

# %%
#User would imput this value
df['day'] = df.Time_stamp.dt.day
df['month'] = df.Time_stamp.dt.month
df['year'] = df.Time_stamp.dt.year

# %%
df
# Out:
#                  City        Date  Temperature  temp_max  temp_min  humidity  \
# 0        Montreal, QC  2020-01-01          0.2       1.1      -0.8     87.84
# 1        Montreal, QC  2020-01-02          0.9       2.6      -1.0     78.70
# 2        Montreal, QC  2020-01-03          4.8       5.8       2.8     74.88
# 3        Montreal, QC  2020-01-04          0.5       3.2      -1.9     78.79
# 4        Montreal, QC  2020-01-05         -5.3      -1.8      -9.9     69.09
# ...               ...         ...          ...       ...       ...       ...
# 12805  Washington, DC  2020-12-27          1.0       5.6      -3.6     60.64
# 12806  Washington, DC  2020-12-28          6.1      11.3       1.6     64.95
# 12807  Washington, DC  2020-12-29          3.8       6.2       0.3     46.13
# 12808  Washington, DC  2020-12-30          3.8       7.8      -0.3     52.82
# 12809  Washington, DC  2020-12-31          8.1      12.8       4.4     70.87
#
#        precip  snow  windspeed        conditions Time_stamp  day  month  year
# 0        5.71  0.00        7.9              Rain 2020-01-01    1      1  2020
# 1        0.00  0.00        7.7             Clear 2020-01-02    2      1  2020
# 2        0.00  0.00        7.6             Clear 2020-01-03    3      1  2020
# 3        2.27  0.00       11.2              Rain 2020-01-04    4      1  2020
# 4        0.76  3.88       13.1              Snow 2020-01-05    5      1  2020
# ...       ...   ...        ...               ...        ...  ...    ...   ...
# 12805    0.00  0.00       17.2  Partially cloudy 2020-12-27   27     12  2020
# 12806    0.00  0.00       19.5  Partially cloudy 2020-12-28   28     12  2020
# 12807    0.00  0.00       32.7  Partially cloudy 2020-12-29   29     12  2020
# 12808    0.00  0.00       29.0          Overcast 2020-12-30   30     12  2020
# 12809    0.00  0.00       28.8          Overcast 2020-12-31   31     12  2020
#
# [12810 rows x 14 columns]

# %%
#Answers to be provided by user
Month = 12
Start_Day = 21
End_Day = 31

# %%
df_new = df[(df.month == Month) & (df.day >= Start_Day) & (df.day <= End_Day)]

# %%
df_new
# Out:
#                  City        Date  Temperature  temp_max  temp_min  humidity  \
# 355      Montreal, QC  2020-12-21          1.3       3.1       0.0     86.73
# 356      Montreal, QC  2020-12-22          0.2       1.9      -5.6     87.84
# 357      Montreal, QC  2020-12-23         -5.3       1.0      -9.2     72.31
# 358      Montreal, QC  2020-12-24          5.4       8.7       1.3     79.80
# 359      Montreal, QC  2020-12-25          7.6      13.4       0.6     90.44
# ...               ...         ...          ...       ...       ...       ...
# 12805  Washington, DC  2020-12-27          1.0       5.6      -3.6     60.64
# 12806  Washington, DC  2020-12-28          6.1      11.3       1.6     64.95
# 12807  Washington, DC  2020-12-29          3.8       6.2       0.3     46.13
# 12808  Washington, DC  2020-12-30          3.8       7.8      -0.3     52.82
# 12809  Washington, DC  2020-12-31          8.1      12.8       4.4     70.87
#
#        precip  snow  windspeed        conditions Time_stamp  day  month  year
# 355      0.96  4.00        7.7              Snow 2020-12-21   21     12  2020
# 356      4.70  0.00        9.6              Rain 2020-12-22   22     12  2020
# 357      2.99  0.00       11.3              Snow 2020-12-23   23     12  2020
# 358     19.43  1.92       11.6              Snow 2020-12-24   24     12  2020
# 359     34.46  0.63       11.5              Snow 2020-12-25   25     12  2020
# ...       ...   ...        ...               ...        ...  ...    ...   ...
# 12805    0.00  0.00       17.2  Partially cloudy 2020-12-27   27     12  2020
# 12806    0.00  0.00       19.5  Partially cloudy 2020-12-28   28     12  2020
# 12807    0.00  0.00       32.7  Partially cloudy 2020-12-29   29     12  2020
# 12808    0.00  0.00       29.0          Overcast 2020-12-30   30     12  2020
# 12809    0.00  0.00       28.8          Overcast 2020-12-31   31     12  2020
#
# [385 rows x 14 columns]

# %%
y = df_new3["City"]

# %%
X= df_new3[["temp_max", "temp_min"]]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
model = DecisionTreeClassifier()
model.fit(X_train, y_train)
model.score(X_test, y_test)
# Out:
# 0.28524590163934427

# %%
data_point = [[15, 10]]

model.predict(data_point)
# Out:
# array(['Santa Cruz County, CA'], dtype=object)

# %% [markdown]
# # Let's keep same period of time and add humidity

# %%
y = df_new["City"]

# %%
X= df_new[["temp_max", "temp_min", "humidity"]] #"humidity", "windspeed", "precip", "snow"

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
model = DecisionTreeClassifier()
model.fit(X_train, y_train)
model.score(X_test, y_test)
# Out:
# 0.1958762886597938

# %%
#For humidity, maybe the user inputs very high high, medium or low --> very high 80 , high 65, medium 40, low 20
data_point = [[-5, -10, 80]]

model.predict(data_point)
# Out:
# array(['Asheville, NC'], dtype=object)

# %% [markdown]
# # Neighbors

# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier

# %%
df
# Out:
#                  City        Date  Temperature  temp_max  temp_min  humidity  \
# 0        Montreal, QC  2020-01-01          0.2       1.1      -0.8     87.84
# 1        Montreal, QC  2020-01-02          0.9       2.6      -1.0     78.70
# 2        Montreal, QC  2020-01-03          4.8       5.8       2.8     74.88
# 3        Montreal, QC  2020-01-04          0.5       3.2      -1.9     78.79
# 4        Montreal, QC  2020-01-05         -5.3      -1.8      -9.9     69.09
# ...               ...         ...          ...       ...       ...       ...
# 12805  Washington, DC  2020-12-27          1.0       5.6      -3.6     60.64
# 12806  Washington, DC  2020-12-28          6.1      11.3       1.6     64.95
# 12807  Washington, DC  2020-12-29          3.8       6.2       0.3     46.13
# 12808  Washington, DC  2020-12-30          3.8       7.8      -0.3     52.82
# 12809  Washington, DC  2020-12-31          8.1      12.8       4.4     70.87
#
#        precip  snow  windspeed        conditions Time_stamp  day  month  year
# 0        5.71  0.00        7.9              Rain 2020-01-01    1      1  2020
# 1        0.00  0.00        7.7             Clear 2020-01-02    2      1  2020
# 2        0.00  0.00        7.6             Clear 2020-01-03    3      1  2020
# 3        2.27  0.00       11.2              Rain 2020-01-04    4      1  2020
# 4        0.76  3.88       13.1              Snow 2020-01-05    5      1  2020
# ...       ...   ...        ...               ...        ...  ...    ...   ...
# 12805    0.00  0.00       17.2  Partially cloudy 2020-12-27   27     12  2020
# 12806    0.00  0.00       19.5  Partially cloudy 2020-12-28   28     12  2020
# 12807    0.00  0.00       32.7  Partially cloudy 2020-12-29   29     12  2020
# 12808    0.00  0.00       29.0          Overcast 2020-12-30   30     12  2020
# 12809    0.00  0.00       28.8          Overcast 2020-12-31   31     12  2020
#
# [12810 rows x 14 columns]

# %%
X= df_new3[["temp_max", "temp_min", "humidity", "snow"]]

# %%
y = df_new3["City"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

# %%
X_scaler = StandardScaler().fit(X_train)

# %%
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
model1 = KNeighborsClassifier(n_neighbors=3)
model1.fit(X_train_scaled, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
model1.score(X_test_scaled, y_test)
# Out:
# 0.36721311475409835

# %%
train_score = []
test_score = []
for k in range(1, 20, 2): 
  model = KNeighborsClassifier(n_neighbors=k)
  model.fit(X_train_scaled, y_train)
  train_score.append(model.score(X_train_scaled, y_train))
  test_score.append(model.score(X_test_scaled, y_test))
  print(k, model.score(X_train_scaled, y_train), model.score(X_test_scaled, y_test))
# Out:
# 1 1.0 0.3628415300546448
# 3 0.6477231329690346 0.36721311475409835
# 5 0.5912568306010929 0.4054644808743169
# 7 0.5701275045537341 0.4087431693989071
# 9 0.5551912568306011 0.40327868852459015
# 11 0.5482695810564663 0.41092896174863386
# 13 0.5355191256830601 0.4098360655737705
# 15 0.526047358834244 0.40327868852459015
# 17 0.5227686703096539 0.40437158469945356
# 19 0.5107468123861566 0.41092896174863386

# %%
plt.plot(range(1, 20, 2), train_score, marker='o')

# %%
plt.plot(range(1, 20, 2), test_score, marker="x")

# %%
data_point = [[3.1, 0, 90...]]

model1.predict(data_point)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-147-81e01a431060> in <module>
#       1 data_point = [[3.1, 0, 90]]
#       2
# ----> 3 model1.predict(data_point)
#
# ~\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py in predict(self, X)
#     173         X = check_array(X, accept_sparse='csr')
#     174
# --> 175         neigh_dist, neigh_ind = self.kneighbors(X)
#     176         classes_ = self.classes_
#     177         _y = self._y
#
# ~\anaconda3\lib\site-packages\sklearn\neighbors\_base.py in kneighbors(self, X, n_neighbors, return_distance)
#     660                 delayed_query = delayed(_tree_query_parallel_helper)
#     661                 parallel_kwargs = {"prefer": "threads"}
# --> 662             chunked_results = Parallel(n_jobs, **parallel_kwargs)(
#     663                 delayed_query(
#     664                     self._tree, X[s], n_neighbors, return_distance)
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1027             # remaining jobs.
#    1028             self._iterating = False
# -> 1029             if self.dispatch_one_batch(iterator):
#    1030                 self._iterating = self._original_iterator is not None
#    1031
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     845                 return False
#     846             else:
# --> 847                 self._dispatch(tasks)
#     848                 return True
#     849
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     763         with self._lock:
#     764             job_idx = len(self._jobs)
# --> 765             job = self._backend.apply_async(batch, callback=cb)
#     766             # A job can complete so quickly than its callback is
#     767             # called before we get here, causing self._jobs to
#
# ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self)
#     250         # change the default number of processes to -1
#     251         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 252             return [func(*args, **kwargs)
#     253                     for func, args, kwargs in self.items]
#     254
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     250         # change the default number of processes to -1
#     251         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 252             return [func(*args, **kwargs)
#     253                     for func, args, kwargs in self.items]
#     254
#
# ~\anaconda3\lib\site-packages\sklearn\neighbors\_base.py in _tree_query_parallel_helper(tree, *args, **kwargs)
#     490     under PyPy.
#     491     """
# --> 492     return tree.query(*args, **kwargs)
#     493
#     494
#
# sklearn\neighbors\_binary_tree.pxi in sklearn.neighbors._kd_tree.BinaryTree.query()
#
# ValueError: query data dimension must match training data dimension

# %% [markdown]
# # Le'ts reduce dataset

# %%
df_new1 = df[(df.City == "Quebec City, QC")&(df.City == "New Brunswick, NB")&(df.City == "Twin Cities, MN")&(df.City == "Ottawa, ON")&(df.City == "Montreal, QC")&(df.City == "Hawaii, HI")&(df.City == "Broward County, FL")&(df.City == "New Orleans, LA")&(df.City == "Austin, TX")&(df.City == "Clark County, NV")]

# %%
df_new1
# Out:
# Empty DataFrame
# Columns: [City, Date, Temperature, temp_max, temp_min, humidity, precip, snow, windspeed, conditions, Time_stamp, day, month, year]
# Index: []

# %%
df_new2 = pd.concat([df[(df.City == "Quebec City, QC")], df[(df.City == "New Brunswick, NB")]])

# %%
df_new2
# Out:
#                    City        Date  Temperature  temp_max  temp_min  \
# 1098    Quebec City, QC  2020-01-01         -3.7      -1.8      -6.6
# 1099    Quebec City, QC  2020-01-02         -2.7      -1.2      -4.0
# 1100    Quebec City, QC  2020-01-03         -0.2       1.3      -2.5
# 1101    Quebec City, QC  2020-01-04         -1.9       0.3      -3.7
# 1102    Quebec City, QC  2020-01-05         -8.1      -3.8     -14.7
# ...                 ...         ...          ...       ...       ...
# 727   New Brunswick, NB  2020-12-27         -4.9      -2.0      -7.9
# 728   New Brunswick, NB  2020-12-28         -2.9       4.3     -10.0
# 729   New Brunswick, NB  2020-12-29         -1.1       6.0      -8.4
# 730   New Brunswick, NB  2020-12-30         -6.2      -3.0      -9.0
# 731   New Brunswick, NB  2020-12-31          0.4       3.4      -2.7
#
#       humidity  precip  snow  windspeed              conditions Time_stamp  \
# 1098     86.02    8.07   0.0       12.1  Snow, Partially cloudy 2020-01-01
# 1099     81.41    2.10   0.0       11.2                    Snow 2020-01-02
# 1100     92.71    3.25   0.0        8.8  Snow, Partially cloudy 2020-01-03
# 1101     81.45    0.50   0.0       12.0                    Snow 2020-01-04
# 1102     73.14    4.86   0.0       19.9                    Snow 2020-01-05
# ...        ...     ...   ...        ...                     ...        ...
# 727      71.25    0.20   0.0       18.1                    Snow 2020-12-27
# 728      91.54    0.70   0.0       15.5                    Snow 2020-12-28
# 729      69.06    4.90   0.0       31.7                    Snow 2020-12-29
# 730      57.86    0.00   0.0       20.7                   Clear 2020-12-30
# 731      81.48   27.51   0.0       23.3                    Rain 2020-12-31
#
#       day  month  year
# 1098    1      1  2020
# 1099    2      1  2020
# 1100    3      1  2020
# 1101    4      1  2020
# 1102    5      1  2020
# ...   ...    ...   ...
# 727    27     12  2020
# 728    28     12  2020
# 729    29     12  2020
# 730    30     12  2020
# 731    31     12  2020
#
# [732 rows x 14 columns]

# %%
df_new3 = df[df.City.isin(["Quebec City, QC", "New Brunswick, NB", "Twin Cities, MN", "Ottawa, ON", "Montreal, QC", "Hawaii, HI", "Broward County, FL", "New Orleans, LA", "Austin, TX", "Clark County, NV"])]

# %%
df_new3
# Out:
#                   City        Date  Temperature  temp_max  temp_min  humidity  \
# 0         Montreal, QC  2020-01-01          0.2       1.1      -0.8     87.84
# 1         Montreal, QC  2020-01-02          0.9       2.6      -1.0     78.70
# 2         Montreal, QC  2020-01-03          4.8       5.8       2.8     74.88
# 3         Montreal, QC  2020-01-04          0.5       3.2      -1.9     78.79
# 4         Montreal, QC  2020-01-05         -5.3      -1.8      -9.9     69.09
# ...                ...         ...          ...       ...       ...       ...
# 12439  Twin Cities, MN  2020-12-27         -5.8      -4.2      -9.6     82.43
# 12440  Twin Cities, MN  2020-12-28         -9.0      -4.5     -13.8     77.48
# 12441  Twin Cities, MN  2020-12-29        -10.1      -5.5     -16.7     83.29
# 12442  Twin Cities, MN  2020-12-30         -5.3      -4.2      -9.1     76.69
# 12443  Twin Cities, MN  2020-12-31         -8.5      -5.7     -12.3     84.88
#
#        precip  snow  windspeed              conditions Time_stamp  day  month  \
# 0        5.71  0.00        7.9                    Rain 2020-01-01    1      1
# 1        0.00  0.00        7.7                   Clear 2020-01-02    2      1
# 2        0.00  0.00        7.6                   Clear 2020-01-03    3      1
# 3        2.27  0.00       11.2                    Rain 2020-01-04    4      1
# 4        0.76  3.88       13.1                    Snow 2020-01-05    5      1
# ...       ...   ...        ...                     ...        ...  ...    ...
# 12439    0.28  1.25       20.1          Snow, Overcast 2020-12-27   27     12
# 12440    0.00  0.75       16.9  Snow, Partially cloudy 2020-12-28   28     12
# 12441    2.44  2.44       20.2  Snow, Partially cloudy 2020-12-29   29     12
# 12442    0.18  1.57       25.2          Snow, Overcast 2020-12-30   30     12
# 12443    0.00  0.52       18.2  Snow, Partially cloudy 2020-12-31   31     12
#
#        year
# 0      2020
# 1      2020
# 2      2020
# 3      2020
# 4      2020
# ...     ...
# 12439  2020
# 12440  2020
# 12441  2020
# 12442  2020
# 12443  2020
#
# [3660 rows x 14 columns]
