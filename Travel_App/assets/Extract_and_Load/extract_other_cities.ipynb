# %%
import pandas as pd
import os

# %%
df1 = pd.read_csv(os.path.join("melbourne_listings.csv"))
df1.insert(0,'city','Melbourne, AU')
df1.head(3)
# Out:
#             city     id                                           name  \
# 0  Melbourne, AU   9835                         Beautiful Room & House
# 1  Melbourne, AU  10803  Room in Cool Deco Apartment in Brunswick East
# 2  Melbourne, AU  12936         St Kilda 1BR+BEACHSIDE+BALCONY+WIFI+AC
#
#    host_id     host_name  neighbourhood_group neighbourhood  latitude  \
# 0    33057         Manju                  NaN    Manningham -37.77268
# 1    38901       Lindsay                  NaN      Moreland -37.76651
# 2    50121  The A2C Team                  NaN  Port Phillip -37.85999
#
#    longitude        room_type  price  minimum_nights  number_of_reviews  \
# 0  145.09213     Private room     60               1                  4
# 1  144.98074     Private room     28               4                145
# 2  144.97662  Entire home/apt     95               3                 42
#
#   last_review  reviews_per_month  calculated_host_listings_count  \
# ...

# %%
df2 = pd.read_csv(os.path.join("rio_de_janeiro_listings.csv"))
df2.insert(0,'city','Rio de Janeiro, BR')
df2.head(3)
# Out:
#                  city     id  \
# 0  Rio de Janeiro, BR  17878
# 1  Rio de Janeiro, BR  24480
# 2  Rio de Janeiro, BR  25026
#
#                                                 name  host_id host_name  \
# 0  Very Nice 2Br in Copacabana w. balcony, fast WiFi    68997  Matthias
# 1                   Nice and cozy near Ipanema Beach    99249      Goya
# 2          Beautiful Modern Decorated Studio in Copa  3746246  Ghizlane
#
#    neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0                  NaN    Copacabana -22.96592  -43.17896  Entire home/apt
# 1                  NaN       Ipanema -22.98570  -43.20193  Entire home/apt
# 2                  NaN    Copacabana -22.97712  -43.19045  Entire home/apt
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0    221               5                260  2021-02-08               2.01
# 1    307               3                 85  2018-02-14               0.67
# ...

# %%
df3 = pd.read_csv(os.path.join("mexico_city_listings.csv"))
df3.insert(0,'city','Mexico City, ME')
df3.head(3)
# Out:
#               city     id                                  name  host_id  \
# 0  Mexico City, ME  35797                           Villa Dante   153786
# 1  Mexico City, ME  44616                     CONDESA HAUS  B&B   196253
# 2  Mexico City, ME  56074  Great space in historical San Rafael   265650
#
#                             host_name  neighbourhood_group  \
# 0                                Dici                  NaN
# 1  Condesa Haus Bed & Breakfast  CDMX                  NaN
# 2                               Maris                  NaN
#
#            neighbourhood  latitude  longitude        room_type  price  \
# 0  Cuajimalpa de Morelos  19.38399  -99.27335  Entire home/apt   4088
# 1             Cuauhtémoc  19.41006  -99.17645  Entire home/apt   7293
# 2             Cuauhtémoc  19.43778  -99.15549  Entire home/apt    600
#
#    minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0               1                  0         NaN                NaN
# ...

# %%
df4 = pd.read_csv(os.path.join("cape_town_listings.csv"))
df4.insert(0,'city','Cape Town, RSA')
df4.head(3)
# Out:
#              city     id                     name  host_id host_name  \
# 0  Cape Town, RSA   3191  Malleson Garden Cottage     3754  Brigitte
# 1  Cape Town, RSA  15007         Blaauwberg House    59072      Dirk
# 2  Cape Town, RSA  15068               Grande Bay    59318     Linda
#
#    neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0                  NaN       Ward 57 -33.94739   18.47600  Entire home/apt
# 1                  NaN       Ward 23 -33.80001   18.46063  Entire home/apt
# 2                  NaN       Ward 23 -33.78799   18.46082  Entire home/apt
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0    497               3                 54  2020-03-07               0.57
# 1   2408               2                 29  2021-01-05               0.33
# 2   2800               4                  0         NaN                NaN
#
#    calculated_host_listings_count  availability_365
# ...

# %%
df5 = pd.read_csv(os.path.join("porto_listings.csv"))
df5.insert(0,'city','Porto, PT')
df5.head(3)
# Out:
#         city     id                                               name  \
# 0  Porto, PT  41339                       Porto city flat near the sea
# 1  Porto, PT  42462                  Large Penthouse in Vila Nova Gaia
# 2  Porto, PT  55111  Fontielas Houses |Floor1 in House with shared ...
#
#    host_id      host_name neighbourhood_group                 neighbourhood  \
# 0   180050          Paula               PORTO  Lordelo do Ouro e Massarelos
# 1   185492       Gabriela   VILA NOVA DE GAIA   Mafamude e Vilar do Paraíso
# 2   259711  Isabel E João             PAREDES                          Cete
#
#    latitude  longitude        room_type  price  minimum_nights  \
# 0  41.15010   -8.66035  Entire home/apt     75               5
# 1  41.10739   -8.59430  Entire home/apt     73              30
# 2  41.17481   -8.35362  Entire home/apt     66               3
#
#    number_of_reviews last_review  reviews_per_month  \
# 0                 17  2018-09-28               0.18
# ...

# %%
df6 = pd.read_csv(os.path.join("buenos_aires_listings.csv"))
df6.insert(0,'city','Buenos Aires, AR')
df6.head(3)
# Out:
#                city     id                                 name  host_id  \
# 0  Buenos Aires, AR   6283                          Casa Al Sur    13310
# 1  Buenos Aires, AR  11508   Amazing Luxurious Apt-Palermo Soho    42762
# 2  Buenos Aires, AR  12463  Room in Recoleta - awesome location    48799
#
#   host_name  neighbourhood_group neighbourhood  latitude  longitude  \
# 0    Pamela                  NaN     Balvanera -34.60367  -58.40875
# 1   Candela                  NaN       Palermo -34.58184  -58.42415
# 2      Matt                  NaN      Recoleta -34.59761  -58.39468
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0  Entire home/apt   4473               3                  1  2011-01-31
# 1  Entire home/apt   5368               2                 26  2019-11-28
# 2     Private room   2415               1                 20  2017-12-11
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# ...

# %%
df7 = pd.read_csv(os.path.join("santiago_listings.csv"))
df7.insert(0,'city','Santiago, CH')
df7.head(3)
# Out:
#            city     id                             name  host_id host_name  \
# 0  Santiago, CH  14576           Dp Valen Castillo 1600    14972     Bruno
# 1  Santiago, CH  30950  Apartment Providencia, Santiago   132845    Pamela
# 2  Santiago, CH  47936               My Flat in English   218471     Nelsk
#
#    neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0                  NaN      Santiago -33.46413  -70.64869  Entire home/apt
# 1                  NaN   Providencia -33.43174  -70.61845  Entire home/apt
# 2                  NaN      Santiago -33.44791  -70.63547     Private room
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0  70862               5                  0         NaN                NaN
# 1  30714               5                  9  2021-01-03               0.21
# 2  38974               1                  0         NaN                NaN
#
#    calculated_host_listings_count  availability_365
# ...

# %%
# compile the list of dataframes to merge
data_frames = [df1, df2, df3, df4, df5, df6, df7]

# %%
Final_df = pd.concat(data_frames)

# %%
Final_df
# Out:
#                 city        id  \
# 0      Melbourne, AU      9835
# 1      Melbourne, AU     10803
# 2      Melbourne, AU     12936
# 3      Melbourne, AU     38271
# 4      Melbourne, AU     41836
# ...              ...       ...
# 11676   Santiago, CH  48282407
# 11677   Santiago, CH  48282455
# 11678   Santiago, CH  48282944
# 11679   Santiago, CH  48286053
# 11680   Santiago, CH  48287530
#
#                                                     name    host_id  \
# 0                                 Beautiful Room & House      33057
# 1          Room in Cool Deco Apartment in Brunswick East      38901
# 2                 St Kilda 1BR+BEACHSIDE+BALCONY+WIFI+AC      50121
# 3                     Melbourne - Old Trafford Apartment     164193
# 4                      CLOSE TO CITY & MELBOURNE AIRPORT     182833
# ...                                                  ...        ...
# 11676    "Habitación con baño privado,  seguro y bonito"  104252261
# ...

# %%
# MONICA
#City	Host Name	Neighbourhood	Latitude	Longitude	Property Type	Room 
#Type	Price	Minimum Nights	Availability 365	Reviews Scores Rating

# %%
Final_df.columns
# Out:
# Index(['city', 'id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
other_cities = Final_df[['city', 'host_name', 'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
       'minimum_nights', 'availability_365']]

# %%
other_cities.head()
# Out:
#             city     host_name neighbourhood  latitude  longitude  \
# 0  Melbourne, AU         Manju    Manningham -37.77268  145.09213
# 1  Melbourne, AU       Lindsay      Moreland -37.76651  144.98074
# 2  Melbourne, AU  The A2C Team  Port Phillip -37.85999  144.97662
# 3  Melbourne, AU   Daryl & Dee         Casey -38.05725  145.33936
# 4  Melbourne, AU         Diana       Darebin -37.69729  145.00082
#
#          room_type  price  minimum_nights  availability_365
# 0     Private room     60               1                 1
# 1     Private room     28               4                 0
# 2  Entire home/apt     95               3                 0
# 3  Entire home/apt     99               1               296
# 4     Private room     40               7                 0

# %%
other_cities['city'].unique()
# Out:
# array(['Melbourne, AU', 'Rio de Janeiro, BR', 'Mexico City, ME',
#        'Cape Town, RSA', 'Porto, PT', 'Buenos Aires, AR', 'Santiago, CH'],
#       dtype=object)

# %%
# Converting df to csv
other_cities.to_csv("other_cities.csv", index=False)
