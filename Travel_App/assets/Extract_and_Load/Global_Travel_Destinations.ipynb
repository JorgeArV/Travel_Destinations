# %%
import pandas as pd

# %%
# %run Airbnb_Combined_Dataset.ipynb
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (67) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
# %run Outside_North_America.ipynb
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4125: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
other_cities
# Out:
#                 City     Host Name Neighbourhood   Latitude   Longitude  \
# 0      Melbourne, AU         Manju    Manningham -37.772680  145.092130
# 1      Melbourne, AU       Lindsay      Moreland -37.766510  144.980740
# 2      Melbourne, AU  The A2C Team  Port Phillip -37.859990  144.976620
# 3      Melbourne, AU   Daryl & Dee         Casey -38.057250  145.339360
# 4      Melbourne, AU         Diana       Darebin -37.697290  145.000820
# ...              ...           ...           ...        ...         ...
# 11676   Santiago, CH         Lercy         Ñuñoa -33.447560  -70.602660
# 11677   Santiago, CH         Lynda   Providencia -33.423320  -70.608910
# 11678   Santiago, CH        Felipe    Las Condes -33.417040  -70.597040
# 11679   Santiago, CH      Fernanda      La Reina -33.458125  -70.526992
# 11680   Santiago, CH       Angel J      Santiago -33.446999  -70.640088
#
#                    Property Type        Room Type       Price  Minimum Nights  \
# ...

# %%
GlobalDestinations = pd.concat([NorthAmerica, other_cities])
GlobalDestinations
# Out:
#                City Host Name              Neighbourhood   Latitude  \
# 0       Montreal,QC     Nelia      Le Plateau-Mont-Royal  45.530690
# 1       Montreal,QC  Maryline                Ville-Marie  45.519390
# 2       Montreal,QC  Maryline                Ville-Marie  45.519290
# 3       Montreal,QC      Gail               Le Sud-Ouest  45.484670
# 4       Montreal,QC     Alain  Rosemont-La Petite-Patrie  45.538400
# ...             ...       ...                        ...        ...
# 11676  Santiago, CH     Lercy                      Ñuñoa -33.447560
# 11677  Santiago, CH     Lynda                Providencia -33.423320
# 11678  Santiago, CH    Felipe                 Las Condes -33.417040
# 11679  Santiago, CH  Fernanda                   La Reina -33.458125
# 11680  Santiago, CH   Angel J                   Santiago -33.446999
#
#        Longitude              Property Type        Room Type       Price  \
# 0     -73.585880      Private room in house     Private room      $38.00
# ...

# %%
GlobalDestinations['Price'] = GlobalDestinations['Price'].str.replace('$','')
GlobalDestinations['Price'] = GlobalDestinations['Price'].str.replace(',','')
GlobalDestinations['Price'] = pd.to_numeric(GlobalDestinations['Price'])

# %%
GlobalDestinations.dtypes
# Out:
# City                      object
# Host Name                 object
# Neighbourhood             object
# Latitude                 float64
# Longitude                float64
# Property Type             object
# Room Type                 object
# Price                    float64
# Minimum Nights             int64
# Availability 365           int64
# Reviews Scores Rating    float64
# dtype: object

# %%
GlobalDestinations.dropna()
# Out:
#                City Host Name              Neighbourhood  Latitude  Longitude  \
# 0       Montreal,QC     Nelia      Le Plateau-Mont-Royal  45.53069  -73.58588
# 1       Montreal,QC  Maryline                Ville-Marie  45.51939  -73.56482
# 2       Montreal,QC  Maryline                Ville-Marie  45.51929  -73.56493
# 3       Montreal,QC      Gail               Le Sud-Ouest  45.48467  -73.57995
# 4       Montreal,QC     Alain  Rosemont-La Petite-Patrie  45.53840  -73.60355
# ...             ...       ...                        ...       ...        ...
# 11597  Santiago, CH    Matías                Providencia -33.44333  -70.60766
# 11602  Santiago, CH   Ricardo                   Santiago -33.43806  -70.66085
# 11646  Santiago, CH    Felipe                   Santiago -33.43772  -70.64580
# 11658  Santiago, CH   Soledad                   Santiago -33.44305  -70.64260
# 11661  Santiago, CH     Piero                   Recoleta -33.43347  -70.63638
#
# ...

# %%
FinalDataSet = GlobalDestinations.dropna()
FinalDataSet
# Out:
#                City Host Name              Neighbourhood  Latitude  Longitude  \
# 0       Montreal,QC     Nelia      Le Plateau-Mont-Royal  45.53069  -73.58588
# 1       Montreal,QC  Maryline                Ville-Marie  45.51939  -73.56482
# 2       Montreal,QC  Maryline                Ville-Marie  45.51929  -73.56493
# 3       Montreal,QC      Gail               Le Sud-Ouest  45.48467  -73.57995
# 4       Montreal,QC     Alain  Rosemont-La Petite-Patrie  45.53840  -73.60355
# ...             ...       ...                        ...       ...        ...
# 11597  Santiago, CH    Matías                Providencia -33.44333  -70.60766
# 11602  Santiago, CH   Ricardo                   Santiago -33.43806  -70.66085
# 11646  Santiago, CH    Felipe                   Santiago -33.43772  -70.64580
# 11658  Santiago, CH   Soledad                   Santiago -33.44305  -70.64260
# 11661  Santiago, CH     Piero                   Recoleta -33.43347  -70.63638
#
# ...

# %%
FinalDataSet.to_csv('FinalAirbnb.csv')
